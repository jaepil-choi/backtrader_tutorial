# %%
# %matplotlib inline 
# inline plot만 하면 된다. 

# %matplotlib ipympl
# %matplotlib widget

# %% [markdown]
# # Backtrader: Quick Start
#
# https://www.backtrader.com/docu/quickstart/quickstart/

# %% [markdown]
# ## Basic Setup

# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

from IPython.core.debugger import set_trace

import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %%
if __name__ == '__main__':
    cerebro = bt.Cerebro() # The Cerebro engine was instantiated
    print('Starting portfolio value: %.2f' % cerebro.broker.getvalue())
    
    cerebro.run() # The resulting cerebro instance was told to run (loop over data)
    print('Final portfolio value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting portfolio value: 10000.00
# Final portfolio value: 10000.00

# %% [markdown]
# Although it doesn’t seem much, let’s point out something explicitly shown:
#
# The Cerebro engine has created a broker instance in the background
#
# The instance already has some cash to start with
#
# This behind the scenes broker instantiation is a constant trait in the platform to simplify the life of the user. If no broker is set by the user, a default one is put in place.
#
# And 10K monetary units is a usual value with some brokers to begin with.

# %% [markdown]
# ## Setting the cash

# %%
if __name__ == '__main__':
    cerebro = bt.Cerebro()
    cerebro.broker.setcash(1000000.0) # Set custom start cash. 
    print('Starting portfolio value: %.2f' % cerebro.broker.getvalue())
    
    cerebro.run() 
    print('Final portfolio value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting portfolio value: 1000000.00
# Final portfolio value: 1000000.00

# %% [markdown]
# ## Adding a Data Feed
#
# Having cash is fun, but the purpose behind all this is to let an automated strategy multiply the cash without moving a finger by operating on an asset which we see as a Data Feed

# %%
# Add data directly from Yahoo finance using pandas-datareader

start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2020, 1, 10)

data = web.DataReader('AAPL', 'yahoo', start, end)
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# 2020-01-09  310.429993  306.200012  307.239990  309.630005  42527100.0
# 2020-01-10  312.670013  308.250000  310.600006  310.329987  35161200.0
#
#              Adj Close
# Date
# 2020-01-06  299.799988
# 2020-01-07  298.390015
# 2020-01-08  303.190002
# 2020-01-09  309.630005
# 2020-01-10  310.329987

# %%
# To OHLC + Adj CLose + V format

data = data[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-06  293.790009  299.959991  292.750000  299.799988  299.799988
# 2020-01-07  299.839996  300.899994  297.480011  298.390015  298.390015
# 2020-01-08  297.160004  304.440002  297.160004  303.190002  303.190002
# 2020-01-09  307.239990  310.429993  306.200012  309.630005  309.630005
# 2020-01-10  310.600006  312.670013  308.250000  310.329987  310.329987
#
#                 Volume
# Date
# 2020-01-06  29596800.0
# 2020-01-07  27218000.0
# 2020-01-08  33019800.0
# 2020-01-09  42527100.0
# 2020-01-10  35161200.0

# %%
data.to_csv('AAPL.csv', index=1)

# %%
os.getcwd()
# Out:
# 'E:\\VSCodeProjects\\backtrader_tutorial'

# %%
datapath = os.path.join(os.getcwd(), './AAPL.csv')
datapath
# Out:
# 'E:\\VSCodeProjects\\backtrader_tutorial\\./AAPL.csv'

# %%
os.path.isfile(datapath)
# Out:
# True

# %% [markdown]
# Yahoo Online sends the CSV data in date descending order, which is not the standard convention. The reversed=True prameter takes into account that the CSV data in the file has already been reversed and has the standard expected date ascending order.

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    
#     modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
#     datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')
    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        reverse=False) # Yahoo data는 보통의 데이터와 반대이다. 

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# Final Portfolio Value: 100000.00

# %% [markdown]
# ## Our First Strategy
#
# The cash is in the broker and the Data Feed is there. It seems like risky business is just around the corner.
#
# Let’s put a Strategy into the equation and print the “Close” price of each day (bar).
#
# DataSeries (the underlying class in Data Feeds) objects have aliases to access the well known OHLC (Open High Low Close) daily values. This should ease up the creation of our printing logic.

# %%
a = None
b = 2
c = a or b
c
# Out:
# 2

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
#         print(self.datas) # [<backtrader.feeds.yahoo.YahooFinanceCSVData object at 0x0000022A079EA488>] 이러한 object가 들어있다. 
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close # close 데이터 모음. .datas[0].close[0] 이면 처음, [-1]이면 바로 이전 이런 식. 

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

# %% [markdown]
# Let’s explain some of the magic:
#
# - Upon init being called the strategy already has a list of datas that are present in the platform. This is a standard Python list and datas can be accessed in the order they were inserted. The first data in the list `self.datas[0]` is the default data for trading operations and to keep all strategy elements synchronized (it’s the system clock)
#
# - `self.dataclose = self.datas[0].close` keeps a reference to the close line. Only one level of indirection is later needed to access the close values.
#
# - The strategy `next` method will be called on each bar of the system clock (`self.datas[0]`). This is true until other things come into play like indicators, which need some bars to start producing an output. More on that later.

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2015-01-02, Close, 100.45
# 2015-01-05, Close, 97.62
# 2015-01-06, Close, 97.63
# 2015-01-07, Close, 99.00
# 2015-01-08, Close, 102.81
# 2015-01-09, Close, 102.92
# 2015-01-12, Close, 100.38
# 2015-01-13, Close, 101.27
# 2015-01-14, Close, 100.89
# 2015-01-15, Close, 98.15
# 2015-01-16, Close, 97.39
# 2015-01-20, Close, 99.89
# 2015-01-21, Close, 100.66
# 2015-01-22, Close, 103.28
# 2015-01-23, Close, 103.81
# 2015-01-26, Close, 103.92
# 2015-01-27, Close, 100.28
# 2015-01-28, Close, 105.95
# 2015-01-29, Close, 109.25
# 2015-01-30, Close, 107.65
# 2015-02-02, Close, 109.00
# 2015-02-03, Close, 109.02
# 2015-02-04, Close, 109.85
# 2015-02-05, Close, 110.64
# 2015-02-06, Close, 109.71
# 2015-02-09, Close, 110.43
# 2015-02-10, Close, 112.56
# 2015-02-11, Close, 115.19
# 2015-02-12, Close, 116.65
# 2015-02-13, Close, 117.22
# 2015-02-17, Close, 117.92
# 2015-02-18, Close, 118.74
# 2015-02-19, Close, 118.49
# 2015-02-20, Close, 119.46
# 2015-02-23, Close, 122.68
# 2015-02-24, Close, 121.92
# 2015-02-25, Close, 118.80
# 2015-02-26, Close, 120.31
# 2015-02-27, Close, 118.50
# 2015-03-02, Close, 119.08
# 2015-03-03, Close, 119.33
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-18, Close, 118.51
# 2015-03-19, Close, 117.61
# 2015-03-20, Close, 116.14
# 2015-03-23, Close, 117.34
# 2015-03-24, Close, 116.86
# 2015-03-25, Close, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-07, Close, 116.24
# 2015-04-08, Close, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-10, Close, 117.24
# 2015-04-13, Close, 117.01
# 2015-04-14, Close, 116.50
# 2015-04-15, Close, 116.95
# 2015-04-16, Close, 116.38
# 2015-04-17, Close, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-21, Close, 117.07
# 2015-04-22, Close, 118.64
# 2015-04-23, Close, 119.61
# 2015-04-24, Close, 120.18
# 2015-04-27, Close, 122.36
# 2015-04-28, Close, 120.43
# 2015-04-29, Close, 118.66
# 2015-04-30, Close, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-04, Close, 118.72
# 2015-05-05, Close, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-15, Close, 119.28
# 2015-05-18, Close, 120.59
# 2015-05-19, Close, 120.48
# 2015-05-20, Close, 120.47
# 2015-05-21, Close, 121.71
# 2015-05-22, Close, 122.77
# 2015-05-26, Close, 120.07
# 2015-05-27, Close, 122.31
# 2015-05-28, Close, 122.07
# 2015-05-29, Close, 120.68
# 2015-06-01, Close, 120.92
# 2015-06-02, Close, 120.38
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-09, Close, 118.03
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-29, Close, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-08, Close, 113.54
# 2015-07-09, Close, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-14, Close, 116.35
# 2015-07-15, Close, 117.47
# 2015-07-16, Close, 119.04
# 2015-07-17, Close, 120.07
# 2015-07-20, Close, 122.34
# 2015-07-21, Close, 121.11
# 2015-07-22, Close, 115.99
# 2015-07-23, Close, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-31, Close, 112.36
# 2015-08-03, Close, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-20, Close, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-28, Close, 105.42
# 2015-08-31, Close, 104.92
# 2015-09-01, Close, 100.23
# 2015-09-02, Close, 104.53
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-09, Close, 102.49
# 2015-09-10, Close, 104.75
# 2015-09-11, Close, 106.27
# 2015-09-14, Close, 107.29
# 2015-09-15, Close, 108.20
# 2015-09-16, Close, 108.32
# 2015-09-17, Close, 106.00
# 2015-09-18, Close, 105.56
# 2015-09-21, Close, 107.20
# 2015-09-22, Close, 105.52
# 2015-09-23, Close, 106.37
# 2015-09-24, Close, 107.01
# 2015-09-25, Close, 106.74
# 2015-09-28, Close, 104.62
# 2015-09-29, Close, 101.48
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-08, Close, 101.89
# 2015-10-09, Close, 104.33
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-16, Close, 103.32
# 2015-10-19, Close, 103.96
# 2015-10-20, Close, 105.86
# 2015-10-21, Close, 105.85
# 2015-10-22, Close, 107.47
# 2015-10-23, Close, 110.80
# 2015-10-26, Close, 107.27
# 2015-10-27, Close, 106.59
# 2015-10-28, Close, 110.98
# 2015-10-29, Close, 112.15
# 2015-10-30, Close, 111.19
# 2015-11-02, Close, 112.76
# 2015-11-03, Close, 114.05
# 2015-11-04, Close, 113.52
# 2015-11-05, Close, 113.00
# 2015-11-06, Close, 113.13
# 2015-11-09, Close, 112.67
# 2015-11-10, Close, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-20, Close, 111.48
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-25, Close, 110.30
# 2015-11-27, Close, 110.09
# 2015-11-30, Close, 110.55
# 2015-12-01, Close, 109.65
# 2015-12-02, Close, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-07, Close, 110.53
# 2015-12-08, Close, 110.48
# 2015-12-09, Close, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-05, Close, 88.34
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-11, Close, 88.04
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-17, Close, 92.19
# 2016-02-18, Close, 90.44
# 2016-02-19, Close, 90.23
# 2016-02-22, Close, 91.02
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-25, Close, 90.91
# 2016-02-26, Close, 91.05
# 2016-02-29, Close, 90.84
# 2016-03-01, Close, 94.45
# 2016-03-02, Close, 94.66
# 2016-03-03, Close, 95.36
# 2016-03-04, Close, 96.78
# 2016-03-07, Close, 95.71
# 2016-03-08, Close, 94.92
# 2016-03-09, Close, 95.01
# 2016-03-10, Close, 95.05
# 2016-03-11, Close, 96.08
# 2016-03-14, Close, 96.32
# 2016-03-15, Close, 98.26
# 2016-03-16, Close, 99.56
# 2016-03-17, Close, 99.40
# 2016-03-18, Close, 99.52
# 2016-03-21, Close, 99.51
# 2016-03-22, Close, 100.27
# 2016-03-23, Close, 99.71
# 2016-03-24, Close, 99.28
# 2016-03-28, Close, 98.83
# 2016-03-29, Close, 101.17
# 2016-03-30, Close, 102.94
# 2016-03-31, Close, 102.40
# 2016-04-01, Close, 103.34
# 2016-04-04, Close, 104.40
# 2016-04-05, Close, 103.17
# 2016-04-06, Close, 104.25
# 2016-04-07, Close, 101.98
# 2016-04-08, Close, 102.09
# 2016-04-11, Close, 102.43
# 2016-04-12, Close, 103.76
# 2016-04-13, Close, 105.27
# 2016-04-14, Close, 105.32
# 2016-04-15, Close, 103.21
# 2016-04-18, Close, 100.98
# 2016-04-19, Close, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-27, Close, 91.91
# 2016-04-28, Close, 89.10
# 2016-04-29, Close, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-06, Close, 87.64
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-17, Close, 88.37
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-06-01, Close, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-05, Close, 89.79
# 2016-07-06, Close, 90.30
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-25, Close, 92.01
# 2016-07-26, Close, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-28, Close, 98.63
# 2016-07-29, Close, 98.51
# 2016-08-01, Close, 100.25
# 2016-08-02, Close, 98.76
# 2016-08-03, Close, 100.00
# 2016-08-04, Close, 100.62
# 2016-08-05, Close, 102.15
# 2016-08-08, Close, 102.99
# 2016-08-09, Close, 103.41
# 2016-08-10, Close, 102.64
# 2016-08-11, Close, 102.57
# 2016-08-12, Close, 102.81
# 2016-08-15, Close, 104.05
# 2016-08-16, Close, 103.95
# 2016-08-17, Close, 103.80
# 2016-08-18, Close, 103.67
# 2016-08-19, Close, 103.93
# 2016-08-22, Close, 103.13
# 2016-08-23, Close, 103.45
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-26, Close, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-14, Close, 106.22
# 2016-09-15, Close, 109.84
# 2016-09-16, Close, 109.22
# 2016-09-19, Close, 107.94
# 2016-09-20, Close, 107.94
# 2016-09-21, Close, 107.92
# 2016-09-22, Close, 108.93
# 2016-09-23, Close, 107.12
# 2016-09-26, Close, 107.28
# 2016-09-27, Close, 107.48
# 2016-09-28, Close, 108.30
# 2016-09-29, Close, 106.61
# 2016-09-30, Close, 107.44
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-07, Close, 108.40
# 2016-10-10, Close, 110.29
# 2016-10-11, Close, 110.53
# 2016-10-12, Close, 111.52
# 2016-10-13, Close, 111.18
# 2016-10-14, Close, 111.79
# 2016-10-17, Close, 111.72
# 2016-10-18, Close, 111.64
# 2016-10-19, Close, 111.31
# 2016-10-20, Close, 111.25
# 2016-10-21, Close, 110.81
# 2016-10-24, Close, 111.81
# 2016-10-25, Close, 112.38
# 2016-10-26, Close, 109.85
# 2016-10-27, Close, 108.80
# 2016-10-28, Close, 108.08
# 2016-10-31, Close, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-18, Close, 105.14
# 2016-11-21, Close, 106.73
# 2016-11-22, Close, 106.80
# 2016-11-23, Close, 106.25
# 2016-11-25, Close, 106.79
# 2016-11-28, Close, 106.58
# 2016-11-29, Close, 106.47
# 2016-11-30, Close, 105.58
# 2016-12-01, Close, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-08, Close, 107.10
# 2016-12-09, Close, 108.85
# 2016-12-12, Close, 108.23
# 2016-12-13, Close, 110.04
# 2016-12-14, Close, 110.04
# 2016-12-15, Close, 110.64
# 2016-12-16, Close, 110.78
# 2016-12-19, Close, 111.42
# 2016-12-20, Close, 111.72
# 2016-12-21, Close, 111.82
# 2016-12-22, Close, 111.09
# 2016-12-23, Close, 111.31
# 2016-12-27, Close, 112.01
# 2016-12-28, Close, 111.54
# 2016-12-29, Close, 111.51
# 2016-12-30, Close, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-06, Close, 112.64
# 2017-01-09, Close, 113.67
# 2017-01-10, Close, 113.78
# 2017-01-11, Close, 114.39
# 2017-01-12, Close, 113.92
# 2017-01-13, Close, 113.71
# 2017-01-17, Close, 114.63
# 2017-01-18, Close, 114.62
# 2017-01-19, Close, 114.42
# 2017-01-20, Close, 114.63
# 2017-01-23, Close, 114.71
# 2017-01-24, Close, 114.60
# 2017-01-25, Close, 116.43
# 2017-01-26, Close, 116.48
# 2017-01-27, Close, 116.49
# 2017-01-30, Close, 116.19
# 2017-01-31, Close, 115.92
# 2017-02-01, Close, 122.99
# 2017-02-02, Close, 122.78
# 2017-02-03, Close, 123.31
# 2017-02-06, Close, 124.46
# 2017-02-07, Close, 125.65
# 2017-02-08, Close, 126.13
# 2017-02-09, Close, 127.04
# 2017-02-10, Close, 126.76
# 2017-02-13, Close, 127.88
# 2017-02-14, Close, 129.54
# 2017-02-15, Close, 130.01
# 2017-02-16, Close, 129.86
# 2017-02-17, Close, 130.21
# 2017-02-21, Close, 131.15
# 2017-02-22, Close, 131.54
# 2017-02-23, Close, 130.99
# 2017-02-24, Close, 131.11
# 2017-02-27, Close, 131.37
# 2017-02-28, Close, 131.43
# 2017-03-01, Close, 134.12
# 2017-03-02, Close, 133.32
# 2017-03-03, Close, 134.11
# 2017-03-06, Close, 133.68
# 2017-03-07, Close, 133.86
# 2017-03-08, Close, 133.36
# 2017-03-09, Close, 133.05
# 2017-03-10, Close, 133.49
# 2017-03-13, Close, 133.55
# 2017-03-14, Close, 133.35
# 2017-03-15, Close, 134.76
# 2017-03-16, Close, 134.98
# 2017-03-17, Close, 134.31
# 2017-03-20, Close, 135.72
# 2017-03-21, Close, 134.16
# 2017-03-22, Close, 135.68
# 2017-03-23, Close, 135.20
# 2017-03-24, Close, 134.93
# 2017-03-27, Close, 135.16
# 2017-03-28, Close, 137.96
# 2017-03-29, Close, 138.27
# 2017-03-30, Close, 138.09
# 2017-03-31, Close, 137.83
# 2017-04-03, Close, 137.87
# 2017-04-04, Close, 138.89
# 2017-04-05, Close, 138.17
# 2017-04-06, Close, 137.83
# 2017-04-07, Close, 137.52
# 2017-04-10, Close, 137.36
# 2017-04-11, Close, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-25, Close, 138.66
# 2017-04-26, Close, 137.85
# 2017-04-27, Close, 137.95
# 2017-04-28, Close, 137.82
# 2017-05-01, Close, 140.63
# 2017-05-02, Close, 141.52
# 2017-05-03, Close, 141.09
# 2017-05-04, Close, 140.58
# 2017-05-05, Close, 142.91
# 2017-05-08, Close, 146.80
# 2017-05-09, Close, 147.74
# 2017-05-10, Close, 147.04
# 2017-05-11, Close, 148.31
# 2017-05-12, Close, 150.38
# 2017-05-15, Close, 150.00
# 2017-05-16, Close, 149.77
# 2017-05-17, Close, 144.75
# 2017-05-18, Close, 146.95
# 2017-05-19, Close, 147.45
# 2017-05-22, Close, 148.35
# 2017-05-23, Close, 148.17
# 2017-05-24, Close, 147.72
# 2017-05-25, Close, 148.23
# 2017-05-26, Close, 147.98
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-05, Close, 148.29
# 2017-06-06, Close, 148.79
# 2017-06-07, Close, 149.68
# 2017-06-08, Close, 149.31
# 2017-06-09, Close, 143.52
# 2017-06-12, Close, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-11, Close, 140.20
# 2017-07-12, Close, 140.40
# 2017-07-13, Close, 142.36
# 2017-07-14, Close, 143.58
# 2017-07-17, Close, 144.08
# 2017-07-18, Close, 144.58
# 2017-07-19, Close, 145.49
# 2017-07-20, Close, 144.83
# 2017-07-21, Close, 144.76
# 2017-07-24, Close, 146.52
# 2017-07-25, Close, 147.14
# 2017-07-26, Close, 147.84
# 2017-07-27, Close, 145.04
# 2017-07-28, Close, 144.02
# 2017-07-31, Close, 143.28
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-03, Close, 149.87
# 2017-08-04, Close, 150.66
# 2017-08-07, Close, 152.99
# 2017-08-08, Close, 154.22
# 2017-08-09, Close, 155.16
# 2017-08-10, Close, 150.22
# 2017-08-11, Close, 152.31
# 2017-08-14, Close, 154.60
# 2017-08-15, Close, 156.29
# 2017-08-16, Close, 155.66
# 2017-08-17, Close, 152.67
# 2017-08-18, Close, 152.33
# 2017-08-21, Close, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-23, Close, 154.72
# 2017-08-24, Close, 154.04
# 2017-08-25, Close, 154.61
# 2017-08-28, Close, 156.17
# 2017-08-29, Close, 157.56
# 2017-08-30, Close, 157.98
# 2017-08-31, Close, 158.61
# 2017-09-01, Close, 158.66
# 2017-09-05, Close, 156.76
# 2017-09-06, Close, 156.59
# 2017-09-07, Close, 155.96
# 2017-09-08, Close, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-22, Close, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-06, Close, 150.20
# 2017-10-09, Close, 150.72
# 2017-10-10, Close, 150.78
# 2017-10-11, Close, 151.41
# 2017-10-12, Close, 150.88
# 2017-10-13, Close, 151.83
# 2017-10-16, Close, 154.63
# 2017-10-17, Close, 155.20
# 2017-10-18, Close, 154.51
# 2017-10-19, Close, 150.86
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-27, Close, 157.69
# 2017-10-30, Close, 161.24
# 2017-10-31, Close, 163.49
# 2017-11-01, Close, 161.41
# 2017-11-02, Close, 162.59
# 2017-11-03, Close, 166.83
# 2017-11-06, Close, 168.53
# 2017-11-07, Close, 169.07
# 2017-11-08, Close, 170.45
# 2017-11-09, Close, 170.10
# 2017-11-10, Close, 169.54
# 2017-11-13, Close, 168.86
# 2017-11-14, Close, 166.31
# 2017-11-15, Close, 164.11
# 2017-11-16, Close, 166.07
# 2017-11-17, Close, 165.15
# 2017-11-20, Close, 164.99
# 2017-11-21, Close, 168.05
# 2017-11-22, Close, 169.82
# 2017-11-24, Close, 169.83
# 2017-11-27, Close, 168.98
# 2017-11-28, Close, 167.99
# 2017-11-29, Close, 164.50
# 2017-11-30, Close, 166.80
# 2017-12-01, Close, 166.03
# 2017-12-04, Close, 164.81
# 2017-12-05, Close, 164.66
# 2017-12-06, Close, 164.05
# 2017-12-07, Close, 164.35
# 2017-12-08, Close, 164.39
# 2017-12-11, Close, 167.60
# 2017-12-12, Close, 166.66
# 2017-12-13, Close, 167.21
# 2017-12-14, Close, 167.16
# 2017-12-15, Close, 168.86
# 2017-12-18, Close, 171.24
# 2017-12-19, Close, 169.41
# 2017-12-20, Close, 169.23
# 2017-12-21, Close, 169.87
# 2017-12-22, Close, 169.87
# 2017-12-26, Close, 165.56
# 2017-12-27, Close, 165.59
# 2017-12-28, Close, 166.05
# 2017-12-29, Close, 164.26
# 2018-01-02, Close, 167.20
# 2018-01-03, Close, 167.17
# 2018-01-04, Close, 167.95
# 2018-01-05, Close, 169.86
# 2018-01-08, Close, 169.23
# 2018-01-09, Close, 169.21
# 2018-01-10, Close, 169.17
# 2018-01-11, Close, 170.13
# 2018-01-12, Close, 171.89
# 2018-01-16, Close, 171.01
# 2018-01-17, Close, 173.84
# 2018-01-18, Close, 173.99
# 2018-01-19, Close, 173.22
# 2018-01-22, Close, 171.80
# 2018-01-23, Close, 171.84
# 2018-01-24, Close, 169.10
# 2018-01-25, Close, 166.08
# 2018-01-26, Close, 166.47
# 2018-01-29, Close, 163.03
# 2018-01-30, Close, 162.07
# 2018-01-31, Close, 162.51
# 2018-02-01, Close, 162.85
# 2018-02-02, Close, 155.79
# 2018-02-05, Close, 151.89
# 2018-02-06, Close, 158.24
# 2018-02-07, Close, 154.85
# 2018-02-08, Close, 150.59
# 2018-02-09, Close, 152.43
# 2018-02-12, Close, 158.57
# 2018-02-13, Close, 160.16
# 2018-02-14, Close, 163.12
# 2018-02-15, Close, 168.59
# 2018-02-16, Close, 168.05
# 2018-02-20, Close, 167.48
# 2018-02-21, Close, 166.72
# 2018-02-22, Close, 168.12
# 2018-02-23, Close, 171.04
# 2018-02-26, Close, 174.42
# 2018-02-27, Close, 173.86
# 2018-02-28, Close, 173.59
# 2018-03-01, Close, 170.55
# 2018-03-02, Close, 171.73
# 2018-03-05, Close, 172.33
# 2018-03-06, Close, 172.18
# 2018-03-07, Close, 170.58
# 2018-03-08, Close, 172.44
# 2018-03-09, Close, 175.41
# 2018-03-12, Close, 177.10
# 2018-03-13, Close, 175.40
# 2018-03-14, Close, 173.90
# 2018-03-15, Close, 174.11
# 2018-03-16, Close, 173.50
# 2018-03-19, Close, 170.84
# 2018-03-20, Close, 170.79
# 2018-03-21, Close, 166.92
# 2018-03-22, Close, 164.56
# 2018-03-23, Close, 160.75
# 2018-03-26, Close, 168.38
# 2018-03-27, Close, 164.06
# 2018-03-28, Close, 162.25
# 2018-03-29, Close, 163.52
# 2018-04-02, Close, 162.44
# 2018-04-03, Close, 164.11
# 2018-04-04, Close, 167.25
# 2018-04-05, Close, 168.41
# 2018-04-06, Close, 164.10
# 2018-04-09, Close, 165.73
# 2018-04-10, Close, 168.85
# 2018-04-11, Close, 168.06
# 2018-04-12, Close, 169.71
# 2018-04-13, Close, 170.29
# 2018-04-16, Close, 171.35
# 2018-04-17, Close, 173.71
# 2018-04-18, Close, 173.32
# 2018-04-19, Close, 168.41
# 2018-04-20, Close, 161.51
# 2018-04-23, Close, 161.04
# 2018-04-24, Close, 158.80
# 2018-04-25, Close, 159.49
# 2018-04-26, Close, 160.05
# 2018-04-27, Close, 158.19
# 2018-04-30, Close, 161.06
# 2018-05-01, Close, 164.80
# 2018-05-02, Close, 172.08
# 2018-05-03, Close, 172.39
# 2018-05-04, Close, 179.16
# 2018-05-07, Close, 180.45
# 2018-05-08, Close, 181.32
# 2018-05-09, Close, 182.60
# 2018-05-10, Close, 185.21
# 2018-05-11, Close, 184.51
# 2018-05-14, Close, 184.07
# 2018-05-15, Close, 182.40
# 2018-05-16, Close, 184.10
# 2018-05-17, Close, 182.94
# 2018-05-18, Close, 182.27
# 2018-05-21, Close, 183.57
# 2018-05-22, Close, 183.11
# 2018-05-23, Close, 184.28
# 2018-05-24, Close, 184.07
# 2018-05-25, Close, 184.50
# 2018-05-29, Close, 183.83
# 2018-05-30, Close, 183.44
# 2018-05-31, Close, 182.82
# 2018-06-01, Close, 186.12
# 2018-06-04, Close, 187.68
# 2018-06-05, Close, 189.12
# 2018-06-06, Close, 189.78
# 2018-06-07, Close, 189.27
# 2018-06-08, Close, 187.55
# 2018-06-11, Close, 187.09
# 2018-06-12, Close, 188.12
# 2018-06-13, Close, 186.57
# 2018-06-14, Close, 186.67
# 2018-06-15, Close, 184.75
# 2018-06-18, Close, 184.65
# 2018-06-19, Close, 181.67
# 2018-06-20, Close, 182.46
# 2018-06-21, Close, 181.44
# 2018-06-22, Close, 180.91
# 2018-06-25, Close, 178.22
# 2018-06-26, Close, 180.44
# 2018-06-27, Close, 180.17
# 2018-06-28, Close, 181.48
# 2018-06-29, Close, 181.10
# 2018-07-02, Close, 183.13
# 2018-07-03, Close, 179.94
# 2018-07-05, Close, 181.38
# 2018-07-06, Close, 183.90
# 2018-07-09, Close, 186.45
# 2018-07-10, Close, 186.23
# 2018-07-11, Close, 183.81
# 2018-07-12, Close, 186.89
# 2018-07-13, Close, 187.19
# 2018-07-16, Close, 186.78
# 2018-07-17, Close, 187.30
# 2018-07-18, Close, 186.28
# 2018-07-19, Close, 187.72
# 2018-07-20, Close, 187.29
# 2018-07-23, Close, 187.46
# 2018-07-24, Close, 188.82
# 2018-07-25, Close, 190.60
# 2018-07-26, Close, 190.00
# 2018-07-27, Close, 186.84
# 2018-07-30, Close, 185.80
# 2018-07-31, Close, 186.17
# 2018-08-01, Close, 197.14
# 2018-08-02, Close, 202.90
# 2018-08-03, Close, 203.49
# 2018-08-06, Close, 204.54
# 2018-08-07, Close, 202.62
# 2018-08-08, Close, 202.76
# 2018-08-09, Close, 204.36
# 2018-08-10, Close, 203.75
# 2018-08-13, Close, 205.06
# 2018-08-14, Close, 205.93
# 2018-08-15, Close, 206.41
# 2018-08-16, Close, 209.43
# 2018-08-17, Close, 213.61
# 2018-08-20, Close, 211.53
# 2018-08-21, Close, 211.12
# 2018-08-22, Close, 211.13
# 2018-08-23, Close, 211.56
# 2018-08-24, Close, 212.22
# 2018-08-27, Close, 213.97
# 2018-08-28, Close, 215.70
# 2018-08-29, Close, 218.92
# 2018-08-30, Close, 220.93
# 2018-08-31, Close, 223.48
# 2018-09-04, Close, 224.20
# 2018-09-05, Close, 222.73
# 2018-09-06, Close, 219.03
# 2018-09-07, Close, 217.27
# 2018-09-10, Close, 214.35
# 2018-09-11, Close, 219.77
# 2018-09-12, Close, 217.04
# 2018-09-13, Close, 222.28
# 2018-09-14, Close, 219.76
# 2018-09-17, Close, 213.91
# 2018-09-18, Close, 214.26
# 2018-09-19, Close, 214.39
# 2018-09-20, Close, 216.02
# 2018-09-21, Close, 213.69
# 2018-09-24, Close, 216.77
# 2018-09-25, Close, 218.14
# 2018-09-26, Close, 216.40
# 2018-09-27, Close, 220.85
# 2018-09-28, Close, 221.63
# 2018-10-01, Close, 223.12
# 2018-10-02, Close, 225.10
# 2018-10-03, Close, 227.84
# 2018-10-04, Close, 223.83
# 2018-10-05, Close, 220.20
# 2018-10-08, Close, 219.69
# 2018-10-09, Close, 222.73
# 2018-10-10, Close, 212.42
# 2018-10-11, Close, 210.54
# 2018-10-12, Close, 218.06
# 2018-10-15, Close, 213.40
# 2018-10-16, Close, 218.10
# 2018-10-17, Close, 217.16
# 2018-10-18, Close, 212.08
# 2018-10-19, Close, 215.31
# 2018-10-22, Close, 216.63
# 2018-10-23, Close, 218.67
# 2018-10-24, Close, 211.17
# 2018-10-25, Close, 215.79
# 2018-10-26, Close, 212.36
# 2018-10-29, Close, 208.37
# 2018-10-30, Close, 209.41
# 2018-10-31, Close, 214.87
# 2018-11-01, Close, 218.17
# 2018-11-02, Close, 203.70
# 2018-11-05, Close, 197.92
# 2018-11-06, Close, 200.06
# 2018-11-07, Close, 206.12
# 2018-11-08, Close, 205.40
# 2018-11-09, Close, 201.44
# 2018-11-12, Close, 191.30
# 2018-11-13, Close, 189.38
# 2018-11-14, Close, 184.03
# 2018-11-15, Close, 188.58
# 2018-11-16, Close, 190.67
# 2018-11-19, Close, 183.11
# 2018-11-20, Close, 174.36
# 2018-11-21, Close, 174.16
# 2018-11-23, Close, 169.74
# 2018-11-26, Close, 172.04
# 2018-11-27, Close, 171.66
# 2018-11-28, Close, 178.26
# 2018-11-29, Close, 176.89
# 2018-11-30, Close, 175.94
# 2018-12-03, Close, 182.08
# 2018-12-04, Close, 174.07
# 2018-12-06, Close, 172.13
# 2018-12-07, Close, 166.00
# 2018-12-10, Close, 167.09
# 2018-12-11, Close, 166.13
# 2018-12-12, Close, 166.60
# 2018-12-13, Close, 168.42
# 2018-12-14, Close, 163.03
# 2018-12-17, Close, 161.51
# 2018-12-18, Close, 163.61
# 2018-12-19, Close, 158.51
# 2018-12-20, Close, 154.51
# 2018-12-21, Close, 148.50
# 2018-12-24, Close, 144.66
# 2018-12-26, Close, 154.84
# 2018-12-27, Close, 153.84
# 2018-12-28, Close, 153.92
# 2018-12-31, Close, 155.41
# 2019-01-02, Close, 155.58
# 2019-01-03, Close, 140.09
# 2019-01-04, Close, 146.07
# 2019-01-07, Close, 145.74
# 2019-01-08, Close, 148.52
# 2019-01-09, Close, 151.04
# 2019-01-10, Close, 151.52
# 2019-01-11, Close, 150.04
# 2019-01-14, Close, 147.78
# 2019-01-15, Close, 150.80
# 2019-01-16, Close, 152.65
# 2019-01-17, Close, 153.55
# 2019-01-18, Close, 154.50
# 2019-01-22, Close, 151.03
# 2019-01-23, Close, 151.64
# 2019-01-24, Close, 150.44
# 2019-01-25, Close, 155.42
# 2019-01-28, Close, 153.99
# 2019-01-29, Close, 152.39
# 2019-01-30, Close, 162.80
# 2019-01-31, Close, 163.98
# 2019-02-01, Close, 164.06
# 2019-02-04, Close, 168.72
# 2019-02-05, Close, 171.60
# 2019-02-06, Close, 171.66
# 2019-02-07, Close, 168.41
# 2019-02-08, Close, 168.61
# 2019-02-11, Close, 167.64
# 2019-02-12, Close, 169.08
# 2019-02-13, Close, 168.38
# 2019-02-14, Close, 168.99
# 2019-02-15, Close, 168.62
# 2019-02-19, Close, 169.12
# 2019-02-20, Close, 170.21
# 2019-02-21, Close, 169.25
# 2019-02-22, Close, 171.14
# 2019-02-25, Close, 172.39
# 2019-02-26, Close, 172.49
# 2019-02-27, Close, 173.02
# 2019-02-28, Close, 171.32
# 2019-03-01, Close, 173.12
# 2019-03-04, Close, 173.99
# 2019-03-05, Close, 173.67
# 2019-03-06, Close, 172.67
# 2019-03-07, Close, 170.68
# 2019-03-08, Close, 171.08
# 2019-03-11, Close, 177.01
# 2019-03-12, Close, 179.00
# 2019-03-13, Close, 179.79
# 2019-03-14, Close, 181.79
# 2019-03-15, Close, 184.15
# 2019-03-18, Close, 186.03
# 2019-03-19, Close, 184.56
# 2019-03-20, Close, 186.17
# 2019-03-21, Close, 193.03
# 2019-03-22, Close, 189.03
# 2019-03-25, Close, 186.74
# 2019-03-26, Close, 184.81
# 2019-03-27, Close, 186.48
# 2019-03-28, Close, 186.72
# 2019-03-29, Close, 187.94
# 2019-04-01, Close, 189.22
# 2019-04-02, Close, 191.97
# 2019-04-03, Close, 193.28
# 2019-04-04, Close, 193.62
# 2019-04-05, Close, 194.92
# 2019-04-08, Close, 197.98
# 2019-04-09, Close, 197.39
# 2019-04-10, Close, 198.50
# 2019-04-11, Close, 196.85
# 2019-04-12, Close, 196.77
# 2019-04-15, Close, 197.12
# 2019-04-16, Close, 197.14
# 2019-04-17, Close, 200.98
# 2019-04-18, Close, 201.70
# 2019-04-22, Close, 202.37
# 2019-04-23, Close, 205.29
# 2019-04-24, Close, 204.97
# 2019-04-25, Close, 203.11
# 2019-04-26, Close, 202.14
# 2019-04-29, Close, 202.45
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-02, Close, 206.94
# 2019-05-03, Close, 209.51
# 2019-05-06, Close, 206.27
# 2019-05-07, Close, 200.71
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-20, Close, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-29, Close, 176.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-06, Close, 183.97
# 2019-06-07, Close, 188.86
# 2019-06-10, Close, 191.28
# 2019-06-11, Close, 193.49
# 2019-06-12, Close, 192.88
# 2019-06-13, Close, 192.84
# 2019-06-14, Close, 191.44
# 2019-06-17, Close, 192.58
# 2019-06-18, Close, 197.11
# 2019-06-19, Close, 196.53
# 2019-06-20, Close, 198.11
# 2019-06-21, Close, 197.43
# 2019-06-24, Close, 197.24
# 2019-06-25, Close, 194.25
# 2019-06-26, Close, 198.45
# 2019-06-27, Close, 198.39
# 2019-06-28, Close, 196.58
# 2019-07-01, Close, 200.19
# 2019-07-02, Close, 201.36
# 2019-07-03, Close, 203.03
# 2019-07-05, Close, 202.85
# 2019-07-08, Close, 198.67
# 2019-07-09, Close, 199.88
# 2019-07-10, Close, 201.85
# 2019-07-11, Close, 200.38
# 2019-07-12, Close, 201.92
# 2019-07-15, Close, 203.82
# 2019-07-16, Close, 203.12
# 2019-07-17, Close, 201.97
# 2019-07-18, Close, 204.27
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-23, Close, 207.43
# 2019-07-24, Close, 207.26
# 2019-07-25, Close, 205.62
# 2019-07-26, Close, 206.33
# 2019-07-29, Close, 208.26
# 2019-07-30, Close, 207.37
# 2019-07-31, Close, 211.60
# 2019-08-01, Close, 207.02
# 2019-08-02, Close, 202.64
# 2019-08-05, Close, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-13, Close, 208.34
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-16, Close, 205.88
# 2019-08-19, Close, 209.72
# 2019-08-20, Close, 209.73
# 2019-08-21, Close, 212.00
# 2019-08-22, Close, 211.82
# 2019-08-23, Close, 202.03
# 2019-08-26, Close, 205.87
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-30, Close, 208.12
# 2019-09-03, Close, 205.08
# 2019-09-04, Close, 208.56
# 2019-09-05, Close, 212.64
# 2019-09-06, Close, 212.62
# 2019-09-09, Close, 213.53
# 2019-09-10, Close, 216.05
# 2019-09-11, Close, 222.92
# 2019-09-12, Close, 222.42
# 2019-09-13, Close, 218.10
# 2019-09-16, Close, 219.24
# 2019-09-17, Close, 220.04
# 2019-09-18, Close, 222.10
# 2019-09-19, Close, 220.30
# 2019-09-20, Close, 217.08
# 2019-09-23, Close, 218.07
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-26, Close, 219.23
# 2019-09-27, Close, 218.17
# 2019-09-30, Close, 223.30
# 2019-10-01, Close, 223.92
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-04, Close, 226.33
# 2019-10-07, Close, 226.38
# 2019-10-08, Close, 223.73
# 2019-10-09, Close, 226.35
# 2019-10-10, Close, 229.40
# 2019-10-11, Close, 235.50
# 2019-10-14, Close, 235.16
# 2019-10-15, Close, 234.62
# 2019-10-16, Close, 233.67
# 2019-10-17, Close, 234.58
# 2019-10-18, Close, 235.70
# 2019-10-21, Close, 239.79
# 2019-10-22, Close, 239.24
# 2019-10-23, Close, 242.45
# 2019-10-24, Close, 242.85
# 2019-10-25, Close, 245.84
# 2019-10-28, Close, 248.30
# 2019-10-29, Close, 242.56
# 2019-10-30, Close, 242.53
# 2019-10-31, Close, 248.02
# 2019-11-01, Close, 255.05
# 2019-11-04, Close, 256.73
# 2019-11-05, Close, 256.36
# 2019-11-06, Close, 256.47
# 2019-11-07, Close, 259.43
# 2019-11-08, Close, 260.14
# 2019-11-11, Close, 262.20
# 2019-11-12, Close, 261.96
# 2019-11-13, Close, 264.47
# 2019-11-14, Close, 262.64
# 2019-11-15, Close, 265.76
# 2019-11-18, Close, 267.10
# 2019-11-19, Close, 266.29
# 2019-11-20, Close, 263.19
# 2019-11-21, Close, 262.01
# 2019-11-22, Close, 261.78
# 2019-11-25, Close, 266.37
# 2019-11-26, Close, 264.29
# 2019-11-27, Close, 267.84
# 2019-11-29, Close, 267.25
# 2019-12-02, Close, 264.16
# 2019-12-03, Close, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-06, Close, 270.71
# 2019-12-09, Close, 266.92
# 2019-12-10, Close, 268.48
# 2019-12-11, Close, 270.77
# 2019-12-12, Close, 271.46
# 2019-12-13, Close, 275.15
# 2019-12-16, Close, 279.86
# 2019-12-17, Close, 280.41
# 2019-12-18, Close, 279.74
# 2019-12-19, Close, 280.02
# 2019-12-20, Close, 279.44
# 2019-12-23, Close, 284.00
# 2019-12-24, Close, 284.27
# 2019-12-26, Close, 289.91
# 2019-12-27, Close, 289.80
# 2019-12-30, Close, 291.52
# 2019-12-31, Close, 293.65
# 2020-01-02, Close, 300.35
# 2020-01-03, Close, 297.43
# 2020-01-06, Close, 299.80
# 2020-01-07, Close, 298.39
# 2020-01-08, Close, 303.19
# 2020-01-09, Close, 309.63
# Final Portfolio Value: 100000.00

# %% [markdown]
# ## Adding some Logic to the Strategy
#
# Let’s try some crazy idea we had by looking at some charts
#
# If the price has been falling 3 sessions in a row … BUY BUY BUY!!!

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        if self.dataclose[0] < self.dataclose[-1]:
            # current close less than previous close

            if self.dataclose[-1] < self.dataclose[-2]:
                # previous close less than the previous close

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.buy()

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2015-01-02, Close, 100.45
# 2015-01-05, Close, 97.62
# 2015-01-05, BUY CREATE, 97.62
# 2015-01-06, Close, 97.63
# 2015-01-07, Close, 99.00
# 2015-01-08, Close, 102.81
# 2015-01-09, Close, 102.92
# 2015-01-12, Close, 100.38
# 2015-01-13, Close, 101.27
# 2015-01-14, Close, 100.89
# 2015-01-15, Close, 98.15
# 2015-01-15, BUY CREATE, 98.15
# 2015-01-16, Close, 97.39
# 2015-01-16, BUY CREATE, 97.39
# 2015-01-20, Close, 99.89
# 2015-01-21, Close, 100.66
# 2015-01-22, Close, 103.28
# 2015-01-23, Close, 103.81
# 2015-01-26, Close, 103.92
# 2015-01-27, Close, 100.28
# 2015-01-28, Close, 105.95
# 2015-01-29, Close, 109.25
# 2015-01-30, Close, 107.65
# 2015-02-02, Close, 109.00
# 2015-02-03, Close, 109.02
# 2015-02-04, Close, 109.85
# 2015-02-05, Close, 110.64
# 2015-02-06, Close, 109.71
# 2015-02-09, Close, 110.43
# 2015-02-10, Close, 112.56
# 2015-02-11, Close, 115.19
# 2015-02-12, Close, 116.65
# 2015-02-13, Close, 117.22
# 2015-02-17, Close, 117.92
# 2015-02-18, Close, 118.74
# 2015-02-19, Close, 118.49
# 2015-02-20, Close, 119.46
# 2015-02-23, Close, 122.68
# 2015-02-24, Close, 121.92
# 2015-02-25, Close, 118.80
# 2015-02-25, BUY CREATE, 118.80
# 2015-02-26, Close, 120.31
# 2015-02-27, Close, 118.50
# 2015-03-02, Close, 119.08
# 2015-03-03, Close, 119.33
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-05, BUY CREATE, 116.61
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-11, BUY CREATE, 112.76
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-18, Close, 118.51
# 2015-03-19, Close, 117.61
# 2015-03-20, Close, 116.14
# 2015-03-20, BUY CREATE, 116.14
# 2015-03-23, Close, 117.34
# 2015-03-24, Close, 116.86
# 2015-03-25, Close, 113.81
# 2015-03-25, BUY CREATE, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-01, BUY CREATE, 114.61
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-07, Close, 116.24
# 2015-04-08, Close, 115.86
# 2015-04-08, BUY CREATE, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-10, Close, 117.24
# 2015-04-13, Close, 117.01
# 2015-04-14, Close, 116.50
# 2015-04-14, BUY CREATE, 116.50
# 2015-04-15, Close, 116.95
# 2015-04-16, Close, 116.38
# 2015-04-17, Close, 115.07
# 2015-04-17, BUY CREATE, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-21, Close, 117.07
# 2015-04-22, Close, 118.64
# 2015-04-23, Close, 119.61
# 2015-04-24, Close, 120.18
# 2015-04-27, Close, 122.36
# 2015-04-28, Close, 120.43
# 2015-04-29, Close, 118.66
# 2015-04-29, BUY CREATE, 118.66
# 2015-04-30, Close, 115.44
# 2015-04-30, BUY CREATE, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-04, Close, 118.72
# 2015-05-05, Close, 116.04
# 2015-05-05, BUY CREATE, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-06, BUY CREATE, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-12, BUY CREATE, 116.59
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-15, Close, 119.28
# 2015-05-18, Close, 120.59
# 2015-05-19, Close, 120.48
# 2015-05-20, Close, 120.47
# 2015-05-20, BUY CREATE, 120.47
# 2015-05-21, Close, 121.71
# 2015-05-22, Close, 122.77
# 2015-05-26, Close, 120.07
# 2015-05-27, Close, 122.31
# 2015-05-28, Close, 122.07
# 2015-05-29, Close, 120.68
# 2015-05-29, BUY CREATE, 120.68
# 2015-06-01, Close, 120.92
# 2015-06-02, Close, 120.38
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-05, BUY CREATE, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-08, BUY CREATE, 118.38
# 2015-06-09, Close, 118.03
# 2015-06-09, BUY CREATE, 118.03
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-12, BUY CREATE, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-15, BUY CREATE, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-26, BUY CREATE, 117.41
# 2015-06-29, Close, 115.35
# 2015-06-29, BUY CREATE, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-06, BUY CREATE, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-07, BUY CREATE, 116.43
# 2015-07-08, Close, 113.54
# 2015-07-08, BUY CREATE, 113.54
# 2015-07-09, Close, 111.22
# 2015-07-09, BUY CREATE, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-14, Close, 116.35
# 2015-07-15, Close, 117.47
# 2015-07-16, Close, 119.04
# 2015-07-17, Close, 120.07
# 2015-07-20, Close, 122.34
# 2015-07-21, Close, 121.11
# 2015-07-22, Close, 115.99
# 2015-07-22, BUY CREATE, 115.99
# 2015-07-23, Close, 115.94
# 2015-07-23, BUY CREATE, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-24, BUY CREATE, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-27, BUY CREATE, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-30, BUY CREATE, 113.35
# 2015-07-31, Close, 112.36
# 2015-07-31, BUY CREATE, 112.36
# 2015-08-03, Close, 109.71
# 2015-08-03, BUY CREATE, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-04, BUY CREATE, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-19, BUY CREATE, 107.02
# 2015-08-20, Close, 104.82
# 2015-08-20, BUY CREATE, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-21, BUY CREATE, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-24, BUY CREATE, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-28, Close, 105.42
# 2015-08-31, Close, 104.92
# 2015-09-01, Close, 100.23
# 2015-09-01, BUY CREATE, 100.23
# 2015-09-02, Close, 104.53
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-04, BUY CREATE, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-09, Close, 102.49
# 2015-09-10, Close, 104.75
# 2015-09-11, Close, 106.27
# 2015-09-14, Close, 107.29
# 2015-09-15, Close, 108.20
# 2015-09-16, Close, 108.32
# 2015-09-17, Close, 106.00
# 2015-09-18, Close, 105.56
# 2015-09-18, BUY CREATE, 105.56
# 2015-09-21, Close, 107.20
# 2015-09-22, Close, 105.52
# 2015-09-23, Close, 106.37
# 2015-09-24, Close, 107.01
# 2015-09-25, Close, 106.74
# 2015-09-28, Close, 104.62
# 2015-09-28, BUY CREATE, 104.62
# 2015-09-29, Close, 101.48
# 2015-09-29, BUY CREATE, 101.48
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-08, Close, 101.89
# 2015-10-08, BUY CREATE, 101.89
# 2015-10-09, Close, 104.33
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-16, Close, 103.32
# 2015-10-19, Close, 103.96
# 2015-10-20, Close, 105.86
# 2015-10-21, Close, 105.85
# 2015-10-22, Close, 107.47
# 2015-10-23, Close, 110.80
# 2015-10-26, Close, 107.27
# 2015-10-27, Close, 106.59
# 2015-10-27, BUY CREATE, 106.59
# 2015-10-28, Close, 110.98
# 2015-10-29, Close, 112.15
# 2015-10-30, Close, 111.19
# 2015-11-02, Close, 112.76
# 2015-11-03, Close, 114.05
# 2015-11-04, Close, 113.52
# 2015-11-05, Close, 113.00
# 2015-11-05, BUY CREATE, 113.00
# 2015-11-06, Close, 113.13
# 2015-11-09, Close, 112.67
# 2015-11-10, Close, 109.12
# 2015-11-10, BUY CREATE, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-11, BUY CREATE, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-12, BUY CREATE, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-13, BUY CREATE, 104.98
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-20, Close, 111.48
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-25, Close, 110.30
# 2015-11-27, Close, 110.09
# 2015-11-27, BUY CREATE, 110.09
# 2015-11-30, Close, 110.55
# 2015-12-01, Close, 109.65
# 2015-12-02, Close, 108.66
# 2015-12-02, BUY CREATE, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-03, BUY CREATE, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-07, Close, 110.53
# 2015-12-08, Close, 110.48
# 2015-12-08, BUY CREATE, 110.48
# 2015-12-09, Close, 108.04
# 2015-12-09, BUY CREATE, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-14, BUY CREATE, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-15, BUY CREATE, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-18, BUY CREATE, 99.08
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-28, BUY CREATE, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2015-12-31, BUY CREATE, 98.36
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-06, BUY CREATE, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-07, BUY CREATE, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-19, BUY CREATE, 90.33
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-02, BUY CREATE, 88.29
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-05, Close, 88.34
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-10, BUY CREATE, 88.57
# 2016-02-11, Close, 88.04
# 2016-02-11, BUY CREATE, 88.04
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-17, Close, 92.19
# 2016-02-18, Close, 90.44
# 2016-02-19, Close, 90.23
# 2016-02-19, BUY CREATE, 90.23
# 2016-02-22, Close, 91.02
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-25, Close, 90.91
# 2016-02-26, Close, 91.05
# 2016-02-29, Close, 90.84
# 2016-03-01, Close, 94.45
# 2016-03-02, Close, 94.66
# 2016-03-03, Close, 95.36
# 2016-03-04, Close, 96.78
# 2016-03-07, Close, 95.71
# 2016-03-08, Close, 94.92
# 2016-03-08, BUY CREATE, 94.92
# 2016-03-09, Close, 95.01
# 2016-03-10, Close, 95.05
# 2016-03-11, Close, 96.08
# 2016-03-14, Close, 96.32
# 2016-03-15, Close, 98.26
# 2016-03-16, Close, 99.56
# 2016-03-17, Close, 99.40
# 2016-03-18, Close, 99.52
# 2016-03-21, Close, 99.51
# 2016-03-22, Close, 100.27
# 2016-03-23, Close, 99.71
# 2016-03-24, Close, 99.28
# 2016-03-24, BUY CREATE, 99.28
# 2016-03-28, Close, 98.83
# 2016-03-28, BUY CREATE, 98.83
# 2016-03-29, Close, 101.17
# 2016-03-30, Close, 102.94
# 2016-03-31, Close, 102.40
# 2016-04-01, Close, 103.34
# 2016-04-04, Close, 104.40
# 2016-04-05, Close, 103.17
# 2016-04-06, Close, 104.25
# 2016-04-07, Close, 101.98
# 2016-04-08, Close, 102.09
# 2016-04-11, Close, 102.43
# 2016-04-12, Close, 103.76
# 2016-04-13, Close, 105.27
# 2016-04-14, Close, 105.32
# 2016-04-15, Close, 103.21
# 2016-04-18, Close, 100.98
# 2016-04-18, BUY CREATE, 100.98
# 2016-04-19, Close, 100.45
# 2016-04-19, BUY CREATE, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-22, BUY CREATE, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-25, BUY CREATE, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-26, BUY CREATE, 98.04
# 2016-04-27, Close, 91.91
# 2016-04-27, BUY CREATE, 91.91
# 2016-04-28, Close, 89.10
# 2016-04-28, BUY CREATE, 89.10
# 2016-04-29, Close, 88.07
# 2016-04-29, BUY CREATE, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-02, BUY CREATE, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-05, BUY CREATE, 88.14
# 2016-05-06, Close, 87.64
# 2016-05-06, BUY CREATE, 87.64
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-12, BUY CREATE, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-17, Close, 88.37
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-05-31, BUY CREATE, 94.39
# 2016-06-01, Close, 93.07
# 2016-06-01, BUY CREATE, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-02, BUY CREATE, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-13, BUY CREATE, 92.01
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-20, BUY CREATE, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-27, BUY CREATE, 87.00
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-05, Close, 89.79
# 2016-07-06, Close, 90.30
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-22, BUY CREATE, 93.26
# 2016-07-25, Close, 92.01
# 2016-07-25, BUY CREATE, 92.01
# 2016-07-26, Close, 91.38
# 2016-07-26, BUY CREATE, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-28, Close, 98.63
# 2016-07-29, Close, 98.51
# 2016-08-01, Close, 100.25
# 2016-08-02, Close, 98.76
# 2016-08-03, Close, 100.00
# 2016-08-04, Close, 100.62
# 2016-08-05, Close, 102.15
# 2016-08-08, Close, 102.99
# 2016-08-09, Close, 103.41
# 2016-08-10, Close, 102.64
# 2016-08-11, Close, 102.57
# 2016-08-11, BUY CREATE, 102.57
# 2016-08-12, Close, 102.81
# 2016-08-15, Close, 104.05
# 2016-08-16, Close, 103.95
# 2016-08-17, Close, 103.80
# 2016-08-17, BUY CREATE, 103.80
# 2016-08-18, Close, 103.67
# 2016-08-18, BUY CREATE, 103.67
# 2016-08-19, Close, 103.93
# 2016-08-22, Close, 103.13
# 2016-08-23, Close, 103.45
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-25, BUY CREATE, 102.23
# 2016-08-26, Close, 101.63
# 2016-08-26, BUY CREATE, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-29, BUY CREATE, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-30, BUY CREATE, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-09, BUY CREATE, 98.01
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-14, Close, 106.22
# 2016-09-15, Close, 109.84
# 2016-09-16, Close, 109.22
# 2016-09-19, Close, 107.94
# 2016-09-19, BUY CREATE, 107.94
# 2016-09-20, Close, 107.94
# 2016-09-21, Close, 107.92
# 2016-09-22, Close, 108.93
# 2016-09-23, Close, 107.12
# 2016-09-26, Close, 107.28
# 2016-09-27, Close, 107.48
# 2016-09-28, Close, 108.30
# 2016-09-29, Close, 106.61
# 2016-09-30, Close, 107.44
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-07, Close, 108.40
# 2016-10-10, Close, 110.29
# 2016-10-11, Close, 110.53
# 2016-10-12, Close, 111.52
# 2016-10-13, Close, 111.18
# 2016-10-14, Close, 111.79
# 2016-10-17, Close, 111.72
# 2016-10-18, Close, 111.64
# 2016-10-18, BUY CREATE, 111.64
# 2016-10-19, Close, 111.31
# 2016-10-19, BUY CREATE, 111.31
# 2016-10-20, Close, 111.25
# 2016-10-20, BUY CREATE, 111.25
# 2016-10-21, Close, 110.81
# 2016-10-21, BUY CREATE, 110.81
# 2016-10-24, Close, 111.81
# 2016-10-25, Close, 112.38
# 2016-10-26, Close, 109.85
# 2016-10-27, Close, 108.80
# 2016-10-27, BUY CREATE, 108.80
# 2016-10-28, Close, 108.08
# 2016-10-28, BUY CREATE, 108.08
# 2016-10-31, Close, 107.91
# 2016-10-31, BUY CREATE, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-01, BUY CREATE, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-04, BUY CREATE, 103.97
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-10, BUY CREATE, 102.97
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-18, Close, 105.14
# 2016-11-21, Close, 106.73
# 2016-11-22, Close, 106.80
# 2016-11-23, Close, 106.25
# 2016-11-25, Close, 106.79
# 2016-11-28, Close, 106.58
# 2016-11-29, Close, 106.47
# 2016-11-29, BUY CREATE, 106.47
# 2016-11-30, Close, 105.58
# 2016-11-30, BUY CREATE, 105.58
# 2016-12-01, Close, 104.59
# 2016-12-01, BUY CREATE, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-08, Close, 107.10
# 2016-12-09, Close, 108.85
# 2016-12-12, Close, 108.23
# 2016-12-13, Close, 110.04
# 2016-12-14, Close, 110.04
# 2016-12-15, Close, 110.64
# 2016-12-16, Close, 110.78
# 2016-12-19, Close, 111.42
# 2016-12-20, Close, 111.72
# 2016-12-21, Close, 111.82
# 2016-12-22, Close, 111.09
# 2016-12-23, Close, 111.31
# 2016-12-27, Close, 112.01
# 2016-12-28, Close, 111.54
# 2016-12-29, Close, 111.51
# 2016-12-29, BUY CREATE, 111.51
# 2016-12-30, Close, 110.64
# 2016-12-30, BUY CREATE, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-06, Close, 112.64
# 2017-01-09, Close, 113.67
# 2017-01-10, Close, 113.78
# 2017-01-11, Close, 114.39
# 2017-01-12, Close, 113.92
# 2017-01-13, Close, 113.71
# 2017-01-13, BUY CREATE, 113.71
# 2017-01-17, Close, 114.63
# 2017-01-18, Close, 114.62
# 2017-01-19, Close, 114.42
# 2017-01-19, BUY CREATE, 114.42
# 2017-01-20, Close, 114.63
# 2017-01-23, Close, 114.71
# 2017-01-24, Close, 114.60
# 2017-01-25, Close, 116.43
# 2017-01-26, Close, 116.48
# 2017-01-27, Close, 116.49
# 2017-01-30, Close, 116.19
# 2017-01-31, Close, 115.92
# 2017-01-31, BUY CREATE, 115.92
# 2017-02-01, Close, 122.99
# 2017-02-02, Close, 122.78
# 2017-02-03, Close, 123.31
# 2017-02-06, Close, 124.46
# 2017-02-07, Close, 125.65
# 2017-02-08, Close, 126.13
# 2017-02-09, Close, 127.04
# 2017-02-10, Close, 126.76
# 2017-02-13, Close, 127.88
# 2017-02-14, Close, 129.54
# 2017-02-15, Close, 130.01
# 2017-02-16, Close, 129.86
# 2017-02-17, Close, 130.21
# 2017-02-21, Close, 131.15
# 2017-02-22, Close, 131.54
# 2017-02-23, Close, 130.99
# 2017-02-24, Close, 131.11
# 2017-02-27, Close, 131.37
# 2017-02-28, Close, 131.43
# 2017-03-01, Close, 134.12
# 2017-03-02, Close, 133.32
# 2017-03-03, Close, 134.11
# 2017-03-06, Close, 133.68
# 2017-03-07, Close, 133.86
# 2017-03-08, Close, 133.36
# 2017-03-09, Close, 133.05
# 2017-03-09, BUY CREATE, 133.05
# 2017-03-10, Close, 133.49
# 2017-03-13, Close, 133.55
# 2017-03-14, Close, 133.35
# 2017-03-15, Close, 134.76
# 2017-03-16, Close, 134.98
# 2017-03-17, Close, 134.31
# 2017-03-20, Close, 135.72
# 2017-03-21, Close, 134.16
# 2017-03-22, Close, 135.68
# 2017-03-23, Close, 135.20
# 2017-03-24, Close, 134.93
# 2017-03-24, BUY CREATE, 134.93
# 2017-03-27, Close, 135.16
# 2017-03-28, Close, 137.96
# 2017-03-29, Close, 138.27
# 2017-03-30, Close, 138.09
# 2017-03-31, Close, 137.83
# 2017-03-31, BUY CREATE, 137.83
# 2017-04-03, Close, 137.87
# 2017-04-04, Close, 138.89
# 2017-04-05, Close, 138.17
# 2017-04-06, Close, 137.83
# 2017-04-06, BUY CREATE, 137.83
# 2017-04-07, Close, 137.52
# 2017-04-07, BUY CREATE, 137.52
# 2017-04-10, Close, 137.36
# 2017-04-10, BUY CREATE, 137.36
# 2017-04-11, Close, 135.88
# 2017-04-11, BUY CREATE, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-19, BUY CREATE, 134.97
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-25, Close, 138.66
# 2017-04-26, Close, 137.85
# 2017-04-27, Close, 137.95
# 2017-04-28, Close, 137.82
# 2017-05-01, Close, 140.63
# 2017-05-02, Close, 141.52
# 2017-05-03, Close, 141.09
# 2017-05-04, Close, 140.58
# 2017-05-04, BUY CREATE, 140.58
# 2017-05-05, Close, 142.91
# 2017-05-08, Close, 146.80
# 2017-05-09, Close, 147.74
# 2017-05-10, Close, 147.04
# 2017-05-11, Close, 148.31
# 2017-05-12, Close, 150.38
# 2017-05-15, Close, 150.00
# 2017-05-16, Close, 149.77
# 2017-05-16, BUY CREATE, 149.77
# 2017-05-17, Close, 144.75
# 2017-05-17, BUY CREATE, 144.75
# 2017-05-18, Close, 146.95
# 2017-05-19, Close, 147.45
# 2017-05-22, Close, 148.35
# 2017-05-23, Close, 148.17
# 2017-05-24, Close, 147.72
# 2017-05-24, BUY CREATE, 147.72
# 2017-05-25, Close, 148.23
# 2017-05-26, Close, 147.98
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-05, Close, 148.29
# 2017-06-06, Close, 148.79
# 2017-06-07, Close, 149.68
# 2017-06-08, Close, 149.31
# 2017-06-09, Close, 143.52
# 2017-06-09, BUY CREATE, 143.52
# 2017-06-12, Close, 140.09
# 2017-06-12, BUY CREATE, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-15, BUY CREATE, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-16, BUY CREATE, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-27, BUY CREATE, 138.46
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-11, Close, 140.20
# 2017-07-12, Close, 140.40
# 2017-07-13, Close, 142.36
# 2017-07-14, Close, 143.58
# 2017-07-17, Close, 144.08
# 2017-07-18, Close, 144.58
# 2017-07-19, Close, 145.49
# 2017-07-20, Close, 144.83
# 2017-07-21, Close, 144.76
# 2017-07-21, BUY CREATE, 144.76
# 2017-07-24, Close, 146.52
# 2017-07-25, Close, 147.14
# 2017-07-26, Close, 147.84
# 2017-07-27, Close, 145.04
# 2017-07-28, Close, 144.02
# 2017-07-28, BUY CREATE, 144.02
# 2017-07-31, Close, 143.28
# 2017-07-31, BUY CREATE, 143.28
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-03, Close, 149.87
# 2017-08-04, Close, 150.66
# 2017-08-07, Close, 152.99
# 2017-08-08, Close, 154.22
# 2017-08-09, Close, 155.16
# 2017-08-10, Close, 150.22
# 2017-08-11, Close, 152.31
# 2017-08-14, Close, 154.60
# 2017-08-15, Close, 156.29
# 2017-08-16, Close, 155.66
# 2017-08-17, Close, 152.67
# 2017-08-17, BUY CREATE, 152.67
# 2017-08-18, Close, 152.33
# 2017-08-18, BUY CREATE, 152.33
# 2017-08-21, Close, 152.05
# 2017-08-21, BUY CREATE, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-23, Close, 154.72
# 2017-08-24, Close, 154.04
# 2017-08-25, Close, 154.61
# 2017-08-28, Close, 156.17
# 2017-08-29, Close, 157.56
# 2017-08-30, Close, 157.98
# 2017-08-31, Close, 158.61
# 2017-09-01, Close, 158.66
# 2017-09-05, Close, 156.76
# 2017-09-06, Close, 156.59
# 2017-09-06, BUY CREATE, 156.59
# 2017-09-07, Close, 155.96
# 2017-09-07, BUY CREATE, 155.96
# 2017-09-08, Close, 153.42
# 2017-09-08, BUY CREATE, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-13, BUY CREATE, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-14, BUY CREATE, 153.08
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-21, BUY CREATE, 148.35
# 2017-09-22, Close, 146.90
# 2017-09-22, BUY CREATE, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-25, BUY CREATE, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-06, Close, 150.20
# 2017-10-09, Close, 150.72
# 2017-10-10, Close, 150.78
# 2017-10-11, Close, 151.41
# 2017-10-12, Close, 150.88
# 2017-10-13, Close, 151.83
# 2017-10-16, Close, 154.63
# 2017-10-17, Close, 155.20
# 2017-10-18, Close, 154.51
# 2017-10-19, Close, 150.86
# 2017-10-19, BUY CREATE, 150.86
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-27, Close, 157.69
# 2017-10-30, Close, 161.24
# 2017-10-31, Close, 163.49
# 2017-11-01, Close, 161.41
# 2017-11-02, Close, 162.59
# 2017-11-03, Close, 166.83
# 2017-11-06, Close, 168.53
# 2017-11-07, Close, 169.07
# 2017-11-08, Close, 170.45
# 2017-11-09, Close, 170.10
# 2017-11-10, Close, 169.54
# 2017-11-10, BUY CREATE, 169.54
# 2017-11-13, Close, 168.86
# 2017-11-13, BUY CREATE, 168.86
# 2017-11-14, Close, 166.31
# 2017-11-14, BUY CREATE, 166.31
# 2017-11-15, Close, 164.11
# 2017-11-15, BUY CREATE, 164.11
# 2017-11-16, Close, 166.07
# 2017-11-17, Close, 165.15
# 2017-11-20, Close, 164.99
# 2017-11-20, BUY CREATE, 164.99
# 2017-11-21, Close, 168.05
# 2017-11-22, Close, 169.82
# 2017-11-24, Close, 169.83
# 2017-11-27, Close, 168.98
# 2017-11-28, Close, 167.99
# 2017-11-28, BUY CREATE, 167.99
# 2017-11-29, Close, 164.50
# 2017-11-29, BUY CREATE, 164.50
# 2017-11-30, Close, 166.80
# 2017-12-01, Close, 166.03
# 2017-12-04, Close, 164.81
# 2017-12-04, BUY CREATE, 164.81
# 2017-12-05, Close, 164.66
# 2017-12-05, BUY CREATE, 164.66
# 2017-12-06, Close, 164.05
# 2017-12-06, BUY CREATE, 164.05
# 2017-12-07, Close, 164.35
# 2017-12-08, Close, 164.39
# 2017-12-11, Close, 167.60
# 2017-12-12, Close, 166.66
# 2017-12-13, Close, 167.21
# 2017-12-14, Close, 167.16
# 2017-12-15, Close, 168.86
# 2017-12-18, Close, 171.24
# 2017-12-19, Close, 169.41
# 2017-12-20, Close, 169.23
# 2017-12-20, BUY CREATE, 169.23
# 2017-12-21, Close, 169.87
# 2017-12-22, Close, 169.87
# 2017-12-26, Close, 165.56
# 2017-12-27, Close, 165.59
# 2017-12-28, Close, 166.05
# 2017-12-29, Close, 164.26
# 2018-01-02, Close, 167.20
# 2018-01-03, Close, 167.17
# 2018-01-04, Close, 167.95
# 2018-01-05, Close, 169.86
# 2018-01-08, Close, 169.23
# 2018-01-09, Close, 169.21
# 2018-01-09, BUY CREATE, 169.21
# 2018-01-10, Close, 169.17
# 2018-01-10, BUY CREATE, 169.17
# 2018-01-11, Close, 170.13
# 2018-01-12, Close, 171.89
# 2018-01-16, Close, 171.01
# 2018-01-17, Close, 173.84
# 2018-01-18, Close, 173.99
# 2018-01-19, Close, 173.22
# 2018-01-22, Close, 171.80
# 2018-01-22, BUY CREATE, 171.80
# 2018-01-23, Close, 171.84
# 2018-01-24, Close, 169.10
# 2018-01-25, Close, 166.08
# 2018-01-25, BUY CREATE, 166.08
# 2018-01-26, Close, 166.47
# 2018-01-29, Close, 163.03
# 2018-01-30, Close, 162.07
# 2018-01-30, BUY CREATE, 162.07
# 2018-01-31, Close, 162.51
# 2018-02-01, Close, 162.85
# 2018-02-02, Close, 155.79
# 2018-02-05, Close, 151.89
# 2018-02-05, BUY CREATE, 151.89
# 2018-02-06, Close, 158.24
# 2018-02-07, Close, 154.85
# 2018-02-08, Close, 150.59
# 2018-02-08, BUY CREATE, 150.59
# 2018-02-09, Close, 152.43
# 2018-02-12, Close, 158.57
# 2018-02-13, Close, 160.16
# 2018-02-14, Close, 163.12
# 2018-02-15, Close, 168.59
# 2018-02-16, Close, 168.05
# 2018-02-20, Close, 167.48
# 2018-02-20, BUY CREATE, 167.48
# 2018-02-21, Close, 166.72
# 2018-02-21, BUY CREATE, 166.72
# 2018-02-22, Close, 168.12
# 2018-02-23, Close, 171.04
# 2018-02-26, Close, 174.42
# 2018-02-27, Close, 173.86
# 2018-02-28, Close, 173.59
# 2018-02-28, BUY CREATE, 173.59
# 2018-03-01, Close, 170.55
# 2018-03-01, BUY CREATE, 170.55
# 2018-03-02, Close, 171.73
# 2018-03-05, Close, 172.33
# 2018-03-06, Close, 172.18
# 2018-03-07, Close, 170.58
# 2018-03-07, BUY CREATE, 170.58
# 2018-03-08, Close, 172.44
# 2018-03-09, Close, 175.41
# 2018-03-12, Close, 177.10
# 2018-03-13, Close, 175.40
# 2018-03-14, Close, 173.90
# 2018-03-14, BUY CREATE, 173.90
# 2018-03-15, Close, 174.11
# 2018-03-16, Close, 173.50
# 2018-03-19, Close, 170.84
# 2018-03-19, BUY CREATE, 170.84
# 2018-03-20, Close, 170.79
# 2018-03-20, BUY CREATE, 170.79
# 2018-03-21, Close, 166.92
# 2018-03-21, BUY CREATE, 166.92
# 2018-03-22, Close, 164.56
# 2018-03-22, BUY CREATE, 164.56
# 2018-03-23, Close, 160.75
# 2018-03-23, BUY CREATE, 160.75
# 2018-03-26, Close, 168.38
# 2018-03-27, Close, 164.06
# 2018-03-28, Close, 162.25
# 2018-03-28, BUY CREATE, 162.25
# 2018-03-29, Close, 163.52
# 2018-04-02, Close, 162.44
# 2018-04-03, Close, 164.11
# 2018-04-04, Close, 167.25
# 2018-04-05, Close, 168.41
# 2018-04-06, Close, 164.10
# 2018-04-09, Close, 165.73
# 2018-04-10, Close, 168.85
# 2018-04-11, Close, 168.06
# 2018-04-12, Close, 169.71
# 2018-04-13, Close, 170.29
# 2018-04-16, Close, 171.35
# 2018-04-17, Close, 173.71
# 2018-04-18, Close, 173.32
# 2018-04-19, Close, 168.41
# 2018-04-19, BUY CREATE, 168.41
# 2018-04-20, Close, 161.51
# 2018-04-20, BUY CREATE, 161.51
# 2018-04-23, Close, 161.04
# 2018-04-23, BUY CREATE, 161.04
# 2018-04-24, Close, 158.80
# 2018-04-24, BUY CREATE, 158.80
# 2018-04-25, Close, 159.49
# 2018-04-26, Close, 160.05
# 2018-04-27, Close, 158.19
# 2018-04-30, Close, 161.06
# 2018-05-01, Close, 164.80
# 2018-05-02, Close, 172.08
# 2018-05-03, Close, 172.39
# 2018-05-04, Close, 179.16
# 2018-05-07, Close, 180.45
# 2018-05-08, Close, 181.32
# 2018-05-09, Close, 182.60
# 2018-05-10, Close, 185.21
# 2018-05-11, Close, 184.51
# 2018-05-14, Close, 184.07
# 2018-05-14, BUY CREATE, 184.07
# 2018-05-15, Close, 182.40
# 2018-05-15, BUY CREATE, 182.40
# 2018-05-16, Close, 184.10
# 2018-05-17, Close, 182.94
# 2018-05-18, Close, 182.27
# 2018-05-18, BUY CREATE, 182.27
# 2018-05-21, Close, 183.57
# 2018-05-22, Close, 183.11
# 2018-05-23, Close, 184.28
# 2018-05-24, Close, 184.07
# 2018-05-25, Close, 184.50
# 2018-05-29, Close, 183.83
# 2018-05-30, Close, 183.44
# 2018-05-30, BUY CREATE, 183.44
# 2018-05-31, Close, 182.82
# 2018-05-31, BUY CREATE, 182.82
# 2018-06-01, Close, 186.12
# 2018-06-04, Close, 187.68
# 2018-06-05, Close, 189.12
# 2018-06-06, Close, 189.78
# 2018-06-07, Close, 189.27
# 2018-06-08, Close, 187.55
# 2018-06-08, BUY CREATE, 187.55
# 2018-06-11, Close, 187.09
# 2018-06-11, BUY CREATE, 187.09
# 2018-06-12, Close, 188.12
# 2018-06-13, Close, 186.57
# 2018-06-14, Close, 186.67
# 2018-06-15, Close, 184.75
# 2018-06-18, Close, 184.65
# 2018-06-18, BUY CREATE, 184.65
# 2018-06-19, Close, 181.67
# 2018-06-19, BUY CREATE, 181.67
# 2018-06-20, Close, 182.46
# 2018-06-21, Close, 181.44
# 2018-06-22, Close, 180.91
# 2018-06-22, BUY CREATE, 180.91
# 2018-06-25, Close, 178.22
# 2018-06-25, BUY CREATE, 178.22
# 2018-06-26, Close, 180.44
# 2018-06-27, Close, 180.17
# 2018-06-28, Close, 181.48
# 2018-06-29, Close, 181.10
# 2018-07-02, Close, 183.13
# 2018-07-03, Close, 179.94
# 2018-07-05, Close, 181.38
# 2018-07-06, Close, 183.90
# 2018-07-09, Close, 186.45
# 2018-07-10, Close, 186.23
# 2018-07-11, Close, 183.81
# 2018-07-11, BUY CREATE, 183.81
# 2018-07-12, Close, 186.89
# 2018-07-13, Close, 187.19
# 2018-07-16, Close, 186.78
# 2018-07-17, Close, 187.30
# 2018-07-18, Close, 186.28
# 2018-07-19, Close, 187.72
# 2018-07-20, Close, 187.29
# 2018-07-23, Close, 187.46
# 2018-07-24, Close, 188.82
# 2018-07-25, Close, 190.60
# 2018-07-26, Close, 190.00
# 2018-07-27, Close, 186.84
# 2018-07-27, BUY CREATE, 186.84
# 2018-07-30, Close, 185.80
# 2018-07-30, BUY CREATE, 185.80
# 2018-07-31, Close, 186.17
# 2018-08-01, Close, 197.14
# 2018-08-02, Close, 202.90
# 2018-08-03, Close, 203.49
# 2018-08-06, Close, 204.54
# 2018-08-07, Close, 202.62
# 2018-08-08, Close, 202.76
# 2018-08-09, Close, 204.36
# 2018-08-10, Close, 203.75
# 2018-08-13, Close, 205.06
# 2018-08-14, Close, 205.93
# 2018-08-15, Close, 206.41
# 2018-08-16, Close, 209.43
# 2018-08-17, Close, 213.61
# 2018-08-20, Close, 211.53
# 2018-08-21, Close, 211.12
# 2018-08-21, BUY CREATE, 211.12
# 2018-08-22, Close, 211.13
# 2018-08-23, Close, 211.56
# 2018-08-24, Close, 212.22
# 2018-08-27, Close, 213.97
# 2018-08-28, Close, 215.70
# 2018-08-29, Close, 218.92
# 2018-08-30, Close, 220.93
# 2018-08-31, Close, 223.48
# 2018-09-04, Close, 224.20
# 2018-09-05, Close, 222.73
# 2018-09-06, Close, 219.03
# 2018-09-06, BUY CREATE, 219.03
# 2018-09-07, Close, 217.27
# 2018-09-07, BUY CREATE, 217.27
# 2018-09-10, Close, 214.35
# 2018-09-10, BUY CREATE, 214.35
# 2018-09-11, Close, 219.77
# 2018-09-12, Close, 217.04
# 2018-09-13, Close, 222.28
# 2018-09-14, Close, 219.76
# 2018-09-17, Close, 213.91
# 2018-09-17, BUY CREATE, 213.91
# 2018-09-18, Close, 214.26
# 2018-09-19, Close, 214.39
# 2018-09-20, Close, 216.02
# 2018-09-21, Close, 213.69
# 2018-09-24, Close, 216.77
# 2018-09-25, Close, 218.14
# 2018-09-26, Close, 216.40
# 2018-09-27, Close, 220.85
# 2018-09-28, Close, 221.63
# 2018-10-01, Close, 223.12
# 2018-10-02, Close, 225.10
# 2018-10-03, Close, 227.84
# 2018-10-04, Close, 223.83
# 2018-10-05, Close, 220.20
# 2018-10-05, BUY CREATE, 220.20
# 2018-10-08, Close, 219.69
# 2018-10-08, BUY CREATE, 219.69
# 2018-10-09, Close, 222.73
# 2018-10-10, Close, 212.42
# 2018-10-11, Close, 210.54
# 2018-10-11, BUY CREATE, 210.54
# 2018-10-12, Close, 218.06
# 2018-10-15, Close, 213.40
# 2018-10-16, Close, 218.10
# 2018-10-17, Close, 217.16
# 2018-10-18, Close, 212.08
# 2018-10-18, BUY CREATE, 212.08
# 2018-10-19, Close, 215.31
# 2018-10-22, Close, 216.63
# 2018-10-23, Close, 218.67
# 2018-10-24, Close, 211.17
# 2018-10-25, Close, 215.79
# 2018-10-26, Close, 212.36
# 2018-10-29, Close, 208.37
# 2018-10-29, BUY CREATE, 208.37
# 2018-10-30, Close, 209.41
# 2018-10-31, Close, 214.87
# 2018-11-01, Close, 218.17
# 2018-11-02, Close, 203.70
# 2018-11-05, Close, 197.92
# 2018-11-05, BUY CREATE, 197.92
# 2018-11-06, Close, 200.06
# 2018-11-07, Close, 206.12
# 2018-11-08, Close, 205.40
# 2018-11-09, Close, 201.44
# 2018-11-09, BUY CREATE, 201.44
# 2018-11-12, Close, 191.30
# 2018-11-12, BUY CREATE, 191.30
# 2018-11-13, Close, 189.38
# 2018-11-13, BUY CREATE, 189.38
# 2018-11-14, Close, 184.03
# 2018-11-14, BUY CREATE, 184.03
# 2018-11-15, Close, 188.58
# 2018-11-16, Close, 190.67
# 2018-11-19, Close, 183.11
# 2018-11-20, Close, 174.36
# 2018-11-20, BUY CREATE, 174.36
# 2018-11-21, Close, 174.16
# 2018-11-21, BUY CREATE, 174.16
# 2018-11-23, Close, 169.74
# 2018-11-23, BUY CREATE, 169.74
# 2018-11-26, Close, 172.04
# 2018-11-27, Close, 171.66
# 2018-11-28, Close, 178.26
# 2018-11-29, Close, 176.89
# 2018-11-30, Close, 175.94
# 2018-11-30, BUY CREATE, 175.94
# 2018-12-03, Close, 182.08
# 2018-12-04, Close, 174.07
# 2018-12-06, Close, 172.13
# 2018-12-06, BUY CREATE, 172.13
# 2018-12-07, Close, 166.00
# 2018-12-07, BUY CREATE, 166.00
# 2018-12-10, Close, 167.09
# 2018-12-11, Close, 166.13
# 2018-12-12, Close, 166.60
# 2018-12-13, Close, 168.42
# 2018-12-14, Close, 163.03
# 2018-12-17, Close, 161.51
# 2018-12-17, BUY CREATE, 161.51
# 2018-12-18, Close, 163.61
# 2018-12-19, Close, 158.51
# 2018-12-20, Close, 154.51
# 2018-12-20, BUY CREATE, 154.51
# 2018-12-21, Close, 148.50
# 2018-12-21, BUY CREATE, 148.50
# 2018-12-24, Close, 144.66
# 2018-12-24, BUY CREATE, 144.66
# 2018-12-26, Close, 154.84
# 2018-12-27, Close, 153.84
# 2018-12-28, Close, 153.92
# 2018-12-31, Close, 155.41
# 2019-01-02, Close, 155.58
# 2019-01-03, Close, 140.09
# 2019-01-04, Close, 146.07
# 2019-01-07, Close, 145.74
# 2019-01-08, Close, 148.52
# 2019-01-09, Close, 151.04
# 2019-01-10, Close, 151.52
# 2019-01-11, Close, 150.04
# 2019-01-14, Close, 147.78
# 2019-01-14, BUY CREATE, 147.78
# 2019-01-15, Close, 150.80
# 2019-01-16, Close, 152.65
# 2019-01-17, Close, 153.55
# 2019-01-18, Close, 154.50
# 2019-01-22, Close, 151.03
# 2019-01-23, Close, 151.64
# 2019-01-24, Close, 150.44
# 2019-01-25, Close, 155.42
# 2019-01-28, Close, 153.99
# 2019-01-29, Close, 152.39
# 2019-01-29, BUY CREATE, 152.39
# 2019-01-30, Close, 162.80
# 2019-01-31, Close, 163.98
# 2019-02-01, Close, 164.06
# 2019-02-04, Close, 168.72
# 2019-02-05, Close, 171.60
# 2019-02-06, Close, 171.66
# 2019-02-07, Close, 168.41
# 2019-02-08, Close, 168.61
# 2019-02-11, Close, 167.64
# 2019-02-12, Close, 169.08
# 2019-02-13, Close, 168.38
# 2019-02-14, Close, 168.99
# 2019-02-15, Close, 168.62
# 2019-02-19, Close, 169.12
# 2019-02-20, Close, 170.21
# 2019-02-21, Close, 169.25
# 2019-02-22, Close, 171.14
# 2019-02-25, Close, 172.39
# 2019-02-26, Close, 172.49
# 2019-02-27, Close, 173.02
# 2019-02-28, Close, 171.32
# 2019-03-01, Close, 173.12
# 2019-03-04, Close, 173.99
# 2019-03-05, Close, 173.67
# 2019-03-06, Close, 172.67
# 2019-03-06, BUY CREATE, 172.67
# 2019-03-07, Close, 170.68
# 2019-03-07, BUY CREATE, 170.68
# 2019-03-08, Close, 171.08
# 2019-03-11, Close, 177.01
# 2019-03-12, Close, 179.00
# 2019-03-13, Close, 179.79
# 2019-03-14, Close, 181.79
# 2019-03-15, Close, 184.15
# 2019-03-18, Close, 186.03
# 2019-03-19, Close, 184.56
# 2019-03-20, Close, 186.17
# 2019-03-21, Close, 193.03
# 2019-03-22, Close, 189.03
# 2019-03-25, Close, 186.74
# 2019-03-25, BUY CREATE, 186.74
# 2019-03-26, Close, 184.81
# 2019-03-26, BUY CREATE, 184.81
# 2019-03-27, Close, 186.48
# 2019-03-28, Close, 186.72
# 2019-03-29, Close, 187.94
# 2019-04-01, Close, 189.22
# 2019-04-02, Close, 191.97
# 2019-04-03, Close, 193.28
# 2019-04-04, Close, 193.62
# 2019-04-05, Close, 194.92
# 2019-04-08, Close, 197.98
# 2019-04-09, Close, 197.39
# 2019-04-10, Close, 198.50
# 2019-04-11, Close, 196.85
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE, 196.77
# 2019-04-15, Close, 197.12
# 2019-04-16, Close, 197.14
# 2019-04-17, Close, 200.98
# 2019-04-18, Close, 201.70
# 2019-04-22, Close, 202.37
# 2019-04-23, Close, 205.29
# 2019-04-24, Close, 204.97
# 2019-04-25, Close, 203.11
# 2019-04-25, BUY CREATE, 203.11
# 2019-04-26, Close, 202.14
# 2019-04-26, BUY CREATE, 202.14
# 2019-04-29, Close, 202.45
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-02, Close, 206.94
# 2019-05-03, Close, 209.51
# 2019-05-06, Close, 206.27
# 2019-05-07, Close, 200.71
# 2019-05-07, BUY CREATE, 200.71
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-10, BUY CREATE, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-13, BUY CREATE, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-17, BUY CREATE, 187.72
# 2019-05-20, Close, 181.85
# 2019-05-20, BUY CREATE, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-23, BUY CREATE, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-24, BUY CREATE, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-28, BUY CREATE, 177.02
# 2019-05-29, Close, 176.18
# 2019-05-29, BUY CREATE, 176.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-03, BUY CREATE, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-06, Close, 183.97
# 2019-06-07, Close, 188.86
# 2019-06-10, Close, 191.28
# 2019-06-11, Close, 193.49
# 2019-06-12, Close, 192.88
# 2019-06-13, Close, 192.84
# 2019-06-13, BUY CREATE, 192.84
# 2019-06-14, Close, 191.44
# 2019-06-14, BUY CREATE, 191.44
# 2019-06-17, Close, 192.58
# 2019-06-18, Close, 197.11
# 2019-06-19, Close, 196.53
# 2019-06-20, Close, 198.11
# 2019-06-21, Close, 197.43
# 2019-06-24, Close, 197.24
# 2019-06-24, BUY CREATE, 197.24
# 2019-06-25, Close, 194.25
# 2019-06-25, BUY CREATE, 194.25
# 2019-06-26, Close, 198.45
# 2019-06-27, Close, 198.39
# 2019-06-28, Close, 196.58
# 2019-06-28, BUY CREATE, 196.58
# 2019-07-01, Close, 200.19
# 2019-07-02, Close, 201.36
# 2019-07-03, Close, 203.03
# 2019-07-05, Close, 202.85
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE, 198.67
# 2019-07-09, Close, 199.88
# 2019-07-10, Close, 201.85
# 2019-07-11, Close, 200.38
# 2019-07-12, Close, 201.92
# 2019-07-15, Close, 203.82
# 2019-07-16, Close, 203.12
# 2019-07-17, Close, 201.97
# 2019-07-17, BUY CREATE, 201.97
# 2019-07-18, Close, 204.27
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-23, Close, 207.43
# 2019-07-24, Close, 207.26
# 2019-07-25, Close, 205.62
# 2019-07-25, BUY CREATE, 205.62
# 2019-07-26, Close, 206.33
# 2019-07-29, Close, 208.26
# 2019-07-30, Close, 207.37
# 2019-07-31, Close, 211.60
# 2019-08-01, Close, 207.02
# 2019-08-02, Close, 202.64
# 2019-08-02, BUY CREATE, 202.64
# 2019-08-05, Close, 192.03
# 2019-08-05, BUY CREATE, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-12, BUY CREATE, 199.88
# 2019-08-13, Close, 208.34
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-15, BUY CREATE, 201.14
# 2019-08-16, Close, 205.88
# 2019-08-19, Close, 209.72
# 2019-08-20, Close, 209.73
# 2019-08-21, Close, 212.00
# 2019-08-22, Close, 211.82
# 2019-08-23, Close, 202.03
# 2019-08-23, BUY CREATE, 202.03
# 2019-08-26, Close, 205.87
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-30, Close, 208.12
# 2019-09-03, Close, 205.08
# 2019-09-03, BUY CREATE, 205.08
# 2019-09-04, Close, 208.56
# 2019-09-05, Close, 212.64
# 2019-09-06, Close, 212.62
# 2019-09-09, Close, 213.53
# 2019-09-10, Close, 216.05
# 2019-09-11, Close, 222.92
# 2019-09-12, Close, 222.42
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE, 218.10
# 2019-09-16, Close, 219.24
# 2019-09-17, Close, 220.04
# 2019-09-18, Close, 222.10
# 2019-09-19, Close, 220.30
# 2019-09-20, Close, 217.08
# 2019-09-20, BUY CREATE, 217.08
# 2019-09-23, Close, 218.07
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-26, Close, 219.23
# 2019-09-27, Close, 218.17
# 2019-09-27, BUY CREATE, 218.17
# 2019-09-30, Close, 223.30
# 2019-10-01, Close, 223.92
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-04, Close, 226.33
# 2019-10-07, Close, 226.38
# 2019-10-08, Close, 223.73
# 2019-10-09, Close, 226.35
# 2019-10-10, Close, 229.40
# 2019-10-11, Close, 235.50
# 2019-10-14, Close, 235.16
# 2019-10-15, Close, 234.62
# 2019-10-15, BUY CREATE, 234.62
# 2019-10-16, Close, 233.67
# 2019-10-16, BUY CREATE, 233.67
# 2019-10-17, Close, 234.58
# 2019-10-18, Close, 235.70
# 2019-10-21, Close, 239.79
# 2019-10-22, Close, 239.24
# 2019-10-23, Close, 242.45
# 2019-10-24, Close, 242.85
# 2019-10-25, Close, 245.84
# 2019-10-28, Close, 248.30
# 2019-10-29, Close, 242.56
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE, 242.53
# 2019-10-31, Close, 248.02
# 2019-11-01, Close, 255.05
# 2019-11-04, Close, 256.73
# 2019-11-05, Close, 256.36
# 2019-11-06, Close, 256.47
# 2019-11-07, Close, 259.43
# 2019-11-08, Close, 260.14
# 2019-11-11, Close, 262.20
# 2019-11-12, Close, 261.96
# 2019-11-13, Close, 264.47
# 2019-11-14, Close, 262.64
# 2019-11-15, Close, 265.76
# 2019-11-18, Close, 267.10
# 2019-11-19, Close, 266.29
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE, 263.19
# 2019-11-21, Close, 262.01
# 2019-11-21, BUY CREATE, 262.01
# 2019-11-22, Close, 261.78
# 2019-11-22, BUY CREATE, 261.78
# 2019-11-25, Close, 266.37
# 2019-11-26, Close, 264.29
# 2019-11-27, Close, 267.84
# 2019-11-29, Close, 267.25
# 2019-12-02, Close, 264.16
# 2019-12-02, BUY CREATE, 264.16
# 2019-12-03, Close, 259.45
# 2019-12-03, BUY CREATE, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-06, Close, 270.71
# 2019-12-09, Close, 266.92
# 2019-12-10, Close, 268.48
# 2019-12-11, Close, 270.77
# 2019-12-12, Close, 271.46
# 2019-12-13, Close, 275.15
# 2019-12-16, Close, 279.86
# 2019-12-17, Close, 280.41
# 2019-12-18, Close, 279.74
# 2019-12-19, Close, 280.02
# 2019-12-20, Close, 279.44
# 2019-12-23, Close, 284.00
# 2019-12-24, Close, 284.27
# 2019-12-26, Close, 289.91
# 2019-12-27, Close, 289.80
# 2019-12-30, Close, 291.52
# 2019-12-31, Close, 293.65
# 2020-01-02, Close, 300.35
# 2020-01-03, Close, 297.43
# 2020-01-06, Close, 299.80
# 2020-01-07, Close, 298.39
# 2020-01-08, Close, 303.19
# 2020-01-09, Close, 309.63
# Final Portfolio Value: 144582.76

# %% [markdown]
# ## Do not only buy ... but SELL
#
# After knowing how to enter the market (long), an “exit concept” is needed and also understanding whether the strategy is in the market.
#
# - Luckily a `Strategy` object offers access to a position attribute for the default data feed
#
# - Methods `.buy` and `.sell` return the created (not yet executed) order
#
# - Changes in orders’ status will be notified to the strategy via a `notify` method
#
# The “exit concept” will be an easy one:
#
# - Exit after 5 bars (on the 6th bar) have elapsed for good or for worse. Please notice that there is no “time” or “timeframe” implied: number of bars. The bars can represent 1 minute, 1 hour, 1 day, 1 week or any other time period. Although we know the data source is a daily one, the strategy makes no assumption about that.
#
# Additionally and to simplify:
#
# - Do only allow a Buy order if not yet in the market
#
# 추가된 부분을 잘 살피자.

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders
        self.order = None #### 추가된 부분. 

    def notify_order(self, order): ### 추가된 부분. 
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + 5):
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2015-01-02, Close, 100.45
# 2015-01-05, Close, 97.62
# 2015-01-05, BUY CREATE, 97.62
# 2015-01-06, BUY EXECUTED, 97.89
# 2015-01-06, Close, 97.63
# 2015-01-07, Close, 99.00
# 2015-01-08, Close, 102.81
# 2015-01-09, Close, 102.92
# 2015-01-12, Close, 100.38
# 2015-01-13, Close, 101.27
# 2015-01-13, SELL CREATE, 101.27
# 2015-01-14, SELL EXECUTED, 100.19
# 2015-01-14, Close, 100.89
# 2015-01-15, Close, 98.15
# 2015-01-15, BUY CREATE, 98.15
# 2015-01-16, BUY EXECUTED, 98.34
# 2015-01-16, Close, 97.39
# 2015-01-20, Close, 99.89
# 2015-01-21, Close, 100.66
# 2015-01-22, Close, 103.28
# 2015-01-23, Close, 103.81
# 2015-01-26, Close, 103.92
# 2015-01-26, SELL CREATE, 103.92
# 2015-01-27, SELL EXECUTED, 103.29
# 2015-01-27, Close, 100.28
# 2015-01-28, Close, 105.95
# 2015-01-29, Close, 109.25
# 2015-01-30, Close, 107.65
# 2015-02-02, Close, 109.00
# 2015-02-03, Close, 109.02
# 2015-02-04, Close, 109.85
# 2015-02-05, Close, 110.64
# 2015-02-06, Close, 109.71
# 2015-02-09, Close, 110.43
# 2015-02-10, Close, 112.56
# 2015-02-11, Close, 115.19
# 2015-02-12, Close, 116.65
# 2015-02-13, Close, 117.22
# 2015-02-17, Close, 117.92
# 2015-02-18, Close, 118.74
# 2015-02-19, Close, 118.49
# 2015-02-20, Close, 119.46
# 2015-02-23, Close, 122.68
# 2015-02-24, Close, 121.92
# 2015-02-25, Close, 118.80
# 2015-02-25, BUY CREATE, 118.80
# 2015-02-26, BUY EXECUTED, 118.80
# 2015-02-26, Close, 120.31
# 2015-02-27, Close, 118.50
# 2015-03-02, Close, 119.08
# 2015-03-03, Close, 119.33
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-05, SELL CREATE, 116.61
# 2015-03-06, SELL EXECUTED, 118.44
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-11, BUY CREATE, 112.76
# 2015-03-12, BUY EXECUTED, 112.82
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-18, Close, 118.51
# 2015-03-19, Close, 117.61
# 2015-03-19, SELL CREATE, 117.61
# 2015-03-20, SELL EXECUTED, 118.30
# 2015-03-20, Close, 116.14
# 2015-03-20, BUY CREATE, 116.14
# 2015-03-23, BUY EXECUTED, 117.26
# 2015-03-23, Close, 117.34
# 2015-03-24, Close, 116.86
# 2015-03-25, Close, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-30, SELL CREATE, 116.57
# 2015-03-31, SELL EXECUTED, 116.31
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-01, BUY CREATE, 114.61
# 2015-04-02, BUY EXECUTED, 115.33
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-07, Close, 116.24
# 2015-04-08, Close, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-10, Close, 117.24
# 2015-04-10, SELL CREATE, 117.24
# 2015-04-13, SELL EXECUTED, 118.41
# 2015-04-13, Close, 117.01
# 2015-04-14, Close, 116.50
# 2015-04-14, BUY CREATE, 116.50
# 2015-04-15, BUY EXECUTED, 116.61
# 2015-04-15, Close, 116.95
# 2015-04-16, Close, 116.38
# 2015-04-17, Close, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-21, Close, 117.07
# 2015-04-22, Close, 118.64
# 2015-04-22, SELL CREATE, 118.64
# 2015-04-23, SELL EXECUTED, 118.35
# 2015-04-23, Close, 119.61
# 2015-04-24, Close, 120.18
# 2015-04-27, Close, 122.36
# 2015-04-28, Close, 120.43
# 2015-04-29, Close, 118.66
# 2015-04-29, BUY CREATE, 118.66
# 2015-04-30, BUY EXECUTED, 118.66
# 2015-04-30, Close, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-04, Close, 118.72
# 2015-05-05, Close, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-07, SELL CREATE, 116.03
# 2015-05-08, SELL EXECUTED, 117.34
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-12, BUY CREATE, 116.59
# 2015-05-13, BUY EXECUTED, 116.85
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-15, Close, 119.28
# 2015-05-18, Close, 120.59
# 2015-05-19, Close, 120.48
# 2015-05-20, Close, 120.47
# 2015-05-20, SELL CREATE, 120.47
# 2015-05-21, SELL EXECUTED, 120.48
# 2015-05-21, Close, 121.71
# 2015-05-22, Close, 122.77
# 2015-05-26, Close, 120.07
# 2015-05-27, Close, 122.31
# 2015-05-28, Close, 122.07
# 2015-05-29, Close, 120.68
# 2015-05-29, BUY CREATE, 120.68
# 2015-06-01, BUY EXECUTED, 120.68
# 2015-06-01, Close, 120.92
# 2015-06-02, Close, 120.38
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-08, SELL CREATE, 118.38
# 2015-06-09, SELL EXECUTED, 117.36
# 2015-06-09, Close, 118.03
# 2015-06-09, BUY CREATE, 118.03
# 2015-06-10, BUY EXECUTED, 118.49
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-17, SELL CREATE, 117.92
# 2015-06-18, SELL EXECUTED, 117.85
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-26, BUY CREATE, 117.41
# 2015-06-29, BUY EXECUTED, 116.21
# 2015-06-29, Close, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-07, SELL CREATE, 116.43
# 2015-07-08, SELL EXECUTED, 115.31
# 2015-07-08, Close, 113.54
# 2015-07-08, BUY CREATE, 113.54
# 2015-07-09, BUY EXECUTED, 114.72
# 2015-07-09, Close, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-14, Close, 116.35
# 2015-07-15, Close, 117.47
# 2015-07-16, Close, 119.04
# 2015-07-16, SELL CREATE, 119.04
# 2015-07-17, SELL EXECUTED, 119.57
# 2015-07-17, Close, 120.07
# 2015-07-20, Close, 122.34
# 2015-07-21, Close, 121.11
# 2015-07-22, Close, 115.99
# 2015-07-22, BUY CREATE, 115.99
# 2015-07-23, BUY EXECUTED, 116.90
# 2015-07-23, Close, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-30, SELL CREATE, 113.35
# 2015-07-31, SELL EXECUTED, 113.56
# 2015-07-31, Close, 112.36
# 2015-07-31, BUY CREATE, 112.36
# 2015-08-03, BUY EXECUTED, 112.55
# 2015-08-03, Close, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-10, SELL CREATE, 111.40
# 2015-08-11, SELL EXECUTED, 109.62
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-19, BUY CREATE, 107.02
# 2015-08-20, BUY EXECUTED, 106.15
# 2015-08-20, Close, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-27, SELL CREATE, 105.07
# 2015-08-28, SELL EXECUTED, 104.37
# 2015-08-28, Close, 105.42
# 2015-08-31, Close, 104.92
# 2015-09-01, Close, 100.23
# 2015-09-01, BUY CREATE, 100.23
# 2015-09-02, BUY EXECUTED, 102.57
# 2015-09-02, Close, 104.53
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-09, Close, 102.49
# 2015-09-10, Close, 104.75
# 2015-09-10, SELL CREATE, 104.75
# 2015-09-11, SELL EXECUTED, 104.02
# 2015-09-11, Close, 106.27
# 2015-09-14, Close, 107.29
# 2015-09-15, Close, 108.20
# 2015-09-16, Close, 108.32
# 2015-09-17, Close, 106.00
# 2015-09-18, Close, 105.56
# 2015-09-18, BUY CREATE, 105.56
# 2015-09-21, BUY EXECUTED, 105.77
# 2015-09-21, Close, 107.20
# 2015-09-22, Close, 105.52
# 2015-09-23, Close, 106.37
# 2015-09-24, Close, 107.01
# 2015-09-25, Close, 106.74
# 2015-09-28, Close, 104.62
# 2015-09-28, SELL CREATE, 104.62
# 2015-09-29, SELL EXECUTED, 104.99
# 2015-09-29, Close, 101.48
# 2015-09-29, BUY CREATE, 101.48
# 2015-09-30, BUY EXECUTED, 102.51
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-07, SELL CREATE, 103.08
# 2015-10-08, SELL EXECUTED, 102.53
# 2015-10-08, Close, 101.89
# 2015-10-08, BUY CREATE, 101.89
# 2015-10-09, BUY EXECUTED, 102.35
# 2015-10-09, Close, 104.33
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-16, Close, 103.32
# 2015-10-16, SELL CREATE, 103.32
# 2015-10-19, SELL EXECUTED, 103.10
# 2015-10-19, Close, 103.96
# 2015-10-20, Close, 105.86
# 2015-10-21, Close, 105.85
# 2015-10-22, Close, 107.47
# 2015-10-23, Close, 110.80
# 2015-10-26, Close, 107.27
# 2015-10-27, Close, 106.59
# 2015-10-27, BUY CREATE, 106.59
# 2015-10-28, BUY EXECUTED, 108.80
# 2015-10-28, Close, 110.98
# 2015-10-29, Close, 112.15
# 2015-10-30, Close, 111.19
# 2015-11-02, Close, 112.76
# 2015-11-03, Close, 114.05
# 2015-11-04, Close, 113.52
# 2015-11-04, SELL CREATE, 113.52
# 2015-11-05, SELL EXECUTED, 113.87
# 2015-11-05, Close, 113.00
# 2015-11-05, BUY CREATE, 113.00
# 2015-11-06, BUY EXECUTED, 113.17
# 2015-11-06, Close, 113.13
# 2015-11-09, Close, 112.67
# 2015-11-10, Close, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-13, SELL CREATE, 104.98
# 2015-11-16, SELL EXECUTED, 104.08
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-20, Close, 111.48
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-25, Close, 110.30
# 2015-11-27, Close, 110.09
# 2015-11-27, BUY CREATE, 110.09
# 2015-11-30, BUY EXECUTED, 110.26
# 2015-11-30, Close, 110.55
# 2015-12-01, Close, 109.65
# 2015-12-02, Close, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-07, Close, 110.53
# 2015-12-07, SELL CREATE, 110.53
# 2015-12-08, SELL EXECUTED, 109.82
# 2015-12-08, Close, 110.48
# 2015-12-08, BUY CREATE, 110.48
# 2015-12-09, BUY EXECUTED, 109.93
# 2015-12-09, Close, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-16, SELL CREATE, 104.04
# 2015-12-17, SELL EXECUTED, 104.68
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-18, BUY CREATE, 99.08
# 2015-12-21, BUY EXECUTED, 100.25
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-29, SELL CREATE, 101.61
# 2015-12-30, SELL EXECUTED, 101.47
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2015-12-31, BUY CREATE, 98.36
# 2016-01-04, BUY EXECUTED, 95.89
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-11, SELL CREATE, 92.07
# 2016-01-12, SELL EXECUTED, 93.96
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-19, BUY CREATE, 90.33
# 2016-01-20, BUY EXECUTED, 88.87
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-27, SELL CREATE, 87.30
# 2016-01-28, SELL EXECUTED, 87.64
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-02, BUY CREATE, 88.29
# 2016-02-03, BUY EXECUTED, 88.77
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-05, Close, 88.34
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-10, SELL CREATE, 88.57
# 2016-02-11, SELL EXECUTED, 88.12
# 2016-02-11, Close, 88.04
# 2016-02-11, BUY CREATE, 88.04
# 2016-02-12, BUY EXECUTED, 88.50
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-17, Close, 92.19
# 2016-02-18, Close, 90.44
# 2016-02-19, Close, 90.23
# 2016-02-22, Close, 91.02
# 2016-02-22, SELL CREATE, 91.02
# 2016-02-23, SELL EXECUTED, 90.57
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-25, Close, 90.91
# 2016-02-26, Close, 91.05
# 2016-02-29, Close, 90.84
# 2016-03-01, Close, 94.45
# 2016-03-02, Close, 94.66
# 2016-03-03, Close, 95.36
# 2016-03-04, Close, 96.78
# 2016-03-07, Close, 95.71
# 2016-03-08, Close, 94.92
# 2016-03-08, BUY CREATE, 94.92
# 2016-03-09, BUY EXECUTED, 95.19
# 2016-03-09, Close, 95.01
# 2016-03-10, Close, 95.05
# 2016-03-11, Close, 96.08
# 2016-03-14, Close, 96.32
# 2016-03-15, Close, 98.26
# 2016-03-16, Close, 99.56
# 2016-03-16, SELL CREATE, 99.56
# 2016-03-17, SELL EXECUTED, 99.14
# 2016-03-17, Close, 99.40
# 2016-03-18, Close, 99.52
# 2016-03-21, Close, 99.51
# 2016-03-22, Close, 100.27
# 2016-03-23, Close, 99.71
# 2016-03-24, Close, 99.28
# 2016-03-24, BUY CREATE, 99.28
# 2016-03-28, BUY EXECUTED, 99.59
# 2016-03-28, Close, 98.83
# 2016-03-29, Close, 101.17
# 2016-03-30, Close, 102.94
# 2016-03-31, Close, 102.40
# 2016-04-01, Close, 103.34
# 2016-04-04, Close, 104.40
# 2016-04-04, SELL CREATE, 104.40
# 2016-04-05, SELL EXECUTED, 102.89
# 2016-04-05, Close, 103.17
# 2016-04-06, Close, 104.25
# 2016-04-07, Close, 101.98
# 2016-04-08, Close, 102.09
# 2016-04-11, Close, 102.43
# 2016-04-12, Close, 103.76
# 2016-04-13, Close, 105.27
# 2016-04-14, Close, 105.32
# 2016-04-15, Close, 103.21
# 2016-04-18, Close, 100.98
# 2016-04-18, BUY CREATE, 100.98
# 2016-04-19, BUY EXECUTED, 101.36
# 2016-04-19, Close, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-26, SELL CREATE, 98.04
# 2016-04-27, SELL EXECUTED, 90.20
# 2016-04-27, Close, 91.91
# 2016-04-27, BUY CREATE, 91.91
# 2016-04-28, BUY EXECUTED, 91.71
# 2016-04-28, Close, 89.10
# 2016-04-29, Close, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-05, SELL CREATE, 88.14
# 2016-05-06, SELL EXECUTED, 88.26
# 2016-05-06, Close, 87.64
# 2016-05-06, BUY CREATE, 87.64
# 2016-05-09, BUY EXECUTED, 87.91
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-16, SELL CREATE, 88.74
# 2016-05-17, SELL EXECUTED, 89.37
# 2016-05-17, Close, 88.37
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-05-31, BUY CREATE, 94.39
# 2016-06-01, BUY EXECUTED, 93.60
# 2016-06-01, Close, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-08, SELL CREATE, 93.52
# 2016-06-09, SELL EXECUTED, 93.11
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-13, BUY CREATE, 92.01
# 2016-06-14, BUY EXECUTED, 91.99
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-21, SELL CREATE, 90.66
# 2016-06-22, SELL EXECUTED, 90.98
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-27, BUY CREATE, 87.00
# 2016-06-28, BUY EXECUTED, 87.81
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-05, Close, 89.79
# 2016-07-06, Close, 90.30
# 2016-07-06, SELL CREATE, 90.30
# 2016-07-07, SELL EXECUTED, 90.46
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-22, BUY CREATE, 93.26
# 2016-07-25, BUY EXECUTED, 92.87
# 2016-07-25, Close, 92.01
# 2016-07-26, Close, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-28, Close, 98.63
# 2016-07-29, Close, 98.51
# 2016-08-01, Close, 100.25
# 2016-08-01, SELL CREATE, 100.25
# 2016-08-02, SELL EXECUTED, 100.25
# 2016-08-02, Close, 98.76
# 2016-08-03, Close, 100.00
# 2016-08-04, Close, 100.62
# 2016-08-05, Close, 102.15
# 2016-08-08, Close, 102.99
# 2016-08-09, Close, 103.41
# 2016-08-10, Close, 102.64
# 2016-08-11, Close, 102.57
# 2016-08-11, BUY CREATE, 102.57
# 2016-08-12, BUY EXECUTED, 102.43
# 2016-08-12, Close, 102.81
# 2016-08-15, Close, 104.05
# 2016-08-16, Close, 103.95
# 2016-08-17, Close, 103.80
# 2016-08-18, Close, 103.67
# 2016-08-19, Close, 103.93
# 2016-08-19, SELL CREATE, 103.93
# 2016-08-22, SELL EXECUTED, 103.46
# 2016-08-22, Close, 103.13
# 2016-08-23, Close, 103.45
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-25, BUY CREATE, 102.23
# 2016-08-26, BUY EXECUTED, 102.08
# 2016-08-26, Close, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-02, SELL CREATE, 102.38
# 2016-09-06, SELL EXECUTED, 102.55
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-09, BUY CREATE, 98.01
# 2016-09-12, BUY EXECUTED, 97.56
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-14, Close, 106.22
# 2016-09-15, Close, 109.84
# 2016-09-16, Close, 109.22
# 2016-09-19, Close, 107.94
# 2016-09-19, SELL CREATE, 107.94
# 2016-09-20, SELL EXECUTED, 107.44
# 2016-09-20, Close, 107.94
# 2016-09-21, Close, 107.92
# 2016-09-22, Close, 108.93
# 2016-09-23, Close, 107.12
# 2016-09-26, Close, 107.28
# 2016-09-27, Close, 107.48
# 2016-09-28, Close, 108.30
# 2016-09-29, Close, 106.61
# 2016-09-30, Close, 107.44
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-07, Close, 108.40
# 2016-10-10, Close, 110.29
# 2016-10-11, Close, 110.53
# 2016-10-12, Close, 111.52
# 2016-10-13, Close, 111.18
# 2016-10-14, Close, 111.79
# 2016-10-17, Close, 111.72
# 2016-10-18, Close, 111.64
# 2016-10-18, BUY CREATE, 111.64
# 2016-10-19, BUY EXECUTED, 111.43
# 2016-10-19, Close, 111.31
# 2016-10-20, Close, 111.25
# 2016-10-21, Close, 110.81
# 2016-10-24, Close, 111.81
# 2016-10-25, Close, 112.38
# 2016-10-26, Close, 109.85
# 2016-10-26, SELL CREATE, 109.85
# 2016-10-27, SELL EXECUTED, 109.66
# 2016-10-27, Close, 108.80
# 2016-10-27, BUY CREATE, 108.80
# 2016-10-28, BUY EXECUTED, 108.22
# 2016-10-28, Close, 108.08
# 2016-10-31, Close, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-04, SELL CREATE, 103.97
# 2016-11-07, SELL EXECUTED, 105.16
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-10, BUY CREATE, 102.97
# 2016-11-11, BUY EXECUTED, 102.33
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-18, Close, 105.14
# 2016-11-18, SELL CREATE, 105.14
# 2016-11-21, SELL EXECUTED, 105.19
# 2016-11-21, Close, 106.73
# 2016-11-22, Close, 106.80
# 2016-11-23, Close, 106.25
# 2016-11-25, Close, 106.79
# 2016-11-28, Close, 106.58
# 2016-11-29, Close, 106.47
# 2016-11-29, BUY CREATE, 106.47
# 2016-11-30, BUY EXECUTED, 106.61
# 2016-11-30, Close, 105.58
# 2016-12-01, Close, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-07, SELL CREATE, 106.06
# 2016-12-08, SELL EXECUTED, 105.90
# 2016-12-08, Close, 107.10
# 2016-12-09, Close, 108.85
# 2016-12-12, Close, 108.23
# 2016-12-13, Close, 110.04
# 2016-12-14, Close, 110.04
# 2016-12-15, Close, 110.64
# 2016-12-16, Close, 110.78
# 2016-12-19, Close, 111.42
# 2016-12-20, Close, 111.72
# 2016-12-21, Close, 111.82
# 2016-12-22, Close, 111.09
# 2016-12-23, Close, 111.31
# 2016-12-27, Close, 112.01
# 2016-12-28, Close, 111.54
# 2016-12-29, Close, 111.51
# 2016-12-29, BUY CREATE, 111.51
# 2016-12-30, BUY EXECUTED, 111.43
# 2016-12-30, Close, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-06, Close, 112.64
# 2017-01-09, Close, 113.67
# 2017-01-09, SELL CREATE, 113.67
# 2017-01-10, SELL EXECUTED, 113.46
# 2017-01-10, Close, 113.78
# 2017-01-11, Close, 114.39
# 2017-01-12, Close, 113.92
# 2017-01-13, Close, 113.71
# 2017-01-13, BUY CREATE, 113.71
# 2017-01-17, BUY EXECUTED, 113.05
# 2017-01-17, Close, 114.63
# 2017-01-18, Close, 114.62
# 2017-01-19, Close, 114.42
# 2017-01-20, Close, 114.63
# 2017-01-23, Close, 114.71
# 2017-01-24, Close, 114.60
# 2017-01-24, SELL CREATE, 114.60
# 2017-01-25, SELL EXECUTED, 115.03
# 2017-01-25, Close, 116.43
# 2017-01-26, Close, 116.48
# 2017-01-27, Close, 116.49
# 2017-01-30, Close, 116.19
# 2017-01-31, Close, 115.92
# 2017-01-31, BUY CREATE, 115.92
# 2017-02-01, BUY EXECUTED, 121.35
# 2017-02-01, Close, 122.99
# 2017-02-02, Close, 122.78
# 2017-02-03, Close, 123.31
# 2017-02-06, Close, 124.46
# 2017-02-07, Close, 125.65
# 2017-02-08, Close, 126.13
# 2017-02-08, SELL CREATE, 126.13
# 2017-02-09, SELL EXECUTED, 126.31
# 2017-02-09, Close, 127.04
# 2017-02-10, Close, 126.76
# 2017-02-13, Close, 127.88
# 2017-02-14, Close, 129.54
# 2017-02-15, Close, 130.01
# 2017-02-16, Close, 129.86
# 2017-02-17, Close, 130.21
# 2017-02-21, Close, 131.15
# 2017-02-22, Close, 131.54
# 2017-02-23, Close, 130.99
# 2017-02-24, Close, 131.11
# 2017-02-27, Close, 131.37
# 2017-02-28, Close, 131.43
# 2017-03-01, Close, 134.12
# 2017-03-02, Close, 133.32
# 2017-03-03, Close, 134.11
# 2017-03-06, Close, 133.68
# 2017-03-07, Close, 133.86
# 2017-03-08, Close, 133.36
# 2017-03-09, Close, 133.05
# 2017-03-09, BUY CREATE, 133.05
# 2017-03-10, BUY EXECUTED, 133.60
# 2017-03-10, Close, 133.49
# 2017-03-13, Close, 133.55
# 2017-03-14, Close, 133.35
# 2017-03-15, Close, 134.76
# 2017-03-16, Close, 134.98
# 2017-03-17, Close, 134.31
# 2017-03-17, SELL CREATE, 134.31
# 2017-03-20, SELL EXECUTED, 134.70
# 2017-03-20, Close, 135.72
# 2017-03-21, Close, 134.16
# 2017-03-22, Close, 135.68
# 2017-03-23, Close, 135.20
# 2017-03-24, Close, 134.93
# 2017-03-24, BUY CREATE, 134.93
# 2017-03-27, BUY EXECUTED, 133.73
# 2017-03-27, Close, 135.16
# 2017-03-28, Close, 137.96
# 2017-03-29, Close, 138.27
# 2017-03-30, Close, 138.09
# 2017-03-31, Close, 137.83
# 2017-04-03, Close, 137.87
# 2017-04-03, SELL CREATE, 137.87
# 2017-04-04, SELL EXECUTED, 137.43
# 2017-04-04, Close, 138.89
# 2017-04-05, Close, 138.17
# 2017-04-06, Close, 137.83
# 2017-04-06, BUY CREATE, 137.83
# 2017-04-07, BUY EXECUTED, 137.90
# 2017-04-07, Close, 137.52
# 2017-04-10, Close, 137.36
# 2017-04-11, Close, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-17, SELL CREATE, 136.07
# 2017-04-18, SELL EXECUTED, 135.67
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-19, BUY CREATE, 134.97
# 2017-04-20, BUY EXECUTED, 135.49
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-25, Close, 138.66
# 2017-04-26, Close, 137.85
# 2017-04-27, Close, 137.95
# 2017-04-27, SELL CREATE, 137.95
# 2017-04-28, SELL EXECUTED, 138.24
# 2017-04-28, Close, 137.82
# 2017-05-01, Close, 140.63
# 2017-05-02, Close, 141.52
# 2017-05-03, Close, 141.09
# 2017-05-04, Close, 140.58
# 2017-05-04, BUY CREATE, 140.58
# 2017-05-05, BUY EXECUTED, 140.80
# 2017-05-05, Close, 142.91
# 2017-05-08, Close, 146.80
# 2017-05-09, Close, 147.74
# 2017-05-10, Close, 147.04
# 2017-05-11, Close, 148.31
# 2017-05-12, Close, 150.38
# 2017-05-12, SELL CREATE, 150.38
# 2017-05-15, SELL EXECUTED, 150.29
# 2017-05-15, Close, 150.00
# 2017-05-16, Close, 149.77
# 2017-05-16, BUY CREATE, 149.77
# 2017-05-17, BUY EXECUTED, 147.97
# 2017-05-17, Close, 144.75
# 2017-05-18, Close, 146.95
# 2017-05-19, Close, 147.45
# 2017-05-22, Close, 148.35
# 2017-05-23, Close, 148.17
# 2017-05-24, Close, 147.72
# 2017-05-24, SELL CREATE, 147.72
# 2017-05-25, SELL EXECUTED, 148.10
# 2017-05-25, Close, 148.23
# 2017-05-26, Close, 147.98
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-05, Close, 148.29
# 2017-06-06, Close, 148.79
# 2017-06-07, Close, 149.68
# 2017-06-08, Close, 149.31
# 2017-06-09, Close, 143.52
# 2017-06-09, BUY CREATE, 143.52
# 2017-06-12, BUY EXECUTED, 140.40
# 2017-06-12, Close, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-19, SELL CREATE, 140.98
# 2017-06-20, SELL EXECUTED, 141.49
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-27, BUY CREATE, 138.46
# 2017-06-28, BUY EXECUTED, 139.20
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-06, SELL CREATE, 137.50
# 2017-07-07, SELL EXECUTED, 137.66
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-11, Close, 140.20
# 2017-07-12, Close, 140.40
# 2017-07-13, Close, 142.36
# 2017-07-14, Close, 143.58
# 2017-07-17, Close, 144.08
# 2017-07-18, Close, 144.58
# 2017-07-19, Close, 145.49
# 2017-07-20, Close, 144.83
# 2017-07-21, Close, 144.76
# 2017-07-21, BUY CREATE, 144.76
# 2017-07-24, BUY EXECUTED, 145.06
# 2017-07-24, Close, 146.52
# 2017-07-25, Close, 147.14
# 2017-07-26, Close, 147.84
# 2017-07-27, Close, 145.04
# 2017-07-28, Close, 144.02
# 2017-07-31, Close, 143.28
# 2017-07-31, SELL CREATE, 143.28
# 2017-08-01, SELL EXECUTED, 143.64
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-03, Close, 149.87
# 2017-08-04, Close, 150.66
# 2017-08-07, Close, 152.99
# 2017-08-08, Close, 154.22
# 2017-08-09, Close, 155.16
# 2017-08-10, Close, 150.22
# 2017-08-11, Close, 152.31
# 2017-08-14, Close, 154.60
# 2017-08-15, Close, 156.29
# 2017-08-16, Close, 155.66
# 2017-08-17, Close, 152.67
# 2017-08-17, BUY CREATE, 152.67
# 2017-08-18, BUY EXECUTED, 152.67
# 2017-08-18, Close, 152.33
# 2017-08-21, Close, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-23, Close, 154.72
# 2017-08-24, Close, 154.04
# 2017-08-25, Close, 154.61
# 2017-08-25, SELL CREATE, 154.61
# 2017-08-28, SELL EXECUTED, 154.88
# 2017-08-28, Close, 156.17
# 2017-08-29, Close, 157.56
# 2017-08-30, Close, 157.98
# 2017-08-31, Close, 158.61
# 2017-09-01, Close, 158.66
# 2017-09-05, Close, 156.76
# 2017-09-06, Close, 156.59
# 2017-09-06, BUY CREATE, 156.59
# 2017-09-07, BUY EXECUTED, 156.77
# 2017-09-07, Close, 155.96
# 2017-09-08, Close, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-14, SELL CREATE, 153.08
# 2017-09-15, SELL EXECUTED, 153.26
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-21, BUY CREATE, 148.35
# 2017-09-22, BUY EXECUTED, 146.56
# 2017-09-22, Close, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-09-29, SELL CREATE, 149.06
# 2017-10-02, SELL EXECUTED, 149.19
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-06, Close, 150.20
# 2017-10-09, Close, 150.72
# 2017-10-10, Close, 150.78
# 2017-10-11, Close, 151.41
# 2017-10-12, Close, 150.88
# 2017-10-13, Close, 151.83
# 2017-10-16, Close, 154.63
# 2017-10-17, Close, 155.20
# 2017-10-18, Close, 154.51
# 2017-10-19, Close, 150.86
# 2017-10-19, BUY CREATE, 150.86
# 2017-10-20, BUY EXECUTED, 151.47
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-27, Close, 157.69
# 2017-10-27, SELL CREATE, 157.69
# 2017-10-30, SELL EXECUTED, 158.51
# 2017-10-30, Close, 161.24
# 2017-10-31, Close, 163.49
# 2017-11-01, Close, 161.41
# 2017-11-02, Close, 162.59
# 2017-11-03, Close, 166.83
# 2017-11-06, Close, 168.53
# 2017-11-07, Close, 169.07
# 2017-11-08, Close, 170.45
# 2017-11-09, Close, 170.10
# 2017-11-10, Close, 169.54
# 2017-11-10, BUY CREATE, 169.54
# 2017-11-13, BUY EXECUTED, 168.40
# 2017-11-13, Close, 168.86
# 2017-11-14, Close, 166.31
# 2017-11-15, Close, 164.11
# 2017-11-16, Close, 166.07
# 2017-11-17, Close, 165.15
# 2017-11-20, Close, 164.99
# 2017-11-20, SELL CREATE, 164.99
# 2017-11-21, SELL EXECUTED, 165.76
# 2017-11-21, Close, 168.05
# 2017-11-22, Close, 169.82
# 2017-11-24, Close, 169.83
# 2017-11-27, Close, 168.98
# 2017-11-28, Close, 167.99
# 2017-11-28, BUY CREATE, 167.99
# 2017-11-29, BUY EXECUTED, 167.56
# 2017-11-29, Close, 164.50
# 2017-11-30, Close, 166.80
# 2017-12-01, Close, 166.03
# 2017-12-04, Close, 164.81
# 2017-12-05, Close, 164.66
# 2017-12-06, Close, 164.05
# 2017-12-06, SELL CREATE, 164.05
# 2017-12-07, SELL EXECUTED, 164.06
# 2017-12-07, Close, 164.35
# 2017-12-08, Close, 164.39
# 2017-12-11, Close, 167.60
# 2017-12-12, Close, 166.66
# 2017-12-13, Close, 167.21
# 2017-12-14, Close, 167.16
# 2017-12-15, Close, 168.86
# 2017-12-18, Close, 171.24
# 2017-12-19, Close, 169.41
# 2017-12-20, Close, 169.23
# 2017-12-20, BUY CREATE, 169.23
# 2017-12-21, BUY EXECUTED, 169.05
# 2017-12-21, Close, 169.87
# 2017-12-22, Close, 169.87
# 2017-12-26, Close, 165.56
# 2017-12-27, Close, 165.59
# 2017-12-28, Close, 166.05
# 2017-12-29, Close, 164.26
# 2017-12-29, SELL CREATE, 164.26
# 2018-01-02, SELL EXECUTED, 165.16
# 2018-01-02, Close, 167.20
# 2018-01-03, Close, 167.17
# 2018-01-04, Close, 167.95
# 2018-01-05, Close, 169.86
# 2018-01-08, Close, 169.23
# 2018-01-09, Close, 169.21
# 2018-01-09, BUY CREATE, 169.21
# 2018-01-10, BUY EXECUTED, 168.07
# 2018-01-10, Close, 169.17
# 2018-01-11, Close, 170.13
# 2018-01-12, Close, 171.89
# 2018-01-16, Close, 171.01
# 2018-01-17, Close, 173.84
# 2018-01-18, Close, 173.99
# 2018-01-18, SELL CREATE, 173.99
# 2018-01-19, SELL EXECUTED, 173.36
# 2018-01-19, Close, 173.22
# 2018-01-22, Close, 171.80
# 2018-01-22, BUY CREATE, 171.80
# 2018-01-23, BUY EXECUTED, 172.09
# 2018-01-23, Close, 171.84
# 2018-01-24, Close, 169.10
# 2018-01-25, Close, 166.08
# 2018-01-26, Close, 166.47
# 2018-01-29, Close, 163.03
# 2018-01-30, Close, 162.07
# 2018-01-30, SELL CREATE, 162.07
# 2018-01-31, SELL EXECUTED, 161.97
# 2018-01-31, Close, 162.51
# 2018-02-01, Close, 162.85
# 2018-02-02, Close, 155.79
# 2018-02-05, Close, 151.89
# 2018-02-05, BUY CREATE, 151.89
# 2018-02-06, BUY EXECUTED, 150.28
# 2018-02-06, Close, 158.24
# 2018-02-07, Close, 154.85
# 2018-02-08, Close, 150.59
# 2018-02-09, Close, 152.43
# 2018-02-12, Close, 158.57
# 2018-02-13, Close, 160.16
# 2018-02-13, SELL CREATE, 160.16
# 2018-02-14, SELL EXECUTED, 158.90
# 2018-02-14, Close, 163.12
# 2018-02-15, Close, 168.59
# 2018-02-16, Close, 168.05
# 2018-02-20, Close, 167.48
# 2018-02-20, BUY CREATE, 167.48
# 2018-02-21, BUY EXECUTED, 168.44
# 2018-02-21, Close, 166.72
# 2018-02-22, Close, 168.12
# 2018-02-23, Close, 171.04
# 2018-02-26, Close, 174.42
# 2018-02-27, Close, 173.86
# 2018-02-28, Close, 173.59
# 2018-02-28, SELL CREATE, 173.59
# 2018-03-01, SELL EXECUTED, 174.00
# 2018-03-01, Close, 170.55
# 2018-03-01, BUY CREATE, 170.55
# 2018-03-02, BUY EXECUTED, 168.41
# 2018-03-02, Close, 171.73
# 2018-03-05, Close, 172.33
# 2018-03-06, Close, 172.18
# 2018-03-07, Close, 170.58
# 2018-03-08, Close, 172.44
# 2018-03-09, Close, 175.41
# 2018-03-09, SELL CREATE, 175.41
# 2018-03-12, SELL EXECUTED, 175.71
# 2018-03-12, Close, 177.10
# 2018-03-13, Close, 175.40
# 2018-03-14, Close, 173.90
# 2018-03-14, BUY CREATE, 173.90
# 2018-03-15, BUY EXECUTED, 173.96
# 2018-03-15, Close, 174.11
# 2018-03-16, Close, 173.50
# 2018-03-19, Close, 170.84
# 2018-03-20, Close, 170.79
# 2018-03-21, Close, 166.92
# 2018-03-22, Close, 164.56
# 2018-03-22, SELL CREATE, 164.56
# 2018-03-23, SELL EXECUTED, 164.11
# 2018-03-23, Close, 160.75
# 2018-03-23, BUY CREATE, 160.75
# 2018-03-26, BUY EXECUTED, 163.80
# 2018-03-26, Close, 168.38
# 2018-03-27, Close, 164.06
# 2018-03-28, Close, 162.25
# 2018-03-29, Close, 163.52
# 2018-04-02, Close, 162.44
# 2018-04-03, Close, 164.11
# 2018-04-03, SELL CREATE, 164.11
# 2018-04-04, SELL EXECUTED, 160.69
# 2018-04-04, Close, 167.25
# 2018-04-05, Close, 168.41
# 2018-04-06, Close, 164.10
# 2018-04-09, Close, 165.73
# 2018-04-10, Close, 168.85
# 2018-04-11, Close, 168.06
# 2018-04-12, Close, 169.71
# 2018-04-13, Close, 170.29
# 2018-04-16, Close, 171.35
# 2018-04-17, Close, 173.71
# 2018-04-18, Close, 173.32
# 2018-04-19, Close, 168.41
# 2018-04-19, BUY CREATE, 168.41
# 2018-04-20, BUY EXECUTED, 166.26
# 2018-04-20, Close, 161.51
# 2018-04-23, Close, 161.04
# 2018-04-24, Close, 158.80
# 2018-04-25, Close, 159.49
# 2018-04-26, Close, 160.05
# 2018-04-27, Close, 158.19
# 2018-04-27, SELL CREATE, 158.19
# 2018-04-30, SELL EXECUTED, 158.01
# 2018-04-30, Close, 161.06
# 2018-05-01, Close, 164.80
# 2018-05-02, Close, 172.08
# 2018-05-03, Close, 172.39
# 2018-05-04, Close, 179.16
# 2018-05-07, Close, 180.45
# 2018-05-08, Close, 181.32
# 2018-05-09, Close, 182.60
# 2018-05-10, Close, 185.21
# 2018-05-11, Close, 184.51
# 2018-05-14, Close, 184.07
# 2018-05-14, BUY CREATE, 184.07
# 2018-05-15, BUY EXECUTED, 182.73
# 2018-05-15, Close, 182.40
# 2018-05-16, Close, 184.10
# 2018-05-17, Close, 182.94
# 2018-05-18, Close, 182.27
# 2018-05-21, Close, 183.57
# 2018-05-22, Close, 183.11
# 2018-05-22, SELL CREATE, 183.11
# 2018-05-23, SELL EXECUTED, 182.31
# 2018-05-23, Close, 184.28
# 2018-05-24, Close, 184.07
# 2018-05-25, Close, 184.50
# 2018-05-29, Close, 183.83
# 2018-05-30, Close, 183.44
# 2018-05-30, BUY CREATE, 183.44
# 2018-05-31, BUY EXECUTED, 183.16
# 2018-05-31, Close, 182.82
# 2018-06-01, Close, 186.12
# 2018-06-04, Close, 187.68
# 2018-06-05, Close, 189.12
# 2018-06-06, Close, 189.78
# 2018-06-07, Close, 189.27
# 2018-06-07, SELL CREATE, 189.27
# 2018-06-08, SELL EXECUTED, 187.03
# 2018-06-08, Close, 187.55
# 2018-06-08, BUY CREATE, 187.55
# 2018-06-11, BUY EXECUTED, 187.21
# 2018-06-11, Close, 187.09
# 2018-06-12, Close, 188.12
# 2018-06-13, Close, 186.57
# 2018-06-14, Close, 186.67
# 2018-06-15, Close, 184.75
# 2018-06-18, Close, 184.65
# 2018-06-18, SELL CREATE, 184.65
# 2018-06-19, SELL EXECUTED, 181.13
# 2018-06-19, Close, 181.67
# 2018-06-19, BUY CREATE, 181.67
# 2018-06-20, BUY EXECUTED, 182.31
# 2018-06-20, Close, 182.46
# 2018-06-21, Close, 181.44
# 2018-06-22, Close, 180.91
# 2018-06-25, Close, 178.22
# 2018-06-26, Close, 180.44
# 2018-06-27, Close, 180.17
# 2018-06-27, SELL CREATE, 180.17
# 2018-06-28, SELL EXECUTED, 180.11
# 2018-06-28, Close, 181.48
# 2018-06-29, Close, 181.10
# 2018-07-02, Close, 183.13
# 2018-07-03, Close, 179.94
# 2018-07-05, Close, 181.38
# 2018-07-06, Close, 183.90
# 2018-07-09, Close, 186.45
# 2018-07-10, Close, 186.23
# 2018-07-11, Close, 183.81
# 2018-07-11, BUY CREATE, 183.81
# 2018-07-12, BUY EXECUTED, 185.42
# 2018-07-12, Close, 186.89
# 2018-07-13, Close, 187.19
# 2018-07-16, Close, 186.78
# 2018-07-17, Close, 187.30
# 2018-07-18, Close, 186.28
# 2018-07-19, Close, 187.72
# 2018-07-19, SELL CREATE, 187.72
# 2018-07-20, SELL EXECUTED, 187.63
# 2018-07-20, Close, 187.29
# 2018-07-23, Close, 187.46
# 2018-07-24, Close, 188.82
# 2018-07-25, Close, 190.60
# 2018-07-26, Close, 190.00
# 2018-07-27, Close, 186.84
# 2018-07-27, BUY CREATE, 186.84
# 2018-07-30, BUY EXECUTED, 187.74
# 2018-07-30, Close, 185.80
# 2018-07-31, Close, 186.17
# 2018-08-01, Close, 197.14
# 2018-08-02, Close, 202.90
# 2018-08-03, Close, 203.49
# 2018-08-06, Close, 204.54
# 2018-08-06, SELL CREATE, 204.54
# 2018-08-07, SELL EXECUTED, 204.79
# 2018-08-07, Close, 202.62
# 2018-08-08, Close, 202.76
# 2018-08-09, Close, 204.36
# 2018-08-10, Close, 203.75
# 2018-08-13, Close, 205.06
# 2018-08-14, Close, 205.93
# 2018-08-15, Close, 206.41
# 2018-08-16, Close, 209.43
# 2018-08-17, Close, 213.61
# 2018-08-20, Close, 211.53
# 2018-08-21, Close, 211.12
# 2018-08-21, BUY CREATE, 211.12
# 2018-08-22, BUY EXECUTED, 210.20
# 2018-08-22, Close, 211.13
# 2018-08-23, Close, 211.56
# 2018-08-24, Close, 212.22
# 2018-08-27, Close, 213.97
# 2018-08-28, Close, 215.70
# 2018-08-29, Close, 218.92
# 2018-08-29, SELL CREATE, 218.92
# 2018-08-30, SELL EXECUTED, 219.18
# 2018-08-30, Close, 220.93
# 2018-08-31, Close, 223.48
# 2018-09-04, Close, 224.20
# 2018-09-05, Close, 222.73
# 2018-09-06, Close, 219.03
# 2018-09-06, BUY CREATE, 219.03
# 2018-09-07, BUY EXECUTED, 217.81
# 2018-09-07, Close, 217.27
# 2018-09-10, Close, 214.35
# 2018-09-11, Close, 219.77
# 2018-09-12, Close, 217.04
# 2018-09-13, Close, 222.28
# 2018-09-14, Close, 219.76
# 2018-09-14, SELL CREATE, 219.76
# 2018-09-17, SELL EXECUTED, 218.10
# 2018-09-17, Close, 213.91
# 2018-09-17, BUY CREATE, 213.91
# 2018-09-18, BUY EXECUTED, 213.82
# 2018-09-18, Close, 214.26
# 2018-09-19, Close, 214.39
# 2018-09-20, Close, 216.02
# 2018-09-21, Close, 213.69
# 2018-09-24, Close, 216.77
# 2018-09-25, Close, 218.14
# 2018-09-25, SELL CREATE, 218.14
# 2018-09-26, SELL EXECUTED, 216.97
# 2018-09-26, Close, 216.40
# 2018-09-27, Close, 220.85
# 2018-09-28, Close, 221.63
# 2018-10-01, Close, 223.12
# 2018-10-02, Close, 225.10
# 2018-10-03, Close, 227.84
# 2018-10-04, Close, 223.83
# 2018-10-05, Close, 220.20
# 2018-10-05, BUY CREATE, 220.20
# 2018-10-08, BUY EXECUTED, 218.16
# 2018-10-08, Close, 219.69
# 2018-10-09, Close, 222.73
# 2018-10-10, Close, 212.42
# 2018-10-11, Close, 210.54
# 2018-10-12, Close, 218.06
# 2018-10-15, Close, 213.40
# 2018-10-15, SELL CREATE, 213.40
# 2018-10-16, SELL EXECUTED, 214.94
# 2018-10-16, Close, 218.10
# 2018-10-17, Close, 217.16
# 2018-10-18, Close, 212.08
# 2018-10-18, BUY CREATE, 212.08
# 2018-10-19, BUY EXECUTED, 214.09
# 2018-10-19, Close, 215.31
# 2018-10-22, Close, 216.63
# 2018-10-23, Close, 218.67
# 2018-10-24, Close, 211.17
# 2018-10-25, Close, 215.79
# 2018-10-26, Close, 212.36
# 2018-10-26, SELL CREATE, 212.36
# 2018-10-29, SELL EXECUTED, 215.19
# 2018-10-29, Close, 208.37
# 2018-10-29, BUY CREATE, 208.37
# 2018-10-30, BUY EXECUTED, 207.30
# 2018-10-30, Close, 209.41
# 2018-10-31, Close, 214.87
# 2018-11-01, Close, 218.17
# 2018-11-02, Close, 203.70
# 2018-11-05, Close, 197.92
# 2018-11-06, Close, 200.06
# 2018-11-06, SELL CREATE, 200.06
# 2018-11-07, SELL EXECUTED, 202.22
# 2018-11-07, Close, 206.12
# 2018-11-08, Close, 205.40
# 2018-11-09, Close, 201.44
# 2018-11-09, BUY CREATE, 201.44
# 2018-11-12, BUY EXECUTED, 196.05
# 2018-11-12, Close, 191.30
# 2018-11-13, Close, 189.38
# 2018-11-14, Close, 184.03
# 2018-11-15, Close, 188.58
# 2018-11-16, Close, 190.67
# 2018-11-19, Close, 183.11
# 2018-11-19, SELL CREATE, 183.11
# 2018-11-20, SELL EXECUTED, 175.73
# 2018-11-20, Close, 174.36
# 2018-11-20, BUY CREATE, 174.36
# 2018-11-21, BUY EXECUTED, 177.07
# 2018-11-21, Close, 174.16
# 2018-11-23, Close, 169.74
# 2018-11-26, Close, 172.04
# 2018-11-27, Close, 171.66
# 2018-11-28, Close, 178.26
# 2018-11-29, Close, 176.89
# 2018-11-29, SELL CREATE, 176.89
# 2018-11-30, SELL EXECUTED, 177.62
# 2018-11-30, Close, 175.94
# 2018-11-30, BUY CREATE, 175.94
# 2018-12-03, BUY EXECUTED, 181.73
# 2018-12-03, Close, 182.08
# 2018-12-04, Close, 174.07
# 2018-12-06, Close, 172.13
# 2018-12-07, Close, 166.00
# 2018-12-10, Close, 167.09
# 2018-12-11, Close, 166.13
# 2018-12-11, SELL CREATE, 166.13
# 2018-12-12, SELL EXECUTED, 167.88
# 2018-12-12, Close, 166.60
# 2018-12-13, Close, 168.42
# 2018-12-14, Close, 163.03
# 2018-12-17, Close, 161.51
# 2018-12-17, BUY CREATE, 161.51
# 2018-12-18, BUY EXECUTED, 162.93
# 2018-12-18, Close, 163.61
# 2018-12-19, Close, 158.51
# 2018-12-20, Close, 154.51
# 2018-12-21, Close, 148.50
# 2018-12-24, Close, 144.66
# 2018-12-26, Close, 154.84
# 2018-12-26, SELL CREATE, 154.84
# 2018-12-27, SELL EXECUTED, 153.53
# 2018-12-27, Close, 153.84
# 2018-12-28, Close, 153.92
# 2018-12-31, Close, 155.41
# 2019-01-02, Close, 155.58
# 2019-01-03, Close, 140.09
# 2019-01-04, Close, 146.07
# 2019-01-07, Close, 145.74
# 2019-01-08, Close, 148.52
# 2019-01-09, Close, 151.04
# 2019-01-10, Close, 151.52
# 2019-01-11, Close, 150.04
# 2019-01-14, Close, 147.78
# 2019-01-14, BUY CREATE, 147.78
# 2019-01-15, BUY EXECUTED, 148.05
# 2019-01-15, Close, 150.80
# 2019-01-16, Close, 152.65
# 2019-01-17, Close, 153.55
# 2019-01-18, Close, 154.50
# 2019-01-22, Close, 151.03
# 2019-01-23, Close, 151.64
# 2019-01-23, SELL CREATE, 151.64
# 2019-01-24, SELL EXECUTED, 151.83
# 2019-01-24, Close, 150.44
# 2019-01-25, Close, 155.42
# 2019-01-28, Close, 153.99
# 2019-01-29, Close, 152.39
# 2019-01-29, BUY CREATE, 152.39
# 2019-01-30, BUY EXECUTED, 160.83
# 2019-01-30, Close, 162.80
# 2019-01-31, Close, 163.98
# 2019-02-01, Close, 164.06
# 2019-02-04, Close, 168.72
# 2019-02-05, Close, 171.60
# 2019-02-06, Close, 171.66
# 2019-02-06, SELL CREATE, 171.66
# 2019-02-07, SELL EXECUTED, 169.85
# 2019-02-07, Close, 168.41
# 2019-02-08, Close, 168.61
# 2019-02-11, Close, 167.64
# 2019-02-12, Close, 169.08
# 2019-02-13, Close, 168.38
# 2019-02-14, Close, 168.99
# 2019-02-15, Close, 168.62
# 2019-02-19, Close, 169.12
# 2019-02-20, Close, 170.21
# 2019-02-21, Close, 169.25
# 2019-02-22, Close, 171.14
# 2019-02-25, Close, 172.39
# 2019-02-26, Close, 172.49
# 2019-02-27, Close, 173.02
# 2019-02-28, Close, 171.32
# 2019-03-01, Close, 173.12
# 2019-03-04, Close, 173.99
# 2019-03-05, Close, 173.67
# 2019-03-06, Close, 172.67
# 2019-03-06, BUY CREATE, 172.67
# 2019-03-07, BUY EXECUTED, 172.03
# 2019-03-07, Close, 170.68
# 2019-03-08, Close, 171.08
# 2019-03-11, Close, 177.01
# 2019-03-12, Close, 179.00
# 2019-03-13, Close, 179.79
# 2019-03-14, Close, 181.79
# 2019-03-14, SELL CREATE, 181.79
# 2019-03-15, SELL EXECUTED, 182.89
# 2019-03-15, Close, 184.15
# 2019-03-18, Close, 186.03
# 2019-03-19, Close, 184.56
# 2019-03-20, Close, 186.17
# 2019-03-21, Close, 193.03
# 2019-03-22, Close, 189.03
# 2019-03-25, Close, 186.74
# 2019-03-25, BUY CREATE, 186.74
# 2019-03-26, BUY EXECUTED, 189.63
# 2019-03-26, Close, 184.81
# 2019-03-27, Close, 186.48
# 2019-03-28, Close, 186.72
# 2019-03-29, Close, 187.94
# 2019-04-01, Close, 189.22
# 2019-04-02, Close, 191.97
# 2019-04-02, SELL CREATE, 191.97
# 2019-04-03, SELL EXECUTED, 191.21
# 2019-04-03, Close, 193.28
# 2019-04-04, Close, 193.62
# 2019-04-05, Close, 194.92
# 2019-04-08, Close, 197.98
# 2019-04-09, Close, 197.39
# 2019-04-10, Close, 198.50
# 2019-04-11, Close, 196.85
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE, 196.77
# 2019-04-15, BUY EXECUTED, 196.48
# 2019-04-15, Close, 197.12
# 2019-04-16, Close, 197.14
# 2019-04-17, Close, 200.98
# 2019-04-18, Close, 201.70
# 2019-04-22, Close, 202.37
# 2019-04-23, Close, 205.29
# 2019-04-23, SELL CREATE, 205.29
# 2019-04-24, SELL EXECUTED, 205.17
# 2019-04-24, Close, 204.97
# 2019-04-25, Close, 203.11
# 2019-04-25, BUY CREATE, 203.11
# 2019-04-26, BUY EXECUTED, 202.73
# 2019-04-26, Close, 202.14
# 2019-04-29, Close, 202.45
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-02, Close, 206.94
# 2019-05-03, Close, 209.51
# 2019-05-03, SELL CREATE, 209.51
# 2019-05-06, SELL EXECUTED, 202.13
# 2019-05-06, Close, 206.27
# 2019-05-07, Close, 200.71
# 2019-05-07, BUY CREATE, 200.71
# 2019-05-08, BUY EXECUTED, 199.76
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-15, SELL CREATE, 189.63
# 2019-05-16, SELL EXECUTED, 188.62
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-17, BUY CREATE, 187.72
# 2019-05-20, BUY EXECUTED, 182.28
# 2019-05-20, Close, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-28, SELL CREATE, 177.02
# 2019-05-29, SELL EXECUTED, 175.23
# 2019-05-29, Close, 176.18
# 2019-05-29, BUY CREATE, 176.18
# 2019-05-30, BUY EXECUTED, 176.75
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-06, Close, 183.97
# 2019-06-06, SELL CREATE, 183.97
# 2019-06-07, SELL EXECUTED, 185.25
# 2019-06-07, Close, 188.86
# 2019-06-10, Close, 191.28
# 2019-06-11, Close, 193.49
# 2019-06-12, Close, 192.88
# 2019-06-13, Close, 192.84
# 2019-06-13, BUY CREATE, 192.84
# 2019-06-14, BUY EXECUTED, 190.25
# 2019-06-14, Close, 191.44
# 2019-06-17, Close, 192.58
# 2019-06-18, Close, 197.11
# 2019-06-19, Close, 196.53
# 2019-06-20, Close, 198.11
# 2019-06-21, Close, 197.43
# 2019-06-21, SELL CREATE, 197.43
# 2019-06-24, SELL EXECUTED, 197.20
# 2019-06-24, Close, 197.24
# 2019-06-24, BUY CREATE, 197.24
# 2019-06-25, BUY EXECUTED, 197.09
# 2019-06-25, Close, 194.25
# 2019-06-26, Close, 198.45
# 2019-06-27, Close, 198.39
# 2019-06-28, Close, 196.58
# 2019-07-01, Close, 200.19
# 2019-07-02, Close, 201.36
# 2019-07-02, SELL CREATE, 201.36
# 2019-07-03, SELL EXECUTED, 201.90
# 2019-07-03, Close, 203.03
# 2019-07-05, Close, 202.85
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE, 198.67
# 2019-07-09, BUY EXECUTED, 197.85
# 2019-07-09, Close, 199.88
# 2019-07-10, Close, 201.85
# 2019-07-11, Close, 200.38
# 2019-07-12, Close, 201.92
# 2019-07-15, Close, 203.82
# 2019-07-16, Close, 203.12
# 2019-07-16, SELL CREATE, 203.12
# 2019-07-17, SELL EXECUTED, 202.67
# 2019-07-17, Close, 201.97
# 2019-07-17, BUY CREATE, 201.97
# 2019-07-18, BUY EXECUTED, 202.62
# 2019-07-18, Close, 204.27
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-23, Close, 207.43
# 2019-07-24, Close, 207.26
# 2019-07-25, Close, 205.62
# 2019-07-25, SELL CREATE, 205.62
# 2019-07-26, SELL EXECUTED, 206.08
# 2019-07-26, Close, 206.33
# 2019-07-29, Close, 208.26
# 2019-07-30, Close, 207.37
# 2019-07-31, Close, 211.60
# 2019-08-01, Close, 207.02
# 2019-08-02, Close, 202.64
# 2019-08-02, BUY CREATE, 202.64
# 2019-08-05, BUY EXECUTED, 196.65
# 2019-08-05, Close, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-12, SELL CREATE, 199.88
# 2019-08-13, SELL EXECUTED, 200.42
# 2019-08-13, Close, 208.34
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-15, BUY CREATE, 201.14
# 2019-08-16, BUY EXECUTED, 203.67
# 2019-08-16, Close, 205.88
# 2019-08-19, Close, 209.72
# 2019-08-20, Close, 209.73
# 2019-08-21, Close, 212.00
# 2019-08-22, Close, 211.82
# 2019-08-23, Close, 202.03
# 2019-08-23, SELL CREATE, 202.03
# 2019-08-26, SELL EXECUTED, 205.24
# 2019-08-26, Close, 205.87
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-30, Close, 208.12
# 2019-09-03, Close, 205.08
# 2019-09-03, BUY CREATE, 205.08
# 2019-09-04, BUY EXECUTED, 207.77
# 2019-09-04, Close, 208.56
# 2019-09-05, Close, 212.64
# 2019-09-06, Close, 212.62
# 2019-09-09, Close, 213.53
# 2019-09-10, Close, 216.05
# 2019-09-11, Close, 222.92
# 2019-09-11, SELL CREATE, 222.92
# 2019-09-12, SELL EXECUTED, 224.13
# 2019-09-12, Close, 222.42
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE, 218.10
# 2019-09-16, BUY EXECUTED, 217.08
# 2019-09-16, Close, 219.24
# 2019-09-17, Close, 220.04
# 2019-09-18, Close, 222.10
# 2019-09-19, Close, 220.30
# 2019-09-20, Close, 217.08
# 2019-09-23, Close, 218.07
# 2019-09-23, SELL CREATE, 218.07
# 2019-09-24, SELL EXECUTED, 220.37
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-26, Close, 219.23
# 2019-09-27, Close, 218.17
# 2019-09-27, BUY CREATE, 218.17
# 2019-09-30, BUY EXECUTED, 220.24
# 2019-09-30, Close, 223.30
# 2019-10-01, Close, 223.92
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-04, Close, 226.33
# 2019-10-07, Close, 226.38
# 2019-10-07, SELL CREATE, 226.38
# 2019-10-08, SELL EXECUTED, 225.14
# 2019-10-08, Close, 223.73
# 2019-10-09, Close, 226.35
# 2019-10-10, Close, 229.40
# 2019-10-11, Close, 235.50
# 2019-10-14, Close, 235.16
# 2019-10-15, Close, 234.62
# 2019-10-15, BUY CREATE, 234.62
# 2019-10-16, BUY EXECUTED, 232.67
# 2019-10-16, Close, 233.67
# 2019-10-17, Close, 234.58
# 2019-10-18, Close, 235.70
# 2019-10-21, Close, 239.79
# 2019-10-22, Close, 239.24
# 2019-10-23, Close, 242.45
# 2019-10-23, SELL CREATE, 242.45
# 2019-10-24, SELL EXECUTED, 243.78
# 2019-10-24, Close, 242.85
# 2019-10-25, Close, 245.84
# 2019-10-28, Close, 248.30
# 2019-10-29, Close, 242.56
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE, 242.53
# 2019-10-31, BUY EXECUTED, 246.50
# 2019-10-31, Close, 248.02
# 2019-11-01, Close, 255.05
# 2019-11-04, Close, 256.73
# 2019-11-05, Close, 256.36
# 2019-11-06, Close, 256.47
# 2019-11-07, Close, 259.43
# 2019-11-07, SELL CREATE, 259.43
# 2019-11-08, SELL EXECUTED, 258.69
# 2019-11-08, Close, 260.14
# 2019-11-11, Close, 262.20
# 2019-11-12, Close, 261.96
# 2019-11-13, Close, 264.47
# 2019-11-14, Close, 262.64
# 2019-11-15, Close, 265.76
# 2019-11-18, Close, 267.10
# 2019-11-19, Close, 266.29
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE, 263.19
# 2019-11-21, BUY EXECUTED, 263.69
# 2019-11-21, Close, 262.01
# 2019-11-22, Close, 261.78
# 2019-11-25, Close, 266.37
# 2019-11-26, Close, 264.29
# 2019-11-27, Close, 267.84
# 2019-11-29, Close, 267.25
# 2019-11-29, SELL CREATE, 267.25
# 2019-12-02, SELL EXECUTED, 267.27
# 2019-12-02, Close, 264.16
# 2019-12-02, BUY CREATE, 264.16
# 2019-12-03, BUY EXECUTED, 258.31
# 2019-12-03, Close, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-06, Close, 270.71
# 2019-12-09, Close, 266.92
# 2019-12-10, Close, 268.48
# 2019-12-10, SELL CREATE, 268.48
# 2019-12-11, SELL EXECUTED, 268.81
# 2019-12-11, Close, 270.77
# 2019-12-12, Close, 271.46
# 2019-12-13, Close, 275.15
# 2019-12-16, Close, 279.86
# 2019-12-17, Close, 280.41
# 2019-12-18, Close, 279.74
# 2019-12-19, Close, 280.02
# 2019-12-20, Close, 279.44
# 2019-12-23, Close, 284.00
# 2019-12-24, Close, 284.27
# 2019-12-26, Close, 289.91
# 2019-12-27, Close, 289.80
# 2019-12-30, Close, 291.52
# 2019-12-31, Close, 293.65
# 2020-01-02, Close, 300.35
# 2020-01-03, Close, 297.43
# 2020-01-06, Close, 299.80
# 2020-01-07, Close, 298.39
# 2020-01-08, Close, 303.19
# 2020-01-09, Close, 309.63
# Final Portfolio Value: 100116.43

# %% [markdown]
# ## The broker says: Show me the money!
# And the money is called “commission”.
#
# Let’s add a reasonable 0.1% commision rate per operation (both for buying and selling … yes the broker is avid …)
#
# A single line will suffice for it:

# %%
# 0.1% ... divide by 100 to remove the %
cerebro.broker.setcommission(commission=0.001)

# %% [markdown]
# The next method gets no “bar index” passed and therefore it seems obscure how to understand when 5 bars may have elapsed, but this has been modeled in pythonic way: call len on an object and it will tell you the length of its lines. Just write down (save in a variable) at which length in an operation took place and see if the current length is 5 bars away.

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + 5):
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2015-01-02, Close, 100.45
# 2015-01-05, Close, 97.62
# 2015-01-05, BUY CREATE, 97.62
# 2015-01-06, BUY EXECUTED, Price: 97.89, Cost: 97.89, Comm 0.10
# 2015-01-06, Close, 97.63
# 2015-01-07, Close, 99.00
# 2015-01-08, Close, 102.81
# 2015-01-09, Close, 102.92
# 2015-01-12, Close, 100.38
# 2015-01-13, Close, 101.27
# 2015-01-13, SELL CREATE, 101.27
# 2015-01-14, SELL EXECUTED, Price: 100.19, Cost: 97.89, Comm 0.10
# 2015-01-14, OPERATION PROFIT, GROSS 2.30, NET 2.10
# 2015-01-14, Close, 100.89
# 2015-01-15, Close, 98.15
# 2015-01-15, BUY CREATE, 98.15
# 2015-01-16, BUY EXECUTED, Price: 98.34, Cost: 98.34, Comm 0.10
# 2015-01-16, Close, 97.39
# 2015-01-20, Close, 99.89
# 2015-01-21, Close, 100.66
# 2015-01-22, Close, 103.28
# 2015-01-23, Close, 103.81
# 2015-01-26, Close, 103.92
# 2015-01-26, SELL CREATE, 103.92
# 2015-01-27, SELL EXECUTED, Price: 103.29, Cost: 98.34, Comm 0.10
# 2015-01-27, OPERATION PROFIT, GROSS 4.95, NET 4.75
# 2015-01-27, Close, 100.28
# 2015-01-28, Close, 105.95
# 2015-01-29, Close, 109.25
# 2015-01-30, Close, 107.65
# 2015-02-02, Close, 109.00
# 2015-02-03, Close, 109.02
# 2015-02-04, Close, 109.85
# 2015-02-05, Close, 110.64
# 2015-02-06, Close, 109.71
# 2015-02-09, Close, 110.43
# 2015-02-10, Close, 112.56
# 2015-02-11, Close, 115.19
# 2015-02-12, Close, 116.65
# 2015-02-13, Close, 117.22
# 2015-02-17, Close, 117.92
# 2015-02-18, Close, 118.74
# 2015-02-19, Close, 118.49
# 2015-02-20, Close, 119.46
# 2015-02-23, Close, 122.68
# 2015-02-24, Close, 121.92
# 2015-02-25, Close, 118.80
# 2015-02-25, BUY CREATE, 118.80
# 2015-02-26, BUY EXECUTED, Price: 118.80, Cost: 118.80, Comm 0.12
# 2015-02-26, Close, 120.31
# 2015-02-27, Close, 118.50
# 2015-03-02, Close, 119.08
# 2015-03-03, Close, 119.33
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-05, SELL CREATE, 116.61
# 2015-03-06, SELL EXECUTED, Price: 118.44, Cost: 118.80, Comm 0.12
# 2015-03-06, OPERATION PROFIT, GROSS -0.36, NET -0.60
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-11, BUY CREATE, 112.76
# 2015-03-12, BUY EXECUTED, Price: 112.82, Cost: 112.82, Comm 0.11
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-18, Close, 118.51
# 2015-03-19, Close, 117.61
# 2015-03-19, SELL CREATE, 117.61
# 2015-03-20, SELL EXECUTED, Price: 118.30, Cost: 112.82, Comm 0.12
# 2015-03-20, OPERATION PROFIT, GROSS 5.48, NET 5.25
# 2015-03-20, Close, 116.14
# 2015-03-20, BUY CREATE, 116.14
# 2015-03-23, BUY EXECUTED, Price: 117.26, Cost: 117.26, Comm 0.12
# 2015-03-23, Close, 117.34
# 2015-03-24, Close, 116.86
# 2015-03-25, Close, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-30, SELL CREATE, 116.57
# 2015-03-31, SELL EXECUTED, Price: 116.31, Cost: 117.26, Comm 0.12
# 2015-03-31, OPERATION PROFIT, GROSS -0.95, NET -1.18
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-01, BUY CREATE, 114.61
# 2015-04-02, BUY EXECUTED, Price: 115.33, Cost: 115.33, Comm 0.12
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-07, Close, 116.24
# 2015-04-08, Close, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-10, Close, 117.24
# 2015-04-10, SELL CREATE, 117.24
# 2015-04-13, SELL EXECUTED, Price: 118.41, Cost: 115.33, Comm 0.12
# 2015-04-13, OPERATION PROFIT, GROSS 3.08, NET 2.85
# 2015-04-13, Close, 117.01
# 2015-04-14, Close, 116.50
# 2015-04-14, BUY CREATE, 116.50
# 2015-04-15, BUY EXECUTED, Price: 116.61, Cost: 116.61, Comm 0.12
# 2015-04-15, Close, 116.95
# 2015-04-16, Close, 116.38
# 2015-04-17, Close, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-21, Close, 117.07
# 2015-04-22, Close, 118.64
# 2015-04-22, SELL CREATE, 118.64
# 2015-04-23, SELL EXECUTED, Price: 118.35, Cost: 116.61, Comm 0.12
# 2015-04-23, OPERATION PROFIT, GROSS 1.74, NET 1.51
# 2015-04-23, Close, 119.61
# 2015-04-24, Close, 120.18
# 2015-04-27, Close, 122.36
# 2015-04-28, Close, 120.43
# 2015-04-29, Close, 118.66
# 2015-04-29, BUY CREATE, 118.66
# 2015-04-30, BUY EXECUTED, Price: 118.66, Cost: 118.66, Comm 0.12
# 2015-04-30, Close, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-04, Close, 118.72
# 2015-05-05, Close, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-07, SELL CREATE, 116.03
# 2015-05-08, SELL EXECUTED, Price: 117.34, Cost: 118.66, Comm 0.12
# 2015-05-08, OPERATION PROFIT, GROSS -1.32, NET -1.56
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-12, BUY CREATE, 116.59
# 2015-05-13, BUY EXECUTED, Price: 116.85, Cost: 116.85, Comm 0.12
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-15, Close, 119.28
# 2015-05-18, Close, 120.59
# 2015-05-19, Close, 120.48
# 2015-05-20, Close, 120.47
# 2015-05-20, SELL CREATE, 120.47
# 2015-05-21, SELL EXECUTED, Price: 120.48, Cost: 116.85, Comm 0.12
# 2015-05-21, OPERATION PROFIT, GROSS 3.63, NET 3.39
# 2015-05-21, Close, 121.71
# 2015-05-22, Close, 122.77
# 2015-05-26, Close, 120.07
# 2015-05-27, Close, 122.31
# 2015-05-28, Close, 122.07
# 2015-05-29, Close, 120.68
# 2015-05-29, BUY CREATE, 120.68
# 2015-06-01, BUY EXECUTED, Price: 120.68, Cost: 120.68, Comm 0.12
# 2015-06-01, Close, 120.92
# 2015-06-02, Close, 120.38
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-08, SELL CREATE, 118.38
# 2015-06-09, SELL EXECUTED, Price: 117.36, Cost: 120.68, Comm 0.12
# 2015-06-09, OPERATION PROFIT, GROSS -3.32, NET -3.56
# 2015-06-09, Close, 118.03
# 2015-06-09, BUY CREATE, 118.03
# 2015-06-10, BUY EXECUTED, Price: 118.49, Cost: 118.49, Comm 0.12
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-17, SELL CREATE, 117.92
# 2015-06-18, SELL EXECUTED, Price: 117.85, Cost: 118.49, Comm 0.12
# 2015-06-18, OPERATION PROFIT, GROSS -0.64, NET -0.88
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-26, BUY CREATE, 117.41
# 2015-06-29, BUY EXECUTED, Price: 116.21, Cost: 116.21, Comm 0.12
# 2015-06-29, Close, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-07, SELL CREATE, 116.43
# 2015-07-08, SELL EXECUTED, Price: 115.31, Cost: 116.21, Comm 0.12
# 2015-07-08, OPERATION PROFIT, GROSS -0.90, NET -1.13
# 2015-07-08, Close, 113.54
# 2015-07-08, BUY CREATE, 113.54
# 2015-07-09, BUY EXECUTED, Price: 114.72, Cost: 114.72, Comm 0.11
# 2015-07-09, Close, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-14, Close, 116.35
# 2015-07-15, Close, 117.47
# 2015-07-16, Close, 119.04
# 2015-07-16, SELL CREATE, 119.04
# 2015-07-17, SELL EXECUTED, Price: 119.57, Cost: 114.72, Comm 0.12
# 2015-07-17, OPERATION PROFIT, GROSS 4.85, NET 4.62
# 2015-07-17, Close, 120.07
# 2015-07-20, Close, 122.34
# 2015-07-21, Close, 121.11
# 2015-07-22, Close, 115.99
# 2015-07-22, BUY CREATE, 115.99
# 2015-07-23, BUY EXECUTED, Price: 116.90, Cost: 116.90, Comm 0.12
# 2015-07-23, Close, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-30, SELL CREATE, 113.35
# 2015-07-31, SELL EXECUTED, Price: 113.56, Cost: 116.90, Comm 0.11
# 2015-07-31, OPERATION PROFIT, GROSS -3.34, NET -3.57
# 2015-07-31, Close, 112.36
# 2015-07-31, BUY CREATE, 112.36
# 2015-08-03, BUY EXECUTED, Price: 112.55, Cost: 112.55, Comm 0.11
# 2015-08-03, Close, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-10, SELL CREATE, 111.40
# 2015-08-11, SELL EXECUTED, Price: 109.62, Cost: 112.55, Comm 0.11
# 2015-08-11, OPERATION PROFIT, GROSS -2.93, NET -3.15
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-19, BUY CREATE, 107.02
# 2015-08-20, BUY EXECUTED, Price: 106.15, Cost: 106.15, Comm 0.11
# 2015-08-20, Close, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-27, SELL CREATE, 105.07
# 2015-08-28, SELL EXECUTED, Price: 104.37, Cost: 106.15, Comm 0.10
# 2015-08-28, OPERATION PROFIT, GROSS -1.78, NET -1.99
# 2015-08-28, Close, 105.42
# 2015-08-31, Close, 104.92
# 2015-09-01, Close, 100.23
# 2015-09-01, BUY CREATE, 100.23
# 2015-09-02, BUY EXECUTED, Price: 102.57, Cost: 102.57, Comm 0.10
# 2015-09-02, Close, 104.53
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-09, Close, 102.49
# 2015-09-10, Close, 104.75
# 2015-09-10, SELL CREATE, 104.75
# 2015-09-11, SELL EXECUTED, Price: 104.02, Cost: 102.57, Comm 0.10
# 2015-09-11, OPERATION PROFIT, GROSS 1.45, NET 1.24
# 2015-09-11, Close, 106.27
# 2015-09-14, Close, 107.29
# 2015-09-15, Close, 108.20
# 2015-09-16, Close, 108.32
# 2015-09-17, Close, 106.00
# 2015-09-18, Close, 105.56
# 2015-09-18, BUY CREATE, 105.56
# 2015-09-21, BUY EXECUTED, Price: 105.77, Cost: 105.77, Comm 0.11
# 2015-09-21, Close, 107.20
# 2015-09-22, Close, 105.52
# 2015-09-23, Close, 106.37
# 2015-09-24, Close, 107.01
# 2015-09-25, Close, 106.74
# 2015-09-28, Close, 104.62
# 2015-09-28, SELL CREATE, 104.62
# 2015-09-29, SELL EXECUTED, Price: 104.99, Cost: 105.77, Comm 0.10
# 2015-09-29, OPERATION PROFIT, GROSS -0.78, NET -0.99
# 2015-09-29, Close, 101.48
# 2015-09-29, BUY CREATE, 101.48
# 2015-09-30, BUY EXECUTED, Price: 102.51, Cost: 102.51, Comm 0.10
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-07, SELL CREATE, 103.08
# 2015-10-08, SELL EXECUTED, Price: 102.53, Cost: 102.51, Comm 0.10
# 2015-10-08, OPERATION PROFIT, GROSS 0.02, NET -0.19
# 2015-10-08, Close, 101.89
# 2015-10-08, BUY CREATE, 101.89
# 2015-10-09, BUY EXECUTED, Price: 102.35, Cost: 102.35, Comm 0.10
# 2015-10-09, Close, 104.33
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-16, Close, 103.32
# 2015-10-16, SELL CREATE, 103.32
# 2015-10-19, SELL EXECUTED, Price: 103.10, Cost: 102.35, Comm 0.10
# 2015-10-19, OPERATION PROFIT, GROSS 0.75, NET 0.54
# 2015-10-19, Close, 103.96
# 2015-10-20, Close, 105.86
# 2015-10-21, Close, 105.85
# 2015-10-22, Close, 107.47
# 2015-10-23, Close, 110.80
# 2015-10-26, Close, 107.27
# 2015-10-27, Close, 106.59
# 2015-10-27, BUY CREATE, 106.59
# 2015-10-28, BUY EXECUTED, Price: 108.80, Cost: 108.80, Comm 0.11
# 2015-10-28, Close, 110.98
# 2015-10-29, Close, 112.15
# 2015-10-30, Close, 111.19
# 2015-11-02, Close, 112.76
# 2015-11-03, Close, 114.05
# 2015-11-04, Close, 113.52
# 2015-11-04, SELL CREATE, 113.52
# 2015-11-05, SELL EXECUTED, Price: 113.87, Cost: 108.80, Comm 0.11
# 2015-11-05, OPERATION PROFIT, GROSS 5.07, NET 4.85
# 2015-11-05, Close, 113.00
# 2015-11-05, BUY CREATE, 113.00
# 2015-11-06, BUY EXECUTED, Price: 113.17, Cost: 113.17, Comm 0.11
# 2015-11-06, Close, 113.13
# 2015-11-09, Close, 112.67
# 2015-11-10, Close, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-13, SELL CREATE, 104.98
# 2015-11-16, SELL EXECUTED, Price: 104.08, Cost: 113.17, Comm 0.10
# 2015-11-16, OPERATION PROFIT, GROSS -9.09, NET -9.31
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-20, Close, 111.48
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-25, Close, 110.30
# 2015-11-27, Close, 110.09
# 2015-11-27, BUY CREATE, 110.09
# 2015-11-30, BUY EXECUTED, Price: 110.26, Cost: 110.26, Comm 0.11
# 2015-11-30, Close, 110.55
# 2015-12-01, Close, 109.65
# 2015-12-02, Close, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-07, Close, 110.53
# 2015-12-07, SELL CREATE, 110.53
# 2015-12-08, SELL EXECUTED, Price: 109.82, Cost: 110.26, Comm 0.11
# 2015-12-08, OPERATION PROFIT, GROSS -0.44, NET -0.66
# 2015-12-08, Close, 110.48
# 2015-12-08, BUY CREATE, 110.48
# 2015-12-09, BUY EXECUTED, Price: 109.93, Cost: 109.93, Comm 0.11
# 2015-12-09, Close, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-16, SELL CREATE, 104.04
# 2015-12-17, SELL EXECUTED, Price: 104.68, Cost: 109.93, Comm 0.10
# 2015-12-17, OPERATION PROFIT, GROSS -5.25, NET -5.46
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-18, BUY CREATE, 99.08
# 2015-12-21, BUY EXECUTED, Price: 100.25, Cost: 100.25, Comm 0.10
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-29, SELL CREATE, 101.61
# 2015-12-30, SELL EXECUTED, Price: 101.47, Cost: 100.25, Comm 0.10
# 2015-12-30, OPERATION PROFIT, GROSS 1.22, NET 1.02
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2015-12-31, BUY CREATE, 98.36
# 2016-01-04, BUY EXECUTED, Price: 95.89, Cost: 95.89, Comm 0.10
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-11, SELL CREATE, 92.07
# 2016-01-12, SELL EXECUTED, Price: 93.96, Cost: 95.89, Comm 0.09
# 2016-01-12, OPERATION PROFIT, GROSS -1.93, NET -2.12
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-19, BUY CREATE, 90.33
# 2016-01-20, BUY EXECUTED, Price: 88.87, Cost: 88.87, Comm 0.09
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-27, SELL CREATE, 87.30
# 2016-01-28, SELL EXECUTED, Price: 87.64, Cost: 88.87, Comm 0.09
# 2016-01-28, OPERATION PROFIT, GROSS -1.23, NET -1.41
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-02, BUY CREATE, 88.29
# 2016-02-03, BUY EXECUTED, Price: 88.77, Cost: 88.77, Comm 0.09
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-05, Close, 88.34
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-10, SELL CREATE, 88.57
# 2016-02-11, SELL EXECUTED, Price: 88.12, Cost: 88.77, Comm 0.09
# 2016-02-11, OPERATION PROFIT, GROSS -0.65, NET -0.83
# 2016-02-11, Close, 88.04
# 2016-02-11, BUY CREATE, 88.04
# 2016-02-12, BUY EXECUTED, Price: 88.50, Cost: 88.50, Comm 0.09
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-17, Close, 92.19
# 2016-02-18, Close, 90.44
# 2016-02-19, Close, 90.23
# 2016-02-22, Close, 91.02
# 2016-02-22, SELL CREATE, 91.02
# 2016-02-23, SELL EXECUTED, Price: 90.57, Cost: 88.50, Comm 0.09
# 2016-02-23, OPERATION PROFIT, GROSS 2.07, NET 1.89
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-25, Close, 90.91
# 2016-02-26, Close, 91.05
# 2016-02-29, Close, 90.84
# 2016-03-01, Close, 94.45
# 2016-03-02, Close, 94.66
# 2016-03-03, Close, 95.36
# 2016-03-04, Close, 96.78
# 2016-03-07, Close, 95.71
# 2016-03-08, Close, 94.92
# 2016-03-08, BUY CREATE, 94.92
# 2016-03-09, BUY EXECUTED, Price: 95.19, Cost: 95.19, Comm 0.10
# 2016-03-09, Close, 95.01
# 2016-03-10, Close, 95.05
# 2016-03-11, Close, 96.08
# 2016-03-14, Close, 96.32
# 2016-03-15, Close, 98.26
# 2016-03-16, Close, 99.56
# 2016-03-16, SELL CREATE, 99.56
# 2016-03-17, SELL EXECUTED, Price: 99.14, Cost: 95.19, Comm 0.10
# 2016-03-17, OPERATION PROFIT, GROSS 3.95, NET 3.76
# 2016-03-17, Close, 99.40
# 2016-03-18, Close, 99.52
# 2016-03-21, Close, 99.51
# 2016-03-22, Close, 100.27
# 2016-03-23, Close, 99.71
# 2016-03-24, Close, 99.28
# 2016-03-24, BUY CREATE, 99.28
# 2016-03-28, BUY EXECUTED, Price: 99.59, Cost: 99.59, Comm 0.10
# 2016-03-28, Close, 98.83
# 2016-03-29, Close, 101.17
# 2016-03-30, Close, 102.94
# 2016-03-31, Close, 102.40
# 2016-04-01, Close, 103.34
# 2016-04-04, Close, 104.40
# 2016-04-04, SELL CREATE, 104.40
# 2016-04-05, SELL EXECUTED, Price: 102.89, Cost: 99.59, Comm 0.10
# 2016-04-05, OPERATION PROFIT, GROSS 3.30, NET 3.10
# 2016-04-05, Close, 103.17
# 2016-04-06, Close, 104.25
# 2016-04-07, Close, 101.98
# 2016-04-08, Close, 102.09
# 2016-04-11, Close, 102.43
# 2016-04-12, Close, 103.76
# 2016-04-13, Close, 105.27
# 2016-04-14, Close, 105.32
# 2016-04-15, Close, 103.21
# 2016-04-18, Close, 100.98
# 2016-04-18, BUY CREATE, 100.98
# 2016-04-19, BUY EXECUTED, Price: 101.36, Cost: 101.36, Comm 0.10
# 2016-04-19, Close, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-26, SELL CREATE, 98.04
# 2016-04-27, SELL EXECUTED, Price: 90.20, Cost: 101.36, Comm 0.09
# 2016-04-27, OPERATION PROFIT, GROSS -11.16, NET -11.35
# 2016-04-27, Close, 91.91
# 2016-04-27, BUY CREATE, 91.91
# 2016-04-28, BUY EXECUTED, Price: 91.71, Cost: 91.71, Comm 0.09
# 2016-04-28, Close, 89.10
# 2016-04-29, Close, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-05, SELL CREATE, 88.14
# 2016-05-06, SELL EXECUTED, Price: 88.26, Cost: 91.71, Comm 0.09
# 2016-05-06, OPERATION PROFIT, GROSS -3.45, NET -3.63
# 2016-05-06, Close, 87.64
# 2016-05-06, BUY CREATE, 87.64
# 2016-05-09, BUY EXECUTED, Price: 87.91, Cost: 87.91, Comm 0.09
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-16, SELL CREATE, 88.74
# 2016-05-17, SELL EXECUTED, Price: 89.37, Cost: 87.91, Comm 0.09
# 2016-05-17, OPERATION PROFIT, GROSS 1.46, NET 1.28
# 2016-05-17, Close, 88.37
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-05-31, BUY CREATE, 94.39
# 2016-06-01, BUY EXECUTED, Price: 93.60, Cost: 93.60, Comm 0.09
# 2016-06-01, Close, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-08, SELL CREATE, 93.52
# 2016-06-09, SELL EXECUTED, Price: 93.11, Cost: 93.60, Comm 0.09
# 2016-06-09, OPERATION PROFIT, GROSS -0.49, NET -0.68
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-13, BUY CREATE, 92.01
# 2016-06-14, BUY EXECUTED, Price: 91.99, Cost: 91.99, Comm 0.09
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-21, SELL CREATE, 90.66
# 2016-06-22, SELL EXECUTED, Price: 90.98, Cost: 91.99, Comm 0.09
# 2016-06-22, OPERATION PROFIT, GROSS -1.01, NET -1.19
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-27, BUY CREATE, 87.00
# 2016-06-28, BUY EXECUTED, Price: 87.81, Cost: 87.81, Comm 0.09
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-05, Close, 89.79
# 2016-07-06, Close, 90.30
# 2016-07-06, SELL CREATE, 90.30
# 2016-07-07, SELL EXECUTED, Price: 90.46, Cost: 87.81, Comm 0.09
# 2016-07-07, OPERATION PROFIT, GROSS 2.65, NET 2.47
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-22, BUY CREATE, 93.26
# 2016-07-25, BUY EXECUTED, Price: 92.87, Cost: 92.87, Comm 0.09
# 2016-07-25, Close, 92.01
# 2016-07-26, Close, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-28, Close, 98.63
# 2016-07-29, Close, 98.51
# 2016-08-01, Close, 100.25
# 2016-08-01, SELL CREATE, 100.25
# 2016-08-02, SELL EXECUTED, Price: 100.25, Cost: 92.87, Comm 0.10
# 2016-08-02, OPERATION PROFIT, GROSS 7.38, NET 7.19
# 2016-08-02, Close, 98.76
# 2016-08-03, Close, 100.00
# 2016-08-04, Close, 100.62
# 2016-08-05, Close, 102.15
# 2016-08-08, Close, 102.99
# 2016-08-09, Close, 103.41
# 2016-08-10, Close, 102.64
# 2016-08-11, Close, 102.57
# 2016-08-11, BUY CREATE, 102.57
# 2016-08-12, BUY EXECUTED, Price: 102.43, Cost: 102.43, Comm 0.10
# 2016-08-12, Close, 102.81
# 2016-08-15, Close, 104.05
# 2016-08-16, Close, 103.95
# 2016-08-17, Close, 103.80
# 2016-08-18, Close, 103.67
# 2016-08-19, Close, 103.93
# 2016-08-19, SELL CREATE, 103.93
# 2016-08-22, SELL EXECUTED, Price: 103.46, Cost: 102.43, Comm 0.10
# 2016-08-22, OPERATION PROFIT, GROSS 1.03, NET 0.82
# 2016-08-22, Close, 103.13
# 2016-08-23, Close, 103.45
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-25, BUY CREATE, 102.23
# 2016-08-26, BUY EXECUTED, Price: 102.08, Cost: 102.08, Comm 0.10
# 2016-08-26, Close, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-02, SELL CREATE, 102.38
# 2016-09-06, SELL EXECUTED, Price: 102.55, Cost: 102.08, Comm 0.10
# 2016-09-06, OPERATION PROFIT, GROSS 0.47, NET 0.27
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-09, BUY CREATE, 98.01
# 2016-09-12, BUY EXECUTED, Price: 97.56, Cost: 97.56, Comm 0.10
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-14, Close, 106.22
# 2016-09-15, Close, 109.84
# 2016-09-16, Close, 109.22
# 2016-09-19, Close, 107.94
# 2016-09-19, SELL CREATE, 107.94
# 2016-09-20, SELL EXECUTED, Price: 107.44, Cost: 97.56, Comm 0.11
# 2016-09-20, OPERATION PROFIT, GROSS 9.88, NET 9.67
# 2016-09-20, Close, 107.94
# 2016-09-21, Close, 107.92
# 2016-09-22, Close, 108.93
# 2016-09-23, Close, 107.12
# 2016-09-26, Close, 107.28
# 2016-09-27, Close, 107.48
# 2016-09-28, Close, 108.30
# 2016-09-29, Close, 106.61
# 2016-09-30, Close, 107.44
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-07, Close, 108.40
# 2016-10-10, Close, 110.29
# 2016-10-11, Close, 110.53
# 2016-10-12, Close, 111.52
# 2016-10-13, Close, 111.18
# 2016-10-14, Close, 111.79
# 2016-10-17, Close, 111.72
# 2016-10-18, Close, 111.64
# 2016-10-18, BUY CREATE, 111.64
# 2016-10-19, BUY EXECUTED, Price: 111.43, Cost: 111.43, Comm 0.11
# 2016-10-19, Close, 111.31
# 2016-10-20, Close, 111.25
# 2016-10-21, Close, 110.81
# 2016-10-24, Close, 111.81
# 2016-10-25, Close, 112.38
# 2016-10-26, Close, 109.85
# 2016-10-26, SELL CREATE, 109.85
# 2016-10-27, SELL EXECUTED, Price: 109.66, Cost: 111.43, Comm 0.11
# 2016-10-27, OPERATION PROFIT, GROSS -1.77, NET -1.99
# 2016-10-27, Close, 108.80
# 2016-10-27, BUY CREATE, 108.80
# 2016-10-28, BUY EXECUTED, Price: 108.22, Cost: 108.22, Comm 0.11
# 2016-10-28, Close, 108.08
# 2016-10-31, Close, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-04, SELL CREATE, 103.97
# 2016-11-07, SELL EXECUTED, Price: 105.16, Cost: 108.22, Comm 0.11
# 2016-11-07, OPERATION PROFIT, GROSS -3.06, NET -3.27
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-10, BUY CREATE, 102.97
# 2016-11-11, BUY EXECUTED, Price: 102.33, Cost: 102.33, Comm 0.10
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-18, Close, 105.14
# 2016-11-18, SELL CREATE, 105.14
# 2016-11-21, SELL EXECUTED, Price: 105.19, Cost: 102.33, Comm 0.11
# 2016-11-21, OPERATION PROFIT, GROSS 2.86, NET 2.65
# 2016-11-21, Close, 106.73
# 2016-11-22, Close, 106.80
# 2016-11-23, Close, 106.25
# 2016-11-25, Close, 106.79
# 2016-11-28, Close, 106.58
# 2016-11-29, Close, 106.47
# 2016-11-29, BUY CREATE, 106.47
# 2016-11-30, BUY EXECUTED, Price: 106.61, Cost: 106.61, Comm 0.11
# 2016-11-30, Close, 105.58
# 2016-12-01, Close, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-07, SELL CREATE, 106.06
# 2016-12-08, SELL EXECUTED, Price: 105.90, Cost: 106.61, Comm 0.11
# 2016-12-08, OPERATION PROFIT, GROSS -0.71, NET -0.92
# 2016-12-08, Close, 107.10
# 2016-12-09, Close, 108.85
# 2016-12-12, Close, 108.23
# 2016-12-13, Close, 110.04
# 2016-12-14, Close, 110.04
# 2016-12-15, Close, 110.64
# 2016-12-16, Close, 110.78
# 2016-12-19, Close, 111.42
# 2016-12-20, Close, 111.72
# 2016-12-21, Close, 111.82
# 2016-12-22, Close, 111.09
# 2016-12-23, Close, 111.31
# 2016-12-27, Close, 112.01
# 2016-12-28, Close, 111.54
# 2016-12-29, Close, 111.51
# 2016-12-29, BUY CREATE, 111.51
# 2016-12-30, BUY EXECUTED, Price: 111.43, Cost: 111.43, Comm 0.11
# 2016-12-30, Close, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-06, Close, 112.64
# 2017-01-09, Close, 113.67
# 2017-01-09, SELL CREATE, 113.67
# 2017-01-10, SELL EXECUTED, Price: 113.46, Cost: 111.43, Comm 0.11
# 2017-01-10, OPERATION PROFIT, GROSS 2.03, NET 1.81
# 2017-01-10, Close, 113.78
# 2017-01-11, Close, 114.39
# 2017-01-12, Close, 113.92
# 2017-01-13, Close, 113.71
# 2017-01-13, BUY CREATE, 113.71
# 2017-01-17, BUY EXECUTED, Price: 113.05, Cost: 113.05, Comm 0.11
# 2017-01-17, Close, 114.63
# 2017-01-18, Close, 114.62
# 2017-01-19, Close, 114.42
# 2017-01-20, Close, 114.63
# 2017-01-23, Close, 114.71
# 2017-01-24, Close, 114.60
# 2017-01-24, SELL CREATE, 114.60
# 2017-01-25, SELL EXECUTED, Price: 115.03, Cost: 113.05, Comm 0.12
# 2017-01-25, OPERATION PROFIT, GROSS 1.98, NET 1.75
# 2017-01-25, Close, 116.43
# 2017-01-26, Close, 116.48
# 2017-01-27, Close, 116.49
# 2017-01-30, Close, 116.19
# 2017-01-31, Close, 115.92
# 2017-01-31, BUY CREATE, 115.92
# 2017-02-01, BUY EXECUTED, Price: 121.35, Cost: 121.35, Comm 0.12
# 2017-02-01, Close, 122.99
# 2017-02-02, Close, 122.78
# 2017-02-03, Close, 123.31
# 2017-02-06, Close, 124.46
# 2017-02-07, Close, 125.65
# 2017-02-08, Close, 126.13
# 2017-02-08, SELL CREATE, 126.13
# 2017-02-09, SELL EXECUTED, Price: 126.31, Cost: 121.35, Comm 0.13
# 2017-02-09, OPERATION PROFIT, GROSS 4.96, NET 4.71
# 2017-02-09, Close, 127.04
# 2017-02-10, Close, 126.76
# 2017-02-13, Close, 127.88
# 2017-02-14, Close, 129.54
# 2017-02-15, Close, 130.01
# 2017-02-16, Close, 129.86
# 2017-02-17, Close, 130.21
# 2017-02-21, Close, 131.15
# 2017-02-22, Close, 131.54
# 2017-02-23, Close, 130.99
# 2017-02-24, Close, 131.11
# 2017-02-27, Close, 131.37
# 2017-02-28, Close, 131.43
# 2017-03-01, Close, 134.12
# 2017-03-02, Close, 133.32
# 2017-03-03, Close, 134.11
# 2017-03-06, Close, 133.68
# 2017-03-07, Close, 133.86
# 2017-03-08, Close, 133.36
# 2017-03-09, Close, 133.05
# 2017-03-09, BUY CREATE, 133.05
# 2017-03-10, BUY EXECUTED, Price: 133.60, Cost: 133.60, Comm 0.13
# 2017-03-10, Close, 133.49
# 2017-03-13, Close, 133.55
# 2017-03-14, Close, 133.35
# 2017-03-15, Close, 134.76
# 2017-03-16, Close, 134.98
# 2017-03-17, Close, 134.31
# 2017-03-17, SELL CREATE, 134.31
# 2017-03-20, SELL EXECUTED, Price: 134.70, Cost: 133.60, Comm 0.13
# 2017-03-20, OPERATION PROFIT, GROSS 1.10, NET 0.83
# 2017-03-20, Close, 135.72
# 2017-03-21, Close, 134.16
# 2017-03-22, Close, 135.68
# 2017-03-23, Close, 135.20
# 2017-03-24, Close, 134.93
# 2017-03-24, BUY CREATE, 134.93
# 2017-03-27, BUY EXECUTED, Price: 133.73, Cost: 133.73, Comm 0.13
# 2017-03-27, Close, 135.16
# 2017-03-28, Close, 137.96
# 2017-03-29, Close, 138.27
# 2017-03-30, Close, 138.09
# 2017-03-31, Close, 137.83
# 2017-04-03, Close, 137.87
# 2017-04-03, SELL CREATE, 137.87
# 2017-04-04, SELL EXECUTED, Price: 137.43, Cost: 133.73, Comm 0.14
# 2017-04-04, OPERATION PROFIT, GROSS 3.70, NET 3.43
# 2017-04-04, Close, 138.89
# 2017-04-05, Close, 138.17
# 2017-04-06, Close, 137.83
# 2017-04-06, BUY CREATE, 137.83
# 2017-04-07, BUY EXECUTED, Price: 137.90, Cost: 137.90, Comm 0.14
# 2017-04-07, Close, 137.52
# 2017-04-10, Close, 137.36
# 2017-04-11, Close, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-17, SELL CREATE, 136.07
# 2017-04-18, SELL EXECUTED, Price: 135.67, Cost: 137.90, Comm 0.14
# 2017-04-18, OPERATION PROFIT, GROSS -2.23, NET -2.50
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-19, BUY CREATE, 134.97
# 2017-04-20, BUY EXECUTED, Price: 135.49, Cost: 135.49, Comm 0.14
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-25, Close, 138.66
# 2017-04-26, Close, 137.85
# 2017-04-27, Close, 137.95
# 2017-04-27, SELL CREATE, 137.95
# 2017-04-28, SELL EXECUTED, Price: 138.24, Cost: 135.49, Comm 0.14
# 2017-04-28, OPERATION PROFIT, GROSS 2.75, NET 2.48
# 2017-04-28, Close, 137.82
# 2017-05-01, Close, 140.63
# 2017-05-02, Close, 141.52
# 2017-05-03, Close, 141.09
# 2017-05-04, Close, 140.58
# 2017-05-04, BUY CREATE, 140.58
# 2017-05-05, BUY EXECUTED, Price: 140.80, Cost: 140.80, Comm 0.14
# 2017-05-05, Close, 142.91
# 2017-05-08, Close, 146.80
# 2017-05-09, Close, 147.74
# 2017-05-10, Close, 147.04
# 2017-05-11, Close, 148.31
# 2017-05-12, Close, 150.38
# 2017-05-12, SELL CREATE, 150.38
# 2017-05-15, SELL EXECUTED, Price: 150.29, Cost: 140.80, Comm 0.15
# 2017-05-15, OPERATION PROFIT, GROSS 9.49, NET 9.20
# 2017-05-15, Close, 150.00
# 2017-05-16, Close, 149.77
# 2017-05-16, BUY CREATE, 149.77
# 2017-05-17, BUY EXECUTED, Price: 147.97, Cost: 147.97, Comm 0.15
# 2017-05-17, Close, 144.75
# 2017-05-18, Close, 146.95
# 2017-05-19, Close, 147.45
# 2017-05-22, Close, 148.35
# 2017-05-23, Close, 148.17
# 2017-05-24, Close, 147.72
# 2017-05-24, SELL CREATE, 147.72
# 2017-05-25, SELL EXECUTED, Price: 148.10, Cost: 147.97, Comm 0.15
# 2017-05-25, OPERATION PROFIT, GROSS 0.13, NET -0.17
# 2017-05-25, Close, 148.23
# 2017-05-26, Close, 147.98
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-05, Close, 148.29
# 2017-06-06, Close, 148.79
# 2017-06-07, Close, 149.68
# 2017-06-08, Close, 149.31
# 2017-06-09, Close, 143.52
# 2017-06-09, BUY CREATE, 143.52
# 2017-06-12, BUY EXECUTED, Price: 140.40, Cost: 140.40, Comm 0.14
# 2017-06-12, Close, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-19, SELL CREATE, 140.98
# 2017-06-20, SELL EXECUTED, Price: 141.49, Cost: 140.40, Comm 0.14
# 2017-06-20, OPERATION PROFIT, GROSS 1.09, NET 0.81
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-27, BUY CREATE, 138.46
# 2017-06-28, BUY EXECUTED, Price: 139.20, Cost: 139.20, Comm 0.14
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-06, SELL CREATE, 137.50
# 2017-07-07, SELL EXECUTED, Price: 137.66, Cost: 139.20, Comm 0.14
# 2017-07-07, OPERATION PROFIT, GROSS -1.54, NET -1.82
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-11, Close, 140.20
# 2017-07-12, Close, 140.40
# 2017-07-13, Close, 142.36
# 2017-07-14, Close, 143.58
# 2017-07-17, Close, 144.08
# 2017-07-18, Close, 144.58
# 2017-07-19, Close, 145.49
# 2017-07-20, Close, 144.83
# 2017-07-21, Close, 144.76
# 2017-07-21, BUY CREATE, 144.76
# 2017-07-24, BUY EXECUTED, Price: 145.06, Cost: 145.06, Comm 0.15
# 2017-07-24, Close, 146.52
# 2017-07-25, Close, 147.14
# 2017-07-26, Close, 147.84
# 2017-07-27, Close, 145.04
# 2017-07-28, Close, 144.02
# 2017-07-31, Close, 143.28
# 2017-07-31, SELL CREATE, 143.28
# 2017-08-01, SELL EXECUTED, Price: 143.64, Cost: 145.06, Comm 0.14
# 2017-08-01, OPERATION PROFIT, GROSS -1.42, NET -1.71
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-03, Close, 149.87
# 2017-08-04, Close, 150.66
# 2017-08-07, Close, 152.99
# 2017-08-08, Close, 154.22
# 2017-08-09, Close, 155.16
# 2017-08-10, Close, 150.22
# 2017-08-11, Close, 152.31
# 2017-08-14, Close, 154.60
# 2017-08-15, Close, 156.29
# 2017-08-16, Close, 155.66
# 2017-08-17, Close, 152.67
# 2017-08-17, BUY CREATE, 152.67
# 2017-08-18, BUY EXECUTED, Price: 152.67, Cost: 152.67, Comm 0.15
# 2017-08-18, Close, 152.33
# 2017-08-21, Close, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-23, Close, 154.72
# 2017-08-24, Close, 154.04
# 2017-08-25, Close, 154.61
# 2017-08-25, SELL CREATE, 154.61
# 2017-08-28, SELL EXECUTED, Price: 154.88, Cost: 152.67, Comm 0.15
# 2017-08-28, OPERATION PROFIT, GROSS 2.21, NET 1.90
# 2017-08-28, Close, 156.17
# 2017-08-29, Close, 157.56
# 2017-08-30, Close, 157.98
# 2017-08-31, Close, 158.61
# 2017-09-01, Close, 158.66
# 2017-09-05, Close, 156.76
# 2017-09-06, Close, 156.59
# 2017-09-06, BUY CREATE, 156.59
# 2017-09-07, BUY EXECUTED, Price: 156.77, Cost: 156.77, Comm 0.16
# 2017-09-07, Close, 155.96
# 2017-09-08, Close, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-14, SELL CREATE, 153.08
# 2017-09-15, SELL EXECUTED, Price: 153.26, Cost: 156.77, Comm 0.15
# 2017-09-15, OPERATION PROFIT, GROSS -3.51, NET -3.82
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-21, BUY CREATE, 148.35
# 2017-09-22, BUY EXECUTED, Price: 146.56, Cost: 146.56, Comm 0.15
# 2017-09-22, Close, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-09-29, SELL CREATE, 149.06
# 2017-10-02, SELL EXECUTED, Price: 149.19, Cost: 146.56, Comm 0.15
# 2017-10-02, OPERATION PROFIT, GROSS 2.63, NET 2.33
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-06, Close, 150.20
# 2017-10-09, Close, 150.72
# 2017-10-10, Close, 150.78
# 2017-10-11, Close, 151.41
# 2017-10-12, Close, 150.88
# 2017-10-13, Close, 151.83
# 2017-10-16, Close, 154.63
# 2017-10-17, Close, 155.20
# 2017-10-18, Close, 154.51
# 2017-10-19, Close, 150.86
# 2017-10-19, BUY CREATE, 150.86
# 2017-10-20, BUY EXECUTED, Price: 151.47, Cost: 151.47, Comm 0.15
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-27, Close, 157.69
# 2017-10-27, SELL CREATE, 157.69
# 2017-10-30, SELL EXECUTED, Price: 158.51, Cost: 151.47, Comm 0.16
# 2017-10-30, OPERATION PROFIT, GROSS 7.04, NET 6.73
# 2017-10-30, Close, 161.24
# 2017-10-31, Close, 163.49
# 2017-11-01, Close, 161.41
# 2017-11-02, Close, 162.59
# 2017-11-03, Close, 166.83
# 2017-11-06, Close, 168.53
# 2017-11-07, Close, 169.07
# 2017-11-08, Close, 170.45
# 2017-11-09, Close, 170.10
# 2017-11-10, Close, 169.54
# 2017-11-10, BUY CREATE, 169.54
# 2017-11-13, BUY EXECUTED, Price: 168.40, Cost: 168.40, Comm 0.17
# 2017-11-13, Close, 168.86
# 2017-11-14, Close, 166.31
# 2017-11-15, Close, 164.11
# 2017-11-16, Close, 166.07
# 2017-11-17, Close, 165.15
# 2017-11-20, Close, 164.99
# 2017-11-20, SELL CREATE, 164.99
# 2017-11-21, SELL EXECUTED, Price: 165.76, Cost: 168.40, Comm 0.17
# 2017-11-21, OPERATION PROFIT, GROSS -2.64, NET -2.97
# 2017-11-21, Close, 168.05
# 2017-11-22, Close, 169.82
# 2017-11-24, Close, 169.83
# 2017-11-27, Close, 168.98
# 2017-11-28, Close, 167.99
# 2017-11-28, BUY CREATE, 167.99
# 2017-11-29, BUY EXECUTED, Price: 167.56, Cost: 167.56, Comm 0.17
# 2017-11-29, Close, 164.50
# 2017-11-30, Close, 166.80
# 2017-12-01, Close, 166.03
# 2017-12-04, Close, 164.81
# 2017-12-05, Close, 164.66
# 2017-12-06, Close, 164.05
# 2017-12-06, SELL CREATE, 164.05
# 2017-12-07, SELL EXECUTED, Price: 164.06, Cost: 167.56, Comm 0.16
# 2017-12-07, OPERATION PROFIT, GROSS -3.50, NET -3.83
# 2017-12-07, Close, 164.35
# 2017-12-08, Close, 164.39
# 2017-12-11, Close, 167.60
# 2017-12-12, Close, 166.66
# 2017-12-13, Close, 167.21
# 2017-12-14, Close, 167.16
# 2017-12-15, Close, 168.86
# 2017-12-18, Close, 171.24
# 2017-12-19, Close, 169.41
# 2017-12-20, Close, 169.23
# 2017-12-20, BUY CREATE, 169.23
# 2017-12-21, BUY EXECUTED, Price: 169.05, Cost: 169.05, Comm 0.17
# 2017-12-21, Close, 169.87
# 2017-12-22, Close, 169.87
# 2017-12-26, Close, 165.56
# 2017-12-27, Close, 165.59
# 2017-12-28, Close, 166.05
# 2017-12-29, Close, 164.26
# 2017-12-29, SELL CREATE, 164.26
# 2018-01-02, SELL EXECUTED, Price: 165.16, Cost: 169.05, Comm 0.17
# 2018-01-02, OPERATION PROFIT, GROSS -3.89, NET -4.22
# 2018-01-02, Close, 167.20
# 2018-01-03, Close, 167.17
# 2018-01-04, Close, 167.95
# 2018-01-05, Close, 169.86
# 2018-01-08, Close, 169.23
# 2018-01-09, Close, 169.21
# 2018-01-09, BUY CREATE, 169.21
# 2018-01-10, BUY EXECUTED, Price: 168.07, Cost: 168.07, Comm 0.17
# 2018-01-10, Close, 169.17
# 2018-01-11, Close, 170.13
# 2018-01-12, Close, 171.89
# 2018-01-16, Close, 171.01
# 2018-01-17, Close, 173.84
# 2018-01-18, Close, 173.99
# 2018-01-18, SELL CREATE, 173.99
# 2018-01-19, SELL EXECUTED, Price: 173.36, Cost: 168.07, Comm 0.17
# 2018-01-19, OPERATION PROFIT, GROSS 5.29, NET 4.95
# 2018-01-19, Close, 173.22
# 2018-01-22, Close, 171.80
# 2018-01-22, BUY CREATE, 171.80
# 2018-01-23, BUY EXECUTED, Price: 172.09, Cost: 172.09, Comm 0.17
# 2018-01-23, Close, 171.84
# 2018-01-24, Close, 169.10
# 2018-01-25, Close, 166.08
# 2018-01-26, Close, 166.47
# 2018-01-29, Close, 163.03
# 2018-01-30, Close, 162.07
# 2018-01-30, SELL CREATE, 162.07
# 2018-01-31, SELL EXECUTED, Price: 161.97, Cost: 172.09, Comm 0.16
# 2018-01-31, OPERATION PROFIT, GROSS -10.12, NET -10.45
# 2018-01-31, Close, 162.51
# 2018-02-01, Close, 162.85
# 2018-02-02, Close, 155.79
# 2018-02-05, Close, 151.89
# 2018-02-05, BUY CREATE, 151.89
# 2018-02-06, BUY EXECUTED, Price: 150.28, Cost: 150.28, Comm 0.15
# 2018-02-06, Close, 158.24
# 2018-02-07, Close, 154.85
# 2018-02-08, Close, 150.59
# 2018-02-09, Close, 152.43
# 2018-02-12, Close, 158.57
# 2018-02-13, Close, 160.16
# 2018-02-13, SELL CREATE, 160.16
# 2018-02-14, SELL EXECUTED, Price: 158.90, Cost: 150.28, Comm 0.16
# 2018-02-14, OPERATION PROFIT, GROSS 8.62, NET 8.31
# 2018-02-14, Close, 163.12
# 2018-02-15, Close, 168.59
# 2018-02-16, Close, 168.05
# 2018-02-20, Close, 167.48
# 2018-02-20, BUY CREATE, 167.48
# 2018-02-21, BUY EXECUTED, Price: 168.44, Cost: 168.44, Comm 0.17
# 2018-02-21, Close, 166.72
# 2018-02-22, Close, 168.12
# 2018-02-23, Close, 171.04
# 2018-02-26, Close, 174.42
# 2018-02-27, Close, 173.86
# 2018-02-28, Close, 173.59
# 2018-02-28, SELL CREATE, 173.59
# 2018-03-01, SELL EXECUTED, Price: 174.00, Cost: 168.44, Comm 0.17
# 2018-03-01, OPERATION PROFIT, GROSS 5.56, NET 5.22
# 2018-03-01, Close, 170.55
# 2018-03-01, BUY CREATE, 170.55
# 2018-03-02, BUY EXECUTED, Price: 168.41, Cost: 168.41, Comm 0.17
# 2018-03-02, Close, 171.73
# 2018-03-05, Close, 172.33
# 2018-03-06, Close, 172.18
# 2018-03-07, Close, 170.58
# 2018-03-08, Close, 172.44
# 2018-03-09, Close, 175.41
# 2018-03-09, SELL CREATE, 175.41
# 2018-03-12, SELL EXECUTED, Price: 175.71, Cost: 168.41, Comm 0.18
# 2018-03-12, OPERATION PROFIT, GROSS 7.30, NET 6.96
# 2018-03-12, Close, 177.10
# 2018-03-13, Close, 175.40
# 2018-03-14, Close, 173.90
# 2018-03-14, BUY CREATE, 173.90
# 2018-03-15, BUY EXECUTED, Price: 173.96, Cost: 173.96, Comm 0.17
# 2018-03-15, Close, 174.11
# 2018-03-16, Close, 173.50
# 2018-03-19, Close, 170.84
# 2018-03-20, Close, 170.79
# 2018-03-21, Close, 166.92
# 2018-03-22, Close, 164.56
# 2018-03-22, SELL CREATE, 164.56
# 2018-03-23, SELL EXECUTED, Price: 164.11, Cost: 173.96, Comm 0.16
# 2018-03-23, OPERATION PROFIT, GROSS -9.85, NET -10.19
# 2018-03-23, Close, 160.75
# 2018-03-23, BUY CREATE, 160.75
# 2018-03-26, BUY EXECUTED, Price: 163.80, Cost: 163.80, Comm 0.16
# 2018-03-26, Close, 168.38
# 2018-03-27, Close, 164.06
# 2018-03-28, Close, 162.25
# 2018-03-29, Close, 163.52
# 2018-04-02, Close, 162.44
# 2018-04-03, Close, 164.11
# 2018-04-03, SELL CREATE, 164.11
# 2018-04-04, SELL EXECUTED, Price: 160.69, Cost: 163.80, Comm 0.16
# 2018-04-04, OPERATION PROFIT, GROSS -3.11, NET -3.43
# 2018-04-04, Close, 167.25
# 2018-04-05, Close, 168.41
# 2018-04-06, Close, 164.10
# 2018-04-09, Close, 165.73
# 2018-04-10, Close, 168.85
# 2018-04-11, Close, 168.06
# 2018-04-12, Close, 169.71
# 2018-04-13, Close, 170.29
# 2018-04-16, Close, 171.35
# 2018-04-17, Close, 173.71
# 2018-04-18, Close, 173.32
# 2018-04-19, Close, 168.41
# 2018-04-19, BUY CREATE, 168.41
# 2018-04-20, BUY EXECUTED, Price: 166.26, Cost: 166.26, Comm 0.17
# 2018-04-20, Close, 161.51
# 2018-04-23, Close, 161.04
# 2018-04-24, Close, 158.80
# 2018-04-25, Close, 159.49
# 2018-04-26, Close, 160.05
# 2018-04-27, Close, 158.19
# 2018-04-27, SELL CREATE, 158.19
# 2018-04-30, SELL EXECUTED, Price: 158.01, Cost: 166.26, Comm 0.16
# 2018-04-30, OPERATION PROFIT, GROSS -8.25, NET -8.57
# 2018-04-30, Close, 161.06
# 2018-05-01, Close, 164.80
# 2018-05-02, Close, 172.08
# 2018-05-03, Close, 172.39
# 2018-05-04, Close, 179.16
# 2018-05-07, Close, 180.45
# 2018-05-08, Close, 181.32
# 2018-05-09, Close, 182.60
# 2018-05-10, Close, 185.21
# 2018-05-11, Close, 184.51
# 2018-05-14, Close, 184.07
# 2018-05-14, BUY CREATE, 184.07
# 2018-05-15, BUY EXECUTED, Price: 182.73, Cost: 182.73, Comm 0.18
# 2018-05-15, Close, 182.40
# 2018-05-16, Close, 184.10
# 2018-05-17, Close, 182.94
# 2018-05-18, Close, 182.27
# 2018-05-21, Close, 183.57
# 2018-05-22, Close, 183.11
# 2018-05-22, SELL CREATE, 183.11
# 2018-05-23, SELL EXECUTED, Price: 182.31, Cost: 182.73, Comm 0.18
# 2018-05-23, OPERATION PROFIT, GROSS -0.42, NET -0.79
# 2018-05-23, Close, 184.28
# 2018-05-24, Close, 184.07
# 2018-05-25, Close, 184.50
# 2018-05-29, Close, 183.83
# 2018-05-30, Close, 183.44
# 2018-05-30, BUY CREATE, 183.44
# 2018-05-31, BUY EXECUTED, Price: 183.16, Cost: 183.16, Comm 0.18
# 2018-05-31, Close, 182.82
# 2018-06-01, Close, 186.12
# 2018-06-04, Close, 187.68
# 2018-06-05, Close, 189.12
# 2018-06-06, Close, 189.78
# 2018-06-07, Close, 189.27
# 2018-06-07, SELL CREATE, 189.27
# 2018-06-08, SELL EXECUTED, Price: 187.03, Cost: 183.16, Comm 0.19
# 2018-06-08, OPERATION PROFIT, GROSS 3.87, NET 3.50
# 2018-06-08, Close, 187.55
# 2018-06-08, BUY CREATE, 187.55
# 2018-06-11, BUY EXECUTED, Price: 187.21, Cost: 187.21, Comm 0.19
# 2018-06-11, Close, 187.09
# 2018-06-12, Close, 188.12
# 2018-06-13, Close, 186.57
# 2018-06-14, Close, 186.67
# 2018-06-15, Close, 184.75
# 2018-06-18, Close, 184.65
# 2018-06-18, SELL CREATE, 184.65
# 2018-06-19, SELL EXECUTED, Price: 181.13, Cost: 187.21, Comm 0.18
# 2018-06-19, OPERATION PROFIT, GROSS -6.08, NET -6.45
# 2018-06-19, Close, 181.67
# 2018-06-19, BUY CREATE, 181.67
# 2018-06-20, BUY EXECUTED, Price: 182.31, Cost: 182.31, Comm 0.18
# 2018-06-20, Close, 182.46
# 2018-06-21, Close, 181.44
# 2018-06-22, Close, 180.91
# 2018-06-25, Close, 178.22
# 2018-06-26, Close, 180.44
# 2018-06-27, Close, 180.17
# 2018-06-27, SELL CREATE, 180.17
# 2018-06-28, SELL EXECUTED, Price: 180.11, Cost: 182.31, Comm 0.18
# 2018-06-28, OPERATION PROFIT, GROSS -2.20, NET -2.56
# 2018-06-28, Close, 181.48
# 2018-06-29, Close, 181.10
# 2018-07-02, Close, 183.13
# 2018-07-03, Close, 179.94
# 2018-07-05, Close, 181.38
# 2018-07-06, Close, 183.90
# 2018-07-09, Close, 186.45
# 2018-07-10, Close, 186.23
# 2018-07-11, Close, 183.81
# 2018-07-11, BUY CREATE, 183.81
# 2018-07-12, BUY EXECUTED, Price: 185.42, Cost: 185.42, Comm 0.19
# 2018-07-12, Close, 186.89
# 2018-07-13, Close, 187.19
# 2018-07-16, Close, 186.78
# 2018-07-17, Close, 187.30
# 2018-07-18, Close, 186.28
# 2018-07-19, Close, 187.72
# 2018-07-19, SELL CREATE, 187.72
# 2018-07-20, SELL EXECUTED, Price: 187.63, Cost: 185.42, Comm 0.19
# 2018-07-20, OPERATION PROFIT, GROSS 2.21, NET 1.84
# 2018-07-20, Close, 187.29
# 2018-07-23, Close, 187.46
# 2018-07-24, Close, 188.82
# 2018-07-25, Close, 190.60
# 2018-07-26, Close, 190.00
# 2018-07-27, Close, 186.84
# 2018-07-27, BUY CREATE, 186.84
# 2018-07-30, BUY EXECUTED, Price: 187.74, Cost: 187.74, Comm 0.19
# 2018-07-30, Close, 185.80
# 2018-07-31, Close, 186.17
# 2018-08-01, Close, 197.14
# 2018-08-02, Close, 202.90
# 2018-08-03, Close, 203.49
# 2018-08-06, Close, 204.54
# 2018-08-06, SELL CREATE, 204.54
# 2018-08-07, SELL EXECUTED, Price: 204.79, Cost: 187.74, Comm 0.20
# 2018-08-07, OPERATION PROFIT, GROSS 17.05, NET 16.66
# 2018-08-07, Close, 202.62
# 2018-08-08, Close, 202.76
# 2018-08-09, Close, 204.36
# 2018-08-10, Close, 203.75
# 2018-08-13, Close, 205.06
# 2018-08-14, Close, 205.93
# 2018-08-15, Close, 206.41
# 2018-08-16, Close, 209.43
# 2018-08-17, Close, 213.61
# 2018-08-20, Close, 211.53
# 2018-08-21, Close, 211.12
# 2018-08-21, BUY CREATE, 211.12
# 2018-08-22, BUY EXECUTED, Price: 210.20, Cost: 210.20, Comm 0.21
# 2018-08-22, Close, 211.13
# 2018-08-23, Close, 211.56
# 2018-08-24, Close, 212.22
# 2018-08-27, Close, 213.97
# 2018-08-28, Close, 215.70
# 2018-08-29, Close, 218.92
# 2018-08-29, SELL CREATE, 218.92
# 2018-08-30, SELL EXECUTED, Price: 219.18, Cost: 210.20, Comm 0.22
# 2018-08-30, OPERATION PROFIT, GROSS 8.98, NET 8.55
# 2018-08-30, Close, 220.93
# 2018-08-31, Close, 223.48
# 2018-09-04, Close, 224.20
# 2018-09-05, Close, 222.73
# 2018-09-06, Close, 219.03
# 2018-09-06, BUY CREATE, 219.03
# 2018-09-07, BUY EXECUTED, Price: 217.81, Cost: 217.81, Comm 0.22
# 2018-09-07, Close, 217.27
# 2018-09-10, Close, 214.35
# 2018-09-11, Close, 219.77
# 2018-09-12, Close, 217.04
# 2018-09-13, Close, 222.28
# 2018-09-14, Close, 219.76
# 2018-09-14, SELL CREATE, 219.76
# 2018-09-17, SELL EXECUTED, Price: 218.10, Cost: 217.81, Comm 0.22
# 2018-09-17, OPERATION PROFIT, GROSS 0.29, NET -0.15
# 2018-09-17, Close, 213.91
# 2018-09-17, BUY CREATE, 213.91
# 2018-09-18, BUY EXECUTED, Price: 213.82, Cost: 213.82, Comm 0.21
# 2018-09-18, Close, 214.26
# 2018-09-19, Close, 214.39
# 2018-09-20, Close, 216.02
# 2018-09-21, Close, 213.69
# 2018-09-24, Close, 216.77
# 2018-09-25, Close, 218.14
# 2018-09-25, SELL CREATE, 218.14
# 2018-09-26, SELL EXECUTED, Price: 216.97, Cost: 213.82, Comm 0.22
# 2018-09-26, OPERATION PROFIT, GROSS 3.15, NET 2.72
# 2018-09-26, Close, 216.40
# 2018-09-27, Close, 220.85
# 2018-09-28, Close, 221.63
# 2018-10-01, Close, 223.12
# 2018-10-02, Close, 225.10
# 2018-10-03, Close, 227.84
# 2018-10-04, Close, 223.83
# 2018-10-05, Close, 220.20
# 2018-10-05, BUY CREATE, 220.20
# 2018-10-08, BUY EXECUTED, Price: 218.16, Cost: 218.16, Comm 0.22
# 2018-10-08, Close, 219.69
# 2018-10-09, Close, 222.73
# 2018-10-10, Close, 212.42
# 2018-10-11, Close, 210.54
# 2018-10-12, Close, 218.06
# 2018-10-15, Close, 213.40
# 2018-10-15, SELL CREATE, 213.40
# 2018-10-16, SELL EXECUTED, Price: 214.94, Cost: 218.16, Comm 0.21
# 2018-10-16, OPERATION PROFIT, GROSS -3.22, NET -3.65
# 2018-10-16, Close, 218.10
# 2018-10-17, Close, 217.16
# 2018-10-18, Close, 212.08
# 2018-10-18, BUY CREATE, 212.08
# 2018-10-19, BUY EXECUTED, Price: 214.09, Cost: 214.09, Comm 0.21
# 2018-10-19, Close, 215.31
# 2018-10-22, Close, 216.63
# 2018-10-23, Close, 218.67
# 2018-10-24, Close, 211.17
# 2018-10-25, Close, 215.79
# 2018-10-26, Close, 212.36
# 2018-10-26, SELL CREATE, 212.36
# 2018-10-29, SELL EXECUTED, Price: 215.19, Cost: 214.09, Comm 0.22
# 2018-10-29, OPERATION PROFIT, GROSS 1.10, NET 0.67
# 2018-10-29, Close, 208.37
# 2018-10-29, BUY CREATE, 208.37
# 2018-10-30, BUY EXECUTED, Price: 207.30, Cost: 207.30, Comm 0.21
# 2018-10-30, Close, 209.41
# 2018-10-31, Close, 214.87
# 2018-11-01, Close, 218.17
# 2018-11-02, Close, 203.70
# 2018-11-05, Close, 197.92
# 2018-11-06, Close, 200.06
# 2018-11-06, SELL CREATE, 200.06
# 2018-11-07, SELL EXECUTED, Price: 202.22, Cost: 207.30, Comm 0.20
# 2018-11-07, OPERATION PROFIT, GROSS -5.08, NET -5.49
# 2018-11-07, Close, 206.12
# 2018-11-08, Close, 205.40
# 2018-11-09, Close, 201.44
# 2018-11-09, BUY CREATE, 201.44
# 2018-11-12, BUY EXECUTED, Price: 196.05, Cost: 196.05, Comm 0.20
# 2018-11-12, Close, 191.30
# 2018-11-13, Close, 189.38
# 2018-11-14, Close, 184.03
# 2018-11-15, Close, 188.58
# 2018-11-16, Close, 190.67
# 2018-11-19, Close, 183.11
# 2018-11-19, SELL CREATE, 183.11
# 2018-11-20, SELL EXECUTED, Price: 175.73, Cost: 196.05, Comm 0.18
# 2018-11-20, OPERATION PROFIT, GROSS -20.32, NET -20.69
# 2018-11-20, Close, 174.36
# 2018-11-20, BUY CREATE, 174.36
# 2018-11-21, BUY EXECUTED, Price: 177.07, Cost: 177.07, Comm 0.18
# 2018-11-21, Close, 174.16
# 2018-11-23, Close, 169.74
# 2018-11-26, Close, 172.04
# 2018-11-27, Close, 171.66
# 2018-11-28, Close, 178.26
# 2018-11-29, Close, 176.89
# 2018-11-29, SELL CREATE, 176.89
# 2018-11-30, SELL EXECUTED, Price: 177.62, Cost: 177.07, Comm 0.18
# 2018-11-30, OPERATION PROFIT, GROSS 0.55, NET 0.20
# 2018-11-30, Close, 175.94
# 2018-11-30, BUY CREATE, 175.94
# 2018-12-03, BUY EXECUTED, Price: 181.73, Cost: 181.73, Comm 0.18
# 2018-12-03, Close, 182.08
# 2018-12-04, Close, 174.07
# 2018-12-06, Close, 172.13
# 2018-12-07, Close, 166.00
# 2018-12-10, Close, 167.09
# 2018-12-11, Close, 166.13
# 2018-12-11, SELL CREATE, 166.13
# 2018-12-12, SELL EXECUTED, Price: 167.88, Cost: 181.73, Comm 0.17
# 2018-12-12, OPERATION PROFIT, GROSS -13.85, NET -14.20
# 2018-12-12, Close, 166.60
# 2018-12-13, Close, 168.42
# 2018-12-14, Close, 163.03
# 2018-12-17, Close, 161.51
# 2018-12-17, BUY CREATE, 161.51
# 2018-12-18, BUY EXECUTED, Price: 162.93, Cost: 162.93, Comm 0.16
# 2018-12-18, Close, 163.61
# 2018-12-19, Close, 158.51
# 2018-12-20, Close, 154.51
# 2018-12-21, Close, 148.50
# 2018-12-24, Close, 144.66
# 2018-12-26, Close, 154.84
# 2018-12-26, SELL CREATE, 154.84
# 2018-12-27, SELL EXECUTED, Price: 153.53, Cost: 162.93, Comm 0.15
# 2018-12-27, OPERATION PROFIT, GROSS -9.40, NET -9.72
# 2018-12-27, Close, 153.84
# 2018-12-28, Close, 153.92
# 2018-12-31, Close, 155.41
# 2019-01-02, Close, 155.58
# 2019-01-03, Close, 140.09
# 2019-01-04, Close, 146.07
# 2019-01-07, Close, 145.74
# 2019-01-08, Close, 148.52
# 2019-01-09, Close, 151.04
# 2019-01-10, Close, 151.52
# 2019-01-11, Close, 150.04
# 2019-01-14, Close, 147.78
# 2019-01-14, BUY CREATE, 147.78
# 2019-01-15, BUY EXECUTED, Price: 148.05, Cost: 148.05, Comm 0.15
# 2019-01-15, Close, 150.80
# 2019-01-16, Close, 152.65
# 2019-01-17, Close, 153.55
# 2019-01-18, Close, 154.50
# 2019-01-22, Close, 151.03
# 2019-01-23, Close, 151.64
# 2019-01-23, SELL CREATE, 151.64
# 2019-01-24, SELL EXECUTED, Price: 151.83, Cost: 148.05, Comm 0.15
# 2019-01-24, OPERATION PROFIT, GROSS 3.78, NET 3.48
# 2019-01-24, Close, 150.44
# 2019-01-25, Close, 155.42
# 2019-01-28, Close, 153.99
# 2019-01-29, Close, 152.39
# 2019-01-29, BUY CREATE, 152.39
# 2019-01-30, BUY EXECUTED, Price: 160.83, Cost: 160.83, Comm 0.16
# 2019-01-30, Close, 162.80
# 2019-01-31, Close, 163.98
# 2019-02-01, Close, 164.06
# 2019-02-04, Close, 168.72
# 2019-02-05, Close, 171.60
# 2019-02-06, Close, 171.66
# 2019-02-06, SELL CREATE, 171.66
# 2019-02-07, SELL EXECUTED, Price: 169.85, Cost: 160.83, Comm 0.17
# 2019-02-07, OPERATION PROFIT, GROSS 9.02, NET 8.69
# 2019-02-07, Close, 168.41
# 2019-02-08, Close, 168.61
# 2019-02-11, Close, 167.64
# 2019-02-12, Close, 169.08
# 2019-02-13, Close, 168.38
# 2019-02-14, Close, 168.99
# 2019-02-15, Close, 168.62
# 2019-02-19, Close, 169.12
# 2019-02-20, Close, 170.21
# 2019-02-21, Close, 169.25
# 2019-02-22, Close, 171.14
# 2019-02-25, Close, 172.39
# 2019-02-26, Close, 172.49
# 2019-02-27, Close, 173.02
# 2019-02-28, Close, 171.32
# 2019-03-01, Close, 173.12
# 2019-03-04, Close, 173.99
# 2019-03-05, Close, 173.67
# 2019-03-06, Close, 172.67
# 2019-03-06, BUY CREATE, 172.67
# 2019-03-07, BUY EXECUTED, Price: 172.03, Cost: 172.03, Comm 0.17
# 2019-03-07, Close, 170.68
# 2019-03-08, Close, 171.08
# 2019-03-11, Close, 177.01
# 2019-03-12, Close, 179.00
# 2019-03-13, Close, 179.79
# 2019-03-14, Close, 181.79
# 2019-03-14, SELL CREATE, 181.79
# 2019-03-15, SELL EXECUTED, Price: 182.89, Cost: 172.03, Comm 0.18
# 2019-03-15, OPERATION PROFIT, GROSS 10.86, NET 10.51
# 2019-03-15, Close, 184.15
# 2019-03-18, Close, 186.03
# 2019-03-19, Close, 184.56
# 2019-03-20, Close, 186.17
# 2019-03-21, Close, 193.03
# 2019-03-22, Close, 189.03
# 2019-03-25, Close, 186.74
# 2019-03-25, BUY CREATE, 186.74
# 2019-03-26, BUY EXECUTED, Price: 189.63, Cost: 189.63, Comm 0.19
# 2019-03-26, Close, 184.81
# 2019-03-27, Close, 186.48
# 2019-03-28, Close, 186.72
# 2019-03-29, Close, 187.94
# 2019-04-01, Close, 189.22
# 2019-04-02, Close, 191.97
# 2019-04-02, SELL CREATE, 191.97
# 2019-04-03, SELL EXECUTED, Price: 191.21, Cost: 189.63, Comm 0.19
# 2019-04-03, OPERATION PROFIT, GROSS 1.58, NET 1.20
# 2019-04-03, Close, 193.28
# 2019-04-04, Close, 193.62
# 2019-04-05, Close, 194.92
# 2019-04-08, Close, 197.98
# 2019-04-09, Close, 197.39
# 2019-04-10, Close, 198.50
# 2019-04-11, Close, 196.85
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE, 196.77
# 2019-04-15, BUY EXECUTED, Price: 196.48, Cost: 196.48, Comm 0.20
# 2019-04-15, Close, 197.12
# 2019-04-16, Close, 197.14
# 2019-04-17, Close, 200.98
# 2019-04-18, Close, 201.70
# 2019-04-22, Close, 202.37
# 2019-04-23, Close, 205.29
# 2019-04-23, SELL CREATE, 205.29
# 2019-04-24, SELL EXECUTED, Price: 205.17, Cost: 196.48, Comm 0.21
# 2019-04-24, OPERATION PROFIT, GROSS 8.69, NET 8.29
# 2019-04-24, Close, 204.97
# 2019-04-25, Close, 203.11
# 2019-04-25, BUY CREATE, 203.11
# 2019-04-26, BUY EXECUTED, Price: 202.73, Cost: 202.73, Comm 0.20
# 2019-04-26, Close, 202.14
# 2019-04-29, Close, 202.45
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-02, Close, 206.94
# 2019-05-03, Close, 209.51
# 2019-05-03, SELL CREATE, 209.51
# 2019-05-06, SELL EXECUTED, Price: 202.13, Cost: 202.73, Comm 0.20
# 2019-05-06, OPERATION PROFIT, GROSS -0.60, NET -1.00
# 2019-05-06, Close, 206.27
# 2019-05-07, Close, 200.71
# 2019-05-07, BUY CREATE, 200.71
# 2019-05-08, BUY EXECUTED, Price: 199.76, Cost: 199.76, Comm 0.20
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-15, SELL CREATE, 189.63
# 2019-05-16, SELL EXECUTED, Price: 188.62, Cost: 199.76, Comm 0.19
# 2019-05-16, OPERATION PROFIT, GROSS -11.14, NET -11.53
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-17, BUY CREATE, 187.72
# 2019-05-20, BUY EXECUTED, Price: 182.28, Cost: 182.28, Comm 0.18
# 2019-05-20, Close, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-28, SELL CREATE, 177.02
# 2019-05-29, SELL EXECUTED, Price: 175.23, Cost: 182.28, Comm 0.18
# 2019-05-29, OPERATION PROFIT, GROSS -7.05, NET -7.41
# 2019-05-29, Close, 176.18
# 2019-05-29, BUY CREATE, 176.18
# 2019-05-30, BUY EXECUTED, Price: 176.75, Cost: 176.75, Comm 0.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-06, Close, 183.97
# 2019-06-06, SELL CREATE, 183.97
# 2019-06-07, SELL EXECUTED, Price: 185.25, Cost: 176.75, Comm 0.19
# 2019-06-07, OPERATION PROFIT, GROSS 8.50, NET 8.14
# 2019-06-07, Close, 188.86
# 2019-06-10, Close, 191.28
# 2019-06-11, Close, 193.49
# 2019-06-12, Close, 192.88
# 2019-06-13, Close, 192.84
# 2019-06-13, BUY CREATE, 192.84
# 2019-06-14, BUY EXECUTED, Price: 190.25, Cost: 190.25, Comm 0.19
# 2019-06-14, Close, 191.44
# 2019-06-17, Close, 192.58
# 2019-06-18, Close, 197.11
# 2019-06-19, Close, 196.53
# 2019-06-20, Close, 198.11
# 2019-06-21, Close, 197.43
# 2019-06-21, SELL CREATE, 197.43
# 2019-06-24, SELL EXECUTED, Price: 197.20, Cost: 190.25, Comm 0.20
# 2019-06-24, OPERATION PROFIT, GROSS 6.95, NET 6.56
# 2019-06-24, Close, 197.24
# 2019-06-24, BUY CREATE, 197.24
# 2019-06-25, BUY EXECUTED, Price: 197.09, Cost: 197.09, Comm 0.20
# 2019-06-25, Close, 194.25
# 2019-06-26, Close, 198.45
# 2019-06-27, Close, 198.39
# 2019-06-28, Close, 196.58
# 2019-07-01, Close, 200.19
# 2019-07-02, Close, 201.36
# 2019-07-02, SELL CREATE, 201.36
# 2019-07-03, SELL EXECUTED, Price: 201.90, Cost: 197.09, Comm 0.20
# 2019-07-03, OPERATION PROFIT, GROSS 4.81, NET 4.41
# 2019-07-03, Close, 203.03
# 2019-07-05, Close, 202.85
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE, 198.67
# 2019-07-09, BUY EXECUTED, Price: 197.85, Cost: 197.85, Comm 0.20
# 2019-07-09, Close, 199.88
# 2019-07-10, Close, 201.85
# 2019-07-11, Close, 200.38
# 2019-07-12, Close, 201.92
# 2019-07-15, Close, 203.82
# 2019-07-16, Close, 203.12
# 2019-07-16, SELL CREATE, 203.12
# 2019-07-17, SELL EXECUTED, Price: 202.67, Cost: 197.85, Comm 0.20
# 2019-07-17, OPERATION PROFIT, GROSS 4.82, NET 4.42
# 2019-07-17, Close, 201.97
# 2019-07-17, BUY CREATE, 201.97
# 2019-07-18, BUY EXECUTED, Price: 202.62, Cost: 202.62, Comm 0.20
# 2019-07-18, Close, 204.27
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-23, Close, 207.43
# 2019-07-24, Close, 207.26
# 2019-07-25, Close, 205.62
# 2019-07-25, SELL CREATE, 205.62
# 2019-07-26, SELL EXECUTED, Price: 206.08, Cost: 202.62, Comm 0.21
# 2019-07-26, OPERATION PROFIT, GROSS 3.46, NET 3.05
# 2019-07-26, Close, 206.33
# 2019-07-29, Close, 208.26
# 2019-07-30, Close, 207.37
# 2019-07-31, Close, 211.60
# 2019-08-01, Close, 207.02
# 2019-08-02, Close, 202.64
# 2019-08-02, BUY CREATE, 202.64
# 2019-08-05, BUY EXECUTED, Price: 196.65, Cost: 196.65, Comm 0.20
# 2019-08-05, Close, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-12, SELL CREATE, 199.88
# 2019-08-13, SELL EXECUTED, Price: 200.42, Cost: 196.65, Comm 0.20
# 2019-08-13, OPERATION PROFIT, GROSS 3.77, NET 3.37
# 2019-08-13, Close, 208.34
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-15, BUY CREATE, 201.14
# 2019-08-16, BUY EXECUTED, Price: 203.67, Cost: 203.67, Comm 0.20
# 2019-08-16, Close, 205.88
# 2019-08-19, Close, 209.72
# 2019-08-20, Close, 209.73
# 2019-08-21, Close, 212.00
# 2019-08-22, Close, 211.82
# 2019-08-23, Close, 202.03
# 2019-08-23, SELL CREATE, 202.03
# 2019-08-26, SELL EXECUTED, Price: 205.24, Cost: 203.67, Comm 0.21
# 2019-08-26, OPERATION PROFIT, GROSS 1.57, NET 1.16
# 2019-08-26, Close, 205.87
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-30, Close, 208.12
# 2019-09-03, Close, 205.08
# 2019-09-03, BUY CREATE, 205.08
# 2019-09-04, BUY EXECUTED, Price: 207.77, Cost: 207.77, Comm 0.21
# 2019-09-04, Close, 208.56
# 2019-09-05, Close, 212.64
# 2019-09-06, Close, 212.62
# 2019-09-09, Close, 213.53
# 2019-09-10, Close, 216.05
# 2019-09-11, Close, 222.92
# 2019-09-11, SELL CREATE, 222.92
# 2019-09-12, SELL EXECUTED, Price: 224.13, Cost: 207.77, Comm 0.22
# 2019-09-12, OPERATION PROFIT, GROSS 16.36, NET 15.93
# 2019-09-12, Close, 222.42
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE, 218.10
# 2019-09-16, BUY EXECUTED, Price: 217.08, Cost: 217.08, Comm 0.22
# 2019-09-16, Close, 219.24
# 2019-09-17, Close, 220.04
# 2019-09-18, Close, 222.10
# 2019-09-19, Close, 220.30
# 2019-09-20, Close, 217.08
# 2019-09-23, Close, 218.07
# 2019-09-23, SELL CREATE, 218.07
# 2019-09-24, SELL EXECUTED, Price: 220.37, Cost: 217.08, Comm 0.22
# 2019-09-24, OPERATION PROFIT, GROSS 3.29, NET 2.85
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-26, Close, 219.23
# 2019-09-27, Close, 218.17
# 2019-09-27, BUY CREATE, 218.17
# 2019-09-30, BUY EXECUTED, Price: 220.24, Cost: 220.24, Comm 0.22
# 2019-09-30, Close, 223.30
# 2019-10-01, Close, 223.92
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-04, Close, 226.33
# 2019-10-07, Close, 226.38
# 2019-10-07, SELL CREATE, 226.38
# 2019-10-08, SELL EXECUTED, Price: 225.14, Cost: 220.24, Comm 0.23
# 2019-10-08, OPERATION PROFIT, GROSS 4.90, NET 4.45
# 2019-10-08, Close, 223.73
# 2019-10-09, Close, 226.35
# 2019-10-10, Close, 229.40
# 2019-10-11, Close, 235.50
# 2019-10-14, Close, 235.16
# 2019-10-15, Close, 234.62
# 2019-10-15, BUY CREATE, 234.62
# 2019-10-16, BUY EXECUTED, Price: 232.67, Cost: 232.67, Comm 0.23
# 2019-10-16, Close, 233.67
# 2019-10-17, Close, 234.58
# 2019-10-18, Close, 235.70
# 2019-10-21, Close, 239.79
# 2019-10-22, Close, 239.24
# 2019-10-23, Close, 242.45
# 2019-10-23, SELL CREATE, 242.45
# 2019-10-24, SELL EXECUTED, Price: 243.78, Cost: 232.67, Comm 0.24
# 2019-10-24, OPERATION PROFIT, GROSS 11.11, NET 10.63
# 2019-10-24, Close, 242.85
# 2019-10-25, Close, 245.84
# 2019-10-28, Close, 248.30
# 2019-10-29, Close, 242.56
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE, 242.53
# 2019-10-31, BUY EXECUTED, Price: 246.50, Cost: 246.50, Comm 0.25
# 2019-10-31, Close, 248.02
# 2019-11-01, Close, 255.05
# 2019-11-04, Close, 256.73
# 2019-11-05, Close, 256.36
# 2019-11-06, Close, 256.47
# 2019-11-07, Close, 259.43
# 2019-11-07, SELL CREATE, 259.43
# 2019-11-08, SELL EXECUTED, Price: 258.69, Cost: 246.50, Comm 0.26
# 2019-11-08, OPERATION PROFIT, GROSS 12.19, NET 11.68
# 2019-11-08, Close, 260.14
# 2019-11-11, Close, 262.20
# 2019-11-12, Close, 261.96
# 2019-11-13, Close, 264.47
# 2019-11-14, Close, 262.64
# 2019-11-15, Close, 265.76
# 2019-11-18, Close, 267.10
# 2019-11-19, Close, 266.29
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE, 263.19
# 2019-11-21, BUY EXECUTED, Price: 263.69, Cost: 263.69, Comm 0.26
# 2019-11-21, Close, 262.01
# 2019-11-22, Close, 261.78
# 2019-11-25, Close, 266.37
# 2019-11-26, Close, 264.29
# 2019-11-27, Close, 267.84
# 2019-11-29, Close, 267.25
# 2019-11-29, SELL CREATE, 267.25
# 2019-12-02, SELL EXECUTED, Price: 267.27, Cost: 263.69, Comm 0.27
# 2019-12-02, OPERATION PROFIT, GROSS 3.58, NET 3.05
# 2019-12-02, Close, 264.16
# 2019-12-02, BUY CREATE, 264.16
# 2019-12-03, BUY EXECUTED, Price: 258.31, Cost: 258.31, Comm 0.26
# 2019-12-03, Close, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-06, Close, 270.71
# 2019-12-09, Close, 266.92
# 2019-12-10, Close, 268.48
# 2019-12-10, SELL CREATE, 268.48
# 2019-12-11, SELL EXECUTED, Price: 268.81, Cost: 258.31, Comm 0.27
# 2019-12-11, OPERATION PROFIT, GROSS 10.50, NET 9.97
# 2019-12-11, Close, 270.77
# 2019-12-12, Close, 271.46
# 2019-12-13, Close, 275.15
# 2019-12-16, Close, 279.86
# 2019-12-17, Close, 280.41
# 2019-12-18, Close, 279.74
# 2019-12-19, Close, 280.02
# 2019-12-20, Close, 279.44
# 2019-12-23, Close, 284.00
# 2019-12-24, Close, 284.27
# 2019-12-26, Close, 289.91
# 2019-12-27, Close, 289.80
# 2019-12-30, Close, 291.52
# 2019-12-31, Close, 293.65
# 2020-01-02, Close, 300.35
# 2020-01-03, Close, 297.43
# 2020-01-06, Close, 299.80
# 2020-01-07, Close, 298.39
# 2020-01-08, Close, 303.19
# 2020-01-09, Close, 309.63
# Final Portfolio Value: 100083.67

# %% [markdown]
# Create 하는 것과 Execute하는 것 다르다.
# 마지막 날에 Create 되더라도 Execute 되지 않으면 계산되지 않는다.

# %% [markdown]
# ## Customizing the Strategy: Parameters
#
# It would a bit unpractical to hardcode some of the values in the strategy and have no chance to change them easily. Parameters come in handy to help.
#
# Definition of parameters is easy and looks like:

# %%
params = (
    ('myparam', 27), 
    ('exitbars', 5),
)

# With either formatting parametrization of the strategy is allowed when adding the strategy to the Cerebro engine:

# Add a strategy
cerebro.addstrategy(TestStrategy, myparam=20, exitbars=7)
# Out:
# 1

# %% [markdown]
# ## Skipping `setsizing`
#
# The setsizing method below is deprecated. This content is kept here for anyone looking at old samples of the sources. The sources have been update to use:

# %% [markdown]
# ## Adding an indicator
#
# Having heard of indicators, the next thing anyone would add to the strategy is one of them. For sure they must be much better than a simple “3 lower closes” strategy.
#
# Inspired in one of the examples from PyAlgoTrade a strategy using a Simple Moving Average.
#
# - Buy “AtMarket” if the close is greater than the Average
#
# - If in the market, sell if the close is smaller than the Average
#
# - Only 1 active operation is allowed in the market
#
# Most of the existing code can be kept in place. Let’s add the average during init and keep a reference to it:
#
#
# `self.sma = bt.indicators.MovingAverageSimple(self.datas[0], period=self.params.maperiod)`
#
# And of course the logic to enter and exit the market will rely on the Average values. Look in the code for the logic.
#
# * The starting cash will be 1000 monetary units to be in line with the PyAlgoTrade example and no commission will be applied

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 1000.00
# 2015-01-23, Close, 103.81
# 2015-01-23, BUY CREATE, 103.81
# 2015-01-26, Order Canceled/Margin/Rejected
# 2015-01-26, Close, 103.92
# 2015-01-26, BUY CREATE, 103.92
# 2015-01-27, Order Canceled/Margin/Rejected
# 2015-01-27, Close, 100.28
# 2015-01-28, Close, 105.95
# 2015-01-28, BUY CREATE, 105.95
# 2015-01-29, Order Canceled/Margin/Rejected
# 2015-01-29, Close, 109.25
# 2015-01-29, BUY CREATE, 109.25
# 2015-01-30, Order Canceled/Margin/Rejected
# 2015-01-30, Close, 107.65
# 2015-01-30, BUY CREATE, 107.65
# 2015-02-02, Order Canceled/Margin/Rejected
# 2015-02-02, Close, 109.00
# 2015-02-02, BUY CREATE, 109.00
# 2015-02-03, Order Canceled/Margin/Rejected
# 2015-02-03, Close, 109.02
# 2015-02-03, BUY CREATE, 109.02
# 2015-02-04, Order Canceled/Margin/Rejected
# 2015-02-04, Close, 109.85
# 2015-02-04, BUY CREATE, 109.85
# 2015-02-05, Order Canceled/Margin/Rejected
# 2015-02-05, Close, 110.64
# 2015-02-05, BUY CREATE, 110.64
# 2015-02-06, Order Canceled/Margin/Rejected
# 2015-02-06, Close, 109.71
# 2015-02-06, BUY CREATE, 109.71
# 2015-02-09, Order Canceled/Margin/Rejected
# 2015-02-09, Close, 110.43
# 2015-02-09, BUY CREATE, 110.43
# 2015-02-10, Order Canceled/Margin/Rejected
# 2015-02-10, Close, 112.56
# 2015-02-10, BUY CREATE, 112.56
# 2015-02-11, Order Canceled/Margin/Rejected
# 2015-02-11, Close, 115.19
# 2015-02-11, BUY CREATE, 115.19
# 2015-02-12, Order Canceled/Margin/Rejected
# 2015-02-12, Close, 116.65
# 2015-02-12, BUY CREATE, 116.65
# 2015-02-13, Order Canceled/Margin/Rejected
# 2015-02-13, Close, 117.22
# 2015-02-13, BUY CREATE, 117.22
# 2015-02-17, Order Canceled/Margin/Rejected
# 2015-02-17, Close, 117.92
# 2015-02-17, BUY CREATE, 117.92
# 2015-02-18, Order Canceled/Margin/Rejected
# 2015-02-18, Close, 118.74
# 2015-02-18, BUY CREATE, 118.74
# 2015-02-19, Order Canceled/Margin/Rejected
# 2015-02-19, Close, 118.49
# 2015-02-19, BUY CREATE, 118.49
# 2015-02-20, Order Canceled/Margin/Rejected
# 2015-02-20, Close, 119.46
# 2015-02-20, BUY CREATE, 119.46
# 2015-02-23, Order Canceled/Margin/Rejected
# 2015-02-23, Close, 122.68
# 2015-02-23, BUY CREATE, 122.68
# 2015-02-24, Order Canceled/Margin/Rejected
# 2015-02-24, Close, 121.92
# 2015-02-24, BUY CREATE, 121.92
# 2015-02-25, Order Canceled/Margin/Rejected
# 2015-02-25, Close, 118.80
# 2015-02-25, BUY CREATE, 118.80
# 2015-02-26, Order Canceled/Margin/Rejected
# 2015-02-26, Close, 120.31
# 2015-02-26, BUY CREATE, 120.31
# 2015-02-27, Order Canceled/Margin/Rejected
# 2015-02-27, Close, 118.50
# 2015-02-27, BUY CREATE, 118.50
# 2015-03-02, Order Canceled/Margin/Rejected
# 2015-03-02, Close, 119.08
# 2015-03-02, BUY CREATE, 119.08
# 2015-03-03, Order Canceled/Margin/Rejected
# 2015-03-03, Close, 119.33
# 2015-03-03, BUY CREATE, 119.33
# 2015-03-04, Order Canceled/Margin/Rejected
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-17, BUY CREATE, 117.19
# 2015-03-18, Order Canceled/Margin/Rejected
# 2015-03-18, Close, 118.51
# 2015-03-18, BUY CREATE, 118.51
# 2015-03-19, Order Canceled/Margin/Rejected
# 2015-03-19, Close, 117.61
# 2015-03-19, BUY CREATE, 117.61
# 2015-03-20, Order Canceled/Margin/Rejected
# 2015-03-20, Close, 116.14
# 2015-03-23, Close, 117.34
# 2015-03-23, BUY CREATE, 117.34
# 2015-03-24, Order Canceled/Margin/Rejected
# 2015-03-24, Close, 116.86
# 2015-03-24, BUY CREATE, 116.86
# 2015-03-25, Order Canceled/Margin/Rejected
# 2015-03-25, Close, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-30, BUY CREATE, 116.57
# 2015-03-31, Order Canceled/Margin/Rejected
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-06, BUY CREATE, 117.47
# 2015-04-07, Order Canceled/Margin/Rejected
# 2015-04-07, Close, 116.24
# 2015-04-07, BUY CREATE, 116.24
# 2015-04-08, Order Canceled/Margin/Rejected
# 2015-04-08, Close, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-09, BUY CREATE, 116.74
# 2015-04-10, Order Canceled/Margin/Rejected
# 2015-04-10, Close, 117.24
# 2015-04-10, BUY CREATE, 117.24
# 2015-04-13, Order Canceled/Margin/Rejected
# 2015-04-13, Close, 117.01
# 2015-04-13, BUY CREATE, 117.01
# 2015-04-14, Order Canceled/Margin/Rejected
# 2015-04-14, Close, 116.50
# 2015-04-14, BUY CREATE, 116.50
# 2015-04-15, Order Canceled/Margin/Rejected
# 2015-04-15, Close, 116.95
# 2015-04-15, BUY CREATE, 116.95
# 2015-04-16, Order Canceled/Margin/Rejected
# 2015-04-16, Close, 116.38
# 2015-04-16, BUY CREATE, 116.38
# 2015-04-17, Order Canceled/Margin/Rejected
# 2015-04-17, Close, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-20, BUY CREATE, 117.70
# 2015-04-21, Order Canceled/Margin/Rejected
# 2015-04-21, Close, 117.07
# 2015-04-21, BUY CREATE, 117.07
# 2015-04-22, Order Canceled/Margin/Rejected
# 2015-04-22, Close, 118.64
# 2015-04-22, BUY CREATE, 118.64
# 2015-04-23, Order Canceled/Margin/Rejected
# 2015-04-23, Close, 119.61
# 2015-04-23, BUY CREATE, 119.61
# 2015-04-24, Order Canceled/Margin/Rejected
# 2015-04-24, Close, 120.18
# 2015-04-24, BUY CREATE, 120.18
# 2015-04-27, Order Canceled/Margin/Rejected
# 2015-04-27, Close, 122.36
# 2015-04-27, BUY CREATE, 122.36
# 2015-04-28, Order Canceled/Margin/Rejected
# 2015-04-28, Close, 120.43
# 2015-04-28, BUY CREATE, 120.43
# 2015-04-29, Order Canceled/Margin/Rejected
# 2015-04-29, Close, 118.66
# 2015-04-29, BUY CREATE, 118.66
# 2015-04-30, Order Canceled/Margin/Rejected
# 2015-04-30, Close, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-01, BUY CREATE, 118.95
# 2015-05-04, Order Canceled/Margin/Rejected
# 2015-05-04, Close, 118.72
# 2015-05-04, BUY CREATE, 118.72
# 2015-05-05, Order Canceled/Margin/Rejected
# 2015-05-05, Close, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-14, BUY CREATE, 119.45
# 2015-05-15, Order Canceled/Margin/Rejected
# 2015-05-15, Close, 119.28
# 2015-05-15, BUY CREATE, 119.28
# 2015-05-18, Order Canceled/Margin/Rejected
# 2015-05-18, Close, 120.59
# 2015-05-18, BUY CREATE, 120.59
# 2015-05-19, Order Canceled/Margin/Rejected
# 2015-05-19, Close, 120.48
# 2015-05-19, BUY CREATE, 120.48
# 2015-05-20, Order Canceled/Margin/Rejected
# 2015-05-20, Close, 120.47
# 2015-05-20, BUY CREATE, 120.47
# 2015-05-21, Order Canceled/Margin/Rejected
# 2015-05-21, Close, 121.71
# 2015-05-21, BUY CREATE, 121.71
# 2015-05-22, Order Canceled/Margin/Rejected
# 2015-05-22, Close, 122.77
# 2015-05-22, BUY CREATE, 122.77
# 2015-05-26, Order Canceled/Margin/Rejected
# 2015-05-26, Close, 120.07
# 2015-05-26, BUY CREATE, 120.07
# 2015-05-27, Order Canceled/Margin/Rejected
# 2015-05-27, Close, 122.31
# 2015-05-27, BUY CREATE, 122.31
# 2015-05-28, Order Canceled/Margin/Rejected
# 2015-05-28, Close, 122.07
# 2015-05-28, BUY CREATE, 122.07
# 2015-05-29, Order Canceled/Margin/Rejected
# 2015-05-29, Close, 120.68
# 2015-05-29, BUY CREATE, 120.68
# 2015-06-01, Order Canceled/Margin/Rejected
# 2015-06-01, Close, 120.92
# 2015-06-01, BUY CREATE, 120.92
# 2015-06-02, Order Canceled/Margin/Rejected
# 2015-06-02, Close, 120.38
# 2015-06-02, BUY CREATE, 120.38
# 2015-06-03, Order Canceled/Margin/Rejected
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-09, Close, 118.03
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-24, BUY CREATE, 118.67
# 2015-06-25, Order Canceled/Margin/Rejected
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-29, Close, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-08, Close, 113.54
# 2015-07-09, Close, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-13, BUY CREATE, 116.40
# 2015-07-14, Order Canceled/Margin/Rejected
# 2015-07-14, Close, 116.35
# 2015-07-14, BUY CREATE, 116.35
# 2015-07-15, Order Canceled/Margin/Rejected
# 2015-07-15, Close, 117.47
# 2015-07-15, BUY CREATE, 117.47
# 2015-07-16, Order Canceled/Margin/Rejected
# 2015-07-16, Close, 119.04
# 2015-07-16, BUY CREATE, 119.04
# 2015-07-17, Order Canceled/Margin/Rejected
# 2015-07-17, Close, 120.07
# 2015-07-17, BUY CREATE, 120.07
# 2015-07-20, Order Canceled/Margin/Rejected
# 2015-07-20, Close, 122.34
# 2015-07-20, BUY CREATE, 122.34
# 2015-07-21, Order Canceled/Margin/Rejected
# 2015-07-21, Close, 121.11
# 2015-07-21, BUY CREATE, 121.11
# 2015-07-22, Order Canceled/Margin/Rejected
# 2015-07-22, Close, 115.99
# 2015-07-23, Close, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-31, Close, 112.36
# 2015-08-03, Close, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-20, Close, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-27, BUY CREATE, 105.07
# 2015-08-28, Order Canceled/Margin/Rejected
# 2015-08-28, Close, 105.42
# 2015-08-28, BUY CREATE, 105.42
# 2015-08-31, Order Canceled/Margin/Rejected
# 2015-08-31, Close, 104.92
# 2015-08-31, BUY CREATE, 104.92
# 2015-09-01, Order Canceled/Margin/Rejected
# 2015-09-01, Close, 100.23
# 2015-09-02, Close, 104.53
# 2015-09-02, BUY CREATE, 104.53
# 2015-09-03, Order Canceled/Margin/Rejected
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-08, BUY CREATE, 104.50
# 2015-09-09, Order Canceled/Margin/Rejected
# 2015-09-09, Close, 102.49
# 2015-09-09, BUY CREATE, 102.49
# 2015-09-10, Order Canceled/Margin/Rejected
# 2015-09-10, Close, 104.75
# 2015-09-10, BUY CREATE, 104.75
# 2015-09-11, Order Canceled/Margin/Rejected
# 2015-09-11, Close, 106.27
# 2015-09-11, BUY CREATE, 106.27
# 2015-09-14, Order Canceled/Margin/Rejected
# 2015-09-14, Close, 107.29
# 2015-09-14, BUY CREATE, 107.29
# 2015-09-15, Order Canceled/Margin/Rejected
# 2015-09-15, Close, 108.20
# 2015-09-15, BUY CREATE, 108.20
# 2015-09-16, Order Canceled/Margin/Rejected
# 2015-09-16, Close, 108.32
# 2015-09-16, BUY CREATE, 108.32
# 2015-09-17, Order Canceled/Margin/Rejected
# 2015-09-17, Close, 106.00
# 2015-09-17, BUY CREATE, 106.00
# 2015-09-18, Order Canceled/Margin/Rejected
# 2015-09-18, Close, 105.56
# 2015-09-18, BUY CREATE, 105.56
# 2015-09-21, Order Canceled/Margin/Rejected
# 2015-09-21, Close, 107.20
# 2015-09-21, BUY CREATE, 107.20
# 2015-09-22, Order Canceled/Margin/Rejected
# 2015-09-22, Close, 105.52
# 2015-09-22, BUY CREATE, 105.52
# 2015-09-23, Order Canceled/Margin/Rejected
# 2015-09-23, Close, 106.37
# 2015-09-23, BUY CREATE, 106.37
# 2015-09-24, Order Canceled/Margin/Rejected
# 2015-09-24, Close, 107.01
# 2015-09-24, BUY CREATE, 107.01
# 2015-09-25, Order Canceled/Margin/Rejected
# 2015-09-25, Close, 106.74
# 2015-09-25, BUY CREATE, 106.74
# 2015-09-28, Order Canceled/Margin/Rejected
# 2015-09-28, Close, 104.62
# 2015-09-29, Close, 101.48
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-08, Close, 101.89
# 2015-10-09, Close, 104.33
# 2015-10-09, BUY CREATE, 104.33
# 2015-10-12, Order Canceled/Margin/Rejected
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-13, BUY CREATE, 104.02
# 2015-10-14, Order Canceled/Margin/Rejected
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-15, BUY CREATE, 104.08
# 2015-10-16, Order Canceled/Margin/Rejected
# 2015-10-16, Close, 103.32
# 2015-10-16, BUY CREATE, 103.32
# 2015-10-19, Order Canceled/Margin/Rejected
# 2015-10-19, Close, 103.96
# 2015-10-19, BUY CREATE, 103.96
# 2015-10-20, Order Canceled/Margin/Rejected
# 2015-10-20, Close, 105.86
# 2015-10-20, BUY CREATE, 105.86
# 2015-10-21, Order Canceled/Margin/Rejected
# 2015-10-21, Close, 105.85
# 2015-10-21, BUY CREATE, 105.85
# 2015-10-22, Order Canceled/Margin/Rejected
# 2015-10-22, Close, 107.47
# 2015-10-22, BUY CREATE, 107.47
# 2015-10-23, Order Canceled/Margin/Rejected
# 2015-10-23, Close, 110.80
# 2015-10-23, BUY CREATE, 110.80
# 2015-10-26, Order Canceled/Margin/Rejected
# 2015-10-26, Close, 107.27
# 2015-10-26, BUY CREATE, 107.27
# 2015-10-27, Order Canceled/Margin/Rejected
# 2015-10-27, Close, 106.59
# 2015-10-27, BUY CREATE, 106.59
# 2015-10-28, Order Canceled/Margin/Rejected
# 2015-10-28, Close, 110.98
# 2015-10-28, BUY CREATE, 110.98
# 2015-10-29, Order Canceled/Margin/Rejected
# 2015-10-29, Close, 112.15
# 2015-10-29, BUY CREATE, 112.15
# 2015-10-30, Order Canceled/Margin/Rejected
# 2015-10-30, Close, 111.19
# 2015-10-30, BUY CREATE, 111.19
# 2015-11-02, Order Canceled/Margin/Rejected
# 2015-11-02, Close, 112.76
# 2015-11-02, BUY CREATE, 112.76
# 2015-11-03, Order Canceled/Margin/Rejected
# 2015-11-03, Close, 114.05
# 2015-11-03, BUY CREATE, 114.05
# 2015-11-04, Order Canceled/Margin/Rejected
# 2015-11-04, Close, 113.52
# 2015-11-04, BUY CREATE, 113.52
# 2015-11-05, Order Canceled/Margin/Rejected
# 2015-11-05, Close, 113.00
# 2015-11-05, BUY CREATE, 113.00
# 2015-11-06, Order Canceled/Margin/Rejected
# 2015-11-06, Close, 113.13
# 2015-11-06, BUY CREATE, 113.13
# 2015-11-09, Order Canceled/Margin/Rejected
# 2015-11-09, Close, 112.67
# 2015-11-09, BUY CREATE, 112.67
# 2015-11-10, Order Canceled/Margin/Rejected
# 2015-11-10, Close, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-19, BUY CREATE, 111.00
# 2015-11-20, Order Canceled/Margin/Rejected
# 2015-11-20, Close, 111.48
# 2015-11-20, BUY CREATE, 111.48
# 2015-11-23, Order Canceled/Margin/Rejected
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-24, BUY CREATE, 111.09
# 2015-11-25, Order Canceled/Margin/Rejected
# 2015-11-25, Close, 110.30
# 2015-11-25, BUY CREATE, 110.30
# 2015-11-27, Order Canceled/Margin/Rejected
# 2015-11-27, Close, 110.09
# 2015-11-27, BUY CREATE, 110.09
# 2015-11-30, Order Canceled/Margin/Rejected
# 2015-11-30, Close, 110.55
# 2015-11-30, BUY CREATE, 110.55
# 2015-12-01, Order Canceled/Margin/Rejected
# 2015-12-01, Close, 109.65
# 2015-12-01, BUY CREATE, 109.65
# 2015-12-02, Order Canceled/Margin/Rejected
# 2015-12-02, Close, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-04, BUY CREATE, 111.23
# 2015-12-07, Order Canceled/Margin/Rejected
# 2015-12-07, Close, 110.53
# 2015-12-07, BUY CREATE, 110.53
# 2015-12-08, Order Canceled/Margin/Rejected
# 2015-12-08, Close, 110.48
# 2015-12-08, BUY CREATE, 110.48
# 2015-12-09, Order Canceled/Margin/Rejected
# 2015-12-09, Close, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-22, BUY CREATE, 94.77
# 2016-01-25, BUY EXECUTED, Price: 94.87, Cost: 948.70, Comm 0.00
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-27, SELL CREATE, 87.30
# 2016-01-28, SELL EXECUTED, Price: 87.64, Cost: 948.70, Comm 0.00
# 2016-01-28, OPERATION PROFIT, GROSS -72.30, NET -72.30
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-04, BUY CREATE, 90.76
# 2016-02-05, BUY EXECUTED, Price: 90.68, Cost: 906.80, Comm 0.00
# 2016-02-05, Close, 88.34
# 2016-02-05, SELL CREATE, 88.34
# 2016-02-08, SELL EXECUTED, Price: 87.50, Cost: 906.80, Comm 0.00
# 2016-02-08, OPERATION PROFIT, GROSS -31.80, NET -31.80
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-11, Close, 88.04
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-16, BUY CREATE, 90.80
# 2016-02-17, Order Canceled/Margin/Rejected
# 2016-02-17, Close, 92.19
# 2016-02-17, BUY CREATE, 92.19
# 2016-02-18, Order Canceled/Margin/Rejected
# 2016-02-18, Close, 90.44
# 2016-02-18, BUY CREATE, 90.44
# 2016-02-19, Order Canceled/Margin/Rejected
# 2016-02-19, Close, 90.23
# 2016-02-19, BUY CREATE, 90.23
# 2016-02-22, Order Canceled/Margin/Rejected
# 2016-02-22, Close, 91.02
# 2016-02-22, BUY CREATE, 91.02
# 2016-02-23, Order Canceled/Margin/Rejected
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-24, BUY CREATE, 90.29
# 2016-02-25, Order Canceled/Margin/Rejected
# 2016-02-25, Close, 90.91
# 2016-02-25, BUY CREATE, 90.91
# 2016-02-26, Order Canceled/Margin/Rejected
# 2016-02-26, Close, 91.05
# 2016-02-26, BUY CREATE, 91.05
# 2016-02-29, Order Canceled/Margin/Rejected
# 2016-02-29, Close, 90.84
# 2016-02-29, BUY CREATE, 90.84
# 2016-03-01, Order Canceled/Margin/Rejected
# 2016-03-01, Close, 94.45
# 2016-03-01, BUY CREATE, 94.45
# 2016-03-02, Order Canceled/Margin/Rejected
# 2016-03-02, Close, 94.66
# 2016-03-02, BUY CREATE, 94.66
# 2016-03-03, Order Canceled/Margin/Rejected
# 2016-03-03, Close, 95.36
# 2016-03-03, BUY CREATE, 95.36
# 2016-03-04, Order Canceled/Margin/Rejected
# 2016-03-04, Close, 96.78
# 2016-03-04, BUY CREATE, 96.78
# 2016-03-07, Order Canceled/Margin/Rejected
# 2016-03-07, Close, 95.71
# 2016-03-07, BUY CREATE, 95.71
# 2016-03-08, Order Canceled/Margin/Rejected
# 2016-03-08, Close, 94.92
# 2016-03-08, BUY CREATE, 94.92
# 2016-03-09, Order Canceled/Margin/Rejected
# 2016-03-09, Close, 95.01
# 2016-03-09, BUY CREATE, 95.01
# 2016-03-10, Order Canceled/Margin/Rejected
# 2016-03-10, Close, 95.05
# 2016-03-10, BUY CREATE, 95.05
# 2016-03-11, Order Canceled/Margin/Rejected
# 2016-03-11, Close, 96.08
# 2016-03-11, BUY CREATE, 96.08
# 2016-03-14, Order Canceled/Margin/Rejected
# 2016-03-14, Close, 96.32
# 2016-03-14, BUY CREATE, 96.32
# 2016-03-15, Order Canceled/Margin/Rejected
# 2016-03-15, Close, 98.26
# 2016-03-15, BUY CREATE, 98.26
# 2016-03-16, Order Canceled/Margin/Rejected
# 2016-03-16, Close, 99.56
# 2016-03-16, BUY CREATE, 99.56
# 2016-03-17, Order Canceled/Margin/Rejected
# 2016-03-17, Close, 99.40
# 2016-03-17, BUY CREATE, 99.40
# 2016-03-18, Order Canceled/Margin/Rejected
# 2016-03-18, Close, 99.52
# 2016-03-18, BUY CREATE, 99.52
# 2016-03-21, Order Canceled/Margin/Rejected
# 2016-03-21, Close, 99.51
# 2016-03-21, BUY CREATE, 99.51
# 2016-03-22, Order Canceled/Margin/Rejected
# 2016-03-22, Close, 100.27
# 2016-03-22, BUY CREATE, 100.27
# 2016-03-23, Order Canceled/Margin/Rejected
# 2016-03-23, Close, 99.71
# 2016-03-23, BUY CREATE, 99.71
# 2016-03-24, Order Canceled/Margin/Rejected
# 2016-03-24, Close, 99.28
# 2016-03-24, BUY CREATE, 99.28
# 2016-03-28, Order Canceled/Margin/Rejected
# 2016-03-28, Close, 98.83
# 2016-03-28, BUY CREATE, 98.83
# 2016-03-29, Order Canceled/Margin/Rejected
# 2016-03-29, Close, 101.17
# 2016-03-29, BUY CREATE, 101.17
# 2016-03-30, Order Canceled/Margin/Rejected
# 2016-03-30, Close, 102.94
# 2016-03-30, BUY CREATE, 102.94
# 2016-03-31, Order Canceled/Margin/Rejected
# 2016-03-31, Close, 102.40
# 2016-03-31, BUY CREATE, 102.40
# 2016-04-01, Order Canceled/Margin/Rejected
# 2016-04-01, Close, 103.34
# 2016-04-01, BUY CREATE, 103.34
# 2016-04-04, Order Canceled/Margin/Rejected
# 2016-04-04, Close, 104.40
# 2016-04-04, BUY CREATE, 104.40
# 2016-04-05, Order Canceled/Margin/Rejected
# 2016-04-05, Close, 103.17
# 2016-04-05, BUY CREATE, 103.17
# 2016-04-06, Order Canceled/Margin/Rejected
# 2016-04-06, Close, 104.25
# 2016-04-06, BUY CREATE, 104.25
# 2016-04-07, Order Canceled/Margin/Rejected
# 2016-04-07, Close, 101.98
# 2016-04-07, BUY CREATE, 101.98
# 2016-04-08, Order Canceled/Margin/Rejected
# 2016-04-08, Close, 102.09
# 2016-04-08, BUY CREATE, 102.09
# 2016-04-11, Order Canceled/Margin/Rejected
# 2016-04-11, Close, 102.43
# 2016-04-11, BUY CREATE, 102.43
# 2016-04-12, Order Canceled/Margin/Rejected
# 2016-04-12, Close, 103.76
# 2016-04-12, BUY CREATE, 103.76
# 2016-04-13, Order Canceled/Margin/Rejected
# 2016-04-13, Close, 105.27
# 2016-04-13, BUY CREATE, 105.27
# 2016-04-14, Order Canceled/Margin/Rejected
# 2016-04-14, Close, 105.32
# 2016-04-14, BUY CREATE, 105.32
# 2016-04-15, Order Canceled/Margin/Rejected
# 2016-04-15, Close, 103.21
# 2016-04-15, BUY CREATE, 103.21
# 2016-04-18, Order Canceled/Margin/Rejected
# 2016-04-18, Close, 100.98
# 2016-04-19, Close, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-27, Close, 91.91
# 2016-04-28, Close, 89.10
# 2016-04-29, Close, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-06, Close, 87.64
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-17, Close, 88.37
# 2016-05-17, BUY CREATE, 88.37
# 2016-05-18, BUY EXECUTED, Price: 89.01, Cost: 890.10, Comm 0.00
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-06-01, Close, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-13, SELL CREATE, 92.01
# 2016-06-14, SELL EXECUTED, Price: 91.99, Cost: 890.10, Comm 0.00
# 2016-06-14, OPERATION PROFIT, GROSS 29.80, NET 29.80
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-01, BUY CREATE, 90.64
# 2016-07-05, BUY EXECUTED, Price: 90.17, Cost: 901.70, Comm 0.00
# 2016-07-05, Close, 89.79
# 2016-07-05, SELL CREATE, 89.79
# 2016-07-06, SELL EXECUTED, Price: 89.42, Cost: 901.70, Comm 0.00
# 2016-07-06, OPERATION PROFIT, GROSS -7.50, NET -7.50
# 2016-07-06, Close, 90.30
# 2016-07-06, BUY CREATE, 90.30
# 2016-07-07, BUY EXECUTED, Price: 90.46, Cost: 904.60, Comm 0.00
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-25, Close, 92.01
# 2016-07-25, SELL CREATE, 92.01
# 2016-07-26, SELL EXECUTED, Price: 91.52, Cost: 904.60, Comm 0.00
# 2016-07-26, OPERATION PROFIT, GROSS 10.60, NET 10.60
# 2016-07-26, Close, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-27, BUY CREATE, 97.31
# 2016-07-28, Order Canceled/Margin/Rejected
# 2016-07-28, Close, 98.63
# 2016-07-28, BUY CREATE, 98.63
# 2016-07-29, Order Canceled/Margin/Rejected
# 2016-07-29, Close, 98.51
# 2016-07-29, BUY CREATE, 98.51
# 2016-08-01, Order Canceled/Margin/Rejected
# 2016-08-01, Close, 100.25
# 2016-08-01, BUY CREATE, 100.25
# 2016-08-02, Order Canceled/Margin/Rejected
# 2016-08-02, Close, 98.76
# 2016-08-02, BUY CREATE, 98.76
# 2016-08-03, Order Canceled/Margin/Rejected
# 2016-08-03, Close, 100.00
# 2016-08-03, BUY CREATE, 100.00
# 2016-08-04, Order Canceled/Margin/Rejected
# 2016-08-04, Close, 100.62
# 2016-08-04, BUY CREATE, 100.62
# 2016-08-05, Order Canceled/Margin/Rejected
# 2016-08-05, Close, 102.15
# 2016-08-05, BUY CREATE, 102.15
# 2016-08-08, Order Canceled/Margin/Rejected
# 2016-08-08, Close, 102.99
# 2016-08-08, BUY CREATE, 102.99
# 2016-08-09, Order Canceled/Margin/Rejected
# 2016-08-09, Close, 103.41
# 2016-08-09, BUY CREATE, 103.41
# 2016-08-10, Order Canceled/Margin/Rejected
# 2016-08-10, Close, 102.64
# 2016-08-10, BUY CREATE, 102.64
# 2016-08-11, Order Canceled/Margin/Rejected
# 2016-08-11, Close, 102.57
# 2016-08-11, BUY CREATE, 102.57
# 2016-08-12, Order Canceled/Margin/Rejected
# 2016-08-12, Close, 102.81
# 2016-08-12, BUY CREATE, 102.81
# 2016-08-15, Order Canceled/Margin/Rejected
# 2016-08-15, Close, 104.05
# 2016-08-15, BUY CREATE, 104.05
# 2016-08-16, Order Canceled/Margin/Rejected
# 2016-08-16, Close, 103.95
# 2016-08-16, BUY CREATE, 103.95
# 2016-08-17, Order Canceled/Margin/Rejected
# 2016-08-17, Close, 103.80
# 2016-08-17, BUY CREATE, 103.80
# 2016-08-18, Order Canceled/Margin/Rejected
# 2016-08-18, Close, 103.67
# 2016-08-18, BUY CREATE, 103.67
# 2016-08-19, Order Canceled/Margin/Rejected
# 2016-08-19, Close, 103.93
# 2016-08-19, BUY CREATE, 103.93
# 2016-08-22, Order Canceled/Margin/Rejected
# 2016-08-22, Close, 103.13
# 2016-08-22, BUY CREATE, 103.13
# 2016-08-23, Order Canceled/Margin/Rejected
# 2016-08-23, Close, 103.45
# 2016-08-23, BUY CREATE, 103.45
# 2016-08-24, Order Canceled/Margin/Rejected
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-26, Close, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-07, BUY CREATE, 102.98
# 2016-09-08, Order Canceled/Margin/Rejected
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-13, BUY CREATE, 102.59
# 2016-09-14, Order Canceled/Margin/Rejected
# 2016-09-14, Close, 106.22
# 2016-09-14, BUY CREATE, 106.22
# 2016-09-15, Order Canceled/Margin/Rejected
# 2016-09-15, Close, 109.84
# 2016-09-15, BUY CREATE, 109.84
# 2016-09-16, Order Canceled/Margin/Rejected
# 2016-09-16, Close, 109.22
# 2016-09-16, BUY CREATE, 109.22
# 2016-09-19, Order Canceled/Margin/Rejected
# 2016-09-19, Close, 107.94
# 2016-09-19, BUY CREATE, 107.94
# 2016-09-20, Order Canceled/Margin/Rejected
# 2016-09-20, Close, 107.94
# 2016-09-20, BUY CREATE, 107.94
# 2016-09-21, Order Canceled/Margin/Rejected
# 2016-09-21, Close, 107.92
# 2016-09-21, BUY CREATE, 107.92
# 2016-09-22, Order Canceled/Margin/Rejected
# 2016-09-22, Close, 108.93
# 2016-09-22, BUY CREATE, 108.93
# 2016-09-23, Order Canceled/Margin/Rejected
# 2016-09-23, Close, 107.12
# 2016-09-23, BUY CREATE, 107.12
# 2016-09-26, Order Canceled/Margin/Rejected
# 2016-09-26, Close, 107.28
# 2016-09-26, BUY CREATE, 107.28
# 2016-09-27, Order Canceled/Margin/Rejected
# 2016-09-27, Close, 107.48
# 2016-09-27, BUY CREATE, 107.48
# 2016-09-28, Order Canceled/Margin/Rejected
# 2016-09-28, Close, 108.30
# 2016-09-28, BUY CREATE, 108.30
# 2016-09-29, Order Canceled/Margin/Rejected
# 2016-09-29, Close, 106.61
# 2016-09-29, BUY CREATE, 106.61
# 2016-09-30, Order Canceled/Margin/Rejected
# 2016-09-30, Close, 107.44
# 2016-09-30, BUY CREATE, 107.44
# 2016-10-03, Order Canceled/Margin/Rejected
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-06, BUY CREATE, 108.24
# 2016-10-07, Order Canceled/Margin/Rejected
# 2016-10-07, Close, 108.40
# 2016-10-07, BUY CREATE, 108.40
# 2016-10-10, Order Canceled/Margin/Rejected
# 2016-10-10, Close, 110.29
# 2016-10-10, BUY CREATE, 110.29
# 2016-10-11, Order Canceled/Margin/Rejected
# 2016-10-11, Close, 110.53
# 2016-10-11, BUY CREATE, 110.53
# 2016-10-12, Order Canceled/Margin/Rejected
# 2016-10-12, Close, 111.52
# 2016-10-12, BUY CREATE, 111.52
# 2016-10-13, Order Canceled/Margin/Rejected
# 2016-10-13, Close, 111.18
# 2016-10-13, BUY CREATE, 111.18
# 2016-10-14, Order Canceled/Margin/Rejected
# 2016-10-14, Close, 111.79
# 2016-10-14, BUY CREATE, 111.79
# 2016-10-17, Order Canceled/Margin/Rejected
# 2016-10-17, Close, 111.72
# 2016-10-17, BUY CREATE, 111.72
# 2016-10-18, Order Canceled/Margin/Rejected
# 2016-10-18, Close, 111.64
# 2016-10-18, BUY CREATE, 111.64
# 2016-10-19, Order Canceled/Margin/Rejected
# 2016-10-19, Close, 111.31
# 2016-10-19, BUY CREATE, 111.31
# 2016-10-20, Order Canceled/Margin/Rejected
# 2016-10-20, Close, 111.25
# 2016-10-20, BUY CREATE, 111.25
# 2016-10-21, Order Canceled/Margin/Rejected
# 2016-10-21, Close, 110.81
# 2016-10-21, BUY CREATE, 110.81
# 2016-10-24, Order Canceled/Margin/Rejected
# 2016-10-24, Close, 111.81
# 2016-10-24, BUY CREATE, 111.81
# 2016-10-25, Order Canceled/Margin/Rejected
# 2016-10-25, Close, 112.38
# 2016-10-25, BUY CREATE, 112.38
# 2016-10-26, Order Canceled/Margin/Rejected
# 2016-10-26, Close, 109.85
# 2016-10-27, Close, 108.80
# 2016-10-28, Close, 108.08
# 2016-10-31, Close, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-17, BUY CREATE, 105.03
# 2016-11-18, Order Canceled/Margin/Rejected
# 2016-11-18, Close, 105.14
# 2016-11-18, BUY CREATE, 105.14
# 2016-11-21, Order Canceled/Margin/Rejected
# 2016-11-21, Close, 106.73
# 2016-11-21, BUY CREATE, 106.73
# 2016-11-22, Order Canceled/Margin/Rejected
# 2016-11-22, Close, 106.80
# 2016-11-22, BUY CREATE, 106.80
# 2016-11-23, Order Canceled/Margin/Rejected
# 2016-11-23, Close, 106.25
# 2016-11-23, BUY CREATE, 106.25
# 2016-11-25, Order Canceled/Margin/Rejected
# 2016-11-25, Close, 106.79
# 2016-11-25, BUY CREATE, 106.79
# 2016-11-28, Order Canceled/Margin/Rejected
# 2016-11-28, Close, 106.58
# 2016-11-28, BUY CREATE, 106.58
# 2016-11-29, Order Canceled/Margin/Rejected
# 2016-11-29, Close, 106.47
# 2016-11-29, BUY CREATE, 106.47
# 2016-11-30, Order Canceled/Margin/Rejected
# 2016-11-30, Close, 105.58
# 2016-11-30, BUY CREATE, 105.58
# 2016-12-01, Order Canceled/Margin/Rejected
# 2016-12-01, Close, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-07, BUY CREATE, 106.06
# 2016-12-08, Order Canceled/Margin/Rejected
# 2016-12-08, Close, 107.10
# 2016-12-08, BUY CREATE, 107.10
# 2016-12-09, Order Canceled/Margin/Rejected
# 2016-12-09, Close, 108.85
# 2016-12-09, BUY CREATE, 108.85
# 2016-12-12, Order Canceled/Margin/Rejected
# 2016-12-12, Close, 108.23
# 2016-12-12, BUY CREATE, 108.23
# 2016-12-13, Order Canceled/Margin/Rejected
# 2016-12-13, Close, 110.04
# 2016-12-13, BUY CREATE, 110.04
# 2016-12-14, Order Canceled/Margin/Rejected
# 2016-12-14, Close, 110.04
# 2016-12-14, BUY CREATE, 110.04
# 2016-12-15, Order Canceled/Margin/Rejected
# 2016-12-15, Close, 110.64
# 2016-12-15, BUY CREATE, 110.64
# 2016-12-16, Order Canceled/Margin/Rejected
# 2016-12-16, Close, 110.78
# 2016-12-16, BUY CREATE, 110.78
# 2016-12-19, Order Canceled/Margin/Rejected
# 2016-12-19, Close, 111.42
# 2016-12-19, BUY CREATE, 111.42
# 2016-12-20, Order Canceled/Margin/Rejected
# 2016-12-20, Close, 111.72
# 2016-12-20, BUY CREATE, 111.72
# 2016-12-21, Order Canceled/Margin/Rejected
# 2016-12-21, Close, 111.82
# 2016-12-21, BUY CREATE, 111.82
# 2016-12-22, Order Canceled/Margin/Rejected
# 2016-12-22, Close, 111.09
# 2016-12-22, BUY CREATE, 111.09
# 2016-12-23, Order Canceled/Margin/Rejected
# 2016-12-23, Close, 111.31
# 2016-12-23, BUY CREATE, 111.31
# 2016-12-27, Order Canceled/Margin/Rejected
# 2016-12-27, Close, 112.01
# 2016-12-27, BUY CREATE, 112.01
# 2016-12-28, Order Canceled/Margin/Rejected
# 2016-12-28, Close, 111.54
# 2016-12-28, BUY CREATE, 111.54
# 2016-12-29, Order Canceled/Margin/Rejected
# 2016-12-29, Close, 111.51
# 2016-12-29, BUY CREATE, 111.51
# 2016-12-30, Order Canceled/Margin/Rejected
# 2016-12-30, Close, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-03, BUY CREATE, 110.95
# 2017-01-04, Order Canceled/Margin/Rejected
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-05, BUY CREATE, 111.39
# 2017-01-06, Order Canceled/Margin/Rejected
# 2017-01-06, Close, 112.64
# 2017-01-06, BUY CREATE, 112.64
# 2017-01-09, Order Canceled/Margin/Rejected
# 2017-01-09, Close, 113.67
# 2017-01-09, BUY CREATE, 113.67
# 2017-01-10, Order Canceled/Margin/Rejected
# 2017-01-10, Close, 113.78
# 2017-01-10, BUY CREATE, 113.78
# 2017-01-11, Order Canceled/Margin/Rejected
# 2017-01-11, Close, 114.39
# 2017-01-11, BUY CREATE, 114.39
# 2017-01-12, Order Canceled/Margin/Rejected
# 2017-01-12, Close, 113.92
# 2017-01-12, BUY CREATE, 113.92
# 2017-01-13, Order Canceled/Margin/Rejected
# 2017-01-13, Close, 113.71
# 2017-01-13, BUY CREATE, 113.71
# 2017-01-17, Order Canceled/Margin/Rejected
# 2017-01-17, Close, 114.63
# 2017-01-17, BUY CREATE, 114.63
# 2017-01-18, Order Canceled/Margin/Rejected
# 2017-01-18, Close, 114.62
# 2017-01-18, BUY CREATE, 114.62
# 2017-01-19, Order Canceled/Margin/Rejected
# 2017-01-19, Close, 114.42
# 2017-01-19, BUY CREATE, 114.42
# 2017-01-20, Order Canceled/Margin/Rejected
# 2017-01-20, Close, 114.63
# 2017-01-20, BUY CREATE, 114.63
# 2017-01-23, Order Canceled/Margin/Rejected
# 2017-01-23, Close, 114.71
# 2017-01-23, BUY CREATE, 114.71
# 2017-01-24, Order Canceled/Margin/Rejected
# 2017-01-24, Close, 114.60
# 2017-01-24, BUY CREATE, 114.60
# 2017-01-25, Order Canceled/Margin/Rejected
# 2017-01-25, Close, 116.43
# 2017-01-25, BUY CREATE, 116.43
# 2017-01-26, Order Canceled/Margin/Rejected
# 2017-01-26, Close, 116.48
# 2017-01-26, BUY CREATE, 116.48
# 2017-01-27, Order Canceled/Margin/Rejected
# 2017-01-27, Close, 116.49
# 2017-01-27, BUY CREATE, 116.49
# 2017-01-30, Order Canceled/Margin/Rejected
# 2017-01-30, Close, 116.19
# 2017-01-30, BUY CREATE, 116.19
# 2017-01-31, Order Canceled/Margin/Rejected
# 2017-01-31, Close, 115.92
# 2017-01-31, BUY CREATE, 115.92
# 2017-02-01, Order Canceled/Margin/Rejected
# 2017-02-01, Close, 122.99
# 2017-02-01, BUY CREATE, 122.99
# 2017-02-02, Order Canceled/Margin/Rejected
# 2017-02-02, Close, 122.78
# 2017-02-02, BUY CREATE, 122.78
# 2017-02-03, Order Canceled/Margin/Rejected
# 2017-02-03, Close, 123.31
# 2017-02-03, BUY CREATE, 123.31
# 2017-02-06, Order Canceled/Margin/Rejected
# 2017-02-06, Close, 124.46
# 2017-02-06, BUY CREATE, 124.46
# 2017-02-07, Order Canceled/Margin/Rejected
# 2017-02-07, Close, 125.65
# 2017-02-07, BUY CREATE, 125.65
# 2017-02-08, Order Canceled/Margin/Rejected
# 2017-02-08, Close, 126.13
# 2017-02-08, BUY CREATE, 126.13
# 2017-02-09, Order Canceled/Margin/Rejected
# 2017-02-09, Close, 127.04
# 2017-02-09, BUY CREATE, 127.04
# 2017-02-10, Order Canceled/Margin/Rejected
# 2017-02-10, Close, 126.76
# 2017-02-10, BUY CREATE, 126.76
# 2017-02-13, Order Canceled/Margin/Rejected
# 2017-02-13, Close, 127.88
# 2017-02-13, BUY CREATE, 127.88
# 2017-02-14, Order Canceled/Margin/Rejected
# 2017-02-14, Close, 129.54
# 2017-02-14, BUY CREATE, 129.54
# 2017-02-15, Order Canceled/Margin/Rejected
# 2017-02-15, Close, 130.01
# 2017-02-15, BUY CREATE, 130.01
# 2017-02-16, Order Canceled/Margin/Rejected
# 2017-02-16, Close, 129.86
# 2017-02-16, BUY CREATE, 129.86
# 2017-02-17, Order Canceled/Margin/Rejected
# 2017-02-17, Close, 130.21
# 2017-02-17, BUY CREATE, 130.21
# 2017-02-21, Order Canceled/Margin/Rejected
# 2017-02-21, Close, 131.15
# 2017-02-21, BUY CREATE, 131.15
# 2017-02-22, Order Canceled/Margin/Rejected
# 2017-02-22, Close, 131.54
# 2017-02-22, BUY CREATE, 131.54
# 2017-02-23, Order Canceled/Margin/Rejected
# 2017-02-23, Close, 130.99
# 2017-02-23, BUY CREATE, 130.99
# 2017-02-24, Order Canceled/Margin/Rejected
# 2017-02-24, Close, 131.11
# 2017-02-24, BUY CREATE, 131.11
# 2017-02-27, Order Canceled/Margin/Rejected
# 2017-02-27, Close, 131.37
# 2017-02-27, BUY CREATE, 131.37
# 2017-02-28, Order Canceled/Margin/Rejected
# 2017-02-28, Close, 131.43
# 2017-02-28, BUY CREATE, 131.43
# 2017-03-01, Order Canceled/Margin/Rejected
# 2017-03-01, Close, 134.12
# 2017-03-01, BUY CREATE, 134.12
# 2017-03-02, Order Canceled/Margin/Rejected
# 2017-03-02, Close, 133.32
# 2017-03-02, BUY CREATE, 133.32
# 2017-03-03, Order Canceled/Margin/Rejected
# 2017-03-03, Close, 134.11
# 2017-03-03, BUY CREATE, 134.11
# 2017-03-06, Order Canceled/Margin/Rejected
# 2017-03-06, Close, 133.68
# 2017-03-06, BUY CREATE, 133.68
# 2017-03-07, Order Canceled/Margin/Rejected
# 2017-03-07, Close, 133.86
# 2017-03-07, BUY CREATE, 133.86
# 2017-03-08, Order Canceled/Margin/Rejected
# 2017-03-08, Close, 133.36
# 2017-03-08, BUY CREATE, 133.36
# 2017-03-09, Order Canceled/Margin/Rejected
# 2017-03-09, Close, 133.05
# 2017-03-09, BUY CREATE, 133.05
# 2017-03-10, Order Canceled/Margin/Rejected
# 2017-03-10, Close, 133.49
# 2017-03-10, BUY CREATE, 133.49
# 2017-03-13, Order Canceled/Margin/Rejected
# 2017-03-13, Close, 133.55
# 2017-03-13, BUY CREATE, 133.55
# 2017-03-14, Order Canceled/Margin/Rejected
# 2017-03-14, Close, 133.35
# 2017-03-14, BUY CREATE, 133.35
# 2017-03-15, Order Canceled/Margin/Rejected
# 2017-03-15, Close, 134.76
# 2017-03-15, BUY CREATE, 134.76
# 2017-03-16, Order Canceled/Margin/Rejected
# 2017-03-16, Close, 134.98
# 2017-03-16, BUY CREATE, 134.98
# 2017-03-17, Order Canceled/Margin/Rejected
# 2017-03-17, Close, 134.31
# 2017-03-17, BUY CREATE, 134.31
# 2017-03-20, Order Canceled/Margin/Rejected
# 2017-03-20, Close, 135.72
# 2017-03-20, BUY CREATE, 135.72
# 2017-03-21, Order Canceled/Margin/Rejected
# 2017-03-21, Close, 134.16
# 2017-03-21, BUY CREATE, 134.16
# 2017-03-22, Order Canceled/Margin/Rejected
# 2017-03-22, Close, 135.68
# 2017-03-22, BUY CREATE, 135.68
# 2017-03-23, Order Canceled/Margin/Rejected
# 2017-03-23, Close, 135.20
# 2017-03-23, BUY CREATE, 135.20
# 2017-03-24, Order Canceled/Margin/Rejected
# 2017-03-24, Close, 134.93
# 2017-03-24, BUY CREATE, 134.93
# 2017-03-27, Order Canceled/Margin/Rejected
# 2017-03-27, Close, 135.16
# 2017-03-27, BUY CREATE, 135.16
# 2017-03-28, Order Canceled/Margin/Rejected
# 2017-03-28, Close, 137.96
# 2017-03-28, BUY CREATE, 137.96
# 2017-03-29, Order Canceled/Margin/Rejected
# 2017-03-29, Close, 138.27
# 2017-03-29, BUY CREATE, 138.27
# 2017-03-30, Order Canceled/Margin/Rejected
# 2017-03-30, Close, 138.09
# 2017-03-30, BUY CREATE, 138.09
# 2017-03-31, Order Canceled/Margin/Rejected
# 2017-03-31, Close, 137.83
# 2017-03-31, BUY CREATE, 137.83
# 2017-04-03, Order Canceled/Margin/Rejected
# 2017-04-03, Close, 137.87
# 2017-04-03, BUY CREATE, 137.87
# 2017-04-04, Order Canceled/Margin/Rejected
# 2017-04-04, Close, 138.89
# 2017-04-04, BUY CREATE, 138.89
# 2017-04-05, Order Canceled/Margin/Rejected
# 2017-04-05, Close, 138.17
# 2017-04-05, BUY CREATE, 138.17
# 2017-04-06, Order Canceled/Margin/Rejected
# 2017-04-06, Close, 137.83
# 2017-04-06, BUY CREATE, 137.83
# 2017-04-07, Order Canceled/Margin/Rejected
# 2017-04-07, Close, 137.52
# 2017-04-07, BUY CREATE, 137.52
# 2017-04-10, Order Canceled/Margin/Rejected
# 2017-04-10, Close, 137.36
# 2017-04-10, BUY CREATE, 137.36
# 2017-04-11, Order Canceled/Margin/Rejected
# 2017-04-11, Close, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-24, BUY CREATE, 137.81
# 2017-04-25, Order Canceled/Margin/Rejected
# 2017-04-25, Close, 138.66
# 2017-04-25, BUY CREATE, 138.66
# 2017-04-26, Order Canceled/Margin/Rejected
# 2017-04-26, Close, 137.85
# 2017-04-26, BUY CREATE, 137.85
# 2017-04-27, Order Canceled/Margin/Rejected
# 2017-04-27, Close, 137.95
# 2017-04-27, BUY CREATE, 137.95
# 2017-04-28, Order Canceled/Margin/Rejected
# 2017-04-28, Close, 137.82
# 2017-04-28, BUY CREATE, 137.82
# 2017-05-01, Order Canceled/Margin/Rejected
# 2017-05-01, Close, 140.63
# 2017-05-01, BUY CREATE, 140.63
# 2017-05-02, Order Canceled/Margin/Rejected
# 2017-05-02, Close, 141.52
# 2017-05-02, BUY CREATE, 141.52
# 2017-05-03, Order Canceled/Margin/Rejected
# 2017-05-03, Close, 141.09
# 2017-05-03, BUY CREATE, 141.09
# 2017-05-04, Order Canceled/Margin/Rejected
# 2017-05-04, Close, 140.58
# 2017-05-04, BUY CREATE, 140.58
# 2017-05-05, Order Canceled/Margin/Rejected
# 2017-05-05, Close, 142.91
# 2017-05-05, BUY CREATE, 142.91
# 2017-05-08, Order Canceled/Margin/Rejected
# 2017-05-08, Close, 146.80
# 2017-05-08, BUY CREATE, 146.80
# 2017-05-09, Order Canceled/Margin/Rejected
# 2017-05-09, Close, 147.74
# 2017-05-09, BUY CREATE, 147.74
# 2017-05-10, Order Canceled/Margin/Rejected
# 2017-05-10, Close, 147.04
# 2017-05-10, BUY CREATE, 147.04
# 2017-05-11, Order Canceled/Margin/Rejected
# 2017-05-11, Close, 148.31
# 2017-05-11, BUY CREATE, 148.31
# 2017-05-12, Order Canceled/Margin/Rejected
# 2017-05-12, Close, 150.38
# 2017-05-12, BUY CREATE, 150.38
# 2017-05-15, Order Canceled/Margin/Rejected
# 2017-05-15, Close, 150.00
# 2017-05-15, BUY CREATE, 150.00
# 2017-05-16, Order Canceled/Margin/Rejected
# 2017-05-16, Close, 149.77
# 2017-05-16, BUY CREATE, 149.77
# 2017-05-17, Order Canceled/Margin/Rejected
# 2017-05-17, Close, 144.75
# 2017-05-17, BUY CREATE, 144.75
# 2017-05-18, Order Canceled/Margin/Rejected
# 2017-05-18, Close, 146.95
# 2017-05-18, BUY CREATE, 146.95
# 2017-05-19, Order Canceled/Margin/Rejected
# 2017-05-19, Close, 147.45
# 2017-05-19, BUY CREATE, 147.45
# 2017-05-22, Order Canceled/Margin/Rejected
# 2017-05-22, Close, 148.35
# 2017-05-22, BUY CREATE, 148.35
# 2017-05-23, Order Canceled/Margin/Rejected
# 2017-05-23, Close, 148.17
# 2017-05-23, BUY CREATE, 148.17
# 2017-05-24, Order Canceled/Margin/Rejected
# 2017-05-24, Close, 147.72
# 2017-05-24, BUY CREATE, 147.72
# 2017-05-25, Order Canceled/Margin/Rejected
# 2017-05-25, Close, 148.23
# 2017-05-25, BUY CREATE, 148.23
# 2017-05-26, Order Canceled/Margin/Rejected
# 2017-05-26, Close, 147.98
# 2017-05-26, BUY CREATE, 147.98
# 2017-05-30, Order Canceled/Margin/Rejected
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-02, BUY CREATE, 149.76
# 2017-06-05, Order Canceled/Margin/Rejected
# 2017-06-05, Close, 148.29
# 2017-06-05, BUY CREATE, 148.29
# 2017-06-06, Order Canceled/Margin/Rejected
# 2017-06-06, Close, 148.79
# 2017-06-06, BUY CREATE, 148.79
# 2017-06-07, Order Canceled/Margin/Rejected
# 2017-06-07, Close, 149.68
# 2017-06-07, BUY CREATE, 149.68
# 2017-06-08, Order Canceled/Margin/Rejected
# 2017-06-08, Close, 149.31
# 2017-06-08, BUY CREATE, 149.31
# 2017-06-09, Order Canceled/Margin/Rejected
# 2017-06-09, Close, 143.52
# 2017-06-12, Close, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-10, BUY CREATE, 139.75
# 2017-07-11, Order Canceled/Margin/Rejected
# 2017-07-11, Close, 140.20
# 2017-07-11, BUY CREATE, 140.20
# 2017-07-12, Order Canceled/Margin/Rejected
# 2017-07-12, Close, 140.40
# 2017-07-12, BUY CREATE, 140.40
# 2017-07-13, Order Canceled/Margin/Rejected
# 2017-07-13, Close, 142.36
# 2017-07-13, BUY CREATE, 142.36
# 2017-07-14, Order Canceled/Margin/Rejected
# 2017-07-14, Close, 143.58
# 2017-07-14, BUY CREATE, 143.58
# 2017-07-17, Order Canceled/Margin/Rejected
# 2017-07-17, Close, 144.08
# 2017-07-17, BUY CREATE, 144.08
# 2017-07-18, Order Canceled/Margin/Rejected
# 2017-07-18, Close, 144.58
# 2017-07-18, BUY CREATE, 144.58
# 2017-07-19, Order Canceled/Margin/Rejected
# 2017-07-19, Close, 145.49
# 2017-07-19, BUY CREATE, 145.49
# 2017-07-20, Order Canceled/Margin/Rejected
# 2017-07-20, Close, 144.83
# 2017-07-20, BUY CREATE, 144.83
# 2017-07-21, Order Canceled/Margin/Rejected
# 2017-07-21, Close, 144.76
# 2017-07-21, BUY CREATE, 144.76
# 2017-07-24, Order Canceled/Margin/Rejected
# 2017-07-24, Close, 146.52
# 2017-07-24, BUY CREATE, 146.52
# 2017-07-25, Order Canceled/Margin/Rejected
# 2017-07-25, Close, 147.14
# 2017-07-25, BUY CREATE, 147.14
# 2017-07-26, Order Canceled/Margin/Rejected
# 2017-07-26, Close, 147.84
# 2017-07-26, BUY CREATE, 147.84
# 2017-07-27, Order Canceled/Margin/Rejected
# 2017-07-27, Close, 145.04
# 2017-07-27, BUY CREATE, 145.04
# 2017-07-28, Order Canceled/Margin/Rejected
# 2017-07-28, Close, 144.02
# 2017-07-31, Close, 143.28
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-02, BUY CREATE, 151.38
# 2017-08-03, Order Canceled/Margin/Rejected
# 2017-08-03, Close, 149.87
# 2017-08-03, BUY CREATE, 149.87
# 2017-08-04, Order Canceled/Margin/Rejected
# 2017-08-04, Close, 150.66
# 2017-08-04, BUY CREATE, 150.66
# 2017-08-07, Order Canceled/Margin/Rejected
# 2017-08-07, Close, 152.99
# 2017-08-07, BUY CREATE, 152.99
# 2017-08-08, Order Canceled/Margin/Rejected
# 2017-08-08, Close, 154.22
# 2017-08-08, BUY CREATE, 154.22
# 2017-08-09, Order Canceled/Margin/Rejected
# 2017-08-09, Close, 155.16
# 2017-08-09, BUY CREATE, 155.16
# 2017-08-10, Order Canceled/Margin/Rejected
# 2017-08-10, Close, 150.22
# 2017-08-10, BUY CREATE, 150.22
# 2017-08-11, Order Canceled/Margin/Rejected
# 2017-08-11, Close, 152.31
# 2017-08-11, BUY CREATE, 152.31
# 2017-08-14, Order Canceled/Margin/Rejected
# 2017-08-14, Close, 154.60
# 2017-08-14, BUY CREATE, 154.60
# 2017-08-15, Order Canceled/Margin/Rejected
# 2017-08-15, Close, 156.29
# 2017-08-15, BUY CREATE, 156.29
# 2017-08-16, Order Canceled/Margin/Rejected
# 2017-08-16, Close, 155.66
# 2017-08-16, BUY CREATE, 155.66
# 2017-08-17, Order Canceled/Margin/Rejected
# 2017-08-17, Close, 152.67
# 2017-08-17, BUY CREATE, 152.67
# 2017-08-18, Order Canceled/Margin/Rejected
# 2017-08-18, Close, 152.33
# 2017-08-18, BUY CREATE, 152.33
# 2017-08-21, Order Canceled/Margin/Rejected
# 2017-08-21, Close, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-22, BUY CREATE, 154.53
# 2017-08-23, Order Canceled/Margin/Rejected
# 2017-08-23, Close, 154.72
# 2017-08-23, BUY CREATE, 154.72
# 2017-08-24, Order Canceled/Margin/Rejected
# 2017-08-24, Close, 154.04
# 2017-08-24, BUY CREATE, 154.04
# 2017-08-25, Order Canceled/Margin/Rejected
# 2017-08-25, Close, 154.61
# 2017-08-25, BUY CREATE, 154.61
# 2017-08-28, Order Canceled/Margin/Rejected
# 2017-08-28, Close, 156.17
# 2017-08-28, BUY CREATE, 156.17
# 2017-08-29, Order Canceled/Margin/Rejected
# 2017-08-29, Close, 157.56
# 2017-08-29, BUY CREATE, 157.56
# 2017-08-30, Order Canceled/Margin/Rejected
# 2017-08-30, Close, 157.98
# 2017-08-30, BUY CREATE, 157.98
# 2017-08-31, Order Canceled/Margin/Rejected
# 2017-08-31, Close, 158.61
# 2017-08-31, BUY CREATE, 158.61
# 2017-09-01, Order Canceled/Margin/Rejected
# 2017-09-01, Close, 158.66
# 2017-09-01, BUY CREATE, 158.66
# 2017-09-05, Order Canceled/Margin/Rejected
# 2017-09-05, Close, 156.76
# 2017-09-05, BUY CREATE, 156.76
# 2017-09-06, Order Canceled/Margin/Rejected
# 2017-09-06, Close, 156.59
# 2017-09-06, BUY CREATE, 156.59
# 2017-09-07, Order Canceled/Margin/Rejected
# 2017-09-07, Close, 155.96
# 2017-09-07, BUY CREATE, 155.96
# 2017-09-08, Order Canceled/Margin/Rejected
# 2017-09-08, Close, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-11, BUY CREATE, 156.19
# 2017-09-12, Order Canceled/Margin/Rejected
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-22, Close, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-05, BUY CREATE, 150.29
# 2017-10-06, Order Canceled/Margin/Rejected
# 2017-10-06, Close, 150.20
# 2017-10-06, BUY CREATE, 150.20
# 2017-10-09, Order Canceled/Margin/Rejected
# 2017-10-09, Close, 150.72
# 2017-10-09, BUY CREATE, 150.72
# 2017-10-10, Order Canceled/Margin/Rejected
# 2017-10-10, Close, 150.78
# 2017-10-10, BUY CREATE, 150.78
# 2017-10-11, Order Canceled/Margin/Rejected
# 2017-10-11, Close, 151.41
# 2017-10-11, BUY CREATE, 151.41
# 2017-10-12, Order Canceled/Margin/Rejected
# 2017-10-12, Close, 150.88
# 2017-10-12, BUY CREATE, 150.88
# 2017-10-13, Order Canceled/Margin/Rejected
# 2017-10-13, Close, 151.83
# 2017-10-13, BUY CREATE, 151.83
# 2017-10-16, Order Canceled/Margin/Rejected
# 2017-10-16, Close, 154.63
# 2017-10-16, BUY CREATE, 154.63
# 2017-10-17, Order Canceled/Margin/Rejected
# 2017-10-17, Close, 155.20
# 2017-10-17, BUY CREATE, 155.20
# 2017-10-18, Order Canceled/Margin/Rejected
# 2017-10-18, Close, 154.51
# 2017-10-18, BUY CREATE, 154.51
# 2017-10-19, Order Canceled/Margin/Rejected
# 2017-10-19, Close, 150.86
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-24, BUY CREATE, 151.94
# 2017-10-25, Order Canceled/Margin/Rejected
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-26, BUY CREATE, 152.24
# 2017-10-27, Order Canceled/Margin/Rejected
# 2017-10-27, Close, 157.69
# 2017-10-27, BUY CREATE, 157.69
# 2017-10-30, Order Canceled/Margin/Rejected
# 2017-10-30, Close, 161.24
# 2017-10-30, BUY CREATE, 161.24
# 2017-10-31, Order Canceled/Margin/Rejected
# 2017-10-31, Close, 163.49
# 2017-10-31, BUY CREATE, 163.49
# 2017-11-01, Order Canceled/Margin/Rejected
# 2017-11-01, Close, 161.41
# 2017-11-01, BUY CREATE, 161.41
# ...
# 2019-04-10, Order Canceled/Margin/Rejected
# 2019-04-10, Close, 198.50
# 2019-04-10, BUY CREATE, 198.50
# 2019-04-11, Order Canceled/Margin/Rejected
# 2019-04-11, Close, 196.85
# 2019-04-11, BUY CREATE, 196.85
# 2019-04-12, Order Canceled/Margin/Rejected
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE, 196.77
# 2019-04-15, Order Canceled/Margin/Rejected
# 2019-04-15, Close, 197.12
# 2019-04-15, BUY CREATE, 197.12
# 2019-04-16, Order Canceled/Margin/Rejected
# 2019-04-16, Close, 197.14
# 2019-04-16, BUY CREATE, 197.14
# 2019-04-17, Order Canceled/Margin/Rejected
# 2019-04-17, Close, 200.98
# 2019-04-17, BUY CREATE, 200.98
# 2019-04-18, Order Canceled/Margin/Rejected
# 2019-04-18, Close, 201.70
# 2019-04-18, BUY CREATE, 201.70
# 2019-04-22, Order Canceled/Margin/Rejected
# 2019-04-22, Close, 202.37
# 2019-04-22, BUY CREATE, 202.37
# 2019-04-23, Order Canceled/Margin/Rejected
# 2019-04-23, Close, 205.29
# 2019-04-23, BUY CREATE, 205.29
# 2019-04-24, Order Canceled/Margin/Rejected
# 2019-04-24, Close, 204.97
# 2019-04-24, BUY CREATE, 204.97
# 2019-04-25, Order Canceled/Margin/Rejected
# 2019-04-25, Close, 203.11
# 2019-04-25, BUY CREATE, 203.11
# 2019-04-26, Order Canceled/Margin/Rejected
# 2019-04-26, Close, 202.14
# 2019-04-26, BUY CREATE, 202.14
# 2019-04-29, Order Canceled/Margin/Rejected
# 2019-04-29, Close, 202.45
# 2019-04-29, BUY CREATE, 202.45
# 2019-04-30, Order Canceled/Margin/Rejected
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-01, BUY CREATE, 208.29
# 2019-05-02, Order Canceled/Margin/Rejected
# 2019-05-02, Close, 206.94
# 2019-05-02, BUY CREATE, 206.94
# 2019-05-03, Order Canceled/Margin/Rejected
# 2019-05-03, Close, 209.51
# 2019-05-03, BUY CREATE, 209.51
# 2019-05-06, Order Canceled/Margin/Rejected
# 2019-05-06, Close, 206.27
# 2019-05-06, BUY CREATE, 206.27
# 2019-05-07, Order Canceled/Margin/Rejected
# 2019-05-07, Close, 200.71
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-20, Close, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-29, Close, 176.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-05, BUY CREATE, 181.30
# 2019-06-06, Order Canceled/Margin/Rejected
# 2019-06-06, Close, 183.97
# 2019-06-06, BUY CREATE, 183.97
# 2019-06-07, Order Canceled/Margin/Rejected
# 2019-06-07, Close, 188.86
# 2019-06-07, BUY CREATE, 188.86
# 2019-06-10, Order Canceled/Margin/Rejected
# 2019-06-10, Close, 191.28
# 2019-06-10, BUY CREATE, 191.28
# 2019-06-11, Order Canceled/Margin/Rejected
# 2019-06-11, Close, 193.49
# 2019-06-11, BUY CREATE, 193.49
# 2019-06-12, Order Canceled/Margin/Rejected
# 2019-06-12, Close, 192.88
# 2019-06-12, BUY CREATE, 192.88
# 2019-06-13, Order Canceled/Margin/Rejected
# 2019-06-13, Close, 192.84
# 2019-06-13, BUY CREATE, 192.84
# 2019-06-14, Order Canceled/Margin/Rejected
# 2019-06-14, Close, 191.44
# 2019-06-14, BUY CREATE, 191.44
# 2019-06-17, Order Canceled/Margin/Rejected
# 2019-06-17, Close, 192.58
# 2019-06-17, BUY CREATE, 192.58
# 2019-06-18, Order Canceled/Margin/Rejected
# 2019-06-18, Close, 197.11
# 2019-06-18, BUY CREATE, 197.11
# 2019-06-19, Order Canceled/Margin/Rejected
# 2019-06-19, Close, 196.53
# 2019-06-19, BUY CREATE, 196.53
# 2019-06-20, Order Canceled/Margin/Rejected
# 2019-06-20, Close, 198.11
# 2019-06-20, BUY CREATE, 198.11
# 2019-06-21, Order Canceled/Margin/Rejected
# 2019-06-21, Close, 197.43
# 2019-06-21, BUY CREATE, 197.43
# 2019-06-24, Order Canceled/Margin/Rejected
# 2019-06-24, Close, 197.24
# 2019-06-24, BUY CREATE, 197.24
# 2019-06-25, Order Canceled/Margin/Rejected
# 2019-06-25, Close, 194.25
# 2019-06-25, BUY CREATE, 194.25
# 2019-06-26, Order Canceled/Margin/Rejected
# 2019-06-26, Close, 198.45
# 2019-06-26, BUY CREATE, 198.45
# 2019-06-27, Order Canceled/Margin/Rejected
# 2019-06-27, Close, 198.39
# 2019-06-27, BUY CREATE, 198.39
# 2019-06-28, Order Canceled/Margin/Rejected
# 2019-06-28, Close, 196.58
# 2019-06-28, BUY CREATE, 196.58
# 2019-07-01, Order Canceled/Margin/Rejected
# 2019-07-01, Close, 200.19
# 2019-07-01, BUY CREATE, 200.19
# 2019-07-02, Order Canceled/Margin/Rejected
# 2019-07-02, Close, 201.36
# 2019-07-02, BUY CREATE, 201.36
# 2019-07-03, Order Canceled/Margin/Rejected
# 2019-07-03, Close, 203.03
# 2019-07-03, BUY CREATE, 203.03
# 2019-07-05, Order Canceled/Margin/Rejected
# 2019-07-05, Close, 202.85
# 2019-07-05, BUY CREATE, 202.85
# 2019-07-08, Order Canceled/Margin/Rejected
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE, 198.67
# 2019-07-09, Order Canceled/Margin/Rejected
# 2019-07-09, Close, 199.88
# 2019-07-09, BUY CREATE, 199.88
# 2019-07-10, Order Canceled/Margin/Rejected
# 2019-07-10, Close, 201.85
# 2019-07-10, BUY CREATE, 201.85
# 2019-07-11, Order Canceled/Margin/Rejected
# 2019-07-11, Close, 200.38
# 2019-07-11, BUY CREATE, 200.38
# 2019-07-12, Order Canceled/Margin/Rejected
# 2019-07-12, Close, 201.92
# 2019-07-12, BUY CREATE, 201.92
# 2019-07-15, Order Canceled/Margin/Rejected
# 2019-07-15, Close, 203.82
# 2019-07-15, BUY CREATE, 203.82
# 2019-07-16, Order Canceled/Margin/Rejected
# 2019-07-16, Close, 203.12
# 2019-07-16, BUY CREATE, 203.12
# 2019-07-17, Order Canceled/Margin/Rejected
# 2019-07-17, Close, 201.97
# 2019-07-17, BUY CREATE, 201.97
# 2019-07-18, Order Canceled/Margin/Rejected
# 2019-07-18, Close, 204.27
# 2019-07-18, BUY CREATE, 204.27
# 2019-07-19, Order Canceled/Margin/Rejected
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-22, BUY CREATE, 205.82
# 2019-07-23, Order Canceled/Margin/Rejected
# 2019-07-23, Close, 207.43
# 2019-07-23, BUY CREATE, 207.43
# 2019-07-24, Order Canceled/Margin/Rejected
# 2019-07-24, Close, 207.26
# 2019-07-24, BUY CREATE, 207.26
# 2019-07-25, Order Canceled/Margin/Rejected
# 2019-07-25, Close, 205.62
# 2019-07-25, BUY CREATE, 205.62
# 2019-07-26, Order Canceled/Margin/Rejected
# 2019-07-26, Close, 206.33
# 2019-07-26, BUY CREATE, 206.33
# 2019-07-29, Order Canceled/Margin/Rejected
# 2019-07-29, Close, 208.26
# 2019-07-29, BUY CREATE, 208.26
# 2019-07-30, Order Canceled/Margin/Rejected
# 2019-07-30, Close, 207.37
# 2019-07-30, BUY CREATE, 207.37
# 2019-07-31, Order Canceled/Margin/Rejected
# 2019-07-31, Close, 211.60
# 2019-07-31, BUY CREATE, 211.60
# 2019-08-01, Order Canceled/Margin/Rejected
# 2019-08-01, Close, 207.02
# 2019-08-01, BUY CREATE, 207.02
# 2019-08-02, Order Canceled/Margin/Rejected
# 2019-08-02, Close, 202.64
# 2019-08-05, Close, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-13, Close, 208.34
# 2019-08-13, BUY CREATE, 208.34
# 2019-08-14, Order Canceled/Margin/Rejected
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-16, Close, 205.88
# 2019-08-16, BUY CREATE, 205.88
# 2019-08-19, Order Canceled/Margin/Rejected
# 2019-08-19, Close, 209.72
# 2019-08-19, BUY CREATE, 209.72
# 2019-08-20, Order Canceled/Margin/Rejected
# 2019-08-20, Close, 209.73
# 2019-08-20, BUY CREATE, 209.73
# 2019-08-21, Order Canceled/Margin/Rejected
# 2019-08-21, Close, 212.00
# 2019-08-21, BUY CREATE, 212.00
# 2019-08-22, Order Canceled/Margin/Rejected
# 2019-08-22, Close, 211.82
# 2019-08-22, BUY CREATE, 211.82
# 2019-08-23, Order Canceled/Margin/Rejected
# 2019-08-23, Close, 202.03
# 2019-08-26, Close, 205.87
# 2019-08-26, BUY CREATE, 205.87
# 2019-08-27, Order Canceled/Margin/Rejected
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-29, BUY CREATE, 208.38
# 2019-08-30, Order Canceled/Margin/Rejected
# 2019-08-30, Close, 208.12
# 2019-08-30, BUY CREATE, 208.12
# 2019-09-03, Order Canceled/Margin/Rejected
# 2019-09-03, Close, 205.08
# 2019-09-04, Close, 208.56
# 2019-09-04, BUY CREATE, 208.56
# 2019-09-05, Order Canceled/Margin/Rejected
# 2019-09-05, Close, 212.64
# 2019-09-05, BUY CREATE, 212.64
# 2019-09-06, Order Canceled/Margin/Rejected
# 2019-09-06, Close, 212.62
# 2019-09-06, BUY CREATE, 212.62
# 2019-09-09, Order Canceled/Margin/Rejected
# 2019-09-09, Close, 213.53
# 2019-09-09, BUY CREATE, 213.53
# 2019-09-10, Order Canceled/Margin/Rejected
# 2019-09-10, Close, 216.05
# 2019-09-10, BUY CREATE, 216.05
# 2019-09-11, Order Canceled/Margin/Rejected
# 2019-09-11, Close, 222.92
# 2019-09-11, BUY CREATE, 222.92
# 2019-09-12, Order Canceled/Margin/Rejected
# 2019-09-12, Close, 222.42
# 2019-09-12, BUY CREATE, 222.42
# 2019-09-13, Order Canceled/Margin/Rejected
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE, 218.10
# 2019-09-16, Order Canceled/Margin/Rejected
# 2019-09-16, Close, 219.24
# 2019-09-16, BUY CREATE, 219.24
# 2019-09-17, Order Canceled/Margin/Rejected
# 2019-09-17, Close, 220.04
# 2019-09-17, BUY CREATE, 220.04
# 2019-09-18, Order Canceled/Margin/Rejected
# 2019-09-18, Close, 222.10
# 2019-09-18, BUY CREATE, 222.10
# 2019-09-19, Order Canceled/Margin/Rejected
# 2019-09-19, Close, 220.30
# 2019-09-19, BUY CREATE, 220.30
# 2019-09-20, Order Canceled/Margin/Rejected
# 2019-09-20, Close, 217.08
# 2019-09-20, BUY CREATE, 217.08
# 2019-09-23, Order Canceled/Margin/Rejected
# 2019-09-23, Close, 218.07
# 2019-09-23, BUY CREATE, 218.07
# 2019-09-24, Order Canceled/Margin/Rejected
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-25, BUY CREATE, 220.37
# 2019-09-26, Order Canceled/Margin/Rejected
# 2019-09-26, Close, 219.23
# 2019-09-26, BUY CREATE, 219.23
# 2019-09-27, Order Canceled/Margin/Rejected
# 2019-09-27, Close, 218.17
# 2019-09-30, Close, 223.30
# 2019-09-30, BUY CREATE, 223.30
# 2019-10-01, Order Canceled/Margin/Rejected
# 2019-10-01, Close, 223.92
# 2019-10-01, BUY CREATE, 223.92
# 2019-10-02, Order Canceled/Margin/Rejected
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-03, BUY CREATE, 220.16
# 2019-10-04, Order Canceled/Margin/Rejected
# 2019-10-04, Close, 226.33
# 2019-10-04, BUY CREATE, 226.33
# 2019-10-07, Order Canceled/Margin/Rejected
# 2019-10-07, Close, 226.38
# 2019-10-07, BUY CREATE, 226.38
# 2019-10-08, Order Canceled/Margin/Rejected
# 2019-10-08, Close, 223.73
# 2019-10-08, BUY CREATE, 223.73
# 2019-10-09, Order Canceled/Margin/Rejected
# 2019-10-09, Close, 226.35
# 2019-10-09, BUY CREATE, 226.35
# 2019-10-10, Order Canceled/Margin/Rejected
# 2019-10-10, Close, 229.40
# 2019-10-10, BUY CREATE, 229.40
# 2019-10-11, Order Canceled/Margin/Rejected
# 2019-10-11, Close, 235.50
# 2019-10-11, BUY CREATE, 235.50
# 2019-10-14, Order Canceled/Margin/Rejected
# 2019-10-14, Close, 235.16
# 2019-10-14, BUY CREATE, 235.16
# 2019-10-15, Order Canceled/Margin/Rejected
# 2019-10-15, Close, 234.62
# 2019-10-15, BUY CREATE, 234.62
# 2019-10-16, Order Canceled/Margin/Rejected
# 2019-10-16, Close, 233.67
# 2019-10-16, BUY CREATE, 233.67
# 2019-10-17, Order Canceled/Margin/Rejected
# 2019-10-17, Close, 234.58
# 2019-10-17, BUY CREATE, 234.58
# 2019-10-18, Order Canceled/Margin/Rejected
# 2019-10-18, Close, 235.70
# 2019-10-18, BUY CREATE, 235.70
# 2019-10-21, Order Canceled/Margin/Rejected
# 2019-10-21, Close, 239.79
# 2019-10-21, BUY CREATE, 239.79
# 2019-10-22, Order Canceled/Margin/Rejected
# 2019-10-22, Close, 239.24
# 2019-10-22, BUY CREATE, 239.24
# 2019-10-23, Order Canceled/Margin/Rejected
# 2019-10-23, Close, 242.45
# 2019-10-23, BUY CREATE, 242.45
# 2019-10-24, Order Canceled/Margin/Rejected
# 2019-10-24, Close, 242.85
# 2019-10-24, BUY CREATE, 242.85
# 2019-10-25, Order Canceled/Margin/Rejected
# 2019-10-25, Close, 245.84
# 2019-10-25, BUY CREATE, 245.84
# 2019-10-28, Order Canceled/Margin/Rejected
# 2019-10-28, Close, 248.30
# 2019-10-28, BUY CREATE, 248.30
# 2019-10-29, Order Canceled/Margin/Rejected
# 2019-10-29, Close, 242.56
# 2019-10-29, BUY CREATE, 242.56
# 2019-10-30, Order Canceled/Margin/Rejected
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE, 242.53
# 2019-10-31, Order Canceled/Margin/Rejected
# 2019-10-31, Close, 248.02
# 2019-10-31, BUY CREATE, 248.02
# 2019-11-01, Order Canceled/Margin/Rejected
# 2019-11-01, Close, 255.05
# 2019-11-01, BUY CREATE, 255.05
# 2019-11-04, Order Canceled/Margin/Rejected
# 2019-11-04, Close, 256.73
# 2019-11-04, BUY CREATE, 256.73
# 2019-11-05, Order Canceled/Margin/Rejected
# 2019-11-05, Close, 256.36
# 2019-11-05, BUY CREATE, 256.36
# 2019-11-06, Order Canceled/Margin/Rejected
# 2019-11-06, Close, 256.47
# 2019-11-06, BUY CREATE, 256.47
# 2019-11-07, Order Canceled/Margin/Rejected
# 2019-11-07, Close, 259.43
# 2019-11-07, BUY CREATE, 259.43
# 2019-11-08, Order Canceled/Margin/Rejected
# 2019-11-08, Close, 260.14
# 2019-11-08, BUY CREATE, 260.14
# 2019-11-11, Order Canceled/Margin/Rejected
# 2019-11-11, Close, 262.20
# 2019-11-11, BUY CREATE, 262.20
# 2019-11-12, Order Canceled/Margin/Rejected
# 2019-11-12, Close, 261.96
# 2019-11-12, BUY CREATE, 261.96
# 2019-11-13, Order Canceled/Margin/Rejected
# 2019-11-13, Close, 264.47
# 2019-11-13, BUY CREATE, 264.47
# 2019-11-14, Order Canceled/Margin/Rejected
# 2019-11-14, Close, 262.64
# 2019-11-14, BUY CREATE, 262.64
# 2019-11-15, Order Canceled/Margin/Rejected
# 2019-11-15, Close, 265.76
# 2019-11-15, BUY CREATE, 265.76
# 2019-11-18, Order Canceled/Margin/Rejected
# 2019-11-18, Close, 267.10
# 2019-11-18, BUY CREATE, 267.10
# 2019-11-19, Order Canceled/Margin/Rejected
# 2019-11-19, Close, 266.29
# 2019-11-19, BUY CREATE, 266.29
# 2019-11-20, Order Canceled/Margin/Rejected
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE, 263.19
# 2019-11-21, Order Canceled/Margin/Rejected
# 2019-11-21, Close, 262.01
# 2019-11-21, BUY CREATE, 262.01
# 2019-11-22, Order Canceled/Margin/Rejected
# 2019-11-22, Close, 261.78
# 2019-11-22, BUY CREATE, 261.78
# 2019-11-25, Order Canceled/Margin/Rejected
# 2019-11-25, Close, 266.37
# 2019-11-25, BUY CREATE, 266.37
# 2019-11-26, Order Canceled/Margin/Rejected
# 2019-11-26, Close, 264.29
# 2019-11-26, BUY CREATE, 264.29
# 2019-11-27, Order Canceled/Margin/Rejected
# 2019-11-27, Close, 267.84
# 2019-11-27, BUY CREATE, 267.84
# 2019-11-29, Order Canceled/Margin/Rejected
# 2019-11-29, Close, 267.25
# 2019-11-29, BUY CREATE, 267.25
# 2019-12-02, Order Canceled/Margin/Rejected
# 2019-12-02, Close, 264.16
# 2019-12-03, Close, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-05, BUY CREATE, 265.58
# 2019-12-06, Order Canceled/Margin/Rejected
# 2019-12-06, Close, 270.71
# 2019-12-06, BUY CREATE, 270.71
# 2019-12-09, Order Canceled/Margin/Rejected
# 2019-12-09, Close, 266.92
# 2019-12-09, BUY CREATE, 266.92
# 2019-12-10, Order Canceled/Margin/Rejected
# 2019-12-10, Close, 268.48
# 2019-12-10, BUY CREATE, 268.48
# 2019-12-11, Order Canceled/Margin/Rejected
# 2019-12-11, Close, 270.77
# 2019-12-11, BUY CREATE, 270.77
# 2019-12-12, Order Canceled/Margin/Rejected
# 2019-12-12, Close, 271.46
# 2019-12-12, BUY CREATE, 271.46
# 2019-12-13, Order Canceled/Margin/Rejected
# 2019-12-13, Close, 275.15
# 2019-12-13, BUY CREATE, 275.15
# 2019-12-16, Order Canceled/Margin/Rejected
# 2019-12-16, Close, 279.86
# 2019-12-16, BUY CREATE, 279.86
# 2019-12-17, Order Canceled/Margin/Rejected
# 2019-12-17, Close, 280.41
# 2019-12-17, BUY CREATE, 280.41
# 2019-12-18, Order Canceled/Margin/Rejected
# 2019-12-18, Close, 279.74
# 2019-12-18, BUY CREATE, 279.74
# 2019-12-19, Order Canceled/Margin/Rejected
# 2019-12-19, Close, 280.02
# 2019-12-19, BUY CREATE, 280.02
# 2019-12-20, Order Canceled/Margin/Rejected
# 2019-12-20, Close, 279.44
# 2019-12-20, BUY CREATE, 279.44
# 2019-12-23, Order Canceled/Margin/Rejected
# 2019-12-23, Close, 284.00
# 2019-12-23, BUY CREATE, 284.00
# 2019-12-24, Order Canceled/Margin/Rejected
# 2019-12-24, Close, 284.27
# 2019-12-24, BUY CREATE, 284.27
# 2019-12-26, Order Canceled/Margin/Rejected
# 2019-12-26, Close, 289.91
# 2019-12-26, BUY CREATE, 289.91
# 2019-12-27, Order Canceled/Margin/Rejected
# 2019-12-27, Close, 289.80
# 2019-12-27, BUY CREATE, 289.80
# 2019-12-30, Order Canceled/Margin/Rejected
# 2019-12-30, Close, 291.52
# 2019-12-30, BUY CREATE, 291.52
# 2019-12-31, Order Canceled/Margin/Rejected
# 2019-12-31, Close, 293.65
# 2019-12-31, BUY CREATE, 293.65
# 2020-01-02, Order Canceled/Margin/Rejected
# 2020-01-02, Close, 300.35
# 2020-01-02, BUY CREATE, 300.35
# 2020-01-03, Order Canceled/Margin/Rejected
# 2020-01-03, Close, 297.43
# 2020-01-03, BUY CREATE, 297.43
# 2020-01-06, Order Canceled/Margin/Rejected
# 2020-01-06, Close, 299.80
# 2020-01-06, BUY CREATE, 299.80
# 2020-01-07, Order Canceled/Margin/Rejected
# 2020-01-07, Close, 298.39
# 2020-01-07, BUY CREATE, 298.39
# 2020-01-08, Order Canceled/Margin/Rejected
# 2020-01-08, Close, 303.19
# 2020-01-08, BUY CREATE, 303.19
# 2020-01-09, Order Canceled/Margin/Rejected
# 2020-01-09, Close, 309.63
# 2020-01-09, BUY CREATE, 309.63
# Final Portfolio Value: 928.80

# %% [markdown]
# Now, before skipping to the next section LOOK CAREFULLY to the first date which is shown in the log:
#
# 데이터는 2015-01-01부터 feed되었지만 01-23 부터 나온다. 왜냐하면 Simple Moving Average를 썼기 때문.
#
# The missing days are not missing. The platform has adapted to the new circumstances:
#
# - An indicator (SimpleMovingAverage) has been added to the Strategy.
#
# - This indicator needs X bars to produce an output: in the example: 15
#
# - 2000-01-24 is the day in which the 15th bar occurs (내 dataset과 다름.)
#
# The backtrader platform assumes that the Strategy has the indicator in place for a good reason, to use it in the decision making process. And it makes no sense to try to make decisions if the indicator is not yet ready and producing values.
#
# - next will be 1st called when all indicators have already reached the minimum needed period to produce a value
#
# - In the example there is a single indicator, but the strategy could have any number of them.
#
# After the execution the output is:
#
# * The same logic and data with PyAlgoTrade yields a slightly different result (slightly off). Looking at the entire printout reveals that some operations are not exactly the same. Being the culprit again the usual suspect: rounding. 반올림을 주의하라
#
# PyAlgoTrade does not round the datafeed values when applying the divided “adjusted close” to the data feed values.
#
# The Yahoo Data Feed provided by backtrader rounds the values down to 2 decimals after applying the adjusted close. Upon printing the values everything seems the same, but it’s obvious that sometimes that 5th place decimal plays a role.
#
# Rounding down to 2 decimals seems more realistic, because Market Exchanges do only allow a number of decimals per asset (being that 2 decimals usually for stocks)

# %% [markdown]
# ## Visual Inspection: Plotting
#
# `matplotlib` required
#
# A printout or log of the actual whereabouts of the system at each bar-instant is good but humans tend to be visual and therefore it seems right to offer a view of the same whereabouts as chart.
#
# Once again defaults for plotting are there to assist the platform user. Plotting is incredibly a 1 line operation:

# %%
# %%debug
plt.figure(num=0, figsize=(15, 15))
print(cerebro.plot())

cerebro.plot()[0][0]
# Out:
# <div id='3e898d5a-1b79-446e-849a-e094dd3a41e0'></div>
# [[<Figure size 1080x1080 with 4 Axes>]]

# %% [markdown]
# Being the location for sure after cerebro.run() has been called.
#
# In order to display the automatic plotting capabilities and a couple of easy customizations, the following will be done:
#
# - A 2nd MovingAverage (Exponential) will be added. The defaults will plot it (just like the 1st) with the data.
#
# - A 3rd MovingAverage (Weighted) will be added. Customized to plot in an own plot (even if not sensible)
#
# - A Stochastic (Slow) will be added. No change to the defaults.
#
# - A MACD will be added. No change to the defaults.
#
# - A RSI will be added. No change to the defaults.
#
# - A MovingAverage (Simple) will be applied to the RSI. No change to the defaults (it will be plotted with the RSI)
#
# - An AverageTrueRange will be added. Changed defaults to avoid it being plotted.
#
# The entire set of additions to the init method of the Strategy:
#
# * Even if indicators are not explicitly added to a member variable of the strategy (like self.sma = MovingAverageSimple…), they will autoregister with the strategy and will influence the minimum period for next and will be part of the plotting.
#
# In the example only RSI is added to a temporary variable rsi with the only intention to create a MovingAverageSmoothed on it.
#
# The example now:

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

        # Indicators for the plotting show
        bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
        bt.indicators.WeightedMovingAverage(self.datas[0], period=25,
                                            subplot=True)
        bt.indicators.StochasticSlow(self.datas[0])
        bt.indicators.MACDHisto(self.datas[0])
        rsi = bt.indicators.RSI(self.datas[0])
        bt.indicators.SmoothedMovingAverage(rsi, period=10)
        bt.indicators.ATR(self.datas[0], plot=False)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Plot the result
    plt.figure(num=0, figsize=(15, 15))
    cerebro.plot()[0][0]
#     plt.show()
    print(cerebro.plot()[0][0].number)
    print(type(cerebro.plot()[0][0]))
# Out:
# Starting Portfolio Value: 1000.00
# 2015-02-20, Close, 119.46
# 2015-02-20, BUY CREATE, 119.46
# 2015-02-23, Order Canceled/Margin/Rejected
# 2015-02-23, Close, 122.68
# 2015-02-23, BUY CREATE, 122.68
# 2015-02-24, Order Canceled/Margin/Rejected
# 2015-02-24, Close, 121.92
# 2015-02-24, BUY CREATE, 121.92
# 2015-02-25, Order Canceled/Margin/Rejected
# 2015-02-25, Close, 118.80
# 2015-02-25, BUY CREATE, 118.80
# 2015-02-26, Order Canceled/Margin/Rejected
# 2015-02-26, Close, 120.31
# 2015-02-26, BUY CREATE, 120.31
# 2015-02-27, Order Canceled/Margin/Rejected
# 2015-02-27, Close, 118.50
# 2015-02-27, BUY CREATE, 118.50
# 2015-03-02, Order Canceled/Margin/Rejected
# 2015-03-02, Close, 119.08
# 2015-03-02, BUY CREATE, 119.08
# 2015-03-03, Order Canceled/Margin/Rejected
# 2015-03-03, Close, 119.33
# 2015-03-03, BUY CREATE, 119.33
# 2015-03-04, Order Canceled/Margin/Rejected
# 2015-03-04, Close, 118.57
# 2015-03-05, Close, 116.61
# 2015-03-06, Close, 116.78
# 2015-03-09, Close, 117.28
# 2015-03-10, Close, 114.85
# 2015-03-11, Close, 112.76
# 2015-03-12, Close, 114.80
# 2015-03-13, Close, 114.00
# 2015-03-16, Close, 115.26
# 2015-03-17, Close, 117.19
# 2015-03-17, BUY CREATE, 117.19
# 2015-03-18, Order Canceled/Margin/Rejected
# 2015-03-18, Close, 118.51
# 2015-03-18, BUY CREATE, 118.51
# 2015-03-19, Order Canceled/Margin/Rejected
# 2015-03-19, Close, 117.61
# 2015-03-19, BUY CREATE, 117.61
# 2015-03-20, Order Canceled/Margin/Rejected
# 2015-03-20, Close, 116.14
# 2015-03-23, Close, 117.34
# 2015-03-23, BUY CREATE, 117.34
# 2015-03-24, Order Canceled/Margin/Rejected
# 2015-03-24, Close, 116.86
# 2015-03-24, BUY CREATE, 116.86
# 2015-03-25, Order Canceled/Margin/Rejected
# 2015-03-25, Close, 113.81
# 2015-03-26, Close, 114.60
# 2015-03-27, Close, 113.69
# 2015-03-30, Close, 116.57
# 2015-03-30, BUY CREATE, 116.57
# 2015-03-31, Order Canceled/Margin/Rejected
# 2015-03-31, Close, 114.78
# 2015-04-01, Close, 114.61
# 2015-04-02, Close, 115.60
# 2015-04-06, Close, 117.47
# 2015-04-06, BUY CREATE, 117.47
# 2015-04-07, Order Canceled/Margin/Rejected
# 2015-04-07, Close, 116.24
# 2015-04-07, BUY CREATE, 116.24
# 2015-04-08, Order Canceled/Margin/Rejected
# 2015-04-08, Close, 115.86
# 2015-04-09, Close, 116.74
# 2015-04-09, BUY CREATE, 116.74
# 2015-04-10, Order Canceled/Margin/Rejected
# 2015-04-10, Close, 117.24
# 2015-04-10, BUY CREATE, 117.24
# 2015-04-13, Order Canceled/Margin/Rejected
# 2015-04-13, Close, 117.01
# 2015-04-13, BUY CREATE, 117.01
# 2015-04-14, Order Canceled/Margin/Rejected
# 2015-04-14, Close, 116.50
# 2015-04-14, BUY CREATE, 116.50
# 2015-04-15, Order Canceled/Margin/Rejected
# 2015-04-15, Close, 116.95
# 2015-04-15, BUY CREATE, 116.95
# 2015-04-16, Order Canceled/Margin/Rejected
# 2015-04-16, Close, 116.38
# 2015-04-16, BUY CREATE, 116.38
# 2015-04-17, Order Canceled/Margin/Rejected
# 2015-04-17, Close, 115.07
# 2015-04-20, Close, 117.70
# 2015-04-20, BUY CREATE, 117.70
# 2015-04-21, Order Canceled/Margin/Rejected
# 2015-04-21, Close, 117.07
# 2015-04-21, BUY CREATE, 117.07
# 2015-04-22, Order Canceled/Margin/Rejected
# 2015-04-22, Close, 118.64
# 2015-04-22, BUY CREATE, 118.64
# 2015-04-23, Order Canceled/Margin/Rejected
# 2015-04-23, Close, 119.61
# 2015-04-23, BUY CREATE, 119.61
# 2015-04-24, Order Canceled/Margin/Rejected
# 2015-04-24, Close, 120.18
# 2015-04-24, BUY CREATE, 120.18
# 2015-04-27, Order Canceled/Margin/Rejected
# 2015-04-27, Close, 122.36
# 2015-04-27, BUY CREATE, 122.36
# 2015-04-28, Order Canceled/Margin/Rejected
# 2015-04-28, Close, 120.43
# 2015-04-28, BUY CREATE, 120.43
# 2015-04-29, Order Canceled/Margin/Rejected
# 2015-04-29, Close, 118.66
# 2015-04-29, BUY CREATE, 118.66
# 2015-04-30, Order Canceled/Margin/Rejected
# 2015-04-30, Close, 115.44
# 2015-05-01, Close, 118.95
# 2015-05-01, BUY CREATE, 118.95
# 2015-05-04, Order Canceled/Margin/Rejected
# 2015-05-04, Close, 118.72
# 2015-05-04, BUY CREATE, 118.72
# 2015-05-05, Order Canceled/Margin/Rejected
# 2015-05-05, Close, 116.04
# 2015-05-06, Close, 115.31
# 2015-05-07, Close, 116.03
# 2015-05-08, Close, 118.21
# 2015-05-11, Close, 117.01
# 2015-05-12, Close, 116.59
# 2015-05-13, Close, 116.72
# 2015-05-14, Close, 119.45
# 2015-05-14, BUY CREATE, 119.45
# 2015-05-15, Order Canceled/Margin/Rejected
# 2015-05-15, Close, 119.28
# 2015-05-15, BUY CREATE, 119.28
# 2015-05-18, Order Canceled/Margin/Rejected
# 2015-05-18, Close, 120.59
# 2015-05-18, BUY CREATE, 120.59
# 2015-05-19, Order Canceled/Margin/Rejected
# 2015-05-19, Close, 120.48
# 2015-05-19, BUY CREATE, 120.48
# 2015-05-20, Order Canceled/Margin/Rejected
# 2015-05-20, Close, 120.47
# 2015-05-20, BUY CREATE, 120.47
# 2015-05-21, Order Canceled/Margin/Rejected
# 2015-05-21, Close, 121.71
# 2015-05-21, BUY CREATE, 121.71
# 2015-05-22, Order Canceled/Margin/Rejected
# 2015-05-22, Close, 122.77
# 2015-05-22, BUY CREATE, 122.77
# 2015-05-26, Order Canceled/Margin/Rejected
# 2015-05-26, Close, 120.07
# 2015-05-26, BUY CREATE, 120.07
# 2015-05-27, Order Canceled/Margin/Rejected
# 2015-05-27, Close, 122.31
# 2015-05-27, BUY CREATE, 122.31
# 2015-05-28, Order Canceled/Margin/Rejected
# 2015-05-28, Close, 122.07
# 2015-05-28, BUY CREATE, 122.07
# 2015-05-29, Order Canceled/Margin/Rejected
# 2015-05-29, Close, 120.68
# 2015-05-29, BUY CREATE, 120.68
# 2015-06-01, Order Canceled/Margin/Rejected
# 2015-06-01, Close, 120.92
# 2015-06-01, BUY CREATE, 120.92
# 2015-06-02, Order Canceled/Margin/Rejected
# 2015-06-02, Close, 120.38
# 2015-06-02, BUY CREATE, 120.38
# 2015-06-03, Order Canceled/Margin/Rejected
# 2015-06-03, Close, 120.53
# 2015-06-04, Close, 119.83
# 2015-06-05, Close, 119.17
# 2015-06-08, Close, 118.38
# 2015-06-09, Close, 118.03
# 2015-06-10, Close, 119.38
# 2015-06-11, Close, 119.11
# 2015-06-12, Close, 117.80
# 2015-06-15, Close, 117.57
# 2015-06-16, Close, 118.20
# 2015-06-17, Close, 117.92
# 2015-06-18, Close, 118.45
# 2015-06-19, Close, 117.27
# 2015-06-22, Close, 118.20
# 2015-06-23, Close, 117.67
# 2015-06-24, Close, 118.67
# 2015-06-24, BUY CREATE, 118.67
# 2015-06-25, Order Canceled/Margin/Rejected
# 2015-06-25, Close, 118.10
# 2015-06-26, Close, 117.41
# 2015-06-29, Close, 115.35
# 2015-06-30, Close, 116.19
# 2015-07-01, Close, 117.27
# 2015-07-02, Close, 117.12
# 2015-07-06, Close, 116.71
# 2015-07-07, Close, 116.43
# 2015-07-08, Close, 113.54
# 2015-07-09, Close, 111.22
# 2015-07-10, Close, 114.19
# 2015-07-13, Close, 116.40
# 2015-07-13, BUY CREATE, 116.40
# 2015-07-14, Order Canceled/Margin/Rejected
# 2015-07-14, Close, 116.35
# 2015-07-14, BUY CREATE, 116.35
# 2015-07-15, Order Canceled/Margin/Rejected
# 2015-07-15, Close, 117.47
# 2015-07-15, BUY CREATE, 117.47
# 2015-07-16, Order Canceled/Margin/Rejected
# 2015-07-16, Close, 119.04
# 2015-07-16, BUY CREATE, 119.04
# 2015-07-17, Order Canceled/Margin/Rejected
# 2015-07-17, Close, 120.07
# 2015-07-17, BUY CREATE, 120.07
# 2015-07-20, Order Canceled/Margin/Rejected
# 2015-07-20, Close, 122.34
# 2015-07-20, BUY CREATE, 122.34
# 2015-07-21, Order Canceled/Margin/Rejected
# 2015-07-21, Close, 121.11
# 2015-07-21, BUY CREATE, 121.11
# 2015-07-22, Order Canceled/Margin/Rejected
# 2015-07-22, Close, 115.99
# 2015-07-23, Close, 115.94
# 2015-07-24, Close, 115.32
# 2015-07-27, Close, 113.72
# 2015-07-28, Close, 114.29
# 2015-07-29, Close, 113.93
# 2015-07-30, Close, 113.35
# 2015-07-31, Close, 112.36
# 2015-08-03, Close, 109.71
# 2015-08-04, Close, 106.19
# 2015-08-05, Close, 106.89
# 2015-08-06, Close, 107.13
# 2015-08-07, Close, 107.49
# 2015-08-10, Close, 111.40
# 2015-08-11, Close, 105.60
# 2015-08-12, Close, 107.23
# 2015-08-13, Close, 107.15
# 2015-08-14, Close, 107.90
# 2015-08-17, Close, 109.02
# 2015-08-18, Close, 108.40
# 2015-08-19, Close, 107.02
# 2015-08-20, Close, 104.82
# 2015-08-21, Close, 98.41
# 2015-08-24, Close, 95.95
# 2015-08-25, Close, 96.53
# 2015-08-26, Close, 102.07
# 2015-08-27, Close, 105.07
# 2015-08-27, BUY CREATE, 105.07
# 2015-08-28, Order Canceled/Margin/Rejected
# 2015-08-28, Close, 105.42
# 2015-08-28, BUY CREATE, 105.42
# 2015-08-31, Order Canceled/Margin/Rejected
# 2015-08-31, Close, 104.92
# 2015-08-31, BUY CREATE, 104.92
# 2015-09-01, Order Canceled/Margin/Rejected
# 2015-09-01, Close, 100.23
# 2015-09-02, Close, 104.53
# 2015-09-02, BUY CREATE, 104.53
# 2015-09-03, Order Canceled/Margin/Rejected
# 2015-09-03, Close, 102.70
# 2015-09-04, Close, 101.67
# 2015-09-08, Close, 104.50
# 2015-09-08, BUY CREATE, 104.50
# 2015-09-09, Order Canceled/Margin/Rejected
# 2015-09-09, Close, 102.49
# 2015-09-09, BUY CREATE, 102.49
# 2015-09-10, Order Canceled/Margin/Rejected
# 2015-09-10, Close, 104.75
# 2015-09-10, BUY CREATE, 104.75
# 2015-09-11, Order Canceled/Margin/Rejected
# 2015-09-11, Close, 106.27
# 2015-09-11, BUY CREATE, 106.27
# 2015-09-14, Order Canceled/Margin/Rejected
# 2015-09-14, Close, 107.29
# 2015-09-14, BUY CREATE, 107.29
# 2015-09-15, Order Canceled/Margin/Rejected
# 2015-09-15, Close, 108.20
# 2015-09-15, BUY CREATE, 108.20
# 2015-09-16, Order Canceled/Margin/Rejected
# 2015-09-16, Close, 108.32
# 2015-09-16, BUY CREATE, 108.32
# 2015-09-17, Order Canceled/Margin/Rejected
# 2015-09-17, Close, 106.00
# 2015-09-17, BUY CREATE, 106.00
# 2015-09-18, Order Canceled/Margin/Rejected
# 2015-09-18, Close, 105.56
# 2015-09-18, BUY CREATE, 105.56
# 2015-09-21, Order Canceled/Margin/Rejected
# 2015-09-21, Close, 107.20
# 2015-09-21, BUY CREATE, 107.20
# 2015-09-22, Order Canceled/Margin/Rejected
# 2015-09-22, Close, 105.52
# 2015-09-22, BUY CREATE, 105.52
# 2015-09-23, Order Canceled/Margin/Rejected
# 2015-09-23, Close, 106.37
# 2015-09-23, BUY CREATE, 106.37
# 2015-09-24, Order Canceled/Margin/Rejected
# 2015-09-24, Close, 107.01
# 2015-09-24, BUY CREATE, 107.01
# 2015-09-25, Order Canceled/Margin/Rejected
# 2015-09-25, Close, 106.74
# 2015-09-25, BUY CREATE, 106.74
# 2015-09-28, Order Canceled/Margin/Rejected
# 2015-09-28, Close, 104.62
# 2015-09-29, Close, 101.48
# 2015-09-30, Close, 102.63
# 2015-10-01, Close, 101.96
# 2015-10-02, Close, 102.71
# 2015-10-05, Close, 103.08
# 2015-10-06, Close, 103.57
# 2015-10-07, Close, 103.08
# 2015-10-08, Close, 101.89
# 2015-10-09, Close, 104.33
# 2015-10-09, BUY CREATE, 104.33
# 2015-10-12, Order Canceled/Margin/Rejected
# 2015-10-12, Close, 103.84
# 2015-10-13, Close, 104.02
# 2015-10-13, BUY CREATE, 104.02
# 2015-10-14, Order Canceled/Margin/Rejected
# 2015-10-14, Close, 102.55
# 2015-10-15, Close, 104.08
# 2015-10-15, BUY CREATE, 104.08
# 2015-10-16, Order Canceled/Margin/Rejected
# 2015-10-16, Close, 103.32
# 2015-10-16, BUY CREATE, 103.32
# 2015-10-19, Order Canceled/Margin/Rejected
# 2015-10-19, Close, 103.96
# 2015-10-19, BUY CREATE, 103.96
# 2015-10-20, Order Canceled/Margin/Rejected
# 2015-10-20, Close, 105.86
# 2015-10-20, BUY CREATE, 105.86
# 2015-10-21, Order Canceled/Margin/Rejected
# 2015-10-21, Close, 105.85
# 2015-10-21, BUY CREATE, 105.85
# 2015-10-22, Order Canceled/Margin/Rejected
# 2015-10-22, Close, 107.47
# 2015-10-22, BUY CREATE, 107.47
# 2015-10-23, Order Canceled/Margin/Rejected
# 2015-10-23, Close, 110.80
# 2015-10-23, BUY CREATE, 110.80
# 2015-10-26, Order Canceled/Margin/Rejected
# 2015-10-26, Close, 107.27
# 2015-10-26, BUY CREATE, 107.27
# 2015-10-27, Order Canceled/Margin/Rejected
# 2015-10-27, Close, 106.59
# 2015-10-27, BUY CREATE, 106.59
# 2015-10-28, Order Canceled/Margin/Rejected
# 2015-10-28, Close, 110.98
# 2015-10-28, BUY CREATE, 110.98
# 2015-10-29, Order Canceled/Margin/Rejected
# 2015-10-29, Close, 112.15
# 2015-10-29, BUY CREATE, 112.15
# 2015-10-30, Order Canceled/Margin/Rejected
# 2015-10-30, Close, 111.19
# 2015-10-30, BUY CREATE, 111.19
# 2015-11-02, Order Canceled/Margin/Rejected
# 2015-11-02, Close, 112.76
# 2015-11-02, BUY CREATE, 112.76
# 2015-11-03, Order Canceled/Margin/Rejected
# 2015-11-03, Close, 114.05
# 2015-11-03, BUY CREATE, 114.05
# 2015-11-04, Order Canceled/Margin/Rejected
# 2015-11-04, Close, 113.52
# 2015-11-04, BUY CREATE, 113.52
# 2015-11-05, Order Canceled/Margin/Rejected
# 2015-11-05, Close, 113.00
# 2015-11-05, BUY CREATE, 113.00
# 2015-11-06, Order Canceled/Margin/Rejected
# 2015-11-06, Close, 113.13
# 2015-11-06, BUY CREATE, 113.13
# 2015-11-09, Order Canceled/Margin/Rejected
# 2015-11-09, Close, 112.67
# 2015-11-09, BUY CREATE, 112.67
# 2015-11-10, Order Canceled/Margin/Rejected
# 2015-11-10, Close, 109.12
# 2015-11-11, Close, 108.50
# 2015-11-12, Close, 108.14
# 2015-11-13, Close, 104.98
# 2015-11-16, Close, 106.70
# 2015-11-17, Close, 106.24
# 2015-11-18, Close, 109.60
# 2015-11-19, Close, 111.00
# 2015-11-19, BUY CREATE, 111.00
# 2015-11-20, Order Canceled/Margin/Rejected
# 2015-11-20, Close, 111.48
# 2015-11-20, BUY CREATE, 111.48
# 2015-11-23, Order Canceled/Margin/Rejected
# 2015-11-23, Close, 110.03
# 2015-11-24, Close, 111.09
# 2015-11-24, BUY CREATE, 111.09
# 2015-11-25, Order Canceled/Margin/Rejected
# 2015-11-25, Close, 110.30
# 2015-11-25, BUY CREATE, 110.30
# 2015-11-27, Order Canceled/Margin/Rejected
# 2015-11-27, Close, 110.09
# 2015-11-27, BUY CREATE, 110.09
# 2015-11-30, Order Canceled/Margin/Rejected
# 2015-11-30, Close, 110.55
# 2015-11-30, BUY CREATE, 110.55
# 2015-12-01, Order Canceled/Margin/Rejected
# 2015-12-01, Close, 109.65
# 2015-12-01, BUY CREATE, 109.65
# 2015-12-02, Order Canceled/Margin/Rejected
# 2015-12-02, Close, 108.66
# 2015-12-03, Close, 107.65
# 2015-12-04, Close, 111.23
# 2015-12-04, BUY CREATE, 111.23
# 2015-12-07, Order Canceled/Margin/Rejected
# 2015-12-07, Close, 110.53
# 2015-12-07, BUY CREATE, 110.53
# 2015-12-08, Order Canceled/Margin/Rejected
# 2015-12-08, Close, 110.48
# 2015-12-08, BUY CREATE, 110.48
# 2015-12-09, Order Canceled/Margin/Rejected
# 2015-12-09, Close, 108.04
# 2015-12-10, Close, 108.56
# 2015-12-11, Close, 105.76
# 2015-12-14, Close, 105.11
# 2015-12-15, Close, 103.25
# 2015-12-16, Close, 104.04
# 2015-12-17, Close, 101.84
# 2015-12-18, Close, 99.08
# 2015-12-21, Close, 100.30
# 2015-12-22, Close, 100.20
# 2015-12-23, Close, 101.49
# 2015-12-24, Close, 100.95
# 2015-12-28, Close, 99.82
# 2015-12-29, Close, 101.61
# 2015-12-30, Close, 100.29
# 2015-12-31, Close, 98.36
# 2016-01-04, Close, 98.45
# 2016-01-05, Close, 95.98
# 2016-01-06, Close, 94.10
# 2016-01-07, Close, 90.13
# 2016-01-08, Close, 90.61
# 2016-01-11, Close, 92.07
# 2016-01-12, Close, 93.41
# 2016-01-13, Close, 91.01
# 2016-01-14, Close, 93.00
# 2016-01-15, Close, 90.77
# 2016-01-19, Close, 90.33
# 2016-01-20, Close, 90.45
# 2016-01-21, Close, 89.99
# 2016-01-22, Close, 94.77
# 2016-01-22, BUY CREATE, 94.77
# 2016-01-25, BUY EXECUTED, Price: 94.87, Cost: 948.70, Comm 0.00
# 2016-01-25, Close, 92.92
# 2016-01-26, Close, 93.44
# 2016-01-27, Close, 87.30
# 2016-01-27, SELL CREATE, 87.30
# 2016-01-28, SELL EXECUTED, Price: 87.64, Cost: 948.70, Comm 0.00
# 2016-01-28, OPERATION PROFIT, GROSS -72.30, NET -72.30
# 2016-01-28, Close, 87.92
# 2016-01-29, Close, 90.96
# 2016-02-01, Close, 90.11
# 2016-02-02, Close, 88.29
# 2016-02-03, Close, 90.04
# 2016-02-04, Close, 90.76
# 2016-02-04, BUY CREATE, 90.76
# 2016-02-05, BUY EXECUTED, Price: 90.68, Cost: 906.80, Comm 0.00
# 2016-02-05, Close, 88.34
# 2016-02-05, SELL CREATE, 88.34
# 2016-02-08, SELL EXECUTED, Price: 87.50, Cost: 906.80, Comm 0.00
# 2016-02-08, OPERATION PROFIT, GROSS -31.80, NET -31.80
# 2016-02-08, Close, 89.27
# 2016-02-09, Close, 89.25
# 2016-02-10, Close, 88.57
# 2016-02-11, Close, 88.04
# 2016-02-12, Close, 88.31
# 2016-02-16, Close, 90.80
# 2016-02-16, BUY CREATE, 90.80
# 2016-02-17, Order Canceled/Margin/Rejected
# 2016-02-17, Close, 92.19
# 2016-02-17, BUY CREATE, 92.19
# 2016-02-18, Order Canceled/Margin/Rejected
# 2016-02-18, Close, 90.44
# 2016-02-18, BUY CREATE, 90.44
# 2016-02-19, Order Canceled/Margin/Rejected
# 2016-02-19, Close, 90.23
# 2016-02-19, BUY CREATE, 90.23
# 2016-02-22, Order Canceled/Margin/Rejected
# 2016-02-22, Close, 91.02
# 2016-02-22, BUY CREATE, 91.02
# 2016-02-23, Order Canceled/Margin/Rejected
# 2016-02-23, Close, 88.97
# 2016-02-24, Close, 90.29
# 2016-02-24, BUY CREATE, 90.29
# 2016-02-25, Order Canceled/Margin/Rejected
# 2016-02-25, Close, 90.91
# 2016-02-25, BUY CREATE, 90.91
# 2016-02-26, Order Canceled/Margin/Rejected
# 2016-02-26, Close, 91.05
# 2016-02-26, BUY CREATE, 91.05
# 2016-02-29, Order Canceled/Margin/Rejected
# 2016-02-29, Close, 90.84
# 2016-02-29, BUY CREATE, 90.84
# 2016-03-01, Order Canceled/Margin/Rejected
# 2016-03-01, Close, 94.45
# 2016-03-01, BUY CREATE, 94.45
# 2016-03-02, Order Canceled/Margin/Rejected
# 2016-03-02, Close, 94.66
# 2016-03-02, BUY CREATE, 94.66
# 2016-03-03, Order Canceled/Margin/Rejected
# 2016-03-03, Close, 95.36
# 2016-03-03, BUY CREATE, 95.36
# 2016-03-04, Order Canceled/Margin/Rejected
# 2016-03-04, Close, 96.78
# 2016-03-04, BUY CREATE, 96.78
# 2016-03-07, Order Canceled/Margin/Rejected
# 2016-03-07, Close, 95.71
# 2016-03-07, BUY CREATE, 95.71
# 2016-03-08, Order Canceled/Margin/Rejected
# 2016-03-08, Close, 94.92
# 2016-03-08, BUY CREATE, 94.92
# 2016-03-09, Order Canceled/Margin/Rejected
# 2016-03-09, Close, 95.01
# 2016-03-09, BUY CREATE, 95.01
# 2016-03-10, Order Canceled/Margin/Rejected
# 2016-03-10, Close, 95.05
# 2016-03-10, BUY CREATE, 95.05
# 2016-03-11, Order Canceled/Margin/Rejected
# 2016-03-11, Close, 96.08
# 2016-03-11, BUY CREATE, 96.08
# 2016-03-14, Order Canceled/Margin/Rejected
# 2016-03-14, Close, 96.32
# 2016-03-14, BUY CREATE, 96.32
# 2016-03-15, Order Canceled/Margin/Rejected
# 2016-03-15, Close, 98.26
# 2016-03-15, BUY CREATE, 98.26
# 2016-03-16, Order Canceled/Margin/Rejected
# 2016-03-16, Close, 99.56
# 2016-03-16, BUY CREATE, 99.56
# 2016-03-17, Order Canceled/Margin/Rejected
# 2016-03-17, Close, 99.40
# 2016-03-17, BUY CREATE, 99.40
# 2016-03-18, Order Canceled/Margin/Rejected
# 2016-03-18, Close, 99.52
# 2016-03-18, BUY CREATE, 99.52
# 2016-03-21, Order Canceled/Margin/Rejected
# 2016-03-21, Close, 99.51
# 2016-03-21, BUY CREATE, 99.51
# 2016-03-22, Order Canceled/Margin/Rejected
# 2016-03-22, Close, 100.27
# 2016-03-22, BUY CREATE, 100.27
# 2016-03-23, Order Canceled/Margin/Rejected
# 2016-03-23, Close, 99.71
# 2016-03-23, BUY CREATE, 99.71
# 2016-03-24, Order Canceled/Margin/Rejected
# 2016-03-24, Close, 99.28
# 2016-03-24, BUY CREATE, 99.28
# 2016-03-28, Order Canceled/Margin/Rejected
# 2016-03-28, Close, 98.83
# 2016-03-28, BUY CREATE, 98.83
# 2016-03-29, Order Canceled/Margin/Rejected
# 2016-03-29, Close, 101.17
# 2016-03-29, BUY CREATE, 101.17
# 2016-03-30, Order Canceled/Margin/Rejected
# 2016-03-30, Close, 102.94
# 2016-03-30, BUY CREATE, 102.94
# 2016-03-31, Order Canceled/Margin/Rejected
# 2016-03-31, Close, 102.40
# 2016-03-31, BUY CREATE, 102.40
# 2016-04-01, Order Canceled/Margin/Rejected
# 2016-04-01, Close, 103.34
# 2016-04-01, BUY CREATE, 103.34
# 2016-04-04, Order Canceled/Margin/Rejected
# 2016-04-04, Close, 104.40
# 2016-04-04, BUY CREATE, 104.40
# 2016-04-05, Order Canceled/Margin/Rejected
# 2016-04-05, Close, 103.17
# 2016-04-05, BUY CREATE, 103.17
# 2016-04-06, Order Canceled/Margin/Rejected
# 2016-04-06, Close, 104.25
# 2016-04-06, BUY CREATE, 104.25
# 2016-04-07, Order Canceled/Margin/Rejected
# 2016-04-07, Close, 101.98
# 2016-04-07, BUY CREATE, 101.98
# 2016-04-08, Order Canceled/Margin/Rejected
# 2016-04-08, Close, 102.09
# 2016-04-08, BUY CREATE, 102.09
# 2016-04-11, Order Canceled/Margin/Rejected
# 2016-04-11, Close, 102.43
# 2016-04-11, BUY CREATE, 102.43
# 2016-04-12, Order Canceled/Margin/Rejected
# 2016-04-12, Close, 103.76
# 2016-04-12, BUY CREATE, 103.76
# 2016-04-13, Order Canceled/Margin/Rejected
# 2016-04-13, Close, 105.27
# 2016-04-13, BUY CREATE, 105.27
# 2016-04-14, Order Canceled/Margin/Rejected
# 2016-04-14, Close, 105.32
# 2016-04-14, BUY CREATE, 105.32
# 2016-04-15, Order Canceled/Margin/Rejected
# 2016-04-15, Close, 103.21
# 2016-04-15, BUY CREATE, 103.21
# 2016-04-18, Order Canceled/Margin/Rejected
# 2016-04-18, Close, 100.98
# 2016-04-19, Close, 100.45
# 2016-04-20, Close, 100.65
# 2016-04-21, Close, 99.56
# 2016-04-22, Close, 99.29
# 2016-04-25, Close, 98.73
# 2016-04-26, Close, 98.04
# 2016-04-27, Close, 91.91
# 2016-04-28, Close, 89.10
# 2016-04-29, Close, 88.07
# 2016-05-02, Close, 87.98
# 2016-05-03, Close, 89.43
# 2016-05-04, Close, 88.50
# 2016-05-05, Close, 88.14
# 2016-05-06, Close, 87.64
# 2016-05-09, Close, 87.71
# 2016-05-10, Close, 88.31
# 2016-05-11, Close, 87.45
# 2016-05-12, Close, 85.40
# 2016-05-13, Close, 85.57
# 2016-05-16, Close, 88.74
# 2016-05-17, Close, 88.37
# 2016-05-17, BUY CREATE, 88.37
# 2016-05-18, BUY EXECUTED, Price: 89.01, Cost: 890.10, Comm 0.00
# 2016-05-18, Close, 89.38
# 2016-05-19, Close, 89.04
# 2016-05-20, Close, 90.01
# 2016-05-23, Close, 91.15
# 2016-05-24, Close, 92.54
# 2016-05-25, Close, 94.17
# 2016-05-26, Close, 94.91
# 2016-05-27, Close, 94.86
# 2016-05-31, Close, 94.39
# 2016-06-01, Close, 93.07
# 2016-06-02, Close, 92.37
# 2016-06-03, Close, 92.56
# 2016-06-06, Close, 93.23
# 2016-06-07, Close, 93.61
# 2016-06-08, Close, 93.52
# 2016-06-09, Close, 94.20
# 2016-06-10, Close, 93.42
# 2016-06-13, Close, 92.01
# 2016-06-13, SELL CREATE, 92.01
# 2016-06-14, SELL EXECUTED, Price: 91.99, Cost: 890.10, Comm 0.00
# 2016-06-14, OPERATION PROFIT, GROSS 29.80, NET 29.80
# 2016-06-14, Close, 92.13
# 2016-06-15, Close, 91.82
# 2016-06-16, Close, 92.21
# 2016-06-17, Close, 90.11
# 2016-06-20, Close, 89.89
# 2016-06-21, Close, 90.66
# 2016-06-22, Close, 90.32
# 2016-06-23, Close, 90.84
# 2016-06-24, Close, 88.29
# 2016-06-27, Close, 87.00
# 2016-06-28, Close, 88.47
# 2016-06-29, Close, 89.23
# 2016-06-30, Close, 90.37
# 2016-07-01, Close, 90.64
# 2016-07-01, BUY CREATE, 90.64
# 2016-07-05, BUY EXECUTED, Price: 90.17, Cost: 901.70, Comm 0.00
# 2016-07-05, Close, 89.79
# 2016-07-05, SELL CREATE, 89.79
# 2016-07-06, SELL EXECUTED, Price: 89.42, Cost: 901.70, Comm 0.00
# 2016-07-06, OPERATION PROFIT, GROSS -7.50, NET -7.50
# 2016-07-06, Close, 90.30
# 2016-07-06, BUY CREATE, 90.30
# 2016-07-07, BUY EXECUTED, Price: 90.46, Cost: 904.60, Comm 0.00
# 2016-07-07, Close, 90.69
# 2016-07-08, Close, 91.39
# 2016-07-11, Close, 91.67
# 2016-07-12, Close, 92.09
# 2016-07-13, Close, 91.57
# 2016-07-14, Close, 93.38
# 2016-07-15, Close, 93.37
# 2016-07-18, Close, 94.37
# 2016-07-19, Close, 94.40
# 2016-07-20, Close, 94.49
# 2016-07-21, Close, 93.99
# 2016-07-22, Close, 93.26
# 2016-07-25, Close, 92.01
# 2016-07-25, SELL CREATE, 92.01
# 2016-07-26, SELL EXECUTED, Price: 91.52, Cost: 904.60, Comm 0.00
# 2016-07-26, OPERATION PROFIT, GROSS 10.60, NET 10.60
# 2016-07-26, Close, 91.38
# 2016-07-27, Close, 97.31
# 2016-07-27, BUY CREATE, 97.31
# 2016-07-28, Order Canceled/Margin/Rejected
# 2016-07-28, Close, 98.63
# 2016-07-28, BUY CREATE, 98.63
# 2016-07-29, Order Canceled/Margin/Rejected
# 2016-07-29, Close, 98.51
# 2016-07-29, BUY CREATE, 98.51
# 2016-08-01, Order Canceled/Margin/Rejected
# 2016-08-01, Close, 100.25
# 2016-08-01, BUY CREATE, 100.25
# 2016-08-02, Order Canceled/Margin/Rejected
# 2016-08-02, Close, 98.76
# 2016-08-02, BUY CREATE, 98.76
# 2016-08-03, Order Canceled/Margin/Rejected
# 2016-08-03, Close, 100.00
# 2016-08-03, BUY CREATE, 100.00
# 2016-08-04, Order Canceled/Margin/Rejected
# 2016-08-04, Close, 100.62
# 2016-08-04, BUY CREATE, 100.62
# 2016-08-05, Order Canceled/Margin/Rejected
# 2016-08-05, Close, 102.15
# 2016-08-05, BUY CREATE, 102.15
# 2016-08-08, Order Canceled/Margin/Rejected
# 2016-08-08, Close, 102.99
# 2016-08-08, BUY CREATE, 102.99
# 2016-08-09, Order Canceled/Margin/Rejected
# 2016-08-09, Close, 103.41
# 2016-08-09, BUY CREATE, 103.41
# 2016-08-10, Order Canceled/Margin/Rejected
# 2016-08-10, Close, 102.64
# 2016-08-10, BUY CREATE, 102.64
# 2016-08-11, Order Canceled/Margin/Rejected
# 2016-08-11, Close, 102.57
# 2016-08-11, BUY CREATE, 102.57
# 2016-08-12, Order Canceled/Margin/Rejected
# 2016-08-12, Close, 102.81
# 2016-08-12, BUY CREATE, 102.81
# 2016-08-15, Order Canceled/Margin/Rejected
# 2016-08-15, Close, 104.05
# 2016-08-15, BUY CREATE, 104.05
# 2016-08-16, Order Canceled/Margin/Rejected
# 2016-08-16, Close, 103.95
# 2016-08-16, BUY CREATE, 103.95
# 2016-08-17, Order Canceled/Margin/Rejected
# 2016-08-17, Close, 103.80
# 2016-08-17, BUY CREATE, 103.80
# 2016-08-18, Order Canceled/Margin/Rejected
# 2016-08-18, Close, 103.67
# 2016-08-18, BUY CREATE, 103.67
# 2016-08-19, Order Canceled/Margin/Rejected
# 2016-08-19, Close, 103.93
# 2016-08-19, BUY CREATE, 103.93
# 2016-08-22, Order Canceled/Margin/Rejected
# 2016-08-22, Close, 103.13
# 2016-08-22, BUY CREATE, 103.13
# 2016-08-23, Order Canceled/Margin/Rejected
# 2016-08-23, Close, 103.45
# 2016-08-23, BUY CREATE, 103.45
# 2016-08-24, Order Canceled/Margin/Rejected
# 2016-08-24, Close, 102.67
# 2016-08-25, Close, 102.23
# 2016-08-26, Close, 101.63
# 2016-08-29, Close, 101.52
# 2016-08-30, Close, 100.74
# 2016-08-31, Close, 100.84
# 2016-09-01, Close, 101.43
# 2016-09-02, Close, 102.38
# 2016-09-06, Close, 102.36
# 2016-09-07, Close, 102.98
# 2016-09-07, BUY CREATE, 102.98
# 2016-09-08, Order Canceled/Margin/Rejected
# 2016-09-08, Close, 100.28
# 2016-09-09, Close, 98.01
# 2016-09-12, Close, 100.21
# 2016-09-13, Close, 102.59
# 2016-09-13, BUY CREATE, 102.59
# 2016-09-14, Order Canceled/Margin/Rejected
# 2016-09-14, Close, 106.22
# 2016-09-14, BUY CREATE, 106.22
# 2016-09-15, Order Canceled/Margin/Rejected
# 2016-09-15, Close, 109.84
# 2016-09-15, BUY CREATE, 109.84
# 2016-09-16, Order Canceled/Margin/Rejected
# 2016-09-16, Close, 109.22
# 2016-09-16, BUY CREATE, 109.22
# 2016-09-19, Order Canceled/Margin/Rejected
# 2016-09-19, Close, 107.94
# 2016-09-19, BUY CREATE, 107.94
# 2016-09-20, Order Canceled/Margin/Rejected
# 2016-09-20, Close, 107.94
# 2016-09-20, BUY CREATE, 107.94
# 2016-09-21, Order Canceled/Margin/Rejected
# 2016-09-21, Close, 107.92
# 2016-09-21, BUY CREATE, 107.92
# 2016-09-22, Order Canceled/Margin/Rejected
# 2016-09-22, Close, 108.93
# 2016-09-22, BUY CREATE, 108.93
# 2016-09-23, Order Canceled/Margin/Rejected
# 2016-09-23, Close, 107.12
# 2016-09-23, BUY CREATE, 107.12
# 2016-09-26, Order Canceled/Margin/Rejected
# 2016-09-26, Close, 107.28
# 2016-09-26, BUY CREATE, 107.28
# 2016-09-27, Order Canceled/Margin/Rejected
# 2016-09-27, Close, 107.48
# 2016-09-27, BUY CREATE, 107.48
# 2016-09-28, Order Canceled/Margin/Rejected
# 2016-09-28, Close, 108.30
# 2016-09-28, BUY CREATE, 108.30
# 2016-09-29, Order Canceled/Margin/Rejected
# 2016-09-29, Close, 106.61
# 2016-09-29, BUY CREATE, 106.61
# 2016-09-30, Order Canceled/Margin/Rejected
# 2016-09-30, Close, 107.44
# 2016-09-30, BUY CREATE, 107.44
# 2016-10-03, Order Canceled/Margin/Rejected
# 2016-10-03, Close, 106.94
# 2016-10-04, Close, 107.39
# 2016-10-05, Close, 107.44
# 2016-10-06, Close, 108.24
# 2016-10-06, BUY CREATE, 108.24
# 2016-10-07, Order Canceled/Margin/Rejected
# 2016-10-07, Close, 108.40
# 2016-10-07, BUY CREATE, 108.40
# 2016-10-10, Order Canceled/Margin/Rejected
# 2016-10-10, Close, 110.29
# 2016-10-10, BUY CREATE, 110.29
# 2016-10-11, Order Canceled/Margin/Rejected
# 2016-10-11, Close, 110.53
# 2016-10-11, BUY CREATE, 110.53
# 2016-10-12, Order Canceled/Margin/Rejected
# 2016-10-12, Close, 111.52
# 2016-10-12, BUY CREATE, 111.52
# 2016-10-13, Order Canceled/Margin/Rejected
# 2016-10-13, Close, 111.18
# 2016-10-13, BUY CREATE, 111.18
# 2016-10-14, Order Canceled/Margin/Rejected
# 2016-10-14, Close, 111.79
# 2016-10-14, BUY CREATE, 111.79
# 2016-10-17, Order Canceled/Margin/Rejected
# 2016-10-17, Close, 111.72
# 2016-10-17, BUY CREATE, 111.72
# 2016-10-18, Order Canceled/Margin/Rejected
# 2016-10-18, Close, 111.64
# 2016-10-18, BUY CREATE, 111.64
# 2016-10-19, Order Canceled/Margin/Rejected
# 2016-10-19, Close, 111.31
# 2016-10-19, BUY CREATE, 111.31
# 2016-10-20, Order Canceled/Margin/Rejected
# 2016-10-20, Close, 111.25
# 2016-10-20, BUY CREATE, 111.25
# 2016-10-21, Order Canceled/Margin/Rejected
# 2016-10-21, Close, 110.81
# 2016-10-21, BUY CREATE, 110.81
# 2016-10-24, Order Canceled/Margin/Rejected
# 2016-10-24, Close, 111.81
# 2016-10-24, BUY CREATE, 111.81
# 2016-10-25, Order Canceled/Margin/Rejected
# 2016-10-25, Close, 112.38
# 2016-10-25, BUY CREATE, 112.38
# 2016-10-26, Order Canceled/Margin/Rejected
# 2016-10-26, Close, 109.85
# 2016-10-27, Close, 108.80
# 2016-10-28, Close, 108.08
# 2016-10-31, Close, 107.91
# 2016-11-01, Close, 105.96
# 2016-11-02, Close, 106.05
# 2016-11-03, Close, 104.92
# 2016-11-04, Close, 103.97
# 2016-11-07, Close, 105.47
# 2016-11-08, Close, 106.09
# 2016-11-09, Close, 105.92
# 2016-11-10, Close, 102.97
# 2016-11-11, Close, 103.58
# 2016-11-14, Close, 100.98
# 2016-11-15, Close, 102.32
# 2016-11-16, Close, 105.07
# 2016-11-17, Close, 105.03
# 2016-11-17, BUY CREATE, 105.03
# 2016-11-18, Order Canceled/Margin/Rejected
# 2016-11-18, Close, 105.14
# 2016-11-18, BUY CREATE, 105.14
# 2016-11-21, Order Canceled/Margin/Rejected
# 2016-11-21, Close, 106.73
# 2016-11-21, BUY CREATE, 106.73
# 2016-11-22, Order Canceled/Margin/Rejected
# 2016-11-22, Close, 106.80
# 2016-11-22, BUY CREATE, 106.80
# 2016-11-23, Order Canceled/Margin/Rejected
# 2016-11-23, Close, 106.25
# 2016-11-23, BUY CREATE, 106.25
# 2016-11-25, Order Canceled/Margin/Rejected
# 2016-11-25, Close, 106.79
# 2016-11-25, BUY CREATE, 106.79
# 2016-11-28, Order Canceled/Margin/Rejected
# 2016-11-28, Close, 106.58
# 2016-11-28, BUY CREATE, 106.58
# 2016-11-29, Order Canceled/Margin/Rejected
# 2016-11-29, Close, 106.47
# 2016-11-29, BUY CREATE, 106.47
# 2016-11-30, Order Canceled/Margin/Rejected
# 2016-11-30, Close, 105.58
# 2016-11-30, BUY CREATE, 105.58
# 2016-12-01, Order Canceled/Margin/Rejected
# 2016-12-01, Close, 104.59
# 2016-12-02, Close, 104.98
# 2016-12-05, Close, 104.23
# 2016-12-06, Close, 105.03
# 2016-12-07, Close, 106.06
# 2016-12-07, BUY CREATE, 106.06
# 2016-12-08, Order Canceled/Margin/Rejected
# 2016-12-08, Close, 107.10
# 2016-12-08, BUY CREATE, 107.10
# 2016-12-09, Order Canceled/Margin/Rejected
# 2016-12-09, Close, 108.85
# 2016-12-09, BUY CREATE, 108.85
# 2016-12-12, Order Canceled/Margin/Rejected
# 2016-12-12, Close, 108.23
# 2016-12-12, BUY CREATE, 108.23
# 2016-12-13, Order Canceled/Margin/Rejected
# 2016-12-13, Close, 110.04
# 2016-12-13, BUY CREATE, 110.04
# 2016-12-14, Order Canceled/Margin/Rejected
# 2016-12-14, Close, 110.04
# 2016-12-14, BUY CREATE, 110.04
# 2016-12-15, Order Canceled/Margin/Rejected
# 2016-12-15, Close, 110.64
# 2016-12-15, BUY CREATE, 110.64
# 2016-12-16, Order Canceled/Margin/Rejected
# 2016-12-16, Close, 110.78
# 2016-12-16, BUY CREATE, 110.78
# 2016-12-19, Order Canceled/Margin/Rejected
# 2016-12-19, Close, 111.42
# 2016-12-19, BUY CREATE, 111.42
# 2016-12-20, Order Canceled/Margin/Rejected
# 2016-12-20, Close, 111.72
# 2016-12-20, BUY CREATE, 111.72
# 2016-12-21, Order Canceled/Margin/Rejected
# 2016-12-21, Close, 111.82
# 2016-12-21, BUY CREATE, 111.82
# 2016-12-22, Order Canceled/Margin/Rejected
# 2016-12-22, Close, 111.09
# 2016-12-22, BUY CREATE, 111.09
# 2016-12-23, Order Canceled/Margin/Rejected
# 2016-12-23, Close, 111.31
# 2016-12-23, BUY CREATE, 111.31
# 2016-12-27, Order Canceled/Margin/Rejected
# 2016-12-27, Close, 112.01
# 2016-12-27, BUY CREATE, 112.01
# 2016-12-28, Order Canceled/Margin/Rejected
# 2016-12-28, Close, 111.54
# 2016-12-28, BUY CREATE, 111.54
# 2016-12-29, Order Canceled/Margin/Rejected
# 2016-12-29, Close, 111.51
# 2016-12-29, BUY CREATE, 111.51
# 2016-12-30, Order Canceled/Margin/Rejected
# 2016-12-30, Close, 110.64
# 2017-01-03, Close, 110.95
# 2017-01-03, BUY CREATE, 110.95
# 2017-01-04, Order Canceled/Margin/Rejected
# 2017-01-04, Close, 110.83
# 2017-01-05, Close, 111.39
# 2017-01-05, BUY CREATE, 111.39
# 2017-01-06, Order Canceled/Margin/Rejected
# 2017-01-06, Close, 112.64
# 2017-01-06, BUY CREATE, 112.64
# 2017-01-09, Order Canceled/Margin/Rejected
# 2017-01-09, Close, 113.67
# 2017-01-09, BUY CREATE, 113.67
# 2017-01-10, Order Canceled/Margin/Rejected
# 2017-01-10, Close, 113.78
# 2017-01-10, BUY CREATE, 113.78
# 2017-01-11, Order Canceled/Margin/Rejected
# 2017-01-11, Close, 114.39
# 2017-01-11, BUY CREATE, 114.39
# 2017-01-12, Order Canceled/Margin/Rejected
# 2017-01-12, Close, 113.92
# 2017-01-12, BUY CREATE, 113.92
# 2017-01-13, Order Canceled/Margin/Rejected
# 2017-01-13, Close, 113.71
# 2017-01-13, BUY CREATE, 113.71
# 2017-01-17, Order Canceled/Margin/Rejected
# 2017-01-17, Close, 114.63
# 2017-01-17, BUY CREATE, 114.63
# 2017-01-18, Order Canceled/Margin/Rejected
# 2017-01-18, Close, 114.62
# 2017-01-18, BUY CREATE, 114.62
# 2017-01-19, Order Canceled/Margin/Rejected
# 2017-01-19, Close, 114.42
# 2017-01-19, BUY CREATE, 114.42
# 2017-01-20, Order Canceled/Margin/Rejected
# 2017-01-20, Close, 114.63
# 2017-01-20, BUY CREATE, 114.63
# 2017-01-23, Order Canceled/Margin/Rejected
# 2017-01-23, Close, 114.71
# 2017-01-23, BUY CREATE, 114.71
# 2017-01-24, Order Canceled/Margin/Rejected
# 2017-01-24, Close, 114.60
# 2017-01-24, BUY CREATE, 114.60
# 2017-01-25, Order Canceled/Margin/Rejected
# 2017-01-25, Close, 116.43
# 2017-01-25, BUY CREATE, 116.43
# 2017-01-26, Order Canceled/Margin/Rejected
# 2017-01-26, Close, 116.48
# 2017-01-26, BUY CREATE, 116.48
# 2017-01-27, Order Canceled/Margin/Rejected
# 2017-01-27, Close, 116.49
# 2017-01-27, BUY CREATE, 116.49
# 2017-01-30, Order Canceled/Margin/Rejected
# 2017-01-30, Close, 116.19
# 2017-01-30, BUY CREATE, 116.19
# 2017-01-31, Order Canceled/Margin/Rejected
# 2017-01-31, Close, 115.92
# 2017-01-31, BUY CREATE, 115.92
# 2017-02-01, Order Canceled/Margin/Rejected
# 2017-02-01, Close, 122.99
# 2017-02-01, BUY CREATE, 122.99
# 2017-02-02, Order Canceled/Margin/Rejected
# 2017-02-02, Close, 122.78
# 2017-02-02, BUY CREATE, 122.78
# 2017-02-03, Order Canceled/Margin/Rejected
# 2017-02-03, Close, 123.31
# 2017-02-03, BUY CREATE, 123.31
# 2017-02-06, Order Canceled/Margin/Rejected
# 2017-02-06, Close, 124.46
# 2017-02-06, BUY CREATE, 124.46
# 2017-02-07, Order Canceled/Margin/Rejected
# 2017-02-07, Close, 125.65
# 2017-02-07, BUY CREATE, 125.65
# 2017-02-08, Order Canceled/Margin/Rejected
# 2017-02-08, Close, 126.13
# 2017-02-08, BUY CREATE, 126.13
# 2017-02-09, Order Canceled/Margin/Rejected
# 2017-02-09, Close, 127.04
# 2017-02-09, BUY CREATE, 127.04
# 2017-02-10, Order Canceled/Margin/Rejected
# 2017-02-10, Close, 126.76
# 2017-02-10, BUY CREATE, 126.76
# 2017-02-13, Order Canceled/Margin/Rejected
# 2017-02-13, Close, 127.88
# 2017-02-13, BUY CREATE, 127.88
# 2017-02-14, Order Canceled/Margin/Rejected
# 2017-02-14, Close, 129.54
# 2017-02-14, BUY CREATE, 129.54
# 2017-02-15, Order Canceled/Margin/Rejected
# 2017-02-15, Close, 130.01
# 2017-02-15, BUY CREATE, 130.01
# 2017-02-16, Order Canceled/Margin/Rejected
# 2017-02-16, Close, 129.86
# 2017-02-16, BUY CREATE, 129.86
# 2017-02-17, Order Canceled/Margin/Rejected
# 2017-02-17, Close, 130.21
# 2017-02-17, BUY CREATE, 130.21
# 2017-02-21, Order Canceled/Margin/Rejected
# 2017-02-21, Close, 131.15
# 2017-02-21, BUY CREATE, 131.15
# 2017-02-22, Order Canceled/Margin/Rejected
# 2017-02-22, Close, 131.54
# 2017-02-22, BUY CREATE, 131.54
# 2017-02-23, Order Canceled/Margin/Rejected
# 2017-02-23, Close, 130.99
# 2017-02-23, BUY CREATE, 130.99
# 2017-02-24, Order Canceled/Margin/Rejected
# 2017-02-24, Close, 131.11
# 2017-02-24, BUY CREATE, 131.11
# 2017-02-27, Order Canceled/Margin/Rejected
# 2017-02-27, Close, 131.37
# 2017-02-27, BUY CREATE, 131.37
# 2017-02-28, Order Canceled/Margin/Rejected
# 2017-02-28, Close, 131.43
# 2017-02-28, BUY CREATE, 131.43
# 2017-03-01, Order Canceled/Margin/Rejected
# 2017-03-01, Close, 134.12
# 2017-03-01, BUY CREATE, 134.12
# 2017-03-02, Order Canceled/Margin/Rejected
# 2017-03-02, Close, 133.32
# 2017-03-02, BUY CREATE, 133.32
# 2017-03-03, Order Canceled/Margin/Rejected
# 2017-03-03, Close, 134.11
# 2017-03-03, BUY CREATE, 134.11
# 2017-03-06, Order Canceled/Margin/Rejected
# 2017-03-06, Close, 133.68
# 2017-03-06, BUY CREATE, 133.68
# 2017-03-07, Order Canceled/Margin/Rejected
# 2017-03-07, Close, 133.86
# 2017-03-07, BUY CREATE, 133.86
# 2017-03-08, Order Canceled/Margin/Rejected
# 2017-03-08, Close, 133.36
# 2017-03-08, BUY CREATE, 133.36
# 2017-03-09, Order Canceled/Margin/Rejected
# 2017-03-09, Close, 133.05
# 2017-03-09, BUY CREATE, 133.05
# 2017-03-10, Order Canceled/Margin/Rejected
# 2017-03-10, Close, 133.49
# 2017-03-10, BUY CREATE, 133.49
# 2017-03-13, Order Canceled/Margin/Rejected
# 2017-03-13, Close, 133.55
# 2017-03-13, BUY CREATE, 133.55
# 2017-03-14, Order Canceled/Margin/Rejected
# 2017-03-14, Close, 133.35
# 2017-03-14, BUY CREATE, 133.35
# 2017-03-15, Order Canceled/Margin/Rejected
# 2017-03-15, Close, 134.76
# 2017-03-15, BUY CREATE, 134.76
# 2017-03-16, Order Canceled/Margin/Rejected
# 2017-03-16, Close, 134.98
# 2017-03-16, BUY CREATE, 134.98
# 2017-03-17, Order Canceled/Margin/Rejected
# 2017-03-17, Close, 134.31
# 2017-03-17, BUY CREATE, 134.31
# 2017-03-20, Order Canceled/Margin/Rejected
# 2017-03-20, Close, 135.72
# 2017-03-20, BUY CREATE, 135.72
# 2017-03-21, Order Canceled/Margin/Rejected
# 2017-03-21, Close, 134.16
# 2017-03-21, BUY CREATE, 134.16
# 2017-03-22, Order Canceled/Margin/Rejected
# 2017-03-22, Close, 135.68
# 2017-03-22, BUY CREATE, 135.68
# 2017-03-23, Order Canceled/Margin/Rejected
# 2017-03-23, Close, 135.20
# 2017-03-23, BUY CREATE, 135.20
# 2017-03-24, Order Canceled/Margin/Rejected
# 2017-03-24, Close, 134.93
# 2017-03-24, BUY CREATE, 134.93
# 2017-03-27, Order Canceled/Margin/Rejected
# 2017-03-27, Close, 135.16
# 2017-03-27, BUY CREATE, 135.16
# 2017-03-28, Order Canceled/Margin/Rejected
# 2017-03-28, Close, 137.96
# 2017-03-28, BUY CREATE, 137.96
# 2017-03-29, Order Canceled/Margin/Rejected
# 2017-03-29, Close, 138.27
# 2017-03-29, BUY CREATE, 138.27
# 2017-03-30, Order Canceled/Margin/Rejected
# 2017-03-30, Close, 138.09
# 2017-03-30, BUY CREATE, 138.09
# 2017-03-31, Order Canceled/Margin/Rejected
# 2017-03-31, Close, 137.83
# 2017-03-31, BUY CREATE, 137.83
# 2017-04-03, Order Canceled/Margin/Rejected
# 2017-04-03, Close, 137.87
# 2017-04-03, BUY CREATE, 137.87
# 2017-04-04, Order Canceled/Margin/Rejected
# 2017-04-04, Close, 138.89
# 2017-04-04, BUY CREATE, 138.89
# 2017-04-05, Order Canceled/Margin/Rejected
# 2017-04-05, Close, 138.17
# 2017-04-05, BUY CREATE, 138.17
# 2017-04-06, Order Canceled/Margin/Rejected
# 2017-04-06, Close, 137.83
# 2017-04-06, BUY CREATE, 137.83
# 2017-04-07, Order Canceled/Margin/Rejected
# 2017-04-07, Close, 137.52
# 2017-04-07, BUY CREATE, 137.52
# 2017-04-10, Order Canceled/Margin/Rejected
# 2017-04-10, Close, 137.36
# 2017-04-10, BUY CREATE, 137.36
# 2017-04-11, Order Canceled/Margin/Rejected
# 2017-04-11, Close, 135.88
# 2017-04-12, Close, 136.04
# 2017-04-13, Close, 135.32
# 2017-04-17, Close, 136.07
# 2017-04-18, Close, 135.47
# 2017-04-19, Close, 134.97
# 2017-04-20, Close, 136.66
# 2017-04-21, Close, 136.49
# 2017-04-24, Close, 137.81
# 2017-04-24, BUY CREATE, 137.81
# 2017-04-25, Order Canceled/Margin/Rejected
# 2017-04-25, Close, 138.66
# 2017-04-25, BUY CREATE, 138.66
# 2017-04-26, Order Canceled/Margin/Rejected
# 2017-04-26, Close, 137.85
# 2017-04-26, BUY CREATE, 137.85
# 2017-04-27, Order Canceled/Margin/Rejected
# 2017-04-27, Close, 137.95
# 2017-04-27, BUY CREATE, 137.95
# 2017-04-28, Order Canceled/Margin/Rejected
# 2017-04-28, Close, 137.82
# 2017-04-28, BUY CREATE, 137.82
# 2017-05-01, Order Canceled/Margin/Rejected
# 2017-05-01, Close, 140.63
# 2017-05-01, BUY CREATE, 140.63
# 2017-05-02, Order Canceled/Margin/Rejected
# 2017-05-02, Close, 141.52
# 2017-05-02, BUY CREATE, 141.52
# 2017-05-03, Order Canceled/Margin/Rejected
# 2017-05-03, Close, 141.09
# 2017-05-03, BUY CREATE, 141.09
# 2017-05-04, Order Canceled/Margin/Rejected
# 2017-05-04, Close, 140.58
# 2017-05-04, BUY CREATE, 140.58
# 2017-05-05, Order Canceled/Margin/Rejected
# 2017-05-05, Close, 142.91
# 2017-05-05, BUY CREATE, 142.91
# 2017-05-08, Order Canceled/Margin/Rejected
# 2017-05-08, Close, 146.80
# 2017-05-08, BUY CREATE, 146.80
# 2017-05-09, Order Canceled/Margin/Rejected
# 2017-05-09, Close, 147.74
# 2017-05-09, BUY CREATE, 147.74
# 2017-05-10, Order Canceled/Margin/Rejected
# 2017-05-10, Close, 147.04
# 2017-05-10, BUY CREATE, 147.04
# 2017-05-11, Order Canceled/Margin/Rejected
# 2017-05-11, Close, 148.31
# 2017-05-11, BUY CREATE, 148.31
# 2017-05-12, Order Canceled/Margin/Rejected
# 2017-05-12, Close, 150.38
# 2017-05-12, BUY CREATE, 150.38
# 2017-05-15, Order Canceled/Margin/Rejected
# 2017-05-15, Close, 150.00
# 2017-05-15, BUY CREATE, 150.00
# 2017-05-16, Order Canceled/Margin/Rejected
# 2017-05-16, Close, 149.77
# 2017-05-16, BUY CREATE, 149.77
# 2017-05-17, Order Canceled/Margin/Rejected
# 2017-05-17, Close, 144.75
# 2017-05-17, BUY CREATE, 144.75
# 2017-05-18, Order Canceled/Margin/Rejected
# 2017-05-18, Close, 146.95
# 2017-05-18, BUY CREATE, 146.95
# 2017-05-19, Order Canceled/Margin/Rejected
# 2017-05-19, Close, 147.45
# 2017-05-19, BUY CREATE, 147.45
# 2017-05-22, Order Canceled/Margin/Rejected
# 2017-05-22, Close, 148.35
# 2017-05-22, BUY CREATE, 148.35
# 2017-05-23, Order Canceled/Margin/Rejected
# 2017-05-23, Close, 148.17
# 2017-05-23, BUY CREATE, 148.17
# 2017-05-24, Order Canceled/Margin/Rejected
# 2017-05-24, Close, 147.72
# 2017-05-24, BUY CREATE, 147.72
# 2017-05-25, Order Canceled/Margin/Rejected
# 2017-05-25, Close, 148.23
# 2017-05-25, BUY CREATE, 148.23
# 2017-05-26, Order Canceled/Margin/Rejected
# 2017-05-26, Close, 147.98
# 2017-05-26, BUY CREATE, 147.98
# 2017-05-30, Order Canceled/Margin/Rejected
# 2017-05-30, Close, 148.04
# 2017-05-31, Close, 147.16
# 2017-06-01, Close, 147.57
# 2017-06-02, Close, 149.76
# 2017-06-02, BUY CREATE, 149.76
# 2017-06-05, Order Canceled/Margin/Rejected
# 2017-06-05, Close, 148.29
# 2017-06-05, BUY CREATE, 148.29
# 2017-06-06, Order Canceled/Margin/Rejected
# 2017-06-06, Close, 148.79
# 2017-06-06, BUY CREATE, 148.79
# 2017-06-07, Order Canceled/Margin/Rejected
# 2017-06-07, Close, 149.68
# 2017-06-07, BUY CREATE, 149.68
# 2017-06-08, Order Canceled/Margin/Rejected
# 2017-06-08, Close, 149.31
# 2017-06-08, BUY CREATE, 149.31
# 2017-06-09, Order Canceled/Margin/Rejected
# 2017-06-09, Close, 143.52
# 2017-06-12, Close, 140.09
# 2017-06-13, Close, 141.22
# 2017-06-14, Close, 139.84
# 2017-06-15, Close, 139.00
# 2017-06-16, Close, 137.06
# 2017-06-19, Close, 140.98
# 2017-06-20, Close, 139.70
# 2017-06-21, Close, 140.53
# 2017-06-22, Close, 140.29
# 2017-06-23, Close, 140.92
# 2017-06-26, Close, 140.48
# 2017-06-27, Close, 138.46
# 2017-06-28, Close, 140.49
# 2017-06-29, Close, 138.42
# 2017-06-30, Close, 138.74
# 2017-07-03, Close, 138.24
# 2017-07-05, Close, 138.81
# 2017-07-06, Close, 137.50
# 2017-07-07, Close, 138.90
# 2017-07-10, Close, 139.75
# 2017-07-10, BUY CREATE, 139.75
# 2017-07-11, Order Canceled/Margin/Rejected
# 2017-07-11, Close, 140.20
# 2017-07-11, BUY CREATE, 140.20
# 2017-07-12, Order Canceled/Margin/Rejected
# 2017-07-12, Close, 140.40
# 2017-07-12, BUY CREATE, 140.40
# 2017-07-13, Order Canceled/Margin/Rejected
# 2017-07-13, Close, 142.36
# 2017-07-13, BUY CREATE, 142.36
# 2017-07-14, Order Canceled/Margin/Rejected
# 2017-07-14, Close, 143.58
# 2017-07-14, BUY CREATE, 143.58
# 2017-07-17, Order Canceled/Margin/Rejected
# 2017-07-17, Close, 144.08
# 2017-07-17, BUY CREATE, 144.08
# 2017-07-18, Order Canceled/Margin/Rejected
# 2017-07-18, Close, 144.58
# 2017-07-18, BUY CREATE, 144.58
# 2017-07-19, Order Canceled/Margin/Rejected
# 2017-07-19, Close, 145.49
# 2017-07-19, BUY CREATE, 145.49
# 2017-07-20, Order Canceled/Margin/Rejected
# 2017-07-20, Close, 144.83
# 2017-07-20, BUY CREATE, 144.83
# 2017-07-21, Order Canceled/Margin/Rejected
# 2017-07-21, Close, 144.76
# 2017-07-21, BUY CREATE, 144.76
# 2017-07-24, Order Canceled/Margin/Rejected
# 2017-07-24, Close, 146.52
# 2017-07-24, BUY CREATE, 146.52
# 2017-07-25, Order Canceled/Margin/Rejected
# 2017-07-25, Close, 147.14
# 2017-07-25, BUY CREATE, 147.14
# 2017-07-26, Order Canceled/Margin/Rejected
# 2017-07-26, Close, 147.84
# 2017-07-26, BUY CREATE, 147.84
# 2017-07-27, Order Canceled/Margin/Rejected
# 2017-07-27, Close, 145.04
# 2017-07-27, BUY CREATE, 145.04
# 2017-07-28, Order Canceled/Margin/Rejected
# 2017-07-28, Close, 144.02
# 2017-07-31, Close, 143.28
# 2017-08-01, Close, 144.55
# 2017-08-02, Close, 151.38
# 2017-08-02, BUY CREATE, 151.38
# 2017-08-03, Order Canceled/Margin/Rejected
# 2017-08-03, Close, 149.87
# 2017-08-03, BUY CREATE, 149.87
# 2017-08-04, Order Canceled/Margin/Rejected
# 2017-08-04, Close, 150.66
# 2017-08-04, BUY CREATE, 150.66
# 2017-08-07, Order Canceled/Margin/Rejected
# 2017-08-07, Close, 152.99
# 2017-08-07, BUY CREATE, 152.99
# 2017-08-08, Order Canceled/Margin/Rejected
# 2017-08-08, Close, 154.22
# 2017-08-08, BUY CREATE, 154.22
# 2017-08-09, Order Canceled/Margin/Rejected
# 2017-08-09, Close, 155.16
# 2017-08-09, BUY CREATE, 155.16
# 2017-08-10, Order Canceled/Margin/Rejected
# 2017-08-10, Close, 150.22
# 2017-08-10, BUY CREATE, 150.22
# 2017-08-11, Order Canceled/Margin/Rejected
# 2017-08-11, Close, 152.31
# 2017-08-11, BUY CREATE, 152.31
# 2017-08-14, Order Canceled/Margin/Rejected
# 2017-08-14, Close, 154.60
# 2017-08-14, BUY CREATE, 154.60
# 2017-08-15, Order Canceled/Margin/Rejected
# 2017-08-15, Close, 156.29
# 2017-08-15, BUY CREATE, 156.29
# 2017-08-16, Order Canceled/Margin/Rejected
# 2017-08-16, Close, 155.66
# 2017-08-16, BUY CREATE, 155.66
# 2017-08-17, Order Canceled/Margin/Rejected
# 2017-08-17, Close, 152.67
# 2017-08-17, BUY CREATE, 152.67
# 2017-08-18, Order Canceled/Margin/Rejected
# 2017-08-18, Close, 152.33
# 2017-08-18, BUY CREATE, 152.33
# 2017-08-21, Order Canceled/Margin/Rejected
# 2017-08-21, Close, 152.05
# 2017-08-22, Close, 154.53
# 2017-08-22, BUY CREATE, 154.53
# 2017-08-23, Order Canceled/Margin/Rejected
# 2017-08-23, Close, 154.72
# 2017-08-23, BUY CREATE, 154.72
# 2017-08-24, Order Canceled/Margin/Rejected
# 2017-08-24, Close, 154.04
# 2017-08-24, BUY CREATE, 154.04
# 2017-08-25, Order Canceled/Margin/Rejected
# 2017-08-25, Close, 154.61
# 2017-08-25, BUY CREATE, 154.61
# 2017-08-28, Order Canceled/Margin/Rejected
# 2017-08-28, Close, 156.17
# 2017-08-28, BUY CREATE, 156.17
# 2017-08-29, Order Canceled/Margin/Rejected
# 2017-08-29, Close, 157.56
# 2017-08-29, BUY CREATE, 157.56
# 2017-08-30, Order Canceled/Margin/Rejected
# 2017-08-30, Close, 157.98
# 2017-08-30, BUY CREATE, 157.98
# 2017-08-31, Order Canceled/Margin/Rejected
# 2017-08-31, Close, 158.61
# 2017-08-31, BUY CREATE, 158.61
# 2017-09-01, Order Canceled/Margin/Rejected
# 2017-09-01, Close, 158.66
# 2017-09-01, BUY CREATE, 158.66
# 2017-09-05, Order Canceled/Margin/Rejected
# 2017-09-05, Close, 156.76
# 2017-09-05, BUY CREATE, 156.76
# 2017-09-06, Order Canceled/Margin/Rejected
# 2017-09-06, Close, 156.59
# 2017-09-06, BUY CREATE, 156.59
# 2017-09-07, Order Canceled/Margin/Rejected
# 2017-09-07, Close, 155.96
# 2017-09-07, BUY CREATE, 155.96
# 2017-09-08, Order Canceled/Margin/Rejected
# 2017-09-08, Close, 153.42
# 2017-09-11, Close, 156.19
# 2017-09-11, BUY CREATE, 156.19
# 2017-09-12, Order Canceled/Margin/Rejected
# 2017-09-12, Close, 155.58
# 2017-09-13, Close, 154.41
# 2017-09-14, Close, 153.08
# 2017-09-15, Close, 154.63
# 2017-09-18, Close, 153.46
# 2017-09-19, Close, 153.52
# 2017-09-20, Close, 150.94
# 2017-09-21, Close, 148.35
# 2017-09-22, Close, 146.90
# 2017-09-25, Close, 145.60
# 2017-09-26, Close, 148.11
# 2017-09-27, Close, 149.16
# 2017-09-28, Close, 148.24
# 2017-09-29, Close, 149.06
# 2017-10-02, Close, 148.76
# 2017-10-03, Close, 149.41
# 2017-10-04, Close, 148.44
# 2017-10-05, Close, 150.29
# 2017-10-05, BUY CREATE, 150.29
# 2017-10-06, Order Canceled/Margin/Rejected
# 2017-10-06, Close, 150.20
# 2017-10-06, BUY CREATE, 150.20
# 2017-10-09, Order Canceled/Margin/Rejected
# 2017-10-09, Close, 150.72
# 2017-10-09, BUY CREATE, 150.72
# 2017-10-10, Order Canceled/Margin/Rejected
# 2017-10-10, Close, 150.78
# 2017-10-10, BUY CREATE, 150.78
# 2017-10-11, Order Canceled/Margin/Rejected
# 2017-10-11, Close, 151.41
# 2017-10-11, BUY CREATE, 151.41
# 2017-10-12, Order Canceled/Margin/Rejected
# 2017-10-12, Close, 150.88
# 2017-10-12, BUY CREATE, 150.88
# 2017-10-13, Order Canceled/Margin/Rejected
# 2017-10-13, Close, 151.83
# 2017-10-13, BUY CREATE, 151.83
# 2017-10-16, Order Canceled/Margin/Rejected
# 2017-10-16, Close, 154.63
# 2017-10-16, BUY CREATE, 154.63
# 2017-10-17, Order Canceled/Margin/Rejected
# 2017-10-17, Close, 155.20
# 2017-10-17, BUY CREATE, 155.20
# 2017-10-18, Order Canceled/Margin/Rejected
# 2017-10-18, Close, 154.51
# 2017-10-18, BUY CREATE, 154.51
# 2017-10-19, Order Canceled/Margin/Rejected
# 2017-10-19, Close, 150.86
# 2017-10-20, Close, 151.12
# 2017-10-23, Close, 151.04
# 2017-10-24, Close, 151.94
# 2017-10-24, BUY CREATE, 151.94
# 2017-10-25, Order Canceled/Margin/Rejected
# 2017-10-25, Close, 151.27
# 2017-10-26, Close, 152.24
# 2017-10-26, BUY CREATE, 152.24
# 2017-10-27, Order Canceled/Margin/Rejected
# 2017-10-27, Close, 157.69
# 2017-10-27, BUY CREATE, 157.69
# 2017-10-30, Order Canceled/Margin/Rejected
# 2017-10-30, Close, 161.24
# 2017-10-30, BUY CREATE, 161.24
# 2017-10-31, Order Canceled/Margin/Rejected
# 2017-10-31, Close, 163.49
# 2017-10-31, BUY CREATE, 163.49
# 2017-11-01, Order Canceled/Margin/Rejected
# 2017-11-01, Close, 161.41
# 2017-11-01, BUY CREATE, 161.41
# 2017-11-02, Order Canceled/Margin/Rejected
# 2017-11-02, Close, 162.59
# 2017-11-02, BUY CREATE, 162.59
# 2017-11-03, Order Canceled/Margin/Rejected
# 2017-11-03, Close, 166.83
# 2017-11-03, BUY CREATE, 166.83
# 2017-11-06, Order Canceled/Margin/Rejected
# 2017-11-06, Close, 168.53
# 2017-11-06, BUY CREATE, 168.53
# 2017-11-07, Order Canceled/Margin/Rejected
# 2017-11-07, Close, 169.07
# 2017-11-07, BUY CREATE, 169.07
# 2017-11-08, Order Canceled/Margin/Rejected
# 2017-11-08, Close, 170.45
# 2017-11-08, BUY CREATE, 170.45
# 2017-11-09, Order Canceled/Margin/Rejected
# 2017-11-09, Close, 170.10
# 2017-11-09, BUY CREATE, 170.10
# 2017-11-10, Order Canceled/Margin/Rejected
# 2017-11-10, Close, 169.54
# 2017-11-10, BUY CREATE, 169.54
# 2017-11-13, Order Canceled/Margin/Rejected
# 2017-11-13, Close, 168.86
# 2017-11-13, BUY CREATE, 168.86
# 2017-11-14, Order Canceled/Margin/Rejected
# 2017-11-14, Close, 166.31
# 2017-11-14, BUY CREATE, 166.31
# 2017-11-15, Order Canceled/Margin/Rejected
# 2017-11-15, Close, 164.11
# 2017-11-16, Close, 166.07
# 2017-11-16, BUY CREATE, 166.07
# 2017-11-17, Order Canceled/Margin/Rejected
# 2017-11-17, Close, 165.15
# 2017-11-20, Close, 164.99
# 2017-11-21, Close, 168.05
# 2017-11-21, BUY CREATE, 168.05
# 2017-11-22, Order Canceled/Margin/Rejected
# 2017-11-22, Close, 169.82
# 2017-11-22, BUY CREATE, 169.82
# 2017-11-24, Order Canceled/Margin/Rejected
# 2017-11-24, Close, 169.83
# 2017-11-24, BUY CREATE, 169.83
# 2017-11-27, Order Canceled/Margin/Rejected
# 2017-11-27, Close, 168.98
# 2017-11-27, BUY CREATE, 168.98
# 2017-11-28, Order Canceled/Margin/Rejected
# 2017-11-28, Close, 167.99
# 2017-11-28, BUY CREATE, 167.99
# 2017-11-29, Order Canceled/Margin/Rejected
# 2017-11-29, Close, 164.50
# 2017-11-30, Close, 166.80
# 2017-12-01, Close, 166.03
# 2017-12-04, Close, 164.81
# 2017-12-05, Close, 164.66
# 2017-12-06, Close, 164.05
# 2017-12-07, Close, 164.35
# 2017-12-08, Close, 164.39
# ...
# 2019-04-11, Order Canceled/Margin/Rejected
# 2019-04-11, Close, 196.85
# 2019-04-11, BUY CREATE, 196.85
# 2019-04-12, Order Canceled/Margin/Rejected
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE, 196.77
# 2019-04-15, Order Canceled/Margin/Rejected
# 2019-04-15, Close, 197.12
# 2019-04-15, BUY CREATE, 197.12
# 2019-04-16, Order Canceled/Margin/Rejected
# 2019-04-16, Close, 197.14
# 2019-04-16, BUY CREATE, 197.14
# 2019-04-17, Order Canceled/Margin/Rejected
# 2019-04-17, Close, 200.98
# 2019-04-17, BUY CREATE, 200.98
# 2019-04-18, Order Canceled/Margin/Rejected
# 2019-04-18, Close, 201.70
# 2019-04-18, BUY CREATE, 201.70
# 2019-04-22, Order Canceled/Margin/Rejected
# 2019-04-22, Close, 202.37
# 2019-04-22, BUY CREATE, 202.37
# 2019-04-23, Order Canceled/Margin/Rejected
# 2019-04-23, Close, 205.29
# 2019-04-23, BUY CREATE, 205.29
# 2019-04-24, Order Canceled/Margin/Rejected
# 2019-04-24, Close, 204.97
# 2019-04-24, BUY CREATE, 204.97
# 2019-04-25, Order Canceled/Margin/Rejected
# 2019-04-25, Close, 203.11
# 2019-04-25, BUY CREATE, 203.11
# 2019-04-26, Order Canceled/Margin/Rejected
# 2019-04-26, Close, 202.14
# 2019-04-26, BUY CREATE, 202.14
# 2019-04-29, Order Canceled/Margin/Rejected
# 2019-04-29, Close, 202.45
# 2019-04-29, BUY CREATE, 202.45
# 2019-04-30, Order Canceled/Margin/Rejected
# 2019-04-30, Close, 198.55
# 2019-05-01, Close, 208.29
# 2019-05-01, BUY CREATE, 208.29
# 2019-05-02, Order Canceled/Margin/Rejected
# 2019-05-02, Close, 206.94
# 2019-05-02, BUY CREATE, 206.94
# 2019-05-03, Order Canceled/Margin/Rejected
# 2019-05-03, Close, 209.51
# 2019-05-03, BUY CREATE, 209.51
# 2019-05-06, Order Canceled/Margin/Rejected
# 2019-05-06, Close, 206.27
# 2019-05-06, BUY CREATE, 206.27
# 2019-05-07, Order Canceled/Margin/Rejected
# 2019-05-07, Close, 200.71
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-10, Close, 195.85
# 2019-05-13, Close, 184.46
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-20, Close, 181.85
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-29, Close, 176.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-04, Close, 178.42
# 2019-06-05, Close, 181.30
# 2019-06-05, BUY CREATE, 181.30
# 2019-06-06, Order Canceled/Margin/Rejected
# 2019-06-06, Close, 183.97
# 2019-06-06, BUY CREATE, 183.97
# 2019-06-07, Order Canceled/Margin/Rejected
# 2019-06-07, Close, 188.86
# 2019-06-07, BUY CREATE, 188.86
# 2019-06-10, Order Canceled/Margin/Rejected
# 2019-06-10, Close, 191.28
# 2019-06-10, BUY CREATE, 191.28
# 2019-06-11, Order Canceled/Margin/Rejected
# 2019-06-11, Close, 193.49
# 2019-06-11, BUY CREATE, 193.49
# 2019-06-12, Order Canceled/Margin/Rejected
# 2019-06-12, Close, 192.88
# 2019-06-12, BUY CREATE, 192.88
# 2019-06-13, Order Canceled/Margin/Rejected
# 2019-06-13, Close, 192.84
# 2019-06-13, BUY CREATE, 192.84
# 2019-06-14, Order Canceled/Margin/Rejected
# 2019-06-14, Close, 191.44
# 2019-06-14, BUY CREATE, 191.44
# 2019-06-17, Order Canceled/Margin/Rejected
# 2019-06-17, Close, 192.58
# 2019-06-17, BUY CREATE, 192.58
# 2019-06-18, Order Canceled/Margin/Rejected
# 2019-06-18, Close, 197.11
# 2019-06-18, BUY CREATE, 197.11
# 2019-06-19, Order Canceled/Margin/Rejected
# 2019-06-19, Close, 196.53
# 2019-06-19, BUY CREATE, 196.53
# 2019-06-20, Order Canceled/Margin/Rejected
# 2019-06-20, Close, 198.11
# 2019-06-20, BUY CREATE, 198.11
# 2019-06-21, Order Canceled/Margin/Rejected
# 2019-06-21, Close, 197.43
# 2019-06-21, BUY CREATE, 197.43
# 2019-06-24, Order Canceled/Margin/Rejected
# 2019-06-24, Close, 197.24
# 2019-06-24, BUY CREATE, 197.24
# 2019-06-25, Order Canceled/Margin/Rejected
# 2019-06-25, Close, 194.25
# 2019-06-25, BUY CREATE, 194.25
# 2019-06-26, Order Canceled/Margin/Rejected
# 2019-06-26, Close, 198.45
# 2019-06-26, BUY CREATE, 198.45
# 2019-06-27, Order Canceled/Margin/Rejected
# 2019-06-27, Close, 198.39
# 2019-06-27, BUY CREATE, 198.39
# 2019-06-28, Order Canceled/Margin/Rejected
# 2019-06-28, Close, 196.58
# 2019-06-28, BUY CREATE, 196.58
# 2019-07-01, Order Canceled/Margin/Rejected
# 2019-07-01, Close, 200.19
# 2019-07-01, BUY CREATE, 200.19
# 2019-07-02, Order Canceled/Margin/Rejected
# 2019-07-02, Close, 201.36
# 2019-07-02, BUY CREATE, 201.36
# 2019-07-03, Order Canceled/Margin/Rejected
# 2019-07-03, Close, 203.03
# 2019-07-03, BUY CREATE, 203.03
# 2019-07-05, Order Canceled/Margin/Rejected
# 2019-07-05, Close, 202.85
# 2019-07-05, BUY CREATE, 202.85
# 2019-07-08, Order Canceled/Margin/Rejected
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE, 198.67
# 2019-07-09, Order Canceled/Margin/Rejected
# 2019-07-09, Close, 199.88
# 2019-07-09, BUY CREATE, 199.88
# 2019-07-10, Order Canceled/Margin/Rejected
# 2019-07-10, Close, 201.85
# 2019-07-10, BUY CREATE, 201.85
# 2019-07-11, Order Canceled/Margin/Rejected
# 2019-07-11, Close, 200.38
# 2019-07-11, BUY CREATE, 200.38
# 2019-07-12, Order Canceled/Margin/Rejected
# 2019-07-12, Close, 201.92
# 2019-07-12, BUY CREATE, 201.92
# 2019-07-15, Order Canceled/Margin/Rejected
# 2019-07-15, Close, 203.82
# 2019-07-15, BUY CREATE, 203.82
# 2019-07-16, Order Canceled/Margin/Rejected
# 2019-07-16, Close, 203.12
# 2019-07-16, BUY CREATE, 203.12
# 2019-07-17, Order Canceled/Margin/Rejected
# 2019-07-17, Close, 201.97
# 2019-07-17, BUY CREATE, 201.97
# 2019-07-18, Order Canceled/Margin/Rejected
# 2019-07-18, Close, 204.27
# 2019-07-18, BUY CREATE, 204.27
# 2019-07-19, Order Canceled/Margin/Rejected
# 2019-07-19, Close, 201.22
# 2019-07-22, Close, 205.82
# 2019-07-22, BUY CREATE, 205.82
# 2019-07-23, Order Canceled/Margin/Rejected
# 2019-07-23, Close, 207.43
# 2019-07-23, BUY CREATE, 207.43
# 2019-07-24, Order Canceled/Margin/Rejected
# 2019-07-24, Close, 207.26
# 2019-07-24, BUY CREATE, 207.26
# 2019-07-25, Order Canceled/Margin/Rejected
# 2019-07-25, Close, 205.62
# 2019-07-25, BUY CREATE, 205.62
# 2019-07-26, Order Canceled/Margin/Rejected
# 2019-07-26, Close, 206.33
# 2019-07-26, BUY CREATE, 206.33
# 2019-07-29, Order Canceled/Margin/Rejected
# 2019-07-29, Close, 208.26
# 2019-07-29, BUY CREATE, 208.26
# 2019-07-30, Order Canceled/Margin/Rejected
# 2019-07-30, Close, 207.37
# 2019-07-30, BUY CREATE, 207.37
# 2019-07-31, Order Canceled/Margin/Rejected
# 2019-07-31, Close, 211.60
# 2019-07-31, BUY CREATE, 211.60
# 2019-08-01, Order Canceled/Margin/Rejected
# 2019-08-01, Close, 207.02
# 2019-08-01, BUY CREATE, 207.02
# 2019-08-02, Order Canceled/Margin/Rejected
# 2019-08-02, Close, 202.64
# 2019-08-05, Close, 192.03
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-13, Close, 208.34
# 2019-08-13, BUY CREATE, 208.34
# 2019-08-14, Order Canceled/Margin/Rejected
# 2019-08-14, Close, 202.14
# 2019-08-15, Close, 201.14
# 2019-08-16, Close, 205.88
# 2019-08-16, BUY CREATE, 205.88
# 2019-08-19, Order Canceled/Margin/Rejected
# 2019-08-19, Close, 209.72
# 2019-08-19, BUY CREATE, 209.72
# 2019-08-20, Order Canceled/Margin/Rejected
# 2019-08-20, Close, 209.73
# 2019-08-20, BUY CREATE, 209.73
# 2019-08-21, Order Canceled/Margin/Rejected
# 2019-08-21, Close, 212.00
# 2019-08-21, BUY CREATE, 212.00
# 2019-08-22, Order Canceled/Margin/Rejected
# 2019-08-22, Close, 211.82
# 2019-08-22, BUY CREATE, 211.82
# 2019-08-23, Order Canceled/Margin/Rejected
# 2019-08-23, Close, 202.03
# 2019-08-26, Close, 205.87
# 2019-08-26, BUY CREATE, 205.87
# 2019-08-27, Order Canceled/Margin/Rejected
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-29, BUY CREATE, 208.38
# 2019-08-30, Order Canceled/Margin/Rejected
# 2019-08-30, Close, 208.12
# 2019-08-30, BUY CREATE, 208.12
# 2019-09-03, Order Canceled/Margin/Rejected
# 2019-09-03, Close, 205.08
# 2019-09-04, Close, 208.56
# 2019-09-04, BUY CREATE, 208.56
# 2019-09-05, Order Canceled/Margin/Rejected
# 2019-09-05, Close, 212.64
# 2019-09-05, BUY CREATE, 212.64
# 2019-09-06, Order Canceled/Margin/Rejected
# 2019-09-06, Close, 212.62
# 2019-09-06, BUY CREATE, 212.62
# 2019-09-09, Order Canceled/Margin/Rejected
# 2019-09-09, Close, 213.53
# 2019-09-09, BUY CREATE, 213.53
# 2019-09-10, Order Canceled/Margin/Rejected
# 2019-09-10, Close, 216.05
# 2019-09-10, BUY CREATE, 216.05
# 2019-09-11, Order Canceled/Margin/Rejected
# 2019-09-11, Close, 222.92
# 2019-09-11, BUY CREATE, 222.92
# 2019-09-12, Order Canceled/Margin/Rejected
# 2019-09-12, Close, 222.42
# 2019-09-12, BUY CREATE, 222.42
# 2019-09-13, Order Canceled/Margin/Rejected
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE, 218.10
# 2019-09-16, Order Canceled/Margin/Rejected
# 2019-09-16, Close, 219.24
# 2019-09-16, BUY CREATE, 219.24
# 2019-09-17, Order Canceled/Margin/Rejected
# 2019-09-17, Close, 220.04
# 2019-09-17, BUY CREATE, 220.04
# 2019-09-18, Order Canceled/Margin/Rejected
# 2019-09-18, Close, 222.10
# 2019-09-18, BUY CREATE, 222.10
# 2019-09-19, Order Canceled/Margin/Rejected
# 2019-09-19, Close, 220.30
# 2019-09-19, BUY CREATE, 220.30
# 2019-09-20, Order Canceled/Margin/Rejected
# 2019-09-20, Close, 217.08
# 2019-09-20, BUY CREATE, 217.08
# 2019-09-23, Order Canceled/Margin/Rejected
# 2019-09-23, Close, 218.07
# 2019-09-23, BUY CREATE, 218.07
# 2019-09-24, Order Canceled/Margin/Rejected
# 2019-09-24, Close, 217.03
# 2019-09-25, Close, 220.37
# 2019-09-25, BUY CREATE, 220.37
# 2019-09-26, Order Canceled/Margin/Rejected
# 2019-09-26, Close, 219.23
# 2019-09-26, BUY CREATE, 219.23
# 2019-09-27, Order Canceled/Margin/Rejected
# 2019-09-27, Close, 218.17
# 2019-09-30, Close, 223.30
# 2019-09-30, BUY CREATE, 223.30
# 2019-10-01, Order Canceled/Margin/Rejected
# 2019-10-01, Close, 223.92
# 2019-10-01, BUY CREATE, 223.92
# 2019-10-02, Order Canceled/Margin/Rejected
# 2019-10-02, Close, 218.30
# 2019-10-03, Close, 220.16
# 2019-10-03, BUY CREATE, 220.16
# 2019-10-04, Order Canceled/Margin/Rejected
# 2019-10-04, Close, 226.33
# 2019-10-04, BUY CREATE, 226.33
# 2019-10-07, Order Canceled/Margin/Rejected
# 2019-10-07, Close, 226.38
# 2019-10-07, BUY CREATE, 226.38
# 2019-10-08, Order Canceled/Margin/Rejected
# 2019-10-08, Close, 223.73
# 2019-10-08, BUY CREATE, 223.73
# 2019-10-09, Order Canceled/Margin/Rejected
# 2019-10-09, Close, 226.35
# 2019-10-09, BUY CREATE, 226.35
# 2019-10-10, Order Canceled/Margin/Rejected
# 2019-10-10, Close, 229.40
# 2019-10-10, BUY CREATE, 229.40
# 2019-10-11, Order Canceled/Margin/Rejected
# 2019-10-11, Close, 235.50
# 2019-10-11, BUY CREATE, 235.50
# 2019-10-14, Order Canceled/Margin/Rejected
# 2019-10-14, Close, 235.16
# 2019-10-14, BUY CREATE, 235.16
# 2019-10-15, Order Canceled/Margin/Rejected
# 2019-10-15, Close, 234.62
# 2019-10-15, BUY CREATE, 234.62
# 2019-10-16, Order Canceled/Margin/Rejected
# 2019-10-16, Close, 233.67
# 2019-10-16, BUY CREATE, 233.67
# 2019-10-17, Order Canceled/Margin/Rejected
# 2019-10-17, Close, 234.58
# 2019-10-17, BUY CREATE, 234.58
# 2019-10-18, Order Canceled/Margin/Rejected
# 2019-10-18, Close, 235.70
# 2019-10-18, BUY CREATE, 235.70
# 2019-10-21, Order Canceled/Margin/Rejected
# 2019-10-21, Close, 239.79
# 2019-10-21, BUY CREATE, 239.79
# 2019-10-22, Order Canceled/Margin/Rejected
# 2019-10-22, Close, 239.24
# 2019-10-22, BUY CREATE, 239.24
# 2019-10-23, Order Canceled/Margin/Rejected
# 2019-10-23, Close, 242.45
# 2019-10-23, BUY CREATE, 242.45
# 2019-10-24, Order Canceled/Margin/Rejected
# 2019-10-24, Close, 242.85
# 2019-10-24, BUY CREATE, 242.85
# 2019-10-25, Order Canceled/Margin/Rejected
# 2019-10-25, Close, 245.84
# 2019-10-25, BUY CREATE, 245.84
# 2019-10-28, Order Canceled/Margin/Rejected
# 2019-10-28, Close, 248.30
# 2019-10-28, BUY CREATE, 248.30
# 2019-10-29, Order Canceled/Margin/Rejected
# 2019-10-29, Close, 242.56
# 2019-10-29, BUY CREATE, 242.56
# 2019-10-30, Order Canceled/Margin/Rejected
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE, 242.53
# 2019-10-31, Order Canceled/Margin/Rejected
# 2019-10-31, Close, 248.02
# 2019-10-31, BUY CREATE, 248.02
# 2019-11-01, Order Canceled/Margin/Rejected
# 2019-11-01, Close, 255.05
# 2019-11-01, BUY CREATE, 255.05
# 2019-11-04, Order Canceled/Margin/Rejected
# 2019-11-04, Close, 256.73
# 2019-11-04, BUY CREATE, 256.73
# 2019-11-05, Order Canceled/Margin/Rejected
# 2019-11-05, Close, 256.36
# 2019-11-05, BUY CREATE, 256.36
# 2019-11-06, Order Canceled/Margin/Rejected
# 2019-11-06, Close, 256.47
# 2019-11-06, BUY CREATE, 256.47
# 2019-11-07, Order Canceled/Margin/Rejected
# 2019-11-07, Close, 259.43
# 2019-11-07, BUY CREATE, 259.43
# 2019-11-08, Order Canceled/Margin/Rejected
# 2019-11-08, Close, 260.14
# 2019-11-08, BUY CREATE, 260.14
# 2019-11-11, Order Canceled/Margin/Rejected
# 2019-11-11, Close, 262.20
# 2019-11-11, BUY CREATE, 262.20
# 2019-11-12, Order Canceled/Margin/Rejected
# 2019-11-12, Close, 261.96
# 2019-11-12, BUY CREATE, 261.96
# 2019-11-13, Order Canceled/Margin/Rejected
# 2019-11-13, Close, 264.47
# 2019-11-13, BUY CREATE, 264.47
# 2019-11-14, Order Canceled/Margin/Rejected
# 2019-11-14, Close, 262.64
# 2019-11-14, BUY CREATE, 262.64
# 2019-11-15, Order Canceled/Margin/Rejected
# 2019-11-15, Close, 265.76
# 2019-11-15, BUY CREATE, 265.76
# 2019-11-18, Order Canceled/Margin/Rejected
# 2019-11-18, Close, 267.10
# 2019-11-18, BUY CREATE, 267.10
# 2019-11-19, Order Canceled/Margin/Rejected
# 2019-11-19, Close, 266.29
# 2019-11-19, BUY CREATE, 266.29
# 2019-11-20, Order Canceled/Margin/Rejected
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE, 263.19
# 2019-11-21, Order Canceled/Margin/Rejected
# 2019-11-21, Close, 262.01
# 2019-11-21, BUY CREATE, 262.01
# 2019-11-22, Order Canceled/Margin/Rejected
# 2019-11-22, Close, 261.78
# 2019-11-22, BUY CREATE, 261.78
# 2019-11-25, Order Canceled/Margin/Rejected
# 2019-11-25, Close, 266.37
# 2019-11-25, BUY CREATE, 266.37
# 2019-11-26, Order Canceled/Margin/Rejected
# 2019-11-26, Close, 264.29
# 2019-11-26, BUY CREATE, 264.29
# 2019-11-27, Order Canceled/Margin/Rejected
# 2019-11-27, Close, 267.84
# 2019-11-27, BUY CREATE, 267.84
# 2019-11-29, Order Canceled/Margin/Rejected
# 2019-11-29, Close, 267.25
# 2019-11-29, BUY CREATE, 267.25
# 2019-12-02, Order Canceled/Margin/Rejected
# 2019-12-02, Close, 264.16
# 2019-12-03, Close, 259.45
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-05, BUY CREATE, 265.58
# 2019-12-06, Order Canceled/Margin/Rejected
# 2019-12-06, Close, 270.71
# 2019-12-06, BUY CREATE, 270.71
# 2019-12-09, Order Canceled/Margin/Rejected
# 2019-12-09, Close, 266.92
# 2019-12-09, BUY CREATE, 266.92
# 2019-12-10, Order Canceled/Margin/Rejected
# 2019-12-10, Close, 268.48
# 2019-12-10, BUY CREATE, 268.48
# 2019-12-11, Order Canceled/Margin/Rejected
# 2019-12-11, Close, 270.77
# 2019-12-11, BUY CREATE, 270.77
# 2019-12-12, Order Canceled/Margin/Rejected
# 2019-12-12, Close, 271.46
# 2019-12-12, BUY CREATE, 271.46
# 2019-12-13, Order Canceled/Margin/Rejected
# 2019-12-13, Close, 275.15
# 2019-12-13, BUY CREATE, 275.15
# 2019-12-16, Order Canceled/Margin/Rejected
# 2019-12-16, Close, 279.86
# 2019-12-16, BUY CREATE, 279.86
# 2019-12-17, Order Canceled/Margin/Rejected
# 2019-12-17, Close, 280.41
# 2019-12-17, BUY CREATE, 280.41
# 2019-12-18, Order Canceled/Margin/Rejected
# 2019-12-18, Close, 279.74
# 2019-12-18, BUY CREATE, 279.74
# 2019-12-19, Order Canceled/Margin/Rejected
# 2019-12-19, Close, 280.02
# 2019-12-19, BUY CREATE, 280.02
# 2019-12-20, Order Canceled/Margin/Rejected
# 2019-12-20, Close, 279.44
# 2019-12-20, BUY CREATE, 279.44
# 2019-12-23, Order Canceled/Margin/Rejected
# 2019-12-23, Close, 284.00
# 2019-12-23, BUY CREATE, 284.00
# 2019-12-24, Order Canceled/Margin/Rejected
# 2019-12-24, Close, 284.27
# 2019-12-24, BUY CREATE, 284.27
# 2019-12-26, Order Canceled/Margin/Rejected
# 2019-12-26, Close, 289.91
# 2019-12-26, BUY CREATE, 289.91
# 2019-12-27, Order Canceled/Margin/Rejected
# 2019-12-27, Close, 289.80
# 2019-12-27, BUY CREATE, 289.80
# 2019-12-30, Order Canceled/Margin/Rejected
# 2019-12-30, Close, 291.52
# 2019-12-30, BUY CREATE, 291.52
# 2019-12-31, Order Canceled/Margin/Rejected
# 2019-12-31, Close, 293.65
# 2019-12-31, BUY CREATE, 293.65
# 2020-01-02, Order Canceled/Margin/Rejected
# 2020-01-02, Close, 300.35
# 2020-01-02, BUY CREATE, 300.35
# 2020-01-03, Order Canceled/Margin/Rejected
# 2020-01-03, Close, 297.43
# 2020-01-03, BUY CREATE, 297.43
# 2020-01-06, Order Canceled/Margin/Rejected
# 2020-01-06, Close, 299.80
# 2020-01-06, BUY CREATE, 299.80
# 2020-01-07, Order Canceled/Margin/Rejected
# 2020-01-07, Close, 298.39
# 2020-01-07, BUY CREATE, 298.39
# 2020-01-08, Order Canceled/Margin/Rejected
# 2020-01-08, Close, 303.19
# 2020-01-08, BUY CREATE, 303.19
# 2020-01-09, Order Canceled/Margin/Rejected
# 2020-01-09, Close, 309.63
# 2020-01-09, BUY CREATE, 309.63
# Final Portfolio Value: 928.80
# <div id='6fb160be-fea7-47f8-8a20-1f2c58ac7c7c'></div>
# 0
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ## Let’s Optimize
#
# Many trading books say each market and each traded stock (or commodity or ..) have different rythms. That there is no such thing as a one size fits all.
#
# Before the plotting sample, when the strategy started using an indicator the period default value was 15 bars. It’s a strategy parameter and this can be used in an optimization to change the value of the parameter and see which one better fits the market.
#
# parameter optimizing 해주는 것. 오버피팅 되지 않도록 주의해야. test set에 너무 최적화되면 안된다.
#
# There is plenty of literature about Optimization and associated pros and cons. But the advice will always point in the same direction: do not overoptimize. If a trading idea is not sound, optimizing may end producing a positive result which is only valid for the backtested dataset.
#
# The sample is modified to optimize the period of the Simple Moving Average. For the sake of clarity any output with regards to Buy/Sell orders has been removed
#
# The example now:

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
        ('printlog', False),
    )

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function fot this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

    def stop(self):
        self.log('(MA Period %2d) Ending Value %.2f' %
                 (self.params.maperiod, self.broker.getvalue()), doprint=True)

# %% [markdown]
# Instead of calling addstrategy to add a stratey class to Cerebro, the call is made to optstrategy. And instead of passing a value a range of values is passed.
#
# One of the “Strategy” hooks is added, the stop method, which will be called when the data has been exhausted and backtesting is over. It’s used to print the final net value of the portfolio in the broker (it was done in Cerebro previously)
#
# The system will execute the strategy for each value of the range. The following will be output:

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.optstrategy( # 최적화 
        TestStrategy,
        maperiod=range(10, 31))

    datapath = os.path.join(os.getcwd(), './AAPL.csv')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2015, 1, 1),
        # Do not pass values after this date
        todate=datetime.datetime(2020, 1, 10),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Run over everything
    cerebro.run(maxcpus=1)
# Out:
# 2020-01-09, (MA Period 10) Ending Value 886.10
# 2020-01-09, (MA Period 11) Ending Value 941.10
# 2020-01-09, (MA Period 12) Ending Value 947.70
# 2020-01-09, (MA Period 13) Ending Value 937.30
# 2020-01-09, (MA Period 14) Ending Value 937.30
# 2020-01-09, (MA Period 15) Ending Value 928.80
# 2020-01-09, (MA Period 16) Ending Value 924.30
# 2020-01-09, (MA Period 17) Ending Value 1494.30
# 2020-01-09, (MA Period 18) Ending Value 2226.90
# 2020-01-09, (MA Period 19) Ending Value 3211.90
# 2020-01-09, (MA Period 20) Ending Value 3345.60
# 2020-01-09, (MA Period 21) Ending Value 3346.40
# 2020-01-09, (MA Period 22) Ending Value 3534.90
# 2020-01-09, (MA Period 23) Ending Value 3550.10
# 2020-01-09, (MA Period 24) Ending Value 3550.50
# 2020-01-09, (MA Period 25) Ending Value 2635.30
# 2020-01-09, (MA Period 26) Ending Value 2067.30
# 2020-01-09, (MA Period 27) Ending Value 2057.90
# 2020-01-09, (MA Period 28) Ending Value 3098.00
# 2020-01-09, (MA Period 29) Ending Value 2049.60
# 2020-01-09, (MA Period 30) Ending Value 2038.60

# %% [markdown]
# ## Conclusion
#
# The incremental samples have shown how to go from a barebones script to a fully working trading system which even plots the results and can be optimized.
#
# A lot more can be done to try to improve the chances of winning:
#
# Self defined Indicators
#
# Creating an indicator is easy (and even plotting them is easy)
#
# Sizers
#
# Money Management is for many the key to success
#
# Order Types (limit, stop, stoplimit)
#
# Some others
#
# To ensure all the above items can be fully utilized the documentation provides an insight into them (and other topics)
#
# Look in the table of contents and keep on reading … and developing.
#
# Best of luck
